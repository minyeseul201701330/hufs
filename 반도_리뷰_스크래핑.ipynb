# %% [markdown]
# <a href="https://colab.research.google.com/github/minyeseul201701330/hufs/blob/main/%EB%B0%98%EB%8F%84_%EB%A6%AC%EB%B7%B0_%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 161967 ## 기생충
total_count = 36754  ## 전체 크기=19,653

# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1884
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1885
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1886
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1887
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1888
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1889
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1890
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1891
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1892
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1893
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1894
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1895
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1896
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1897
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1898
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1899
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1900
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1901
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1902
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1903
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1904
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1905
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1906
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1907
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1908
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1909
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1910
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1911
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1912
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1913
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1914
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1915
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1916
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1917
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1918
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1919
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1920
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1921
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1922
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1923
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1924
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1925
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1926
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1927
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1928
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1929
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1930
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1931
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1932
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1933
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1934
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1935
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1936
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1937
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1938
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1939
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1940
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1941
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1942
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1943
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1944
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1945
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1946
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1947
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1948
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1949
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1950
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1951
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1952
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1953
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1954
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1955
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1956
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1957
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1958
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1959
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1960
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1961
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1962
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1963
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1964
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1965

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20201023150533" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20201023150533" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20201023150533" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20201023150533" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="107924"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>19,674</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408649, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>lmj7****</span>
# </a>
# </em>
# <em>2014.01.22 00:33</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lmj7****', '3cGndlGu/ht4BrFD1iNcD+3uRuTBGne6R+AFKA3Rogg=', '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! ', '8408649', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408649">4670</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408649">574</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																심은경의 매력을 느낄수잇는영화~~
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409921, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>gudr****</span>
# </a>
# </em>
# <em>2014.01.22 12:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gudr****', 'Th6dVBrzvWiUx+glWWkbLR2/xmW8N/3x0iJ91F04ZyQ=', '심은경의 매력을 느낄수잇는영화~~ ', '8409921', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409921">4157</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409921">377</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																마지막에 여자환호성 듣는영화 입니다 ㅋㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8414887, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>pak9****</span>
# </a>
# </em>
# <em>2014.01.23 09:49</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','pak9****', 'vMKkx6u2U24KWtwKT7Hgx1TLN/c1PiixVm5t6RmIPwk=', '마지막에 여자환호성 듣는영화 입니다 ㅋㅋ ', '8414887', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8414887">2919</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8414887">167</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																스토리는 2% 아쉬운감이 없지않아있는데, 배우들의 연기가 정말 좋습니다! 가족끼리 함께보기 좋은영화 :)
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8410149, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>enchanted(ench****)</span>
# </a>
# </em>
# <em>2014.01.22 13:08</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ench****', 'D/bKm65Iro/1mEGjvK5U9askMKD4OqNt+rQu8lM2GJk=', '스토리는 2% 아쉬운감이 없지않아있는데, 배우들의 연기가 정말 좋습니다! 가족끼리 함께보기 좋은영화 :) ', '8410149', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8410149">2929</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8410149">534</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																마지막 장면을 잊을 수 없다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8411606, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>복부처(ming****)</span>
# </a>
# </em>
# <em>2014.01.22 18:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ming****', 'QJJ+sik4OFdzDhxau23rM0yT6I9mvi4PYtOSYdSSG1c=', '마지막 장면을 잊을 수 없다 ', '8411606', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8411606">1599</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8411606">88</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																심은경을 위한 영화. 정말 심은경을 위해 만들어진 역할이라고 해야하나. 노래실력이며 개그감 넘치는 연기력 모두 최고였다. 무엇보다 최고는, 마지막 장면의 반전!!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8410187, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>thfx****</span>
# </a>
# </em>
# <em>2014.01.22 13:18</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','thfx****', 'LS05SctIqWA14ziNS069/gRP+bglldwGMMQ/9nFoyGs=', '심은경을 위한 영화. 정말 심은경을 위해 만들어진 역할이라고 해야하나. 노래실력이며 개그감 넘치는 연기력 모두 최고였다. 무엇보다 최고는, 마지막 장면의 반전!! ', '8410187', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8410187">1205</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8410187">88</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																심은경 최고. 왜 이렇게 웃기냐...연기 넘 잘 한다. 기분 좋은 영화!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409809, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>미도리(luna****)</span>
# </a>
# </em>
# <em>2014.01.22 11:24</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','luna****', 'yqn6E3Splwd9g+qg9fPL6VtQCPJusrJy0Il14eeEQ/A=', '심은경 최고. 왜 이렇게 웃기냐...연기 넘 잘 한다. 기분 좋은 영화! ', '8409809', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409809">994</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409809">75</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																평점8점대가뭐냐 9점이상짜리다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409952, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>wkdw****</span>
# </a>
# </em>
# <em>2014.01.22 12:14</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','wkdw****', 'xAu0nwVcpi48VAqTpTj/VNZI7oqzP3R0boV9WngnMus=', '평점8점대가뭐냐 9점이상짜리다 ', '8409952', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409952">1003</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409952">133</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																웃음과감동,두마리의토끼를다잡은가족영화
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409024, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>잘되는나(lh00****)</span>
# </a>
# </em>
# <em>2014.01.22 02:00</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lh00****', 'stueHIKT0+ti56DbQQNE7BgSmaIhY0lOCemnPP+2170=', '웃음과감동,두마리의토끼를다잡은가족영화 ', '8409024', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409024">821</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409024">113</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																정말 오랜만에 극장에서 육성으로 현실웃음 터졌었어요!!완전 꿀잼!!!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>아라리요(zzon****)</span>
# </a>
# </em>
# <em>2014.01.22 00:29</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','zzon****', 'W6Jl+l0NHKoFfFR+JvvBaHU4+mv8z4/QzQRqR0HHCvs=', '정말 오랜만에 극장에서 육성으로 현실웃음 터졌었어요!!완전 꿀잼!!! ', '8408627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408627">543</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408627">72</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=107924&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "107924",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=107924#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=107924#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("107924", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8408649, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>lmj7****</span>
# </a>
# </em>
# <em>2014.01.22 00:33</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','lmj7****', '3cGndlGu/ht4BrFD1iNcD+3uRuTBGne6R+AFKA3Rogg=', '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! ', '8408649', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8408649">4670</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8408649">574</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																심은경의 매력을 느낄수잇는영화~~
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8409921, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>gudr****</span>
# </a>
# </em>
# <em>2014.01.22 12:07</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gudr****', 'Th6dVBrzvWiUx+glWWkbLR2/xmW8N/3x0iJ91F04ZyQ=', '심은경의 매력을 느낄수잇는영화~~ ', '8409921', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_8409921">4157</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_8409921">377</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추! \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '첨엔 계속 웃다가 막판엔 울다 나왔네 ㅠㅠ 완전 강추!'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 점수
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('4670', '574')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# 'lmj7****'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2014, 1, 22, 0, 33)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 185917
total_count = 29846  ## 전체 크기=29846

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....
# 259 번째 페이지 parsing....
# 260 번째 페이지 parsing....
# 261 번째 페이지 parsing....
# 262 번째 페이지 parsing....
# 263 번째 페이지 parsing....
# 264 번째 페이지 parsing....
# 265 번째 페이지 parsing....
# 266 번째 페이지 parsing....
# 267 번째 페이지 parsing....
# 268 번째 페이지 parsing....
# 269 번째 페이지 parsing....
# 270 번째 페이지 parsing....
# 271 번째 페이지 parsing....
# 272 번째 페이지 parsing....
# 273 번째 페이지 parsing....
# 274 번째 페이지 parsing....
# 275 번째 페이지 parsing....
# 276 번째 페이지 parsing....
# 277 번째 페이지 parsing....
# 278 번째 페이지 parsing....
# 279 번째 페이지 parsing....
# 280 번째 페이지 parsing....
# 281 번째 페이지 parsing....
# 282 번째 페이지 parsing....
# 283 번째 페이지 parsing....
# 284 번째 페이지 parsing....
# 285 번째 페이지 parsing....
# 286 번째 페이지 parsing....
# 287 번째 페이지 parsing....
# 288 번째 페이지 parsing....
# 289 번째 페이지 parsing....
# 290 번째 페이지 parsing....
# 291 번째 페이지 parsing....
# 292 번째 페이지 parsing....
# 293 번째 페이지 parsing....
# 294 번째 페이지 parsing....
# 295 번째 페이지 parsing....
# 296 번째 페이지 parsing....
# 297 번째 페이지 parsing....
# 298 번째 페이지 parsing....
# 299 번째 페이지 parsing....
# 300 번째 페이지 parsing....
# 301 번째 페이지 parsing....
# 302 번째 페이지 parsing....
# 303 번째 페이지 parsing....
# 304 번째 페이지 parsing....
# 305 번째 페이지 parsing....
# 306 번째 페이지 parsing....
# 307 번째 페이지 parsing....
# 308 번째 페이지 parsing....
# 309 번째 페이지 parsing....
# 310 번째 페이지 parsing....
# 311 번째 페이지 parsing....
# 312 번째 페이지 parsing....
# 313 번째 페이지 parsing....
# 314 번째 페이지 parsing....
# 315 번째 페이지 parsing....
# 316 번째 페이지 parsing....
# 317 번째 페이지 parsing....
# 318 번째 페이지 parsing....
# 319 번째 페이지 parsing....
# 320 번째 페이지 parsing....
# 321 번째 페이지 parsing....
# 322 번째 페이지 parsing....
# 323 번째 페이지 parsing....
# 324 번째 페이지 parsing....
# 325 번째 페이지 parsing....
# 326 번째 페이지 parsing....
# 327 번째 페이지 parsing....
# 328 번째 페이지 parsing....
# 329 번째 페이지 parsing....
# 330 번째 페이지 parsing....
# 331 번째 페이지 parsing....
# 332 번째 페이지 parsing....
# 333 번째 페이지 parsing....
# 334 번째 페이지 parsing....
# 335 번째 페이지 parsing....
# 336 번째 페이지 parsing....
# 337 번째 페이지 parsing....
# 338 번째 페이지 parsing....
# 339 번째 페이지 parsing....
# 340 번째 페이지 parsing....
# 341 번째 페이지 parsing....
# 342 번째 페이지 parsing....
# 343 번째 페이지 parsing....
# 344 번째 페이지 parsing....
# 345 번째 페이지 parsing....
# 346 번째 페이지 parsing....
# 347 번째 페이지 parsing....
# 348 번째 페이지 parsing....
# 349 번째 페이지 parsing....
# 350 번째 페이지 parsing....
# 351 번째 페이지 parsing....
# 352 번째 페이지 parsing....
# 353 번째 페이지 parsing....
# 354 번째 페이지 parsing....
# 355 번째 페이지 parsing....
# 356 번째 페이지 parsing....
# 357 번째 페이지 parsing....
# 358 번째 페이지 parsing....
# 359 번째 페이지 parsing....
# 360 번째 페이지 parsing....
# 361 번째 페이지 parsing....
# 362 번째 페이지 parsing....
# 363 번째 페이지 parsing....
# 364 번째 페이지 parsing....
# 365 번째 페이지 parsing....
# 366 번째 페이지 parsing....
# 367 번째 페이지 parsing....
# 368 번째 페이지 parsing....
# 369 번째 페이지 parsing....
# 370 번째 페이지 parsing....
# 371 번째 페이지 parsing....
# 372 번째 페이지 parsing....
# 373 번째 페이지 parsing....
# 374 번째 페이지 parsing....
# 375 번째 페이지 parsing....
# 376 번째 페이지 parsing....
# 377 번째 페이지 parsing....
# 378 번째 페이지 parsing....
# 379 번째 페이지 parsing....
# 380 번째 페이지 parsing....
# 381 번째 페이지 parsing....
# 382 번째 페이지 parsing....
# 383 번째 페이지 parsing....
# 384 번째 페이지 parsing....
# 385 번째 페이지 parsing....
# 386 번째 페이지 parsing....
# 387 번째 페이지 parsing....
# 388 번째 페이지 parsing....
# 389 번째 페이지 parsing....
# 390 번째 페이지 parsing....
# 391 번째 페이지 parsing....
# 392 번째 페이지 parsing....
# 393 번째 페이지 parsing....
# 394 번째 페이지 parsing....
# 395 번째 페이지 parsing....
# 396 번째 페이지 parsing....
# 397 번째 페이지 parsing....
# 398 번째 페이지 parsing....
# 399 번째 페이지 parsing....
# 400 번째 페이지 parsing....
# 401 번째 페이지 parsing....
# 402 번째 페이지 parsing....
# 403 번째 페이지 parsing....
# 404 번째 페이지 parsing....
# 405 번째 페이지 parsing....
# 406 번째 페이지 parsing....
# 407 번째 페이지 parsing....
# 408 번째 페이지 parsing....
# 409 번째 페이지 parsing....
# 410 번째 페이지 parsing....
# 411 번째 페이지 parsing....
# 412 번째 페이지 parsing....
# 413 번째 페이지 parsing....
# 414 번째 페이지 parsing....
# 415 번째 페이지 parsing....
# 416 번째 페이지 parsing....
# 417 번째 페이지 parsing....
# 418 번째 페이지 parsing....
# 419 번째 페이지 parsing....
# 420 번째 페이지 parsing....
# 421 번째 페이지 parsing....
# 422 번째 페이지 parsing....
# 423 번째 페이지 parsing....
# 424 번째 페이지 parsing....
# 425 번째 페이지 parsing....
# 426 번째 페이지 parsing....
# 427 번째 페이지 parsing....
# 428 번째 페이지 parsing....
# 429 번째 페이지 parsing....
# 430 번째 페이지 parsing....
# 431 번째 페이지 parsing....
# 432 번째 페이지 parsing....
# 433 번째 페이지 parsing....
# 434 번째 페이지 parsing....
# 435 번째 페이지 parsing....
# 436 번째 페이지 parsing....
# 437 번째 페이지 parsing....
# 438 번째 페이지 parsing....
# 439 번째 페이지 parsing....
# 440 번째 페이지 parsing....
# 441 번째 페이지 parsing....
# 442 번째 페이지 parsing....
# 443 번째 페이지 parsing....
# 444 번째 페이지 parsing....
# 445 번째 페이지 parsing....
# 446 번째 페이지 parsing....
# 447 번째 페이지 parsing....
# 448 번째 페이지 parsing....
# 449 번째 페이지 parsing....
# 450 번째 페이지 parsing....
# 451 번째 페이지 parsing....
# 452 번째 페이지 parsing....
# 453 번째 페이지 parsing....
# 454 번째 페이지 parsing....
# 455 번째 페이지 parsing....
# 456 번째 페이지 parsing....
# 457 번째 페이지 parsing....
# 458 번째 페이지 parsing....
# 459 번째 페이지 parsing....
# 460 번째 페이지 parsing....
# 461 번째 페이지 parsing....
# 462 번째 페이지 parsing....
# 463 번째 페이지 parsing....
# 464 번째 페이지 parsing....
# 465 번째 페이지 parsing....
# 466 번째 페이지 parsing....
# 467 번째 페이지 parsing....
# 468 번째 페이지 parsing....
# 469 번째 페이지 parsing....
# 470 번째 페이지 parsing....
# 471 번째 페이지 parsing....
# 472 번째 페이지 parsing....
# 473 번째 페이지 parsing....
# 474 번째 페이지 parsing....
# 475 번째 페이지 parsing....
# 476 번째 페이지 parsing....
# 477 번째 페이지 parsing....
# 478 번째 페이지 parsing....
# 479 번째 페이지 parsing....
# 480 번째 페이지 parsing....
# 481 번째 페이지 parsing....
# 482 번째 페이지 parsing....
# 483 번째 페이지 parsing....
# 484 번째 페이지 parsing....
# 485 번째 페이지 parsing....
# 486 번째 페이지 parsing....
# 487 번째 페이지 parsing....
# 488 번째 페이지 parsing....
# 489 번째 페이지 parsing....
# 490 번째 페이지 parsing....
# 491 번째 페이지 parsing....
# 492 번째 페이지 parsing....
# 493 번째 페이지 parsing....
# 494 번째 페이지 parsing....
# 495 번째 페이지 parsing....
# 496 번째 페이지 parsing....
# 497 번째 페이지 parsing....
# 498 번째 페이지 parsing....
# 499 번째 페이지 parsing....
# 500 번째 페이지 parsing....
# 501 번째 페이지 parsing....
# 502 번째 페이지 parsing....
# 503 번째 페이지 parsing....
# 504 번째 페이지 parsing....
# 505 번째 페이지 parsing....
# 506 번째 페이지 parsing....
# 507 번째 페이지 parsing....
# 508 번째 페이지 parsing....
# 509 번째 페이지 parsing....
# 510 번째 페이지 parsing....
# 511 번째 페이지 parsing....
# 512 번째 페이지 parsing....
# 513 번째 페이지 parsing....
# 514 번째 페이지 parsing....
# 515 번째 페이지 parsing....
# 516 번째 페이지 parsing....
# 517 번째 페이지 parsing....
# 518 번째 페이지 parsing....
# 519 번째 페이지 parsing....
# 520 번째 페이지 parsing....
# 521 번째 페이지 parsing....
# 522 번째 페이지 parsing....
# 523 번째 페이지 parsing....
# 524 번째 페이지 parsing....
# 525 번째 페이지 parsing....
# 526 번째 페이지 parsing....
# 527 번째 페이지 parsing....
# 528 번째 페이지 parsing....
# 529 번째 페이지 parsing....
# 530 번째 페이지 parsing....
# 531 번째 페이지 parsing....
# 532 번째 페이지 parsing....
# 533 번째 페이지 parsing....
# 534 번째 페이지 parsing....
# 535 번째 페이지 parsing....
# 536 번째 페이지 parsing....
# 537 번째 페이지 parsing....
# 538 번째 페이지 parsing....
# 539 번째 페이지 parsing....
# 540 번째 페이지 parsing....
# 541 번째 페이지 parsing....
# 542 번째 페이지 parsing....
# 543 번째 페이지 parsing....
# 544 번째 페이지 parsing....
# 545 번째 페이지 parsing....
# 546 번째 페이지 parsing....
# 547 번째 페이지 parsing....
# 548 번째 페이지 parsing....
# 549 번째 페이지 parsing....
# 550 번째 페이지 parsing....
# 551 번째 페이지 parsing....
# 552 번째 페이지 parsing....
# 553 번째 페이지 parsing....
# 554 번째 페이지 parsing....
# 555 번째 페이지 parsing....
# 556 번째 페이지 parsing....
# 557 번째 페이지 parsing....
# 558 번째 페이지 parsing....
# 559 번째 페이지 parsing....
# 560 번째 페이지 parsing....
# 561 번째 페이지 parsing....
# 562 번째 페이지 parsing....
# 563 번째 페이지 parsing....
# 564 번째 페이지 parsing....
# 565 번째 페이지 parsing....
# 566 번째 페이지 parsing....
# 567 번째 페이지 parsing....
# 568 번째 페이지 parsing....
# 569 번째 페이지 parsing....
# 570 번째 페이지 parsing....
# 571 번째 페이지 parsing....
# 572 번째 페이지 parsing....
# 573 번째 페이지 parsing....
# 574 번째 페이지 parsing....
# 575 번째 페이지 parsing....
# 576 번째 페이지 parsing....
# 577 번째 페이지 parsing....
# 578 번째 페이지 parsing....
# 579 번째 페이지 parsing....
# 580 번째 페이지 parsing....
# 581 번째 페이지 parsing....
# 582 번째 페이지 parsing....
# 583 번째 페이지 parsing....
# 584 번째 페이지 parsing....
# 585 번째 페이지 parsing....
# 586 번째 페이지 parsing....
# 587 번째 페이지 parsing....
# 588 번째 페이지 parsing....
# 589 번째 페이지 parsing....
# 590 번째 페이지 parsing....
# 591 번째 페이지 parsing....
# 592 번째 페이지 parsing....
# 593 번째 페이지 parsing....
# 594 번째 페이지 parsing....
# 595 번째 페이지 parsing....
# 596 번째 페이지 parsing....
# 597 번째 페이지 parsing....
# 598 번째 페이지 parsing....
# 599 번째 페이지 parsing....
# 600 번째 페이지 parsing....
# 601 번째 페이지 parsing....
# 602 번째 페이지 parsing....
# 603 번째 페이지 parsing....
# 604 번째 페이지 parsing....
# 605 번째 페이지 parsing....
# 606 번째 페이지 parsing....
# 607 번째 페이지 parsing....
# 608 번째 페이지 parsing....
# 609 번째 페이지 parsing....
# 610 번째 페이지 parsing....
# 611 번째 페이지 parsing....
# 612 번째 페이지 parsing....
# 613 번째 페이지 parsing....
# 614 번째 페이지 parsing....
# 615 번째 페이지 parsing....
# 616 번째 페이지 parsing....
# 617 번째 페이지 parsing....
# 618 번째 페이지 parsing....
# 619 번째 페이지 parsing....
# 620 번째 페이지 parsing....
# 621 번째 페이지 parsing....
# 622 번째 페이지 parsing....
# 623 번째 페이지 parsing....
# 624 번째 페이지 parsing....
# 625 번째 페이지 parsing....
# 626 번째 페이지 parsing....
# 627 번째 페이지 parsing....
# 628 번째 페이지 parsing....
# 629 번째 페이지 parsing....
# 630 번째 페이지 parsing....
# 631 번째 페이지 parsing....
# 632 번째 페이지 parsing....
# 633 번째 페이지 parsing....
# 634 번째 페이지 parsing....
# 635 번째 페이지 parsing....
# 636 번째 페이지 parsing....
# 637 번째 페이지 parsing....
# 638 번째 페이지 parsing....
# 639 번째 페이지 parsing....
# 640 번째 페이지 parsing....
# 641 번째 페이지 parsing....
# 642 번째 페이지 parsing....
# 643 번째 페이지 parsing....
# 644 번째 페이지 parsing....
# 645 번째 페이지 parsing....
# 646 번째 페이지 parsing....
# 647 번째 페이지 parsing....
# 648 번째 페이지 parsing....
# 649 번째 페이지 parsing....
# 650 번째 페이지 parsing....
# 651 번째 페이지 parsing....
# 652 번째 페이지 parsing....
# 653 번째 페이지 parsing....
# 654 번째 페이지 parsing....
# 655 번째 페이지 parsing....
# 656 번째 페이지 parsing....
# 657 번째 페이지 parsing....
# 658 번째 페이지 parsing....
# 659 번째 페이지 parsing....
# 660 번째 페이지 parsing....
# 661 번째 페이지 parsing....
# 662 번째 페이지 parsing....
# 663 번째 페이지 parsing....
# 664 번째 페이지 parsing....
# 665 번째 페이지 parsing....
# 666 번째 페이지 parsing....
# 667 번째 페이지 parsing....
# 668 번째 페이지 parsing....
# 669 번째 페이지 parsing....
# 670 번째 페이지 parsing....
# 671 번째 페이지 parsing....
# 672 번째 페이지 parsing....
# 673 번째 페이지 parsing....
# 674 번째 페이지 parsing....
# 675 번째 페이지 parsing....
# 676 번째 페이지 parsing....
# 677 번째 페이지 parsing....
# 678 번째 페이지 parsing....
# 679 번째 페이지 parsing....
# 680 번째 페이지 parsing....
# 681 번째 페이지 parsing....
# 682 번째 페이지 parsing....
# 683 번째 페이지 parsing....
# 684 번째 페이지 parsing....
# 685 번째 페이지 parsing....
# 686 번째 페이지 parsing....
# 687 번째 페이지 parsing....
# 688 번째 페이지 parsing....
# 689 번째 페이지 parsing....
# 690 번째 페이지 parsing....
# 691 번째 페이지 parsing....
# 692 번째 페이지 parsing....
# 693 번째 페이지 parsing....
# 694 번째 페이지 parsing....
# 695 번째 페이지 parsing....
# 696 번째 페이지 parsing....
# 697 번째 페이지 parsing....
# 698 번째 페이지 parsing....
# 699 번째 페이지 parsing....
# 700 번째 페이지 parsing....
# 701 번째 페이지 parsing....
# 702 번째 페이지 parsing....
# 703 번째 페이지 parsing....
# 704 번째 페이지 parsing....
# 705 번째 페이지 parsing....
# 706 번째 페이지 parsing....
# 707 번째 페이지 parsing....
# 708 번째 페이지 parsing....
# 709 번째 페이지 parsing....
# 710 번째 페이지 parsing....
# 711 번째 페이지 parsing....
# 712 번째 페이지 parsing....
# 713 번째 페이지 parsing....
# 714 번째 페이지 parsing....
# 715 번째 페이지 parsing....
# 716 번째 페이지 parsing....
# 717 번째 페이지 parsing....
# 718 번째 페이지 parsing....
# 719 번째 페이지 parsing....
# 720 번째 페이지 parsing....
# 721 번째 페이지 parsing....
# 722 번째 페이지 parsing....
# 723 번째 페이지 parsing....
# 724 번째 페이지 parsing....
# 725 번째 페이지 parsing....
# 726 번째 페이지 parsing....
# 727 번째 페이지 parsing....
# 728 번째 페이지 parsing....
# 729 번째 페이지 parsing....
# 730 번째 페이지 parsing....
# 731 번째 페이지 parsing....
# 732 번째 페이지 parsing....
# 733 번째 페이지 parsing....
# 734 번째 페이지 parsing....
# 735 번째 페이지 parsing....
# 736 번째 페이지 parsing....
# 737 번째 페이지 parsing....
# 738 번째 페이지 parsing....
# 739 번째 페이지 parsing....
# 740 번째 페이지 parsing....
# 741 번째 페이지 parsing....
# 742 번째 페이지 parsing....
# 743 번째 페이지 parsing....
# 744 번째 페이지 parsing....
# 745 번째 페이지 parsing....
# 746 번째 페이지 parsing....
# 747 번째 페이지 parsing....
# 748 번째 페이지 parsing....
# 749 번째 페이지 parsing....
# 750 번째 페이지 parsing....
# 751 번째 페이지 parsing....
# 752 번째 페이지 parsing....
# 753 번째 페이지 parsing....
# 754 번째 페이지 parsing....
# 755 번째 페이지 parsing....
# 756 번째 페이지 parsing....
# 757 번째 페이지 parsing....
# 758 번째 페이지 parsing....
# 759 번째 페이지 parsing....
# 760 번째 페이지 parsing....
# 761 번째 페이지 parsing....
# 762 번째 페이지 parsing....
# 763 번째 페이지 parsing....
# 764 번째 페이지 parsing....
# 765 번째 페이지 parsing....
# 766 번째 페이지 parsing....
# 767 번째 페이지 parsing....
# 768 번째 페이지 parsing....
# 769 번째 페이지 parsing....
# 770 번째 페이지 parsing....
# 771 번째 페이지 parsing....
# 772 번째 페이지 parsing....
# 773 번째 페이지 parsing....
# 774 번째 페이지 parsing....
# 775 번째 페이지 parsing....
# 776 번째 페이지 parsing....
# 777 번째 페이지 parsing....
# 778 번째 페이지 parsing....
# 779 번째 페이지 parsing....
# 780 번째 페이지 parsing....
# 781 번째 페이지 parsing....
# 782 번째 페이지 parsing....
# 783 번째 페이지 parsing....
# 784 번째 페이지 parsing....
# 785 번째 페이지 parsing....
# 786 번째 페이지 parsing....
# 787 번째 페이지 parsing....
# 788 번째 페이지 parsing....
# 789 번째 페이지 parsing....
# 790 번째 페이지 parsing....
# 791 번째 페이지 parsing....
# 792 번째 페이지 parsing....
# 793 번째 페이지 parsing....
# 794 번째 페이지 parsing....
# 795 번째 페이지 parsing....
# 796 번째 페이지 parsing....
# 797 번째 페이지 parsing....
# 798 번째 페이지 parsing....
# 799 번째 페이지 parsing....
# 800 번째 페이지 parsing....
# 801 번째 페이지 parsing....
# 802 번째 페이지 parsing....
# 803 번째 페이지 parsing....
# 804 번째 페이지 parsing....
# 805 번째 페이지 parsing....
# 806 번째 페이지 parsing....
# 807 번째 페이지 parsing....
# 808 번째 페이지 parsing....
# 809 번째 페이지 parsing....
# 810 번째 페이지 parsing....
# 811 번째 페이지 parsing....
# 812 번째 페이지 parsing....
# 813 번째 페이지 parsing....
# 814 번째 페이지 parsing....
# 815 번째 페이지 parsing....
# 816 번째 페이지 parsing....
# 817 번째 페이지 parsing....
# 818 번째 페이지 parsing....
# 819 번째 페이지 parsing....
# 820 번째 페이지 parsing....
# 821 번째 페이지 parsing....
# 822 번째 페이지 parsing....
# 823 번째 페이지 parsing....
# 824 번째 페이지 parsing....
# 825 번째 페이지 parsing....
# 826 번째 페이지 parsing....
# 827 번째 페이지 parsing....
# 828 번째 페이지 parsing....
# 829 번째 페이지 parsing....
# 830 번째 페이지 parsing....
# 831 번째 페이지 parsing....
# 832 번째 페이지 parsing....
# 833 번째 페이지 parsing....
# 834 번째 페이지 parsing....
# 835 번째 페이지 parsing....
# 836 번째 페이지 parsing....
# 837 번째 페이지 parsing....
# 838 번째 페이지 parsing....
# 839 번째 페이지 parsing....
# 840 번째 페이지 parsing....
# 841 번째 페이지 parsing....
# 842 번째 페이지 parsing....
# 843 번째 페이지 parsing....
# 844 번째 페이지 parsing....
# 845 번째 페이지 parsing....
# 846 번째 페이지 parsing....
# 847 번째 페이지 parsing....
# 848 번째 페이지 parsing....
# 849 번째 페이지 parsing....
# 850 번째 페이지 parsing....
# 851 번째 페이지 parsing....
# 852 번째 페이지 parsing....
# 853 번째 페이지 parsing....
# 854 번째 페이지 parsing....
# 855 번째 페이지 parsing....
# 856 번째 페이지 parsing....
# 857 번째 페이지 parsing....
# 858 번째 페이지 parsing....
# 859 번째 페이지 parsing....
# 860 번째 페이지 parsing....
# 861 번째 페이지 parsing....
# 862 번째 페이지 parsing....
# 863 번째 페이지 parsing....
# 864 번째 페이지 parsing....
# 865 번째 페이지 parsing....
# 866 번째 페이지 parsing....
# 867 번째 페이지 parsing....
# 868 번째 페이지 parsing....
# 869 번째 페이지 parsing....
# 870 번째 페이지 parsing....
# 871 번째 페이지 parsing....
# 872 번째 페이지 parsing....
# 873 번째 페이지 parsing....
# 874 번째 페이지 parsing....
# 875 번째 페이지 parsing....
# 876 번째 페이지 parsing....
# 877 번째 페이지 parsing....
# 878 번째 페이지 parsing....
# 879 번째 페이지 parsing....
# 880 번째 페이지 parsing....
# 881 번째 페이지 parsing....
# 882 번째 페이지 parsing....
# 883 번째 페이지 parsing....
# 884 번째 페이지 parsing....
# 885 번째 페이지 parsing....
# 886 번째 페이지 parsing....
# 887 번째 페이지 parsing....
# 888 번째 페이지 parsing....
# 889 번째 페이지 parsing....
# 890 번째 페이지 parsing....
# 891 번째 페이지 parsing....
# 892 번째 페이지 parsing....
# 893 번째 페이지 parsing....
# 894 번째 페이지 parsing....
# 895 번째 페이지 parsing....
# 896 번째 페이지 parsing....
# 897 번째 페이지 parsing....
# 898 번째 페이지 parsing....
# 899 번째 페이지 parsing....
# 900 번째 페이지 parsing....
# 901 번째 페이지 parsing....
# 902 번째 페이지 parsing....
# 903 번째 페이지 parsing....
# 904 번째 페이지 parsing....
# 905 번째 페이지 parsing....
# 906 번째 페이지 parsing....
# 907 번째 페이지 parsing....
# 908 번째 페이지 parsing....
# 909 번째 페이지 parsing....
# 910 번째 페이지 parsing....
# 911 번째 페이지 parsing....
# 912 번째 페이지 parsing....
# 913 번째 페이지 parsing....
# 914 번째 페이지 parsing....
# 915 번째 페이지 parsing....
# 916 번째 페이지 parsing....
# 917 번째 페이지 parsing....
# 918 번째 페이지 parsing....
# 919 번째 페이지 parsing....
# 920 번째 페이지 parsing....
# 921 번째 페이지 parsing....
# 922 번째 페이지 parsing....
# 923 번째 페이지 parsing....
# 924 번째 페이지 parsing....
# 925 번째 페이지 parsing....
# 926 번째 페이지 parsing....
# 927 번째 페이지 parsing....
# 928 번째 페이지 parsing....
# 929 번째 페이지 parsing....
# 930 번째 페이지 parsing....
# 931 번째 페이지 parsing....
# 932 번째 페이지 parsing....
# 933 번째 페이지 parsing....
# 934 번째 페이지 parsing....
# 935 번째 페이지 parsing....
# 936 번째 페이지 parsing....
# 937 번째 페이지 parsing....
# 938 번째 페이지 parsing....
# 939 번째 페이지 parsing....
# 940 번째 페이지 parsing....
# 941 번째 페이지 parsing....
# 942 번째 페이지 parsing....
# 943 번째 페이지 parsing....
# 944 번째 페이지 parsing....
# 945 번째 페이지 parsing....
# 946 번째 페이지 parsing....
# 947 번째 페이지 parsing....
# 948 번째 페이지 parsing....
# 949 번째 페이지 parsing....
# 950 번째 페이지 parsing....
# 951 번째 페이지 parsing....
# 952 번째 페이지 parsing....
# 953 번째 페이지 parsing....
# 954 번째 페이지 parsing....
# 955 번째 페이지 parsing....
# 956 번째 페이지 parsing....
# 957 번째 페이지 parsing....
# 958 번째 페이지 parsing....
# 959 번째 페이지 parsing....
# 960 번째 페이지 parsing....
# 961 번째 페이지 parsing....
# 962 번째 페이지 parsing....
# 963 번째 페이지 parsing....
# 964 번째 페이지 parsing....
# 965 번째 페이지 parsing....
# 966 번째 페이지 parsing....
# 967 번째 페이지 parsing....
# 968 번째 페이지 parsing....
# 969 번째 페이지 parsing....
# 970 번째 페이지 parsing....
# 971 번째 페이지 parsing....
# 972 번째 페이지 parsing....
# 973 번째 페이지 parsing....
# 974 번째 페이지 parsing....
# 975 번째 페이지 parsing....
# 976 번째 페이지 parsing....
# 977 번째 페이지 parsing....
# 978 번째 페이지 parsing....
# 979 번째 페이지 parsing....
# 980 번째 페이지 parsing....
# 981 번째 페이지 parsing....
# 982 번째 페이지 parsing....
# 983 번째 페이지 parsing....
# 984 번째 페이지 parsing....
# 985 번째 페이지 parsing....
# 986 번째 페이지 parsing....
# 987 번째 페이지 parsing....
# 988 번째 페이지 parsing....
# 989 번째 페이지 parsing....
# 990 번째 페이지 parsing....
# 991 번째 페이지 parsing....
# 992 번째 페이지 parsing....
# 993 번째 페이지 parsing....
# 994 번째 페이지 parsing....
# 995 번째 페이지 parsing....
# 996 번째 페이지 parsing....
# 997 번째 페이지 parsing....
# 998 번째 페이지 parsing....
# 999 번째 페이지 parsing....
# 1000 번째 페이지 parsing....
# 1001 번째 페이지 parsing....
# 1002 번째 페이지 parsing....
# 1003 번째 페이지 parsing....
# 1004 번째 페이지 parsing....
# 1005 번째 페이지 parsing....
# 1006 번째 페이지 parsing....
# 1007 번째 페이지 parsing....
# 1008 번째 페이지 parsing....
# 1009 번째 페이지 parsing....
# 1010 번째 페이지 parsing....
# 1011 번째 페이지 parsing....
# 1012 번째 페이지 parsing....
# 1013 번째 페이지 parsing....
# 1014 번째 페이지 parsing....
# 1015 번째 페이지 parsing....
# 1016 번째 페이지 parsing....
# 1017 번째 페이지 parsing....
# 1018 번째 페이지 parsing....
# 1019 번째 페이지 parsing....
# 1020 번째 페이지 parsing....
# 1021 번째 페이지 parsing....
# 1022 번째 페이지 parsing....
# 1023 번째 페이지 parsing....
# 1024 번째 페이지 parsing....
# 1025 번째 페이지 parsing....
# 1026 번째 페이지 parsing....
# 1027 번째 페이지 parsing....
# 1028 번째 페이지 parsing....
# 1029 번째 페이지 parsing....
# 1030 번째 페이지 parsing....
# 1031 번째 페이지 parsing....
# 1032 번째 페이지 parsing....
# 1033 번째 페이지 parsing....
# 1034 번째 페이지 parsing....
# 1035 번째 페이지 parsing....
# 1036 번째 페이지 parsing....
# 1037 번째 페이지 parsing....
# 1038 번째 페이지 parsing....
# 1039 번째 페이지 parsing....
# 1040 번째 페이지 parsing....
# 1041 번째 페이지 parsing....
# 1042 번째 페이지 parsing....
# 1043 번째 페이지 parsing....
# 1044 번째 페이지 parsing....
# 1045 번째 페이지 parsing....
# 1046 번째 페이지 parsing....
# 1047 번째 페이지 parsing....
# 1048 번째 페이지 parsing....
# 1049 번째 페이지 parsing....
# 1050 번째 페이지 parsing....
# 1051 번째 페이지 parsing....
# 1052 번째 페이지 parsing....
# 1053 번째 페이지 parsing....
# 1054 번째 페이지 parsing....
# 1055 번째 페이지 parsing....
# 1056 번째 페이지 parsing....
# 1057 번째 페이지 parsing....
# 1058 번째 페이지 parsing....
# 1059 번째 페이지 parsing....
# 1060 번째 페이지 parsing....
# 1061 번째 페이지 parsing....
# 1062 번째 페이지 parsing....
# 1063 번째 페이지 parsing....
# 1064 번째 페이지 parsing....
# 1065 번째 페이지 parsing....
# 1066 번째 페이지 parsing....
# 1067 번째 페이지 parsing....
# 1068 번째 페이지 parsing....
# 1069 번째 페이지 parsing....
# 1070 번째 페이지 parsing....
# 1071 번째 페이지 parsing....
# 1072 번째 페이지 parsing....
# 1073 번째 페이지 parsing....
# 1074 번째 페이지 parsing....
# 1075 번째 페이지 parsing....
# 1076 번째 페이지 parsing....
# 1077 번째 페이지 parsing....
# 1078 번째 페이지 parsing....
# 1079 번째 페이지 parsing....
# 1080 번째 페이지 parsing....
# 1081 번째 페이지 parsing....
# 1082 번째 페이지 parsing....
# 1083 번째 페이지 parsing....
# 1084 번째 페이지 parsing....
# 1085 번째 페이지 parsing....
# 1086 번째 페이지 parsing....
# 1087 번째 페이지 parsing....
# 1088 번째 페이지 parsing....
# 1089 번째 페이지 parsing....
# 1090 번째 페이지 parsing....
# 1091 번째 페이지 parsing....
# 1092 번째 페이지 parsing....
# 1093 번째 페이지 parsing....
# 1094 번째 페이지 parsing....
# 1095 번째 페이지 parsing....
# 1096 번째 페이지 parsing....
# 1097 번째 페이지 parsing....
# 1098 번째 페이지 parsing....
# 1099 번째 페이지 parsing....
# 1100 번째 페이지 parsing....
# 1101 번째 페이지 parsing....
# 1102 번째 페이지 parsing....
# 1103 번째 페이지 parsing....
# 1104 번째 페이지 parsing....
# 1105 번째 페이지 parsing....
# 1106 번째 페이지 parsing....
# 1107 번째 페이지 parsing....
# 1108 번째 페이지 parsing....
# 1109 번째 페이지 parsing....
# 1110 번째 페이지 parsing....
# 1111 번째 페이지 parsing....
# 1112 번째 페이지 parsing....
# 1113 번째 페이지 parsing....
# 1114 번째 페이지 parsing....
# 1115 번째 페이지 parsing....
# 1116 번째 페이지 parsing....
# 1117 번째 페이지 parsing....
# 1118 번째 페이지 parsing....
# 1119 번째 페이지 parsing....
# 1120 번째 페이지 parsing....
# 1121 번째 페이지 parsing....
# 1122 번째 페이지 parsing....
# 1123 번째 페이지 parsing....
# 1124 번째 페이지 parsing....
# 1125 번째 페이지 parsing....
# 1126 번째 페이지 parsing....
# 1127 번째 페이지 parsing....
# 1128 번째 페이지 parsing....
# 1129 번째 페이지 parsing....
# 1130 번째 페이지 parsing....
# 1131 번째 페이지 parsing....
# 1132 번째 페이지 parsing....
# 1133 번째 페이지 parsing....
# 1134 번째 페이지 parsing....
# 1135 번째 페이지 parsing....
# 1136 번째 페이지 parsing....
# 1137 번째 페이지 parsing....
# 1138 번째 페이지 parsing....
# 1139 번째 페이지 parsing....
# 1140 번째 페이지 parsing....
# 1141 번째 페이지 parsing....
# 1142 번째 페이지 parsing....
# 1143 번째 페이지 parsing....
# 1144 번째 페이지 parsing....
# 1145 번째 페이지 parsing....
# 1146 번째 페이지 parsing....
# 1147 번째 페이지 parsing....
# 1148 번째 페이지 parsing....
# 1149 번째 페이지 parsing....
# 1150 번째 페이지 parsing....
# 1151 번째 페이지 parsing....
# 1152 번째 페이지 parsing....
# 1153 번째 페이지 parsing....
# 1154 번째 페이지 parsing....
# 1155 번째 페이지 parsing....
# 1156 번째 페이지 parsing....
# 1157 번째 페이지 parsing....
# 1158 번째 페이지 parsing....
# 1159 번째 페이지 parsing....
# 1160 번째 페이지 parsing....
# 1161 번째 페이지 parsing....
# 1162 번째 페이지 parsing....
# 1163 번째 페이지 parsing....
# 1164 번째 페이지 parsing....
# 1165 번째 페이지 parsing....
# 1166 번째 페이지 parsing....
# 1167 번째 페이지 parsing....
# 1168 번째 페이지 parsing....
# 1169 번째 페이지 parsing....
# 1170 번째 페이지 parsing....
# 1171 번째 페이지 parsing....
# 1172 번째 페이지 parsing....
# 1173 번째 페이지 parsing....
# 1174 번째 페이지 parsing....
# 1175 번째 페이지 parsing....
# 1176 번째 페이지 parsing....
# 1177 번째 페이지 parsing....
# 1178 번째 페이지 parsing....
# 1179 번째 페이지 parsing....
# 1180 번째 페이지 parsing....
# 1181 번째 페이지 parsing....
# 1182 번째 페이지 parsing....
# 1183 번째 페이지 parsing....
# 1184 번째 페이지 parsing....
# 1185 번째 페이지 parsing....
# 1186 번째 페이지 parsing....
# 1187 번째 페이지 parsing....
# 1188 번째 페이지 parsing....
# 1189 번째 페이지 parsing....
# 1190 번째 페이지 parsing....
# 1191 번째 페이지 parsing....
# 1192 번째 페이지 parsing....
# 1193 번째 페이지 parsing....
# 1194 번째 페이지 parsing....
# 1195 번째 페이지 parsing....
# 1196 번째 페이지 parsing....
# 1197 번째 페이지 parsing....
# 1198 번째 페이지 parsing....
# 1199 번째 페이지 parsing....
# 1200 번째 페이지 parsing....
# 1201 번째 페이지 parsing....
# 1202 번째 페이지 parsing....
# 1203 번째 페이지 parsing....
# 1204 번째 페이지 parsing....
# 1205 번째 페이지 parsing....
# 1206 번째 페이지 parsing....
# 1207 번째 페이지 parsing....
# 1208 번째 페이지 parsing....
# 1209 번째 페이지 parsing....
# 1210 번째 페이지 parsing....
# 1211 번째 페이지 parsing....
# 1212 번째 페이지 parsing....
# 1213 번째 페이지 parsing....
# 1214 번째 페이지 parsing....
# 1215 번째 페이지 parsing....
# 1216 번째 페이지 parsing....
# 1217 번째 페이지 parsing....
# 1218 번째 페이지 parsing....
# 1219 번째 페이지 parsing....
# 1220 번째 페이지 parsing....
# 1221 번째 페이지 parsing....
# 1222 번째 페이지 parsing....
# 1223 번째 페이지 parsing....
# 1224 번째 페이지 parsing....
# 1225 번째 페이지 parsing....
# 1226 번째 페이지 parsing....
# 1227 번째 페이지 parsing....
# 1228 번째 페이지 parsing....
# 1229 번째 페이지 parsing....
# 1230 번째 페이지 parsing....
# 1231 번째 페이지 parsing....
# 1232 번째 페이지 parsing....
# 1233 번째 페이지 parsing....
# 1234 번째 페이지 parsing....
# 1235 번째 페이지 parsing....
# 1236 번째 페이지 parsing....
# 1237 번째 페이지 parsing....
# 1238 번째 페이지 parsing....
# 1239 번째 페이지 parsing....
# 1240 번째 페이지 parsing....
# 1241 번째 페이지 parsing....
# 1242 번째 페이지 parsing....
# 1243 번째 페이지 parsing....
# 1244 번째 페이지 parsing....
# 1245 번째 페이지 parsing....
# 1246 번째 페이지 parsing....
# 1247 번째 페이지 parsing....
# 1248 번째 페이지 parsing....
# 1249 번째 페이지 parsing....
# 1250 번째 페이지 parsing....
# 1251 번째 페이지 parsing....
# 1252 번째 페이지 parsing....
# 1253 번째 페이지 parsing....
# 1254 번째 페이지 parsing....
# 1255 번째 페이지 parsing....
# 1256 번째 페이지 parsing....
# 1257 번째 페이지 parsing....
# 1258 번째 페이지 parsing....
# 1259 번째 페이지 parsing....
# 1260 번째 페이지 parsing....
# 1261 번째 페이지 parsing....
# 1262 번째 페이지 parsing....
# 1263 번째 페이지 parsing....
# 1264 번째 페이지 parsing....
# 1265 번째 페이지 parsing....
# 1266 번째 페이지 parsing....
# 1267 번째 페이지 parsing....
# 1268 번째 페이지 parsing....
# 1269 번째 페이지 parsing....
# 1270 번째 페이지 parsing....
# 1271 번째 페이지 parsing....
# 1272 번째 페이지 parsing....
# 1273 번째 페이지 parsing....
# 1274 번째 페이지 parsing....
# 1275 번째 페이지 parsing....
# 1276 번째 페이지 parsing....
# 1277 번째 페이지 parsing....
# 1278 번째 페이지 parsing....
# 1279 번째 페이지 parsing....
# 1280 번째 페이지 parsing....
# 1281 번째 페이지 parsing....
# 1282 번째 페이지 parsing....
# 1283 번째 페이지 parsing....
# 1284 번째 페이지 parsing....
# 1285 번째 페이지 parsing....
# 1286 번째 페이지 parsing....
# 1287 번째 페이지 parsing....
# 1288 번째 페이지 parsing....
# 1289 번째 페이지 parsing....
# 1290 번째 페이지 parsing....
# 1291 번째 페이지 parsing....
# 1292 번째 페이지 parsing....
# 1293 번째 페이지 parsing....
# 1294 번째 페이지 parsing....
# 1295 번째 페이지 parsing....
# 1296 번째 페이지 parsing....
# 1297 번째 페이지 parsing....
# 1298 번째 페이지 parsing....
# 1299 번째 페이지 parsing....
# 1300 번째 페이지 parsing....
# 1301 번째 페이지 parsing....
# 1302 번째 페이지 parsing....
# 1303 번째 페이지 parsing....
# 1304 번째 페이지 parsing....
# 1305 번째 페이지 parsing....
# 1306 번째 페이지 parsing....
# 1307 번째 페이지 parsing....
# 1308 번째 페이지 parsing....
# 1309 번째 페이지 parsing....
# 1310 번째 페이지 parsing....
# 1311 번째 페이지 parsing....
# 1312 번째 페이지 parsing....
# 1313 번째 페이지 parsing....
# 1314 번째 페이지 parsing....
# 1315 번째 페이지 parsing....
# 1316 번째 페이지 parsing....
# 1317 번째 페이지 parsing....
# 1318 번째 페이지 parsing....
# 1319 번째 페이지 parsing....
# 1320 번째 페이지 parsing....
# 1321 번째 페이지 parsing....
# 1322 번째 페이지 parsing....
# 1323 번째 페이지 parsing....
# 1324 번째 페이지 parsing....
# 1325 번째 페이지 parsing....
# 1326 번째 페이지 parsing....
# 1327 번째 페이지 parsing....
# 1328 번째 페이지 parsing....
# 1329 번째 페이지 parsing....
# 1330 번째 페이지 parsing....
# 1331 번째 페이지 parsing....
# 1332 번째 페이지 parsing....
# 1333 번째 페이지 parsing....
# 1334 번째 페이지 parsing....
# 1335 번째 페이지 parsing....
# 1336 번째 페이지 parsing....
# 1337 번째 페이지 parsing....
# 1338 번째 페이지 parsing....
# 1339 번째 페이지 parsing....
# 1340 번째 페이지 parsing....
# 1341 번째 페이지 parsing....
# 1342 번째 페이지 parsing....
# 1343 번째 페이지 parsing....
# 1344 번째 페이지 parsing....
# 1345 번째 페이지 parsing....
# 1346 번째 페이지 parsing....
# 1347 번째 페이지 parsing....
# 1348 번째 페이지 parsing....
# 1349 번째 페이지 parsing....
# 1350 번째 페이지 parsing....
# 1351 번째 페이지 parsing....
# 1352 번째 페이지 parsing....
# 1353 번째 페이지 parsing....
# 1354 번째 페이지 parsing....
# 1355 번째 페이지 parsing....
# 1356 번째 페이지 parsing....
# 1357 번째 페이지 parsing....
# 1358 번째 페이지 parsing....
# 1359 번째 페이지 parsing....
# 1360 번째 페이지 parsing....
# 1361 번째 페이지 parsing....
# 1362 번째 페이지 parsing....
# 1363 번째 페이지 parsing....
# 1364 번째 페이지 parsing....
# 1365 번째 페이지 parsing....
# 1366 번째 페이지 parsing....
# 1367 번째 페이지 parsing....
# 1368 번째 페이지 parsing....
# 1369 번째 페이지 parsing....
# 1370 번째 페이지 parsing....
# 1371 번째 페이지 parsing....
# 1372 번째 페이지 parsing....
# 1373 번째 페이지 parsing....
# 1374 번째 페이지 parsing....
# 1375 번째 페이지 parsing....
# 1376 번째 페이지 parsing....
# 1377 번째 페이지 parsing....
# 1378 번째 페이지 parsing....
# 1379 번째 페이지 parsing....
# 1380 번째 페이지 parsing....
# 1381 번째 페이지 parsing....
# 1382 번째 페이지 parsing....
# 1383 번째 페이지 parsing....
# 1384 번째 페이지 parsing....
# 1385 번째 페이지 parsing....
# 1386 번째 페이지 parsing....
# 1387 번째 페이지 parsing....
# 1388 번째 페이지 parsing....
# 1389 번째 페이지 parsing....
# 1390 번째 페이지 parsing....
# 1391 번째 페이지 parsing....
# 1392 번째 페이지 parsing....
# 1393 번째 페이지 parsing....
# 1394 번째 페이지 parsing....
# 1395 번째 페이지 parsing....
# 1396 번째 페이지 parsing....
# 1397 번째 페이지 parsing....
# 1398 번째 페이지 parsing....
# 1399 번째 페이지 parsing....
# 1400 번째 페이지 parsing....
# 1401 번째 페이지 parsing....
# 1402 번째 페이지 parsing....
# 1403 번째 페이지 parsing....
# 1404 번째 페이지 parsing....
# 1405 번째 페이지 parsing....
# 1406 번째 페이지 parsing....
# 1407 번째 페이지 parsing....
# 1408 번째 페이지 parsing....
# 1409 번째 페이지 parsing....
# 1410 번째 페이지 parsing....
# 1411 번째 페이지 parsing....
# 1412 번째 페이지 parsing....
# 1413 번째 페이지 parsing....
# 1414 번째 페이지 parsing....
# 1415 번째 페이지 parsing....
# 1416 번째 페이지 parsing....
# 1417 번째 페이지 parsing....
# 1418 번째 페이지 parsing....
# 1419 번째 페이지 parsing....
# 1420 번째 페이지 parsing....
# 1421 번째 페이지 parsing....
# 1422 번째 페이지 parsing....
# 1423 번째 페이지 parsing....
# 1424 번째 페이지 parsing....
# 1425 번째 페이지 parsing....
# 1426 번째 페이지 parsing....
# 1427 번째 페이지 parsing....
# 1428 번째 페이지 parsing....
# 1429 번째 페이지 parsing....
# 1430 번째 페이지 parsing....
# 1431 번째 페이지 parsing....
# 1432 번째 페이지 parsing....
# 1433 번째 페이지 parsing....
# 1434 번째 페이지 parsing....
# 1435 번째 페이지 parsing....
# 1436 번째 페이지 parsing....
# 1437 번째 페이지 parsing....
# 1438 번째 페이지 parsing....
# 1439 번째 페이지 parsing....
# 1440 번째 페이지 parsing....
# 1441 번째 페이지 parsing....
# 1442 번째 페이지 parsing....
# 1443 번째 페이지 parsing....
# 1444 번째 페이지 parsing....
# 1445 번째 페이지 parsing....
# 1446 번째 페이지 parsing....
# 1447 번째 페이지 parsing....
# 1448 번째 페이지 parsing....
# 1449 번째 페이지 parsing....
# 1450 번째 페이지 parsing....
# 1451 번째 페이지 parsing....
# 1452 번째 페이지 parsing....
# 1453 번째 페이지 parsing....
# 1454 번째 페이지 parsing....
# 1455 번째 페이지 parsing....
# 1456 번째 페이지 parsing....
# 1457 번째 페이지 parsing....
# 1458 번째 페이지 parsing....
# 1459 번째 페이지 parsing....
# 1460 번째 페이지 parsing....
# 1461 번째 페이지 parsing....
# 1462 번째 페이지 parsing....
# 1463 번째 페이지 parsing....
# 1464 번째 페이지 parsing....
# 1465 번째 페이지 parsing....
# 1466 번째 페이지 parsing....
# 1467 번째 페이지 parsing....
# 1468 번째 페이지 parsing....
# 1469 번째 페이지 parsing....
# 1470 번째 페이지 parsing....
# 1471 번째 페이지 parsing....
# 1472 번째 페이지 parsing....
# 1473 번째 페이지 parsing....
# 1474 번째 페이지 parsing....
# 1475 번째 페이지 parsing....
# 1476 번째 페이지 parsing....
# 1477 번째 페이지 parsing....
# 1478 번째 페이지 parsing....
# 1479 번째 페이지 parsing....
# 1480 번째 페이지 parsing....
# 1481 번째 페이지 parsing....
# 1482 번째 페이지 parsing....
# 1483 번째 페이지 parsing....
# 1484 번째 페이지 parsing....
# 1485 번째 페이지 parsing....
# 1486 번째 페이지 parsing....
# 1487 번째 페이지 parsing....
# 1488 번째 페이지 parsing....
# 1489 번째 페이지 parsing....
# 1490 번째 페이지 parsing....
# 1491 번째 페이지 parsing....
# 1492 번째 페이지 parsing....
# 1493 번째 페이지 parsing....
# 1494 번째 페이지 parsing....
# 1495 번째 페이지 parsing....
# 1496 번째 페이지 parsing....
# 1497 번째 페이지 parsing....
# 1498 번째 페이지 parsing....
# 1499 번째 페이지 parsing....
# 1500 번째 페이지 parsing....
# 1501 번째 페이지 parsing....
# 1502 번째 페이지 parsing....
# 1503 번째 페이지 parsing....
# 1504 번째 페이지 parsing....
# 1505 번째 페이지 parsing....
# 1506 번째 페이지 parsing....
# 1507 번째 페이지 parsing....
# 1508 번째 페이지 parsing....
# 1509 번째 페이지 parsing....
# 1510 번째 페이지 parsing....
# 1511 번째 페이지 parsing....
# 1512 번째 페이지 parsing....
# 1513 번째 페이지 parsing....
# 1514 번째 페이지 parsing....
# 1515 번째 페이지 parsing....
# 1516 번째 페이지 parsing....
# 1517 번째 페이지 parsing....
# 1518 번째 페이지 parsing....
# 1519 번째 페이지 parsing....
# 1520 번째 페이지 parsing....
# 1521 번째 페이지 parsing....
# 1522 번째 페이지 parsing....
# 1523 번째 페이지 parsing....
# 1524 번째 페이지 parsing....
# 1525 번째 페이지 parsing....
# 1526 번째 페이지 parsing....
# 1527 번째 페이지 parsing....
# 1528 번째 페이지 parsing....
# 1529 번째 페이지 parsing....
# 1530 번째 페이지 parsing....
# 1531 번째 페이지 parsing....
# 1532 번째 페이지 parsing....
# 1533 번째 페이지 parsing....
# 1534 번째 페이지 parsing....
# 1535 번째 페이지 parsing....
# 1536 번째 페이지 parsing....
# 1537 번째 페이지 parsing....
# 1538 번째 페이지 parsing....
# 1539 번째 페이지 parsing....
# 1540 번째 페이지 parsing....
# 1541 번째 페이지 parsing....
# 1542 번째 페이지 parsing....
# 1543 번째 페이지 parsing....
# 1544 번째 페이지 parsing....
# 1545 번째 페이지 parsing....
# 1546 번째 페이지 parsing....
# 1547 번째 페이지 parsing....
# 1548 번째 페이지 parsing....
# 1549 번째 페이지 parsing....
# 1550 번째 페이지 parsing....
# 1551 번째 페이지 parsing....
# 1552 번째 페이지 parsing....
# 1553 번째 페이지 parsing....
# 1554 번째 페이지 parsing....
# 1555 번째 페이지 parsing....
# 1556 번째 페이지 parsing....
# 1557 번째 페이지 parsing....
# 1558 번째 페이지 parsing....
# 1559 번째 페이지 parsing....
# 1560 번째 페이지 parsing....
# 1561 번째 페이지 parsing....
# 1562 번째 페이지 parsing....
# 1563 번째 페이지 parsing....
# 1564 번째 페이지 parsing....
# 1565 번째 페이지 parsing....
# 1566 번째 페이지 parsing....
# 1567 번째 페이지 parsing....
# 1568 번째 페이지 parsing....
# 1569 번째 페이지 parsing....
# 1570 번째 페이지 parsing....
# 1571 번째 페이지 parsing....
# 1572 번째 페이지 parsing....
# 1573 번째 페이지 parsing....
# 1574 번째 페이지 parsing....
# 1575 번째 페이지 parsing....
# 1576 번째 페이지 parsing....
# 1577 번째 페이지 parsing....
# 1578 번째 페이지 parsing....
# 1579 번째 페이지 parsing....
# 1580 번째 페이지 parsing....
# 1581 번째 페이지 parsing....
# 1582 번째 페이지 parsing....
# 1583 번째 페이지 parsing....
# 1584 번째 페이지 parsing....
# 1585 번째 페이지 parsing....
# 1586 번째 페이지 parsing....
# 1587 번째 페이지 parsing....
# 1588 번째 페이지 parsing....
# 1589 번째 페이지 parsing....
# 1590 번째 페이지 parsing....
# 1591 번째 페이지 parsing....
# 1592 번째 페이지 parsing....
# 1593 번째 페이지 parsing....
# 1594 번째 페이지 parsing....
# 1595 번째 페이지 parsing....
# 1596 번째 페이지 parsing....
# 1597 번째 페이지 parsing....
# 1598 번째 페이지 parsing....
# 1599 번째 페이지 parsing....
# 1600 번째 페이지 parsing....
# 1601 번째 페이지 parsing....
# 1602 번째 페이지 parsing....
# 1603 번째 페이지 parsing....
# 1604 번째 페이지 parsing....
# 1605 번째 페이지 parsing....
# 1606 번째 페이지 parsing....
# 1607 번째 페이지 parsing....
# 1608 번째 페이지 parsing....
# 1609 번째 페이지 parsing....
# 1610 번째 페이지 parsing....
# 1611 번째 페이지 parsing....
# 1612 번째 페이지 parsing....
# 1613 번째 페이지 parsing....
# 1614 번째 페이지 parsing....
# 1615 번째 페이지 parsing....
# 1616 번째 페이지 parsing....
# 1617 번째 페이지 parsing....
# 1618 번째 페이지 parsing....
# 1619 번째 페이지 parsing....
# 1620 번째 페이지 parsing....
# 1621 번째 페이지 parsing....
# 1622 번째 페이지 parsing....
# 1623 번째 페이지 parsing....
# 1624 번째 페이지 parsing....
# 1625 번째 페이지 parsing....
# 1626 번째 페이지 parsing....
# 1627 번째 페이지 parsing....
# 1628 번째 페이지 parsing....
# 1629 번째 페이지 parsing....
# 1630 번째 페이지 parsing....
# 1631 번째 페이지 parsing....
# 1632 번째 페이지 parsing....
# 1633 번째 페이지 parsing....
# 1634 번째 페이지 parsing....
# 1635 번째 페이지 parsing....
# 1636 번째 페이지 parsing....
# 1637 번째 페이지 parsing....
# 1638 번째 페이지 parsing....
# 1639 번째 페이지 parsing....
# 1640 번째 페이지 parsing....
# 1641 번째 페이지 parsing....
# 1642 번째 페이지 parsing....
# 1643 번째 페이지 parsing....
# 1644 번째 페이지 parsing....
# 1645 번째 페이지 parsing....
# 1646 번째 페이지 parsing....
# 1647 번째 페이지 parsing....
# 1648 번째 페이지 parsing....
# 1649 번째 페이지 parsing....
# 1650 번째 페이지 parsing....
# 1651 번째 페이지 parsing....
# 1652 번째 페이지 parsing....
# 1653 번째 페이지 parsing....
# 1654 번째 페이지 parsing....
# 1655 번째 페이지 parsing....
# 1656 번째 페이지 parsing....
# 1657 번째 페이지 parsing....
# 1658 번째 페이지 parsing....
# 1659 번째 페이지 parsing....
# 1660 번째 페이지 parsing....
# 1661 번째 페이지 parsing....
# 1662 번째 페이지 parsing....
# 1663 번째 페이지 parsing....
# 1664 번째 페이지 parsing....
# 1665 번째 페이지 parsing....
# 1666 번째 페이지 parsing....
# 1667 번째 페이지 parsing....
# 1668 번째 페이지 parsing....
# 1669 번째 페이지 parsing....
# 1670 번째 페이지 parsing....
# 1671 번째 페이지 parsing....
# 1672 번째 페이지 parsing....
# 1673 번째 페이지 parsing....
# 1674 번째 페이지 parsing....
# 1675 번째 페이지 parsing....
# 1676 번째 페이지 parsing....
# 1677 번째 페이지 parsing....
# 1678 번째 페이지 parsing....
# 1679 번째 페이지 parsing....
# 1680 번째 페이지 parsing....
# 1681 번째 페이지 parsing....
# 1682 번째 페이지 parsing....
# 1683 번째 페이지 parsing....
# 1684 번째 페이지 parsing....
# 1685 번째 페이지 parsing....
# 1686 번째 페이지 parsing....
# 1687 번째 페이지 parsing....
# 1688 번째 페이지 parsing....
# 1689 번째 페이지 parsing....
# 1690 번째 페이지 parsing....
# 1691 번째 페이지 parsing....
# 1692 번째 페이지 parsing....
# 1693 번째 페이지 parsing....
# 1694 번째 페이지 parsing....
# 1695 번째 페이지 parsing....
# 1696 번째 페이지 parsing....
# 1697 번째 페이지 parsing....
# 1698 번째 페이지 parsing....
# 1699 번째 페이지 parsing....
# 1700 번째 페이지 parsing....
# 1701 번째 페이지 parsing....
# 1702 번째 페이지 parsing....
# 1703 번째 페이지 parsing....
# 1704 번째 페이지 parsing....
# 1705 번째 페이지 parsing....
# 1706 번째 페이지 parsing....
# 1707 번째 페이지 parsing....
# 1708 번째 페이지 parsing....
# 1709 번째 페이지 parsing....
# 1710 번째 페이지 parsing....
# 1711 번째 페이지 parsing....
# 1712 번째 페이지 parsing....
# 1713 번째 페이지 parsing....
# 1714 번째 페이지 parsing....
# 1715 번째 페이지 parsing....
# 1716 번째 페이지 parsing....
# 1717 번째 페이지 parsing....
# 1718 번째 페이지 parsing....
# 1719 번째 페이지 parsing....
# 1720 번째 페이지 parsing....
# 1721 번째 페이지 parsing....
# 1722 번째 페이지 parsing....
# 1723 번째 페이지 parsing....
# 1724 번째 페이지 parsing....
# 1725 번째 페이지 parsing....
# 1726 번째 페이지 parsing....
# 1727 번째 페이지 parsing....
# 1728 번째 페이지 parsing....
# 1729 번째 페이지 parsing....
# 1730 번째 페이지 parsing....
# 1731 번째 페이지 parsing....
# 1732 번째 페이지 parsing....
# 1733 번째 페이지 parsing....
# 1734 번째 페이지 parsing....
# 1735 번째 페이지 parsing....
# 1736 번째 페이지 parsing....
# 1737 번째 페이지 parsing....
# 1738 번째 페이지 parsing....
# 1739 번째 페이지 parsing....
# 1740 번째 페이지 parsing....
# 1741 번째 페이지 parsing....
# 1742 번째 페이지 parsing....
# 1743 번째 페이지 parsing....
# 1744 번째 페이지 parsing....
# 1745 번째 페이지 parsing....
# 1746 번째 페이지 parsing....
# 1747 번째 페이지 parsing....
# 1748 번째 페이지 parsing....
# 1749 번째 페이지 parsing....
# 1750 번째 페이지 parsing....
# 1751 번째 페이지 parsing....
# 1752 번째 페이지 parsing....
# 1753 번째 페이지 parsing....
# 1754 번째 페이지 parsing....
# 1755 번째 페이지 parsing....
# 1756 번째 페이지 parsing....
# 1757 번째 페이지 parsing....
# 1758 번째 페이지 parsing....
# 1759 번째 페이지 parsing....
# 1760 번째 페이지 parsing....
# 1761 번째 페이지 parsing....
# 1762 번째 페이지 parsing....
# 1763 번째 페이지 parsing....
# 1764 번째 페이지 parsing....
# 1765 번째 페이지 parsing....
# 1766 번째 페이지 parsing....
# 1767 번째 페이지 parsing....
# 1768 번째 페이지 parsing....
# 1769 번째 페이지 parsing....
# 1770 번째 페이지 parsing....
# 1771 번째 페이지 parsing....
# 1772 번째 페이지 parsing....
# 1773 번째 페이지 parsing....
# 1774 번째 페이지 parsing....
# 1775 번째 페이지 parsing....
# 1776 번째 페이지 parsing....
# 1777 번째 페이지 parsing....
# 1778 번째 페이지 parsing....
# 1779 번째 페이지 parsing....
# 1780 번째 페이지 parsing....
# 1781 번째 페이지 parsing....
# 1782 번째 페이지 parsing....
# 1783 번째 페이지 parsing....
# 1784 번째 페이지 parsing....
# 1785 번째 페이지 parsing....
# 1786 번째 페이지 parsing....
# 1787 번째 페이지 parsing....
# 1788 번째 페이지 parsing....
# 1789 번째 페이지 parsing....
# 1790 번째 페이지 parsing....
# 1791 번째 페이지 parsing....
# 1792 번째 페이지 parsing....
# 1793 번째 페이지 parsing....
# 1794 번째 페이지 parsing....
# 1795 번째 페이지 parsing....
# 1796 번째 페이지 parsing....
# 1797 번째 페이지 parsing....
# 1798 번째 페이지 parsing....
# 1799 번째 페이지 parsing....
# 1800 번째 페이지 parsing....
# 1801 번째 페이지 parsing....
# 1802 번째 페이지 parsing....
# 1803 번째 페이지 parsing....
# 1804 번째 페이지 parsing....
# 1805 번째 페이지 parsing....
# 1806 번째 페이지 parsing....
# 1807 번째 페이지 parsing....
# 1808 번째 페이지 parsing....
# 1809 번째 페이지 parsing....
# 1810 번째 페이지 parsing....
# 1811 번째 페이지 parsing....
# 1812 번째 페이지 parsing....
# 1813 번째 페이지 parsing....
# 1814 번째 페이지 parsing....
# 1815 번째 페이지 parsing....
# 1816 번째 페이지 parsing....
# 1817 번째 페이지 parsing....
# 1818 번째 페이지 parsing....
# 1819 번째 페이지 parsing....
# 1820 번째 페이지 parsing....
# 1821 번째 페이지 parsing....
# 1822 번째 페이지 parsing....
# 1823 번째 페이지 parsing....
# 1824 번째 페이지 parsing....
# 1825 번째 페이지 parsing....
# 1826 번째 페이지 parsing....
# 1827 번째 페이지 parsing....
# 1828 번째 페이지 parsing....
# 1829 번째 페이지 parsing....
# 1830 번째 페이지 parsing....
# 1831 번째 페이지 parsing....
# 1832 번째 페이지 parsing....
# 1833 번째 페이지 parsing....
# 1834 번째 페이지 parsing....
# 1835 번째 페이지 parsing....
# 1836 번째 페이지 parsing....
# 1837 번째 페이지 parsing....
# 1838 번째 페이지 parsing....
# 1839 번째 페이지 parsing....
# 1840 번째 페이지 parsing....
# 1841 번째 페이지 parsing....
# 1842 번째 페이지 parsing....
# 1843 번째 페이지 parsing....
# 1844 번째 페이지 parsing....
# 1845 번째 페이지 parsing....
# 1846 번째 페이지 parsing....
# 1847 번째 페이지 parsing....
# 1848 번째 페이지 parsing....
# 1849 번째 페이지 parsing....
# 1850 번째 페이지 parsing....
# 1851 번째 페이지 parsing....
# 1852 번째 페이지 parsing....
# 1853 번째 페이지 parsing....
# 1854 번째 페이지 parsing....
# 1855 번째 페이지 parsing....
# 1856 번째 페이지 parsing....
# 1857 번째 페이지 parsing....
# 1858 번째 페이지 parsing....
# 1859 번째 페이지 parsing....
# 1860 번째 페이지 parsing....
# 1861 번째 페이지 parsing....
# 1862 번째 페이지 parsing....
# 1863 번째 페이지 parsing....
# 1864 번째 페이지 parsing....
# 1865 번째 페이지 parsing....
# 1866 번째 페이지 parsing....
# 1867 번째 페이지 parsing....
# 1868 번째 페이지 parsing....
# 1869 번째 페이지 parsing....
# 1870 번째 페이지 parsing....
# 1871 번째 페이지 parsing....
# 1872 번째 페이지 parsing....
# 1873 번째 페이지 parsing....
# 1874 번째 페이지 parsing....
# 1875 번째 페이지 parsing....
# 1876 번째 페이지 parsing....
# 1877 번째 페이지 parsing....
# 1878 번째 페이지 parsing....
# 1879 번째 페이지 parsing....
# 1880 번째 페이지 parsing....
# 1881 번째 페이지 parsing....
# 1882 번째 페이지 parsing....
# 1883 번째 페이지 parsing....
# 1884 번째 페이지 parsing....
# 1885 번째 페이지 parsing....
# 1886 번째 페이지 parsing....
# 1887 번째 페이지 parsing....
# 1888 번째 페이지 parsing....
# 1889 번째 페이지 parsing....
# 1890 번째 페이지 parsing....
# 1891 번째 페이지 parsing....
# 1892 번째 페이지 parsing....
# 1893 번째 페이지 parsing....
# 1894 번째 페이지 parsing....
# 1895 번째 페이지 parsing....
# 1896 번째 페이지 parsing....
# 1897 번째 페이지 parsing....
# 1898 번째 페이지 parsing....
# 1899 번째 페이지 parsing....
# 1900 번째 페이지 parsing....
# 1901 번째 페이지 parsing....
# 1902 번째 페이지 parsing....
# 1903 번째 페이지 parsing....
# 1904 번째 페이지 parsing....
# 1905 번째 페이지 parsing....
# 1906 번째 페이지 parsing....
# 1907 번째 페이지 parsing....
# 1908 번째 페이지 parsing....
# 1909 번째 페이지 parsing....
# 1910 번째 페이지 parsing....
# 1911 번째 페이지 parsing....
# 1912 번째 페이지 parsing....
# 1913 번째 페이지 parsing....
# 1914 번째 페이지 parsing....
# 1915 번째 페이지 parsing....
# 1916 번째 페이지 parsing....
# 1917 번째 페이지 parsing....
# 1918 번째 페이지 parsing....
# 1919 번째 페이지 parsing....
# 1920 번째 페이지 parsing....
# 1921 번째 페이지 parsing....
# 1922 번째 페이지 parsing....
# 1923 번째 페이지 parsing....
# 1924 번째 페이지 parsing....
# 1925 번째 페이지 parsing....
# 1926 번째 페이지 parsing....
# 1927 번째 페이지 parsing....
# 1928 번째 페이지 parsing....
# 1929 번째 페이지 parsing....
# 1930 번째 페이지 parsing....
# 1931 번째 페이지 parsing....
# 1932 번째 페이지 parsing....
# 1933 번째 페이지 parsing....
# 1934 번째 페이지 parsing....
# 1935 번째 페이지 parsing....
# 1936 번째 페이지 parsing....
# 1937 번째 페이지 parsing....
# 1938 번째 페이지 parsing....
# 1939 번째 페이지 parsing....
# 1940 번째 페이지 parsing....
# 1941 번째 페이지 parsing....
# 1942 번째 페이지 parsing....
# 1943 번째 페이지 parsing....
# 1944 번째 페이지 parsing....
# 1945 번째 페이지 parsing....
# 1946 번째 페이지 parsing....
# 1947 번째 페이지 parsing....
# 1948 번째 페이지 parsing....
# 1949 번째 페이지 parsing....
# 1950 번째 페이지 parsing....
# 1951 번째 페이지 parsing....
# 1952 번째 페이지 parsing....
# 1953 번째 페이지 parsing....
# 1954 번째 페이지 parsing....
# 1955 번째 페이지 parsing....
# 1956 번째 페이지 parsing....
# 1957 번째 페이지 parsing....
# 1958 번째 페이지 parsing....
# 1959 번째 페이지 parsing....
# 1960 번째 페이지 parsing....
# 1961 번째 페이지 parsing....
# 1962 번째 페이지 parsing....
# 1963 번째 페이지 parsing....
# 1964 번째 페이지 parsing....
# 1965 번째 페이지 parsing....
# 1966 번째 페이지 parsing....
# 1967 번째 페이지 parsing....
# 1968 번째 페이지 parsing....
# 1969 번째 페이지 parsing....
# 1970 번째 페이지 parsing....
# 1971 번째 페이지 parsing....
# 1972 번째 페이지 parsing....
# 1973 번째 페이지 parsing....
# 1974 번째 페이지 parsing....
# 1975 번째 페이지 parsing....
# 1976 번째 페이지 parsing....
# 1977 번째 페이지 parsing....
# 1978 번째 페이지 parsing....
# 1979 번째 페이지 parsing....
# 1980 번째 페이지 parsing....
# 1981 번째 페이지 parsing....
# 1982 번째 페이지 parsing....
# 1983 번째 페이지 parsing....
# 1984 번째 페이지 parsing....
# 1985 번째 페이지 parsing....
# 1986 번째 페이지 parsing....
# 1987 번째 페이지 parsing....
# 1988 번째 페이지 parsing....
# 1989 번째 페이지 parsing....
# 1990 번째 페이지 parsing....
# 1991 번째 페이지 parsing....
# 1992 번째 페이지 parsing....
# 1993 번째 페이지 parsing....
# 1994 번째 페이지 parsing....
# 1995 번째 페이지 parsing....
# 1996 번째 페이지 parsing....
# 1997 번째 페이지 parsing....
# 1998 번째 페이지 parsing....
# 1999 번째 페이지 parsing....
# 2000 번째 페이지 parsing....
# 2001 번째 페이지 parsing....
# 2002 번째 페이지 parsing....
# 2003 번째 페이지 parsing....
# 2004 번째 페이지 parsing....
# 2005 번째 페이지 parsing....
# 2006 번째 페이지 parsing....
# 2007 번째 페이지 parsing....
# 2008 번째 페이지 parsing....
# 2009 번째 페이지 parsing....
# 2010 번째 페이지 parsing....
# 2011 번째 페이지 parsing....
# 2012 번째 페이지 parsing....
# 2013 번째 페이지 parsing....
# 2014 번째 페이지 parsing....
# 2015 번째 페이지 parsing....
# 2016 번째 페이지 parsing....
# 2017 번째 페이지 parsing....
# 2018 번째 페이지 parsing....
# 2019 번째 페이지 parsing....
# 2020 번째 페이지 parsing....
# 2021 번째 페이지 parsing....
# 2022 번째 페이지 parsing....
# 2023 번째 페이지 parsing....
# 2024 번째 페이지 parsing....
# 2025 번째 페이지 parsing....
# 2026 번째 페이지 parsing....
# 2027 번째 페이지 parsing....
# 2028 번째 페이지 parsing....
# 2029 번째 페이지 parsing....
# 2030 번째 페이지 parsing....
# 2031 번째 페이지 parsing....
# 2032 번째 페이지 parsing....
# 2033 번째 페이지 parsing....
# 2034 번째 페이지 parsing....
# 2035 번째 페이지 parsing....
# 2036 번째 페이지 parsing....
# 2037 번째 페이지 parsing....
# 2038 번째 페이지 parsing....
# 2039 번째 페이지 parsing....
# 2040 번째 페이지 parsing....
# 2041 번째 페이지 parsing....
# 2042 번째 페이지 parsing....
# 2043 번째 페이지 parsing....
# 2044 번째 페이지 parsing....
# 2045 번째 페이지 parsing....
# 2046 번째 페이지 parsing....
# ...
# 2319 번째 페이지 parsing....
# 2320 번째 페이지 parsing....
# 2321 번째 페이지 parsing....
# 2322 번째 페이지 parsing....
# 2323 번째 페이지 parsing....
# 2324 번째 페이지 parsing....
# 2325 번째 페이지 parsing....
# 2326 번째 페이지 parsing....
# 2327 번째 페이지 parsing....
# 2328 번째 페이지 parsing....
# 2329 번째 페이지 parsing....
# 2330 번째 페이지 parsing....
# 2331 번째 페이지 parsing....
# 2332 번째 페이지 parsing....
# 2333 번째 페이지 parsing....
# 2334 번째 페이지 parsing....
# 2335 번째 페이지 parsing....
# 2336 번째 페이지 parsing....
# 2337 번째 페이지 parsing....
# 2338 번째 페이지 parsing....
# 2339 번째 페이지 parsing....
# 2340 번째 페이지 parsing....
# 2341 번째 페이지 parsing....
# 2342 번째 페이지 parsing....
# 2343 번째 페이지 parsing....
# 2344 번째 페이지 parsing....
# 2345 번째 페이지 parsing....
# 2346 번째 페이지 parsing....
# 2347 번째 페이지 parsing....
# 2348 번째 페이지 parsing....
# 2349 번째 페이지 parsing....
# 2350 번째 페이지 parsing....
# 2351 번째 페이지 parsing....
# 2352 번째 페이지 parsing....
# 2353 번째 페이지 parsing....
# 2354 번째 페이지 parsing....
# 2355 번째 페이지 parsing....
# 2356 번째 페이지 parsing....
# 2357 번째 페이지 parsing....
# 2358 번째 페이지 parsing....
# 2359 번째 페이지 parsing....
# 2360 번째 페이지 parsing....
# 2361 번째 페이지 parsing....
# 2362 번째 페이지 parsing....
# 2363 번째 페이지 parsing....
# 2364 번째 페이지 parsing....
# 2365 번째 페이지 parsing....
# 2366 번째 페이지 parsing....
# 2367 번째 페이지 parsing....
# 2368 번째 페이지 parsing....
# 2369 번째 페이지 parsing....
# 2370 번째 페이지 parsing....
# 2371 번째 페이지 parsing....
# 2372 번째 페이지 parsing....
# 2373 번째 페이지 parsing....
# 2374 번째 페이지 parsing....
# 2375 번째 페이지 parsing....
# 2376 번째 페이지 parsing....
# 2377 번째 페이지 parsing....
# 2378 번째 페이지 parsing....
# 2379 번째 페이지 parsing....
# 2380 번째 페이지 parsing....
# 2381 번째 페이지 parsing....
# 2382 번째 페이지 parsing....
# 2383 번째 페이지 parsing....
# 2384 번째 페이지 parsing....
# 2385 번째 페이지 parsing....
# 2386 번째 페이지 parsing....
# 2387 번째 페이지 parsing....
# 2388 번째 페이지 parsing....
# 2389 번째 페이지 parsing....
# 2390 번째 페이지 parsing....
# 2391 번째 페이지 parsing....
# 2392 번째 페이지 parsing....
# 2393 번째 페이지 parsing....
# 2394 번째 페이지 parsing....
# 2395 번째 페이지 parsing....
# 2396 번째 페이지 parsing....
# 2397 번째 페이지 parsing....
# 2398 번째 페이지 parsing....
# 2399 번째 페이지 parsing....
# 2400 번째 페이지 parsing....
# 2401 번째 페이지 parsing....
# 2402 번째 페이지 parsing....
# 2403 번째 페이지 parsing....
# 2404 번째 페이지 parsing....
# 2405 번째 페이지 parsing....
# 2406 번째 페이지 parsing....
# 2407 번째 페이지 parsing....
# 2408 번째 페이지 parsing....
# 2409 번째 페이지 parsing....
# 2410 번째 페이지 parsing....
# 2411 번째 페이지 parsing....
# 2412 번째 페이지 parsing....
# 2413 번째 페이지 parsing....
# 2414 번째 페이지 parsing....
# 2415 번째 페이지 parsing....
# 2416 번째 페이지 parsing....
# 2417 번째 페이지 parsing....
# 2418 번째 페이지 parsing....
# 2419 번째 페이지 parsing....
# 2420 번째 페이지 parsing....
# 2421 번째 페이지 parsing....
# 2422 번째 페이지 parsing....
# 2423 번째 페이지 parsing....
# 2424 번째 페이지 parsing....
# 2425 번째 페이지 parsing....
# 2426 번째 페이지 parsing....
# 2427 번째 페이지 parsing....
# 2428 번째 페이지 parsing....
# 2429 번째 페이지 parsing....
# 2430 번째 페이지 parsing....
# 2431 번째 페이지 parsing....
# 2432 번째 페이지 parsing....
# 2433 번째 페이지 parsing....
# 2434 번째 페이지 parsing....
# 2435 번째 페이지 parsing....
# 2436 번째 페이지 parsing....
# 2437 번째 페이지 parsing....
# 2438 번째 페이지 parsing....
# 2439 번째 페이지 parsing....
# 2440 번째 페이지 parsing....
# 2441 번째 페이지 parsing....
# 2442 번째 페이지 parsing....
# 2443 번째 페이지 parsing....
# 2444 번째 페이지 parsing....
# 2445 번째 페이지 parsing....
# 2446 번째 페이지 parsing....
# 2447 번째 페이지 parsing....
# 2448 번째 페이지 parsing....
# 2449 번째 페이지 parsing....
# 2450 번째 페이지 parsing....
# 2451 번째 페이지 parsing....
# 2452 번째 페이지 parsing....
# 2453 번째 페이지 parsing....
# 2454 번째 페이지 parsing....
# 2455 번째 페이지 parsing....
# 2456 번째 페이지 parsing....
# 2457 번째 페이지 parsing....
# 2458 번째 페이지 parsing....
# 2459 번째 페이지 parsing....
# 2460 번째 페이지 parsing....
# 2461 번째 페이지 parsing....
# 2462 번째 페이지 parsing....
# 2463 번째 페이지 parsing....
# 2464 번째 페이지 parsing....
# 2465 번째 페이지 parsing....
# 2466 번째 페이지 parsing....
# 2467 번째 페이지 parsing....
# 2468 번째 페이지 parsing....
# 2469 번째 페이지 parsing....
# 2470 번째 페이지 parsing....
# 2471 번째 페이지 parsing....
# 2472 번째 페이지 parsing....
# 2473 번째 페이지 parsing....
# 2474 번째 페이지 parsing....
# 2475 번째 페이지 parsing....
# 2476 번째 페이지 parsing....
# 2477 번째 페이지 parsing....
# 2478 번째 페이지 parsing....
# 2479 번째 페이지 parsing....
# 2480 번째 페이지 parsing....
# 2481 번째 페이지 parsing....
# 2482 번째 페이지 parsing....
# 2483 번째 페이지 parsing....
# 2484 번째 페이지 parsing....
# 2485 번째 페이지 parsing....
# 2486 번째 페이지 parsing....
# 2487 번째 페이지 parsing....
# 2488 번째 페이지 parsing....
# 2489 번째 페이지 parsing....
# 2490 번째 페이지 parsing....
# 2491 번째 페이지 parsing....
# 2492 번째 페이지 parsing....
# 2493 번째 페이지 parsing....
# 2494 번째 페이지 parsing....
# 2495 번째 페이지 parsing....
# 2496 번째 페이지 parsing....
# 2497 번째 페이지 parsing....
# 2498 번째 페이지 parsing....
# 2499 번째 페이지 parsing....
# 2500 번째 페이지 parsing....
# 2501 번째 페이지 parsing....
# 2502 번째 페이지 parsing....
# 2503 번째 페이지 parsing....
# 2504 번째 페이지 parsing....
# 2505 번째 페이지 parsing....
# 2506 번째 페이지 parsing....
# 2507 번째 페이지 parsing....
# 2508 번째 페이지 parsing....
# 2509 번째 페이지 parsing....
# 2510 번째 페이지 parsing....
# 2511 번째 페이지 parsing....
# 2512 번째 페이지 parsing....
# 2513 번째 페이지 parsing....
# 2514 번째 페이지 parsing....
# 2515 번째 페이지 parsing....
# 2516 번째 페이지 parsing....
# 2517 번째 페이지 parsing....
# 2518 번째 페이지 parsing....
# 2519 번째 페이지 parsing....
# 2520 번째 페이지 parsing....
# 2521 번째 페이지 parsing....
# 2522 번째 페이지 parsing....
# 2523 번째 페이지 parsing....
# 2524 번째 페이지 parsing....
# 2525 번째 페이지 parsing....
# 2526 번째 페이지 parsing....
# 2527 번째 페이지 parsing....
# 2528 번째 페이지 parsing....
# 2529 번째 페이지 parsing....
# 2530 번째 페이지 parsing....
# 2531 번째 페이지 parsing....
# 2532 번째 페이지 parsing....
# 2533 번째 페이지 parsing....
# 2534 번째 페이지 parsing....
# 2535 번째 페이지 parsing....
# 2536 번째 페이지 parsing....
# 2537 번째 페이지 parsing....
# 2538 번째 페이지 parsing....
# 2539 번째 페이지 parsing....
# 2540 번째 페이지 parsing....
# 2541 번째 페이지 parsing....
# 2542 번째 페이지 parsing....
# 2543 번째 페이지 parsing....
# 2544 번째 페이지 parsing....
# 2545 번째 페이지 parsing....
# 2546 번째 페이지 parsing....
# 2547 번째 페이지 parsing....
# 2548 번째 페이지 parsing....
# 2549 번째 페이지 parsing....
# 2550 번째 페이지 parsing....
# 2551 번째 페이지 parsing....
# 2552 번째 페이지 parsing....
# 2553 번째 페이지 parsing....
# 2554 번째 페이지 parsing....
# 2555 번째 페이지 parsing....
# 2556 번째 페이지 parsing....
# 2557 번째 페이지 parsing....
# 2558 번째 페이지 parsing....
# 2559 번째 페이지 parsing....
# 2560 번째 페이지 parsing....
# 2561 번째 페이지 parsing....
# 2562 번째 페이지 parsing....
# 2563 번째 페이지 parsing....
# 2564 번째 페이지 parsing....
# 2565 번째 페이지 parsing....
# 2566 번째 페이지 parsing....
# 2567 번째 페이지 parsing....
# 2568 번째 페이지 parsing....
# 2569 번째 페이지 parsing....
# 2570 번째 페이지 parsing....
# 2571 번째 페이지 parsing....
# 2572 번째 페이지 parsing....
# 2573 번째 페이지 parsing....
# 2574 번째 페이지 parsing....
# 2575 번째 페이지 parsing....
# 2576 번째 페이지 parsing....
# 2577 번째 페이지 parsing....
# 2578 번째 페이지 parsing....
# 2579 번째 페이지 parsing....
# 2580 번째 페이지 parsing....
# 2581 번째 페이지 parsing....
# 2582 번째 페이지 parsing....
# 2583 번째 페이지 parsing....
# 2584 번째 페이지 parsing....
# 2585 번째 페이지 parsing....
# 2586 번째 페이지 parsing....
# 2587 번째 페이지 parsing....
# 2588 번째 페이지 parsing....
# 2589 번째 페이지 parsing....
# 2590 번째 페이지 parsing....
# 2591 번째 페이지 parsing....
# 2592 번째 페이지 parsing....
# 2593 번째 페이지 parsing....
# 2594 번째 페이지 parsing....
# 2595 번째 페이지 parsing....
# 2596 번째 페이지 parsing....
# 2597 번째 페이지 parsing....
# 2598 번째 페이지 parsing....
# 2599 번째 페이지 parsing....
# 2600 번째 페이지 parsing....
# 2601 번째 페이지 parsing....
# 2602 번째 페이지 parsing....
# 2603 번째 페이지 parsing....
# 2604 번째 페이지 parsing....
# 2605 번째 페이지 parsing....
# 2606 번째 페이지 parsing....
# 2607 번째 페이지 parsing....
# 2608 번째 페이지 parsing....
# 2609 번째 페이지 parsing....
# 2610 번째 페이지 parsing....
# 2611 번째 페이지 parsing....
# 2612 번째 페이지 parsing....
# 2613 번째 페이지 parsing....
# 2614 번째 페이지 parsing....
# 2615 번째 페이지 parsing....
# 2616 번째 페이지 parsing....
# 2617 번째 페이지 parsing....
# 2618 번째 페이지 parsing....
# 2619 번째 페이지 parsing....
# 2620 번째 페이지 parsing....
# 2621 번째 페이지 parsing....
# 2622 번째 페이지 parsing....
# 2623 번째 페이지 parsing....
# 2624 번째 페이지 parsing....
# 2625 번째 페이지 parsing....
# 2626 번째 페이지 parsing....
# 2627 번째 페이지 parsing....
# 2628 번째 페이지 parsing....
# 2629 번째 페이지 parsing....
# 2630 번째 페이지 parsing....
# 2631 번째 페이지 parsing....
# 2632 번째 페이지 parsing....
# 2633 번째 페이지 parsing....
# 2634 번째 페이지 parsing....
# 2635 번째 페이지 parsing....
# 2636 번째 페이지 parsing....
# 2637 번째 페이지 parsing....
# 2638 번째 페이지 parsing....
# 2639 번째 페이지 parsing....
# 2640 번째 페이지 parsing....
# 2641 번째 페이지 parsing....
# 2642 번째 페이지 parsing....
# 2643 번째 페이지 parsing....
# 2644 번째 페이지 parsing....
# 2645 번째 페이지 parsing....
# 2646 번째 페이지 parsing....
# 2647 번째 페이지 parsing....
# 2648 번째 페이지 parsing....
# 2649 번째 페이지 parsing....
# 2650 번째 페이지 parsing....
# 2651 번째 페이지 parsing....
# 2652 번째 페이지 parsing....
# 2653 번째 페이지 parsing....
# 2654 번째 페이지 parsing....
# 2655 번째 페이지 parsing....
# 2656 번째 페이지 parsing....
# 2657 번째 페이지 parsing....
# 2658 번째 페이지 parsing....
# 2659 번째 페이지 parsing....
# 2660 번째 페이지 parsing....
# 2661 번째 페이지 parsing....
# 2662 번째 페이지 parsing....
# 2663 번째 페이지 parsing....
# 2664 번째 페이지 parsing....
# 2665 번째 페이지 parsing....
# 2666 번째 페이지 parsing....
# 2667 번째 페이지 parsing....
# 2668 번째 페이지 parsing....
# 2669 번째 페이지 parsing....
# 2670 번째 페이지 parsing....
# 2671 번째 페이지 parsing....
# 2672 번째 페이지 parsing....
# 2673 번째 페이지 parsing....
# 2674 번째 페이지 parsing....
# 2675 번째 페이지 parsing....
# 2676 번째 페이지 parsing....
# 2677 번째 페이지 parsing....
# 2678 번째 페이지 parsing....
# 2679 번째 페이지 parsing....
# 2680 번째 페이지 parsing....
# 2681 번째 페이지 parsing....
# 2682 번째 페이지 parsing....
# 2683 번째 페이지 parsing....
# 2684 번째 페이지 parsing....
# 2685 번째 페이지 parsing....
# 2686 번째 페이지 parsing....
# 2687 번째 페이지 parsing....
# 2688 번째 페이지 parsing....
# 2689 번째 페이지 parsing....
# 2690 번째 페이지 parsing....
# 2691 번째 페이지 parsing....
# 2692 번째 페이지 parsing....
# 2693 번째 페이지 parsing....
# 2694 번째 페이지 parsing....
# 2695 번째 페이지 parsing....
# 2696 번째 페이지 parsing....
# 2697 번째 페이지 parsing....
# 2698 번째 페이지 parsing....
# 2699 번째 페이지 parsing....
# 2700 번째 페이지 parsing....
# 2701 번째 페이지 parsing....
# 2702 번째 페이지 parsing....
# 2703 번째 페이지 parsing....
# 2704 번째 페이지 parsing....
# 2705 번째 페이지 parsing....
# 2706 번째 페이지 parsing....
# 2707 번째 페이지 parsing....
# 2708 번째 페이지 parsing....
# 2709 번째 페이지 parsing....
# 2710 번째 페이지 parsing....
# 2711 번째 페이지 parsing....
# 2712 번째 페이지 parsing....
# 2713 번째 페이지 parsing....
# 2714 번째 페이지 parsing....
# 2715 번째 페이지 parsing....
# 2716 번째 페이지 parsing....
# 2717 번째 페이지 parsing....
# 2718 번째 페이지 parsing....
# 2719 번째 페이지 parsing....
# 2720 번째 페이지 parsing....
# 2721 번째 페이지 parsing....
# 2722 번째 페이지 parsing....
# 2723 번째 페이지 parsing....
# 2724 번째 페이지 parsing....
# 2725 번째 페이지 parsing....
# 2726 번째 페이지 parsing....
# 2727 번째 페이지 parsing....
# 2728 번째 페이지 parsing....
# 2729 번째 페이지 parsing....
# 2730 번째 페이지 parsing....
# 2731 번째 페이지 parsing....
# 2732 번째 페이지 parsing....
# 2733 번째 페이지 parsing....
# 2734 번째 페이지 parsing....
# 2735 번째 페이지 parsing....
# 2736 번째 페이지 parsing....
# 2737 번째 페이지 parsing....
# 2738 번째 페이지 parsing....
# 2739 번째 페이지 parsing....
# 2740 번째 페이지 parsing....
# 2741 번째 페이지 parsing....
# 2742 번째 페이지 parsing....
# 2743 번째 페이지 parsing....
# 2744 번째 페이지 parsing....
# 2745 번째 페이지 parsing....
# 2746 번째 페이지 parsing....
# 2747 번째 페이지 parsing....
# 2748 번째 페이지 parsing....
# 2749 번째 페이지 parsing....
# 2750 번째 페이지 parsing....
# 2751 번째 페이지 parsing....
# 2752 번째 페이지 parsing....
# 2753 번째 페이지 parsing....
# 2754 번째 페이지 parsing....
# 2755 번째 페이지 parsing....
# 2756 번째 페이지 parsing....
# 2757 번째 페이지 parsing....
# 2758 번째 페이지 parsing....
# 2759 번째 페이지 parsing....
# 2760 번째 페이지 parsing....
# 2761 번째 페이지 parsing....
# 2762 번째 페이지 parsing....
# 2763 번째 페이지 parsing....
# 2764 번째 페이지 parsing....
# 2765 번째 페이지 parsing....
# 2766 번째 페이지 parsing....
# 2767 번째 페이지 parsing....
# 2768 번째 페이지 parsing....
# 2769 번째 페이지 parsing....
# 2770 번째 페이지 parsing....
# 2771 번째 페이지 parsing....
# 2772 번째 페이지 parsing....
# 2773 번째 페이지 parsing....
# 2774 번째 페이지 parsing....
# 2775 번째 페이지 parsing....
# 2776 번째 페이지 parsing....
# 2777 번째 페이지 parsing....
# 2778 번째 페이지 parsing....
# 2779 번째 페이지 parsing....
# 2780 번째 페이지 parsing....
# 2781 번째 페이지 parsing....
# 2782 번째 페이지 parsing....
# 2783 번째 페이지 parsing....
# 2784 번째 페이지 parsing....
# 2785 번째 페이지 parsing....
# 2786 번째 페이지 parsing....
# 2787 번째 페이지 parsing....
# 2788 번째 페이지 parsing....
# 2789 번째 페이지 parsing....
# 2790 번째 페이지 parsing....
# 2791 번째 페이지 parsing....
# 2792 번째 페이지 parsing....
# 2793 번째 페이지 parsing....
# 2794 번째 페이지 parsing....
# 2795 번째 페이지 parsing....
# 2796 번째 페이지 parsing....
# 2797 번째 페이지 parsing....
# 2798 번째 페이지 parsing....
# 2799 번째 페이지 parsing....
# 2800 번째 페이지 parsing....
# 2801 번째 페이지 parsing....
# 2802 번째 페이지 parsing....
# 2803 번째 페이지 parsing....
# 2804 번째 페이지 parsing....
# 2805 번째 페이지 parsing....
# 2806 번째 페이지 parsing....
# 2807 번째 페이지 parsing....
# 2808 번째 페이지 parsing....
# 2809 번째 페이지 parsing....
# 2810 번째 페이지 parsing....
# 2811 번째 페이지 parsing....
# 2812 번째 페이지 parsing....
# 2813 번째 페이지 parsing....
# 2814 번째 페이지 parsing....
# 2815 번째 페이지 parsing....
# 2816 번째 페이지 parsing....
# 2817 번째 페이지 parsing....
# 2818 번째 페이지 parsing....
# 2819 번째 페이지 parsing....
# 2820 번째 페이지 parsing....
# 2821 번째 페이지 parsing....
# 2822 번째 페이지 parsing....
# 2823 번째 페이지 parsing....
# 2824 번째 페이지 parsing....
# 2825 번째 페이지 parsing....
# 2826 번째 페이지 parsing....
# 2827 번째 페이지 parsing....
# 2828 번째 페이지 parsing....
# 2829 번째 페이지 parsing....
# 2830 번째 페이지 parsing....
# 2831 번째 페이지 parsing....
# 2832 번째 페이지 parsing....
# 2833 번째 페이지 parsing....
# 2834 번째 페이지 parsing....
# 2835 번째 페이지 parsing....
# 2836 번째 페이지 parsing....
# 2837 번째 페이지 parsing....
# 2838 번째 페이지 parsing....
# 2839 번째 페이지 parsing....
# 2840 번째 페이지 parsing....
# 2841 번째 페이지 parsing....
# 2842 번째 페이지 parsing....
# 2843 번째 페이지 parsing....
# 2844 번째 페이지 parsing....
# 2845 번째 페이지 parsing....
# 2846 번째 페이지 parsing....
# 2847 번째 페이지 parsing....
# 2848 번째 페이지 parsing....
# 2849 번째 페이지 parsing....
# 2850 번째 페이지 parsing....
# 2851 번째 페이지 parsing....
# 2852 번째 페이지 parsing....
# 2853 번째 페이지 parsing....
# 2854 번째 페이지 parsing....
# 2855 번째 페이지 parsing....
# 2856 번째 페이지 parsing....
# 2857 번째 페이지 parsing....
# 2858 번째 페이지 parsing....
# 2859 번째 페이지 parsing....
# 2860 번째 페이지 parsing....
# 2861 번째 페이지 parsing....
# 2862 번째 페이지 parsing....
# 2863 번째 페이지 parsing....
# 2864 번째 페이지 parsing....
# 2865 번째 페이지 parsing....
# 2866 번째 페이지 parsing....
# 2867 번째 페이지 parsing....
# 2868 번째 페이지 parsing....
# 2869 번째 페이지 parsing....
# 2870 번째 페이지 parsing....
# 2871 번째 페이지 parsing....
# 2872 번째 페이지 parsing....
# 2873 번째 페이지 parsing....
# 2874 번째 페이지 parsing....
# 2875 번째 페이지 parsing....
# 2876 번째 페이지 parsing....
# 2877 번째 페이지 parsing....
# 2878 번째 페이지 parsing....
# 2879 번째 페이지 parsing....
# 2880 번째 페이지 parsing....
# 2881 번째 페이지 parsing....
# 2882 번째 페이지 parsing....
# 2883 번째 페이지 parsing....
# 2884 번째 페이지 parsing....
# 2885 번째 페이지 parsing....
# 2886 번째 페이지 parsing....
# 2887 번째 페이지 parsing....
# 2888 번째 페이지 parsing....
# 2889 번째 페이지 parsing....
# 2890 번째 페이지 parsing....
# 2891 번째 페이지 parsing....
# 2892 번째 페이지 parsing....
# 2893 번째 페이지 parsing....
# 2894 번째 페이지 parsing....
# 2895 번째 페이지 parsing....
# 2896 번째 페이지 parsing....
# 2897 번째 페이지 parsing....
# 2898 번째 페이지 parsing....
# 2899 번째 페이지 parsing....
# 2900 번째 페이지 parsing....
# 2901 번째 페이지 parsing....
# 2902 번째 페이지 parsing....
# 2903 번째 페이지 parsing....
# 2904 번째 페이지 parsing....
# 2905 번째 페이지 parsing....
# 2906 번째 페이지 parsing....
# 2907 번째 페이지 parsing....
# 2908 번째 페이지 parsing....
# 2909 번째 페이지 parsing....
# 2910 번째 페이지 parsing....
# 2911 번째 페이지 parsing....
# 2912 번째 페이지 parsing....
# 2913 번째 페이지 parsing....
# 2914 번째 페이지 parsing....
# 2915 번째 페이지 parsing....
# 2916 번째 페이지 parsing....
# 2917 번째 페이지 parsing....
# 2918 번째 페이지 parsing....
# 2919 번째 페이지 parsing....
# 2920 번째 페이지 parsing....
# 2921 번째 페이지 parsing....
# 2922 번째 페이지 parsing....
# 2923 번째 페이지 parsing....
# 2924 번째 페이지 parsing....
# 2925 번째 페이지 parsing....
# 2926 번째 페이지 parsing....
# 2927 번째 페이지 parsing....
# 2928 번째 페이지 parsing....
# 2929 번째 페이지 parsing....
# 2930 번째 페이지 parsing....
# 2931 번째 페이지 parsing....
# 2932 번째 페이지 parsing....
# 2933 번째 페이지 parsing....
# 2934 번째 페이지 parsing....
# 2935 번째 페이지 parsing....
# 2936 번째 페이지 parsing....
# 2937 번째 페이지 parsing....
# 2938 번째 페이지 parsing....
# 2939 번째 페이지 parsing....
# 2940 번째 페이지 parsing....
# 2941 번째 페이지 parsing....
# 2942 번째 페이지 parsing....
# 2943 번째 페이지 parsing....
# 2944 번째 페이지 parsing....
# 2945 번째 페이지 parsing....
# 2946 번째 페이지 parsing....
# 2947 번째 페이지 parsing....
# 2948 번째 페이지 parsing....
# 2949 번째 페이지 parsing....
# 2950 번째 페이지 parsing....
# 2951 번째 페이지 parsing....
# 2952 번째 페이지 parsing....
# 2953 번째 페이지 parsing....
# 2954 번째 페이지 parsing....
# 2955 번째 페이지 parsing....
# 2956 번째 페이지 parsing....
# 2957 번째 페이지 parsing....
# 2958 번째 페이지 parsing....
# 2959 번째 페이지 parsing....
# 2960 번째 페이지 parsing....
# 2961 번째 페이지 parsing....
# 2962 번째 페이지 parsing....
# 2963 번째 페이지 parsing....
# 2964 번째 페이지 parsing....
# 2965 번째 페이지 parsing....
# 2966 번째 페이지 parsing....
# 2967 번째 페이지 parsing....
# 2968 번째 페이지 parsing....
# 2969 번째 페이지 parsing....
# 2970 번째 페이지 parsing....
# 2971 번째 페이지 parsing....
# 2972 번째 페이지 parsing....
# 2973 번째 페이지 parsing....
# 2974 번째 페이지 parsing....
# 2975 번째 페이지 parsing....
# 2976 번째 페이지 parsing....
# 2977 번째 페이지 parsing....
# 2978 번째 페이지 parsing....
# 2979 번째 페이지 parsing....
# 2980 번째 페이지 parsing....
# 2981 번째 페이지 parsing....
# 2982 번째 페이지 parsing....
# 2983 번째 페이지 parsing....
# 2984 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['thsz****',
#   '부산행 반도 못따라감 그래서 반도임',
#   '2',
#   '9817',
#   '2713',
#   datetime.datetime(2020, 7, 18, 19, 52),
#   '관람객'],
#  ['slow life(ssk8****)',
#   '재미있게 잘 봤습니다. 다만 조금 질질 끄는 게 아쉬웠어요. 전형적인 약간의 억지 감동은 빼주셨으면',
#   '6',
#   '5004',
#   '1290',
#   datetime.datetime(2020, 7, 15, 12, 7),
#   '관람객'],
#  ['로야르(vulc****)',
#   '진짜 재미없음 다른말필요없음',
#   '1',
#   '4574',
#   '2149',
#   datetime.datetime(2020, 7, 15, 22, 44),
#   '관람객'],
#  ['윤등(feel****)',
#   '영상미는 좋은데 스토리가....흥미가 안생겨요배우님들 고생 많았습니다',
#   '4',
#   '3391',
#   '1120',
#   datetime.datetime(2020, 7, 15, 12, 21),
#   '관람객'],
#  ['dlad****',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '8',
#   '2603',
#   '484',
#   datetime.datetime(2020, 7, 15, 22, 25),
#   '관람객'],
#  ['pand****',
#   '실망대망.  교과서적 연출로도 평타 이상은 가능할 좀비소재를 이렇게까지...',
#   '1',
#   '3090',
#   '1267',
#   datetime.datetime(2020, 7, 15, 23, 21),
#   '관람객'],
#  ['sj(tnwj****)',
#   '한창 때리고 부수고 싸우는 거 좋아하는 10세 남아 머리에서 나올법한  수준 낮은 각본과 연출. 대신 추진력 하나는 인정. 이런 지지고 볶는 짜파게티같은 각본을 완결짓고 영화판에 내다니..그 점은 대단! 애기들도 연...',
#   '2',
#   '2842',
#   '1213',
#   datetime.datetime(2020, 7, 16, 4, 59),
#   '관람객'],
#  ['강정완(knul****)',
#   '분노의 질주를 본것 같았다...감동을 억지로 씬에 담으려는거 같았고현실성 없는 내용들이 많이 깔려있어서보는내내 이질감이 느껴져 2점 드렸습니다.',
#   '5',
#   '1862',
#   '592',
#   datetime.datetime(2020, 7, 15, 17, 24),
#   '관람객'],
#  ['안녕하세요(qkre****)',
#   '기아 모하비 홍보영상을 보고나온 느낌이 제일 강하게 들었고,차량 액션신은 대부분 cg인데 이질감이 느껴짐좀비 연출은 죄다 때거지로 덤비는 연출 아쉬움그냥 볼만한 수준의 영화이 영화보다 부산행 한 번 더 보는걸 추천드...',
#   '6',
#   '1595',
#   '390',
#   datetime.datetime(2020, 7, 15, 12, 43),
#   '관람객'],
#  ['네일(hije****)',
#   '부산행의 반도 못하다 해서 반도. . 인가..',
#   '2',
#   '1040',
#   '199',
#   datetime.datetime(2020, 7, 15, 12, 15),
#   0],
#  ['에비앙(fhrl****)',
#   '강동원 이정현은 아묻따였는데 악역으로 나온 구교환 너무 좋아ㅠ',
#   '10',
#   '2662',
#   '1829',
#   datetime.datetime(2020, 7, 15, 12, 31),
#   '관람객'],
#  ['풍토피아(gom2****)',
#   '기대안하고 봐서 그런지 재미없었음 ^^ 기대하고 봤으면 더 재미없었을듯',
#   '1',
#   '744',
#   '179',
#   datetime.datetime(2020, 7, 17, 0, 11),
#   '관람객'],
#  ['몹아님(lll1****)',
#   '이것은 좀비영화인가 레이싱영화인가 신파는 왜이리 많은것인가',
#   '2',
#   '655',
#   '120',
#   datetime.datetime(2020, 7, 16, 17, 54),
#   '관람객'],
#  ['따뚜따뚜(dlxo****)',
#   '추천은 안함 근데 강동원 잘생김강동원 총 잘쏨 근데 강동원 잘생김 여자애 운전 개쩜 근데 강동원 잘생김',
#   '6',
#   '662',
#   '132',
#   datetime.datetime(2020, 7, 16, 22, 15),
#   '관람객'],
#  ['꼬댕이(wowo****)',
#   '이거 볼 돈으로 국밥 특대 사드세여 ㅎㅎ',
#   '4',
#   '699',
#   '173',
#   datetime.datetime(2020, 7, 16, 22, 41),
#   '관람객'],
#  ['영근(youn****)',
#   '엔딩크레딧 올라올때"와 진짜 이건 아닌데"라는 생각이듬',
#   '1',
#   '657',
#   '146',
#   datetime.datetime(2020, 7, 17, 9, 17),
#   '관람객'],
#  ['rari****',
#   '부산행생각하고보시면안돼요시간가는줄알고봤습니다',
#   '1',
#   '596',
#   '116',
#   datetime.datetime(2020, 7, 17, 18, 38),
#   '관람객'],
#  ['호이짜(rbdh****)',
#   '모하비 광고 영상인줄 알았습니다',
#   '6',
#   '544',
#   '66',
#   datetime.datetime(2020, 7, 16, 12, 14),
#   '관람객'],
#  ['신새(hi3h****)',
#   '모하비 한대 구매 해야 겠어요',
#   '6',
#   '561',
#   '83',
#   datetime.datetime(2020, 7, 15, 20, 43),
#   '관람객'],
#  ['조선생(gram****)',
#   '차로 좀비 깔아뭉개는 장면만 30분.',
#   '4',
#   '571',
#   '94',
#   datetime.datetime(2020, 7, 16, 18, 16),
#   '관람객'],
#  ['배추벌레(kdb9****)',
#   '하.... 좀비물이 아니라 자동차 액션 보는 거같았어요 초반에는 볼만하다가 점점 지루해지고 결말이 어느정도 예측이되고 개연성도 부족한거같고 부산행급 까진 아니더라도 어느정도 기대하고 봤는데 너무 실망입니다',
#   '1',
#   '648',
#   '171',
#   datetime.datetime(2020, 7, 16, 19, 39),
#   '관람객'],
#  ['bian****',
#   '부산행과 장르가 완전히 바뀌었어요 왜갑자기 트랜스포머가된거죠....?',
#   '2',
#   '623',
#   '147',
#   datetime.datetime(2020, 7, 16, 8, 35),
#   '관람객'],
#  ['미(01ga****)',
#   '그냥 간단하게 홍콩에서 트럭을 가져와라는 지시를 받고 반도에서 가져오는 내용 중간중간 들어간 한국영화의 뻔한 "가족애" 로 인해 중간중간 지루함... PPL 잘한듯.. 차량 좋네 , 제발.. 억지감동....',
#   '7',
#   '626',
#   '150',
#   datetime.datetime(2020, 7, 15, 16, 11),
#   '관람객'],
#  ['ceo(swee****)',
#   '영화보다가 나올뻔하긴 되게 오랜만이네요ㅋ 공포도 스릴도 감동도 없는 전형적인 한국형 신파극',
#   '2',
#   '655',
#   '179',
#   datetime.datetime(2020, 7, 16, 9, 20),
#   '관람객'],
#  ['리플레이(zzub****)',
#   '말하지 않겠다...최악이다 억지로 런타임 맞추려하는게 너무 봄',
#   '1',
#   '677',
#   '202',
#   datetime.datetime(2020, 7, 16, 16, 23),
#   '관람객'],
#  ['요요요용(dydg****)',
#   '너~~~~무 자동차씬만 기억나요,,',
#   '6',
#   '530',
#   '64',
#   datetime.datetime(2020, 7, 15, 21, 28),
#   '관람객'],
#  ['mrjk****',
#   '연기는 4년후인데 연출 스토리 전개는 4년 전으로 돌아간것 같다.',
#   '6',
#   '533',
#   '83',
#   datetime.datetime(2020, 7, 17, 3, 11),
#   '관람객'],
#  ['임재근(just****)',
#   '마자막 신파만 그러려니하고 넘기면 전체적으로볼만함 구교환씨 맛탱이간 연기 맛깔나게 잘하고',
#   '7',
#   '577',
#   '139',
#   datetime.datetime(2020, 7, 15, 18, 14),
#   '관람객'],
#  ['wkmh****',
#   '음...레이싱 영화인지 좀비 영화인지... 억지 감동 포인트도 그렇고 그냥 볼 거 없어서 보는 영화?? 기대 안 하고 보면 괜찮음!',
#   '6',
#   '520',
#   '133',
#   datetime.datetime(2020, 7, 15, 15, 50),
#   '관람객'],
#  ['sjw2****',
#   '초반에는 관람객의 흥미를 끌기엔 충분하였으나, 갈수록 아쉬운 점이 있음영화의 스토리가 하나하나 전부 기억이 날 만큼 별 내용이 없고 액션신으로 가득함.다소 과한 연출.. 억지설정.. 요약 : 용두사미를 2글자로 줄이...',
#   '6',
#   '466',
#   '96',
#   datetime.datetime(2020, 7, 15, 19, 33),
#   '관람객'],
#  ['방방방(ch01****)',
#   "뭐랄까. 염력 엄복동을 피했는데 반도를 못피했네. 부산행의 반의 '반도'못미치는 영화",
#   '3',
#   '501',
#   '141',
#   datetime.datetime(2020, 7, 17, 7, 39),
#   '관람객'],
#  ['태롱이(xogu****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '5',
#   '426',
#   '102',
#   datetime.datetime(2020, 7, 15, 23, 50),
#   '관람객'],
#  ['최시현(tltn****)',
#   '잘 쌓아올리다가 청승으로 범벅된다.',
#   '6',
#   '399',
#   '78',
#   datetime.datetime(2020, 7, 16, 0, 14),
#   '관람객'],
#  ['승현(seun****)',
#   '한국형매드맥스를꿈꿨으나마무리는90년대신파로마무리함',
#   '2',
#   '375',
#   '71',
#   datetime.datetime(2020, 7, 17, 23, 39),
#   '관람객'],
#  ['국사화(rnrt****)',
#   '스토리 머냐?? 발로??  규제가 문제인가.. 돈이문제인가....너무 급급.. 그나마 악당이 괸찮으면 머냐??',
#   '4',
#   '458',
#   '163',
#   datetime.datetime(2020, 7, 15, 21, 33),
#   '관람객'],
#  ['공 민성(0idi****)',
#   '구교환의 재발견. 악역 캐릭터를 정말 본인의 색으로 맛깔나게 소화했음 왜 감독이 한국의 조커라고 한지 알듯',
#   '10',
#   '523',
#   '240',
#   datetime.datetime(2020, 7, 15, 16, 59),
#   '관람객'],
#  ['sms4****',
#   '돈이 아깝다 코로나  시국에 이거 보려고 극장 간 내가 레게노',
#   '1',
#   '377',
#   '96',
#   datetime.datetime(2020, 7, 18, 16, 14),
#   '관람객'],
#  ['idontwontodie(denn****)',
#   '연기는 김민재 배우가 살렸지만 스토리의 개연성이 부족하고 억지스런 신파와 어색한 CG그냥 강동원은 거지같은 머리해도 강동원이구나만 느낌',
#   '2',
#   '362',
#   '82',
#   datetime.datetime(2020, 7, 16, 19, 44),
#   '관람객'],
#  ['joo(jpg0****)',
#   '그냥 오락영화. 다보고나면  이영화가 무슨 말을 하고싶은건지 모르겠을정도로 그냥 허무맹랑.  화려한 카체이싱 액션이 돋보임. 근데 중간중간 긴장감을 깨버리는 대사들. 선과악을 구분지어놔 스토리가 너무 단순함.  전작...',
#   '6',
#   '286',
#   '54',
#   datetime.datetime(2020, 7, 16, 8, 4),
#   '관람객'],
#  ['kw00****',
#   '살아있다2가 개봉한줄. 어떻게 영화를 이렇게 재미없게 만드는지....시간 버림',
#   '1',
#   '344',
#   '115',
#   datetime.datetime(2020, 7, 17, 1, 8),
#   '관람객'],
#  ['Pro(leey****)',
#   '10점 알바들이랑 1점 알바들이랑 싸우니 사이좋게 5점으로 양보하자',
#   '5',
#   '347',
#   '130',
#   datetime.datetime(2020, 7, 15, 9, 35),
#   0],
#  ['방다솜(tree****)',
#   '좀비영화가 아니라 카트라이더임 그냥. 처음부터 끝까지 예상 가능한 스토리고 좀비는 그냥 빌런을 죽이는 장치 그 이상 그 이하도 아님.',
#   '2',
#   '274',
#   '59',
#   datetime.datetime(2020, 7, 18, 9, 31),
#   '관람객'],
#  ['오로치(choc****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '5',
#   '325',
#   '131',
#   datetime.datetime(2020, 7, 15, 11, 48),
#   '관람객'],
#  ['섭이(tjqd****)',
#   '이게 좀비 영화인지 좀비만 나오는 카 액션인지 전혀 개연성도 없고 감동도 억지로 끼어 맞추는 것 같고 원래 영화 기대 안 하고 보는데 완전 바닥이네요',
#   '2',
#   '242',
#   '59',
#   datetime.datetime(2020, 7, 18, 1, 3),
#   '관람객'],
#  ['마로(gust****)',
#   '부산행에서 안전한 부분만 빼서 만든 영화 느낌 갑분 신파 넣고 좀비도 넣어주고 카체이싱이나 액션도 넣었는데 맨날 먹던 반찬 맛이다 나쁘지는 않은데 막 최고!!이것도 아님 딱 평타',
#   '7',
#   '290',
#   '117',
#   datetime.datetime(2020, 7, 15, 15, 21),
#   '관람객'],
#  ['잠수함(ta64****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '2',
#   '216',
#   '44',
#   datetime.datetime(2020, 7, 17, 22, 8),
#   '관람객'],
#  ['양조위(peni****)',
#   '',
#   '2',
#   '259',
#   '87',
#   datetime.datetime(2020, 7, 15, 22, 23),
#   '관람객'],
#  ['다류(tany****)',
#   '대배우 구교환 ??',
#   '6',
#   '226',
#   '55',
#   datetime.datetime(2020, 7, 15, 23, 30),
#   '관람객'],
#  ['히히포(hhp_****)',
#   '억지 신파에 토할뻔했다',
#   '1',
#   '188',
#   '28',
#   datetime.datetime(2020, 7, 20, 2, 25),
#   '관람객'],
#  ['정천(dltj****)',
#   '4년동안 서있던 차를 박았는데 경보기가 막 울려....슈퍼배터리인가?',
#   '6',
#   '898',
#   '740',
#   datetime.datetime(2020, 7, 16, 6, 45),
#   '관람객'],
#  ['정민(wjda****)',
#   '보는내내 와 운전잘한다 느낌 부산행기대하고 가시는거면 가지마시길',
#   '2',
#   '219',
#   '64',
#   datetime.datetime(2020, 7, 16, 9, 18),
#   '관람객'],
#  ['레이(rayt****)',
#   '짧은 총평... 술 취한 형님의 술주정 들어주는 느낌. “형, 무슨 말인지 알아. 안다고. 그런데 그건 아니지. 아니. 안다니까.” 부산행 감독의 후속작일뿐 부산행2는 아니라는걸 모르는 사람이 많은 듯. 아포칼립스로...',
#   '4',
#   '200',
#   '51',
#   datetime.datetime(2020, 7, 16, 13, 10),
#   '관람객'],
#  ['최준호(lter****)',
#   '신파도 문제인데 영화가 전체적으로 매끄럽지가 못 함ㅠ 시작부터 아무리 버릴 카드라고 해도 목적은 큰 돈인데 이미 한 번 실패하고 못 가져왔으면 제대로 준비를 하고 보내야 하는데 허술하게 달랑 총 하나 들고 간다는게 ...',
#   '6',
#   '194',
#   '51',
#   datetime.datetime(2020, 7, 16, 0, 42),
#   '관람객'],
#  ['뭐(vnvn****)',
#   '대실망 핵노잼 강동원 얼굴만 재밌음',
#   '2',
#   '179',
#   '42',
#   datetime.datetime(2020, 7, 19, 2, 47),
#   '관람객'],
#  ['감돌이(aya9****)',
#   '하.. 왜 평점 낮은지 알겠습니다.좀 눈물짜내려는 요소 너무 많아요억지로 넣어놨어요 마지막 끝날쯤에 폭발하는데 한숨나옵니다 제발.. 일반인도 느끼는데 제작진들은 무슨 생각이였는지..알바평점 낮출려고 2점 줍니다',
#   '4',
#   '164',
#   '33',
#   datetime.datetime(2020, 7, 18, 11, 6),
#   '관람객'],
#  ['amer****',
#   '나름 군인이 타락한 얘기는 신박했음 근데 너무 매드맥스 느낌남 모하비 차주들 내심 기분좋을듯 ㅋㅋ',
#   '6',
#   '156',
#   '30',
#   datetime.datetime(2020, 7, 16, 20, 49),
#   '관람객'],
#  ['bohemian(mabu****)',
#   '저기요. 이거 장르가 뭐임? 도대체 뭘 찍은 거야...',
#   '5',
#   '183',
#   '59',
#   datetime.datetime(2020, 7, 15, 10, 10),
#   0],
#  ['달구(8cof****)',
#   '인랑도 재미있게본내가...처음으로 돈아깝다고생각들었음 치누크왔을때부터 진짜 욕나오더라',
#   '1',
#   '210',
#   '86',
#   datetime.datetime(2020, 7, 16, 12, 23),
#   '관람객'],
#  ['죠다쉬(111b****)',
#   '한국 영화의 마케팅계가 이렇게 썩어버렸나..이딴 영화가 어떻게 평점이 9점이냐알바를 쳐써도 작작써야지, 이게 평점조작단이랑 다를게뭐냐',
#   '1',
#   '152',
#   '32',
#   datetime.datetime(2020, 7, 15, 13, 30),
#   0],
#  ['오예일(dhdp****)',
#   '배안에서 백덤블링 하는 좀비 보고 뭔가 느낌이 왔음 그러다가 화장실 갔다 왔는데 어린 애들이 운전을 멧데이먼 수준으로 함ㅋㅋㅋ',
#   '4',
#   '129',
#   '10',
#   datetime.datetime(2020, 7, 20, 10, 2),
#   '관람객'],
#  ['Khr(gpfl****)',
#   '부산행 좀비 보다 빨라졌다고 홍보하더니 좀비 나오는 장면이 레이싱 장면 보다 적으면 어쩌란 말임',
#   '2',
#   '150',
#   '34',
#   datetime.datetime(2020, 7, 15, 12, 5),
#   0],
#  ['강규환(deux****)',
#   '좀비영화에 좀비가 없다. 배우들의 연기는 상황이 있을 뿐 이야기를 거들 수 있는 드라마가 부족하다. 볼거리로 채우기 급급하며 웅장한 비주얼을 자랑하는 듯 하나 결국 영화를 다 보고나서 결국 드는 생각은  플레이스테이...',
#   '4',
#   '141',
#   '26',
#   datetime.datetime(2020, 7, 17, 1, 59),
#   '관람객'],
#  ['pkh5****',
#   '반도70살아있다30',
#   '10',
#   '487',
#   '376',
#   datetime.datetime(2020, 7, 15, 12, 8),
#   0],
#  ['taey****',
#   '신파만 좀 줄였으면....',
#   '8',
#   '160',
#   '51',
#   datetime.datetime(2020, 7, 15, 20, 56),
#   '관람객'],
#  ['yun(hoya****)',
#   '이걸 영화라고 만들었니?? 어휴... 반 도 못보고 나왔다는...',
#   '1',
#   '150',
#   '43',
#   datetime.datetime(2020, 7, 15, 13, 25),
#   0],
#  ['태양속으로(yooy****)',
#   '왜 생존자들끼리 싸우는가?  좀비는 거들 뿐!',
#   '4',
#   '119',
#   '16',
#   datetime.datetime(2020, 7, 15, 13, 29),
#   0],
#  ['tkdd****',
#   '한국판 분노의 질주(feat.좀비군단)',
#   '8',
#   '179',
#   '76',
#   datetime.datetime(2020, 7, 15, 22, 23),
#   '관람객'],
#  ['priz****',
#   '감독님 신파 넣는것도 상황에따라 넣으셔야하는데 너무 사람죽는걸로 억지 감동할려고 질질끌고 오히려 그게 더 따분하게만들고 액션신도 화끈한건 좋으나 너무 말도안되는장면이 오래가니 재미가 많이 반감되네요 부산행을 정말 좋...',
#   '4',
#   '121',
#   '19',
#   datetime.datetime(2020, 7, 18, 20, 17),
#   '관람객'],
#  ['사무리(tkan****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '2',
#   '139',
#   '38',
#   datetime.datetime(2020, 7, 16, 18, 49),
#   '관람객'],
#  ['날아올라(twog****)',
#   '클리셰 범벅. 2020년 영화라 믿기지않는 진부함.',
#   '1',
#   '117',
#   '18',
#   datetime.datetime(2020, 7, 21, 20, 15),
#   '관람객'],
#  ['exters(blad****)',
#   '알바진짜 오지게 풀어놨네',
#   '2',
#   '137',
#   '38',
#   datetime.datetime(2020, 7, 15, 12, 54),
#   0],
#  ['oi유(hoho****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '7',
#   '136',
#   '38',
#   datetime.datetime(2020, 7, 15, 21, 39),
#   '관람객'],
#  ['스타폭스(jojo****)',
#   '이걸 보느니 레지던트 이블 한 편 때리는 게 더 낫습니다',
#   '2',
#   '130',
#   '33',
#   datetime.datetime(2020, 7, 15, 12, 3),
#   0],
#  ['태양권(yhr0****)',
#   '난 돈도많고 시간도 많다 하시는분 보세요 뭔 영화가 아니라 모하비 광고찍는줄',
#   '1',
#   '140',
#   '44',
#   datetime.datetime(2020, 7, 19, 3, 38),
#   '관람객'],
#  ['찬s(poba****)',
#   '말도안되는 운전실력.모하비 겁나튼튼함.그리고 신파 신파 신파 신파',
#   '2',
#   '120',
#   '29',
#   datetime.datetime(2020, 7, 18, 15, 53),
#   '관람객'],
#  ['여행과 꿈(gras****)',
#   '영화값의 반도 못건졌다.남는게 없는 영화',
#   '5',
#   '125',
#   '38',
#   datetime.datetime(2020, 7, 16, 9, 38),
#   '관람객'],
#  ['keun****',
#   '이건 1점이 아니다. 11점을 주고 싶은 내 마음이다.',
#   '1',
#   '158',
#   '73',
#   datetime.datetime(2020, 7, 16, 17, 58),
#   '관람객'],
#  ['박시연(le51****)',
#   '엄복동2 인가요? 왜 한국영화들은 억지감동+신파극을 못끼워넣어서 안달이지? 보는내내 불편할정도로 억지감동 유발에 눈살찌푸려졌음. 부산행2래서 기대하고 본 내 잘못이지..에휴',
#   '2',
#   '101',
#   '21',
#   datetime.datetime(2020, 7, 15, 16, 8),
#   0],
#  ['야후(scni****)',
#   '너무 오글거리고 막파 신파신때문에 짜증났다.',
#   '4',
#   '100',
#   '23',
#   datetime.datetime(2020, 7, 18, 15, 40),
#   '관람객'],
#  ['감마(gara****)',
#   '싸구려 CG에 어설픈 연기력에 집중안되는 시나리오에 강동원 나옴 끝.',
#   '2',
#   '105',
#   '28',
#   datetime.datetime(2020, 7, 15, 13, 3),
#   0],
#  ['권영훈(gkgk****)',
#   '개연성이 너무 앖네요....',
#   '1',
#   '120',
#   '43',
#   datetime.datetime(2020, 7, 17, 4, 58),
#   '관람객'],
#  ['jappo(gud0****)',
#   '처음부터 끝까지 영화를 보는동안 감정에 변동이 생기지 않음.. 그리고 영화를 보는 도중 자꾸 저건 왜?? 저건 또 왜?? 왜 또 슬퍼야해..?? 이런 의문을 들게만듬',
#   '2',
#   '90',
#   '14',
#   datetime.datetime(2020, 7, 19, 18, 23),
#   '관람객'],
#  ['정우준(wooj****)',
#   '노잼',
#   '1',
#   '111',
#   '36',
#   datetime.datetime(2020, 7, 18, 23, 51),
#   '관람객'],
#  ['fasdf34(tkdd****)',
#   '반도 만들면 안 됐어... 부산행은 참신한 소재니까 흥미로워서 봤다면 이건 그런 것도 없이 그냥 ㅠㅠㅠ배급사들은 완성된 영화를 보고 정말 경쟁력 있다고 생각해서 배급한건지...개판임강동원은 제에에에발 영화 고르는 눈...',
#   '1',
#   '90',
#   '16',
#   datetime.datetime(2020, 7, 15, 16, 28),
#   0],
#  ['shwo****',
#   '모하비 광고로 착각할정도..',
#   '6',
#   '95',
#   '23',
#   datetime.datetime(2020, 7, 17, 15, 39),
#   '관람객'],
#  ['9828****',
#   '스토리. 연출 모두 별로네요. 각자의 의견이 다르겠지만 저는 돈주고 보고싶지는 않네요^^그나마 가족과 함게여서 좋았습니다',
#   '4',
#   '97',
#   '25',
#   datetime.datetime(2020, 7, 17, 8, 17),
#   '관람객'],
#  ['pjoh(spri****)',
#   '와 이건 진짜 너무했다ㅠㅋㅋㅋ 앞으로 연상호 감독 영화는 걸러야것어',
#   '4',
#   '94',
#   '23',
#   datetime.datetime(2020, 7, 21, 19, 49),
#   '관람객'],
#  ['어린왕자(0601****)',
#   '스토리가없으니연기가보이지않는다.그냥킬링타임용.',
#   '2',
#   '98',
#   '27',
#   datetime.datetime(2020, 7, 15, 13, 25),
#   0],
#  ['아닌데요(ss18****)',
#   '이거보고 면허따러갑니다',
#   '8',
#   '96',
#   '27',
#   datetime.datetime(2020, 7, 17, 17, 50),
#   '관람객'],
#  ['쭈리(wnfl****)',
#   '살아잇다보다 99.9%잼',
#   '10',
#   '263',
#   '198',
#   datetime.datetime(2020, 7, 15, 10, 50),
#   0],
#  ['신장미(yeeu****)',
#   '뭔가 아쉽다 .... 뭔가 다 짬뽕시켜놓은 느낌...?',
#   '7',
#   '88',
#   '26',
#   datetime.datetime(2020, 7, 16, 1, 33),
#   '관람객'],
#  ['z1ho****',
#   '진짜 너무하네 이게 영화냐',
#   '2',
#   '96',
#   '34',
#   datetime.datetime(2020, 7, 18, 17, 44),
#   '관람객'],
#  ['농협인(99ts****)',
#   '왠지모르게 재미가 없었네요. 전체적으로 완성도가 조금 미흡한듯...',
#   '4',
#   '90',
#   '29',
#   datetime.datetime(2020, 7, 17, 22, 32),
#   '관람객'],
#  ['진우(jino****)',
#   '돈이 아까울 정도',
#   '1',
#   '98',
#   '37',
#   datetime.datetime(2020, 7, 17, 17, 37),
#   '관람객'],
#  ['콧털남(kims****)',
#   '솔직히  이렇게  재미없을줄이야',
#   '2',
#   '75',
#   '15',
#   datetime.datetime(2020, 8, 27, 19, 41),
#   '관람객'],
#  ['소똥구리(cowh****)',
#   '재미없고.. 잠이 솔솔 왔다.',
#   '2',
#   '88',
#   '29',
#   datetime.datetime(2020, 7, 19, 0, 4),
#   '관람객'],
#  ['학생(why4****)',
#   '별로였어요 그냥 중간에도 좀 지루했고 재밌는지는 모르겠네요ㅜㅜ',
#   '4',
#   '99',
#   '40',
#   datetime.datetime(2020, 7, 17, 2, 27),
#   '관람객'],
#  ['covong2(myti****)',
#   '이거슨 좀비영화가아니라 자동차영화입니다',
#   '6',
#   '60',
#   '3',
#   datetime.datetime(2020, 7, 22, 21, 55),
#   '관람객'],
#  ['tmdd****',
#   '전형적인 한국형 산파극',
#   '1',
#   '70',
#   '13',
#   datetime.datetime(2020, 7, 15, 16, 28),
#   0],
#  ['파리챔스우승0(mess****)',
#   '진짜 오지게재미없어요.. 진짜 돈주고보라해도 안볼정도.. 좀비영화보러갔더니 하루종일 자동차로 레이싱경주하는거 보러간줄 ㅋㅋ그리고 어떻게든 억지눈물만드려고 노력은한거같은데 진짜 오글거리고 최악이네요;그냥 한국좀비영화는...',
#   '1',
#   '74',
#   '17',
#   datetime.datetime(2020, 7, 15, 13, 36),
#   0],
#  ['푸른옷을입은마법사(aphr****)',
#   '평점이 너무 높네요! 하..',
#   '4',
#   '79',
#   '22',
#   datetime.datetime(2020, 7, 18, 19, 19),
#   '관람객'],
#  ['AkibaRico(tlse****)',
#   '초중번은 좋았지만 후반의 억지스러운 신파극이 별로였다.',
#   '6',
#   '68',
#   '13',
#   datetime.datetime(2020, 7, 16, 14, 11),
#   '관람객'],
#  ['akwl****',
#   '배우들은 진지한데 난 왜 웃음이 나지',
#   '6',
#   '71',
#   '16',
#   datetime.datetime(2020, 7, 17, 17, 9),
#   '관람객'],
#  ['미니미닛(homi****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '67',
#   '13',
#   datetime.datetime(2020, 7, 17, 17, 33),
#   '관람객'],
#  ['jjy7****',
#   '강동원 존잘 얼굴 시커매도 잘생겼었음 좀비판 카트라이더를 본 느낌',
#   '4',
#   '59',
#   '6',
#   datetime.datetime(2020, 7, 24, 16, 28),
#   '관람객'],
#  ['사권명투(dlwo****)',
#   '이렇게 못 만드는 것도 재능이다',
#   '1',
#   '70',
#   '17',
#   datetime.datetime(2020, 7, 21, 17, 42),
#   '관람객'],
#  ['아디(adar****)',
#   '킬링타임용으로는 괜찮음. 그러나 너무 신파극..',
#   '4',
#   '86',
#   '33',
#   datetime.datetime(2020, 7, 15, 23, 3),
#   '관람객'],
#  ['ya14****',
#   '좀비가 주인공인줄 알았더니 그냥 강동원이 주인공통제가능한 좀비는 전혀 두려운존재가 아님631부대도 더 지독한 빌런이필요했다',
#   '6',
#   '67',
#   '15',
#   datetime.datetime(2020, 7, 17, 3, 25),
#   '관람객'],
#  ['1047K(tmdg****)',
#   '방금 영화 보고 왔습니다 웬만하면 영화 재밌게보는데..이건 좀.. 부산행은 스릴감이라도 있었지 이건차로 좀비치는 영화도아니고;; 억지감동 뿜뿜임..한달뒤에 영화 풀릴듯',
#   '2',
#   '66',
#   '15',
#   datetime.datetime(2020, 7, 15, 12, 52),
#   0],
#  ['도울(ruda****)',
#   '좀비 ?♀? ?♂? 들이 너무 불쌍한 영화였어요 볼링  치는거 잘 봤습니다..',
#   '2',
#   '69',
#   '19',
#   datetime.datetime(2020, 7, 18, 13, 3),
#   '관람객'],
#  ['My Wife(korg****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '59',
#   '10',
#   datetime.datetime(2020, 7, 15, 12, 44),
#   0],
#  ['팩트리어트(vale****)',
#   '이게 한국 영화 현주소다ㅡㅡ 실력있는 감독 몇 명이 하드캐리하고 신인 감독이라는 새키들은 겉멋만 들어서 유명배우만 있으면 어떤 똥을 내놔도 쳐봐주고 숼드쳐주는 멍청한 대중들ㅡㅡ 연상호 상업영화는 믿거 다시 한 번 인...',
#   '1',
#   '64',
#   '15',
#   datetime.datetime(2020, 7, 15, 14, 9),
#   0],
#  ['drym****',
#   '약자코스프레....',
#   '2',
#   '92',
#   '43',
#   datetime.datetime(2020, 7, 15, 21, 24),
#   '관람객'],
#  ['spell(leem****)',
#   '3류 매드맥스 + 억지 감정표현 + 축구공 좀비 ... 실망스런 영화..',
#   '3',
#   '62',
#   '14',
#   datetime.datetime(2020, 7, 23, 13, 1),
#   '관람객'],
#  ['bros****',
#   '한국 신파라는 새로운 장르를 개척해 나가시는 연상호 감독님!! 신파장르의 넘버원 답게 시작부터 끝까지 줄줄이 신파의 대향연!!',
#   '3',
#   '68',
#   '20',
#   datetime.datetime(2020, 7, 15, 13, 29),
#   0],
#  ['이상엽(cauc****)',
#   '신파 음악 억지눈물 이제 좀 그만..',
#   '3',
#   '68',
#   '20',
#   datetime.datetime(2020, 7, 15, 11, 51),
#   0],
#  ['단비맘(psun****)',
#   '눈물흘리고 가족이 끌어안는 장면은 언제쯤이면 사라지나요...진부합니다 모하비한대 장만해야겠어요',
#   '4',
#   '51',
#   '4',
#   datetime.datetime(2020, 7, 22, 12, 15),
#   '관람객'],
#  ['내아이디건들지마라(uji0****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '56',
#   '10',
#   datetime.datetime(2020, 7, 16, 23, 26),
#   '관람객'],
#  ['최팀좡(jk_r****)',
#   '부산행을 만든 사람과 동일 인물 맞나? 개연성없고 늘어지는 스토리.진부한 설정. 개성없는 인물들.억지 신파.cg도 평범하고. 언제까지 그나마 강동원 얼굴본걸로 만족한다는 여자들의 멘트로 위안을 삼아야하니.',
#   '4',
#   '57',
#   '11',
#   datetime.datetime(2020, 7, 19, 18, 3),
#   '관람객'],
#  ['모모(minj****)',
#   '안전빵 좀비 가족 카체이싱 영화아주 감동즙을 짜네',
#   '6',
#   '65',
#   '19',
#   datetime.datetime(2020, 7, 16, 1, 26),
#   '관람객'],
#  ['물2L(jee1****)',
#   '저는 웬만하면 재밌게 보는 타입이고, 진작에 부산행같은 기대는 안했어서 재밌게 봤어요 근데 엔딩 15분 마지막 억지 즙짜기 장면은 정말 ..ㅎㅎ 즙이 안나와여 헤헤.. 그런거 없는게 낫겠어요!!! 제인한테 총 겨눌때...',
#   '8',
#   '71',
#   '25',
#   datetime.datetime(2020, 7, 17, 21, 12),
#   '관람객'],
#  ['오시원(tldn****)',
#   '댓글알바해서 얼마 받아요?',
#   '1',
#   '74',
#   '28',
#   datetime.datetime(2020, 7, 15, 16, 28),
#   0],
#  ['april21(yuse****)',
#   '부산행 반도 못따라가 영화 제목을 “반도”로 지었네. 연상호감독 안타깝다. 왜 계속 병살타만 치는건가.',
#   '6',
#   '75',
#   '29',
#   datetime.datetime(2020, 7, 17, 14, 0),
#   '관람객'],
#  ['툽툽(sks5****)',
#   '그냥 최악임 모하비 홍보영상이 더 잘어울림 설정 개나 줘버리고 개연성 없고 신파 ㅈㄴ많고 보기 불편함 굳이 하나 뽑자면 영상미?',
#   '1',
#   '60',
#   '16',
#   datetime.datetime(2020, 7, 15, 12, 57),
#   0],
#  ['eun_****',
#   '액션은좋은데 애니같고 너무 과해요',
#   '6',
#   '65',
#   '21',
#   datetime.datetime(2020, 7, 16, 17, 26),
#   '관람객'],
#  ['물렁뼈(sori****)',
#   '여러분 이 감독의 전작은 염력입니다. 정신 차리세요.',
#   '2',
#   '70',
#   '26',
#   datetime.datetime(2020, 7, 15, 11, 54),
#   0],
#  ['상남자이현서(gust****)',
#   '한국판 매드맥스, 다른건 모르겠고 구교환 연기 지린다',
#   '8',
#   '103',
#   '59',
#   datetime.datetime(2020, 7, 15, 10, 50),
#   0],
#  ['hjss****',
#   '와..  평점 좋게준 사람들은 머냐..?애들하고보다가 중간에 나왔다..어쩜이리 엉망이냐..  연기..연출..cg..돈 아깝다',
#   '2',
#   '47',
#   '5',
#   datetime.datetime(2020, 7, 26, 2, 0),
#   0],
#  ['절망찬(mg70****)',
#   '잘 봤습니다. 대신 슬로우 금지 억지 감동 교훈 넣기 금지 한국인 답답하게 하지 않기 약속',
#   '6',
#   '50',
#   '8',
#   datetime.datetime(2020, 7, 21, 18, 30),
#   '관람객'],
#  ['world(wesd****)',
#   '다들 운전 잘하시더라고요.',
#   '8',
#   '51',
#   '10',
#   datetime.datetime(2020, 8, 26, 3, 7),
#   '관람객'],
#  ['THeOL(tlsd****)',
#   '기대가 커서인지 아쉬운 부분이 많은 작품입니다...',
#   '4',
#   '57',
#   '16',
#   datetime.datetime(2020, 7, 18, 15, 46),
#   '관람객'],
#  ['Palette(1jun****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '2',
#   '48',
#   '8',
#   datetime.datetime(2020, 7, 21, 18, 0),
#   '관람객'],
#  ['하나둘셋(nona****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '1',
#   '49',
#   '10',
#   datetime.datetime(2020, 7, 15, 22, 7),
#   0],
#  ['조민재(vict****)',
#   '전형적인 한국영화ㅋㅋ재미도없고 감동도없다',
#   '2',
#   '51',
#   '12',
#   datetime.datetime(2020, 7, 15, 13, 1),
#   0],
#  ['떡보(seve****)',
#   '누가 주연인지 잘 모르겠고 시간끄는것도 심하고 음....^^ 그렇다고 심하게 재밌는것도 아니고;;^^',
#   '4',
#   '49',
#   '11',
#   datetime.datetime(2020, 7, 18, 18, 11),
#   '관람객'],
#  ['열심히살자(rlac****)',
#   '킬링타임용으로는 괜찮음.근데 아무리 영화라고 해도 보다 보면 상식적으로 의아한 부분이 좀 있음.어린 여자 애들 연기도 엄청 어색하고 한국 영화 종특 억지 감동 당연히 존재 ㅡ ㅡ',
#   '5',
#   '54',
#   '16',
#   datetime.datetime(2020, 7, 17, 9, 2),
#   '관람객'],
#  ['금돌(gumd****)',
#   '부산행의  반에반에 반도 안됨!!! 의심하지마삼!!',
#   '4',
#   '57',
#   '19',
#   datetime.datetime(2020, 7, 15, 12, 7),
#   0],
#  ['미운52(ugly****)',
#   '부산행이 훨 좋았었던거 같아요...영상은 정말 잘만든거같은데...너무 아쉬워요...ㅠㅠ',
#   '2',
#   '70',
#   '32',
#   datetime.datetime(2020, 7, 17, 4, 51),
#   '관람객'],
#  ['님(djtm****)',
#   '28년 살면서 처음 영화 평점 달아요....뭘본건지 아직도 모르겠어요....혼돈...',
#   '2',
#   '47',
#   '10',
#   datetime.datetime(2020, 7, 26, 18, 15),
#   '관람객'],
#  ['이남훈(leen****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '1',
#   '48',
#   '11',
#   datetime.datetime(2020, 8, 25, 11, 29),
#   '관람객'],
#  ['jss(jss9****)',
#   '진짜 인생 역대 최악의 영화다....날 욕할사람은 일단보고 와봐라ㅋㅋ...보면 내말에 공감할 것이다. 내가 돈과 시간이 넘쳐난다는 사람도 보지마라.... 난 재미없는 영화도 앵간하면 잘보는 편임(미술영화제외) 근데 ...',
#   '1',
#   '48',
#   '11',
#   datetime.datetime(2020, 7, 15, 17, 5),
#   0],
#  ['주지윤(gyoo****)',
#   '좀비영화가 아닌 그냥 카 레이싱 영화본 기분이었어요기대도 안 하고 봤는데도 실망이었어요...',
#   '4',
#   '51',
#   '14',
#   datetime.datetime(2020, 8, 26, 15, 25),
#   '관람객'],
#  ['구루구루(cjfd****)',
#   '부산행을 보고 다음 작품이 반도라면 실망하겠지만 염력을 보고 반도를 봤다면 선녀같은 작품이다',
#   '6',
#   '51',
#   '14',
#   datetime.datetime(2020, 7, 17, 18, 57),
#   '관람객'],
#  ['jyam****',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '2',
#   '40',
#   '4',
#   datetime.datetime(2020, 7, 18, 18, 20),
#   '관람객'],
#  ['젤리키스(kmyu****)',
#   '영상미는 볼만합니다만 스토리는 하품하면서 봤네요 그리고 감독님 제작사가 억지로 신파를 넣으라고 하던가요? 진짜 적당히좀 넣으세요 ㅋㅋ 요새 트랜드를 모르시네',
#   '6',
#   '44',
#   '8',
#   datetime.datetime(2020, 7, 15, 11, 55),
#   0],
#  ['파워맨(powe****)',
#   '진짜 예고편이 다네요.. 잘모르겠어요. 억지감동과 몰입방해수준의 스토리..',
#   '6',
#   '51',
#   '15',
#   datetime.datetime(2020, 7, 18, 8, 46),
#   '관람객'],
#  ['빵가루(kgb1****)',
#   '기대가 크게 다르지 않은 상태에서 별루에요',
#   '6',
#   '51',
#   '15',
#   datetime.datetime(2020, 7, 16, 16, 41),
#   '관람객'],
#  ['임예리(yele****)',
#   '',
#   '2',
#   '44',
#   '9',
#   datetime.datetime(2020, 7, 15, 12, 56),
#   0],
#  ['배서진(qotj****)',
#   '실망스러웠다고 하기에는 부산행을 빼고 봐도 정말 그냥 너무 잘못 만들어진것같아요. 영화가 전달하는 메세지도 감동도 이상한 전개와 예상했지만 더 심했던 신파, 너무나도 부족해 있기는 한건지 의심되는 세세한 설정들, 모...',
#   '2',
#   '49',
#   '14',
#   datetime.datetime(2020, 7, 19, 13, 54),
#   '관람객'],
#  ['에베베베베벱베베(gktk****)',
#   '평점알바아닙니다.돈버렸습니다',
#   '1',
#   '49',
#   '14',
#   datetime.datetime(2020, 7, 15, 17, 2),
#   0],
#  ['사검(dark****)',
#   '별 기대 안했습니다.스토리,연기등등...그런데CG는 정말 구려서 못 봐주겠어요. 그나마 악당캐스팅은 맘에 드네요.외국의 B급 영화보다 못 한 수준입니다.국내 영화의 발전을 위해 차마1점은 못 주겠네요.돈 아깝단 생각...',
#   '4',
#   '50',
#   '16',
#   datetime.datetime(2020, 7, 16, 15, 19),
#   '관람객'],
#  ['바렌(dmsg****)',
#   '평식이형 5점, 거른다',
#   '2',
#   '50',
#   '16',
#   datetime.datetime(2020, 7, 15, 13, 34),
#   0],
#  ['단백질36그램(long****)',
#   '할말이없다 한국 영화 특유의 신파에,특전사인 강동원이 사주경계도 똑바로 못하고 그놈의 PC질은 떡칠에 뻔한 스토리',
#   '2',
#   '42',
#   '9',
#   datetime.datetime(2020, 7, 15, 14, 51),
#   0],
#  ['베가(qprk****)',
#   '모하비와 큰딸만 기억남',
#   '6',
#   '49',
#   '16',
#   datetime.datetime(2020, 7, 18, 8, 55),
#   '관람객'],
#  ['황민지(hang****)',
#   '살아있다보다 스토리가 심각함 왜 좀비영화는 무조건 해피엔딩으로 끝나야되는건지 그냥 강동원 얼굴이 잘생겨서 보고옴 좀비는 배경일뿐이고 차 씬이 가장많은데 너무 초라함',
#   '1',
#   '63',
#   '30',
#   datetime.datetime(2020, 7, 17, 22, 29),
#   '관람객'],
#  ['이종권(jkjk****)',
#   '내용이 뭐 인지   돈이 아깝다',
#   '4',
#   '43',
#   '11',
#   datetime.datetime(2020, 7, 15, 12, 54),
#   0],
#  ['Djdjtjbe(tae9****)',
#   '아 아 홀리 이게뭐노,,',
#   '1',
#   '46',
#   '14',
#   datetime.datetime(2020, 7, 15, 12, 3),
#   0],
#  ['즐겁게운동하자(king****)',
#   '영화 보고나서 느낀점  SUV는 모하비다...',
#   '8',
#   '48',
#   '16',
#   datetime.datetime(2020, 7, 18, 15, 49),
#   '관람객'],
#  ['클리너(pjc5****)',
#   '모하비 광고 찍는데 굳이 강동원 까지 쓸필요가...?!',
#   '4',
#   '51',
#   '19',
#   datetime.datetime(2020, 7, 17, 19, 11),
#   '관람객'],
#  ['다영짜웅(crca****)',
#   '억지 신파 이제 신물이난다',
#   '5',
#   '42',
#   '11',
#   datetime.datetime(2020, 7, 15, 12, 44),
#   0],
#  ['봉대(alcl****)',
#   '뇌를 잠시 정지시키고 생각없이 보면 흥미를 느낄수있는 영화. 영화보고 생각할수록 이상함을 느낀영화는 처음이네요.',
#   '5',
#   '44',
#   '13',
#   datetime.datetime(2020, 7, 17, 13, 2),
#   '관람객'],
#  ['이성복(tjdq****)',
#   '부산행 후속작이라 너무 기대햇나바요.반도 이 영화는 좀비물이라하기보다 액션이라할가.화면 또한 어두운 밤을 배경으로 찍은거라 영....솔직히 돈아까워요',
#   '6',
#   '45',
#   '14',
#   datetime.datetime(2020, 7, 16, 11, 23),
#   '관람객'],
#  ['은기에(ssi2****)',
#   '재미가 반도 안되는 영화',
#   '1',
#   '55',
#   '24',
#   datetime.datetime(2020, 7, 19, 11, 43),
#   '관람객'],
#  ['김유나(yuna****)',
#   'K좀비물이 한국에서도 완성도 높게 나오고 또 표현력깊은 강동원배우님과 군함도에서 인상적인 역할을 했던 이정현 배우를 기대하며 봤는데, 좀비가 영화내용속에 좀 자연스럽게 적용되어 스토리에 녹아지길 바랬지만 비인륜적인 ...',
#   '4',
#   '36',
#   '6',
#   datetime.datetime(2020, 7, 18, 15, 44),
#   '관람객'],
#  ['팝컹(park****)',
#   '이거보고 조잡한 그래픽에 어지러워서 눈병이 생겼어요',
#   '1',
#   '38',
#   '8',
#   datetime.datetime(2020, 10, 9, 15, 39),
#   '관람객'],
#  ['우루룽(sken****)',
#   '한국 신파의 정수, 어벤져스',
#   '1',
#   '40',
#   '10',
#   datetime.datetime(2020, 7, 15, 13, 3),
#   0],
#  ['기똥찬인생(kkam****)',
#   '휴....감독이 문제다 ㅠ명배우 권해효의 활용도가 그거밖에 안되나 그리고서대위역 ...진짜 이분은 연기발성부터가ㅠㅠ',
#   '4',
#   '47',
#   '17',
#   datetime.datetime(2020, 7, 15, 12, 52),
#   0],
#  ['agada2692(adad****)',
#   '코로나로 외부활동에 제약이 많아 찾은 영화네요 종비영화로 알고갔는데 가족드라마(?) 스토리도 엉성하고...이정현배우님 연기잘하는배운데 여기서는 영~~~기억에남는건  이레배우님 운전씬뿐..코로나로  일상에 지치신분들께...',
#   '6',
#   '49',
#   '19',
#   datetime.datetime(2020, 7, 16, 6, 24),
#   '관람객'],
#  ['rugy****',
#   '진짜 볼만했다 그러나 마지막 즙짜기 시전 후 또 즙짜기 하더니 갑자기 뛰면서 즙을 짜다가 또 즙짜고 끝나더라',
#   '8',
#   '56',
#   '26',
#   datetime.datetime(2020, 7, 16, 15, 24),
#   '관람객'],
#  ['ll20****',
#   '재미 있는 편 입니다. 한번 보셔도 될 듯.',
#   '10',
#   '179',
#   '149',
#   datetime.datetime(2020, 7, 15, 10, 27),
#   0],
#  ['vvmarsh(cheo****)',
#   '각본이 S급재료로 개죽을 쑤어놓은 영화.ㅎㅎ 영화보면서 입밖으로 욕나오는 영화는 오늘이 처음 ㅆㄹㅈㄷ.',
#   '1',
#   '35',
#   '6',
#   datetime.datetime(2020, 7, 15, 19, 36),
#   0],
#  ['샐리(ssss****)',
#   '부산행의 반도 못미치는 후속작',
#   '4',
#   '35',
#   '6',
#   datetime.datetime(2020, 7, 15, 17, 59),
#   0],
#  ['Wooost(oskg****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '36',
#   '7',
#   datetime.datetime(2020, 7, 16, 23, 23),
#   '관람객'],
#  ['눈깔(jomi****)',
#   '재미없다 시간아깝고 연기 몇몇빼고 다 어설프고 부산행 좀비 보다 더 멍청해진 좀비',
#   '6',
#   '46',
#   '17',
#   datetime.datetime(2020, 7, 15, 10, 36),
#   0],
#  ['홍산하(sanh****)',
#   '약간 이영화는 “이장면에서는 어럴거 같은데?”이러면 정말 그런장면이 나옵니다...그냥 말하자면 좀 뻔한..?하지만 연기자들 연기와 강동원의 외모가 이영화를 더 재미있게 만든것 같습니다.(강동원 너무 잘생겼잖아.......',
#   '8',
#   '57',
#   '28',
#   datetime.datetime(2020, 7, 16, 23, 43),
#   '관람객'],
#  ['HAHA(jung****)',
#   '한국판 매드맥스, 월드워Z 혼합 짬뽕 삼류 쓰레기영화 제2의 골든슬림버',
#   '1',
#   '34',
#   '6',
#   datetime.datetime(2020, 7, 15, 20, 28),
#   0],
#  ['ㅎㅎ(jean****)',
#   '억지 감동 , 지극히 한국적인 감성 자극.카트라이더에 좀비 뿌린격 이라는 감상평에 극공감.',
#   '6',
#   '37',
#   '9',
#   datetime.datetime(2020, 7, 18, 8, 10),
#   '관람객'],
#  ['이영민(lee1****)',
#   '볼만합니다 존잼은 아닌데 볼만합니다그러므로 봅시다ㅋㅎ',
#   '8',
#   '138',
#   '110',
#   datetime.datetime(2020, 7, 15, 10, 6),
#   0],
#  ['고근형(rhrm****)',
#   '이렇게 만들꺼면 만들지 말지 그러셨어요..',
#   '1',
#   '35',
#   '8',
#   datetime.datetime(2020, 8, 19, 19, 37),
#   '관람객'],
#  ['Yoo(zhdk****)',
#   '기대없이 보면 재밌게 볼만하지만 스토리가 예측 가능한 좀 뻔한 좀비영화ㅜ',
#   '6',
#   '36',
#   '9',
#   datetime.datetime(2020, 7, 17, 17, 6),
#   '관람객'],
#  ['mekb****',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '38',
#   '11',
#   datetime.datetime(2020, 7, 15, 12, 7),
#   0],
#  ['채린(cofl****)',
#   '강동원 얼굴 봤으면 평점 높게줘라 ㅋㅋ',
#   '10',
#   '41',
#   '14',
#   datetime.datetime(2020, 7, 31, 21, 16),
#   '관람객'],
#  ['choe(vamb****)',
#   "호평의 부산행, 혹평의 서울역. 시리즈 3번째인 '반도'가 연상호 감독의 찐 실력이라고 생각한다. 너무나도 실망스러웠다.",
#   '1',
#   '41',
#   '14',
#   datetime.datetime(2020, 7, 19, 13, 31),
#   '관람객'],
#  ['따듯한라떼한잔굿(dusw****)',
#   '볼만합니다.... 재미는 없습니다.',
#   '1',
#   '41',
#   '14',
#   datetime.datetime(2020, 7, 18, 18, 37),
#   '관람객'],
#  ['솜니움(jeri****)',
#   '나름 스릴?도 있고 볼만하다 생각했는데 마지막 10분은,,할많하않,, 너무 억지감동 억지눈물 끌어내려고 하는듯요 좀비영화라기보단 레이싱 영화인들 싶습니다',
#   '4',
#   '26',
#   '0',
#   datetime.datetime(2020, 7, 22, 20, 45),
#   0],
#  ['1급(wjdg****)',
#   '이런 영화가 평점이 8점후반? 장난하나 ㅋㅋ영화에 절반은 자동차ppl이고 애초에 좀비는 소리에 반응하니 조심하라면서 악셀을 그렇게 밟는데 안온다고?ㅋㅋㅋ쓰레기영화임그냥 그리고 먼영화가 자연스럽게 감동 슬픔을 끄집어 ...',
#   '2',
#   '32',
#   '6',
#   datetime.datetime(2020, 7, 15, 19, 47),
#   0],
#  ['최유경(wewi****)',
#   '카트라이더인줄 감동스러워야되는 부분이 억지스러워서 하나도 안슬픔 되려 웃김 ㅋㅋㅋㅋ 코미디 보는줄 알았음 억지 그 자체 내가 영화관에서 본 영화중에 최악임',
#   '2',
#   '32',
#   '6',
#   datetime.datetime(2020, 7, 15, 19, 45),
#   0],
#  ['추천친구(gaga****)',
#   "단언컨데 2020년 최악의 영화를 봤다.이 영화를 보기 위해 들였던 내 수고와 노력이 너무나 아까워 눈물이 흐를 지경이었다.첫 좀비가 등장하는 순간부터 '어?' 하는 의문이 생겼고, 장면이 거듭되며 의...",
#   '1',
#   '33',
#   '7',
#   datetime.datetime(2020, 7, 15, 22, 6),
#   0],
#  ['윤(baey****)',
#   '형(부산행)만한  아우없다.. 이정현과 강동원이  아깝다...',
#   '4',
#   '34',
#   '8',
#   datetime.datetime(2020, 7, 15, 14, 9),
#   0],
#  ['상추(heyh****)',
#   '이 영화의 주연은 강동원이 아닌 모하비 입니다.',
#   '2',
#   '35',
#   '9',
#   datetime.datetime(2020, 7, 20, 14, 13),
#   '관람객'],
#  ['무취미(wkdl****)',
#   '어떻게 된게 애들이 어른들보다 연기를 더 잘해 ㅋㅋㅋㅋ권해효는 대체 왜 나온거냐 ㅋㅋㅋㅋ',
#   '2',
#   '49',
#   '23',
#   datetime.datetime(2020, 7, 15, 12, 58),
#   0],
#  ['brilliant(brig****)',
#   '본인이 능력미달인데 영화의 변화를 못 받아들인다며 관객 탓으로 돌리는 감독 수준. 이래서 한 장르나 분야에 오래 머무르고 나이 좀 먹은 사람들이 꼰대 소리 고집 쎄다는 소리를 듣는거지. 내 말이 맞아 너희들 말이 틀...',
#   '1',
#   '26',
#   '1',
#   datetime.datetime(2020, 7, 22, 20, 45),
#   0],
#  ['aa01a(yy01****)',
#   '부산행의 반도 못하다 해서 반도...이 말이 맞는듯',
#   '2',
#   '28',
#   '3',
#   datetime.datetime(2020, 10, 17, 12, 18),
#   '관람객'],
#  ['길라잡이(hys1****)',
#   '긴박한  씬 에서  너무  지루한  행동을  함',
#   '6',
#   '29',
#   '4',
#   datetime.datetime(2020, 7, 15, 18, 1),
#   0],
#  ['9gg9gg(kdw7****)',
#   '액션만 보면 정말 좋지만 억지감동(신파)가 심해서 아쉬웠다.',
#   '6',
#   '30',
#   '5',
#   datetime.datetime(2020, 7, 24, 16, 56),
#   '관람객'],
#  ['조물조물(ssu3****)',
#   '반도의 질주 ㅋ CG 너무 엉성',
#   '1',
#   '31',
#   '6',
#   datetime.datetime(2020, 7, 27, 7, 47),
#   '관람객'],
#  ['wogn****',
#   '솔까 이게 어찌 평점이 8.8점인가요?너무 실망했네요영화가 완전 산으로 가는줄~기대가 크면 실망??진심 그냥 실망~~좋은재료로 라면보다 못한 음식나온듯한 절대 추천못함조조로 봤는데 돈아까움8.8점은 알바들인듯 아님 ...',
#   '2',
#   '31',
#   '6',
#   datetime.datetime(2020, 7, 15, 19, 47),
#   0],
#  ['나인(nain****)',
#   '관객을 초등학생 수준으로 만드는 황당한 스토리 연출 수준',
#   '1',
#   '32',
#   '7',
#   datetime.datetime(2020, 7, 30, 0, 1),
#   '관람객'],
#  ['vkvkdltm(siah****)',
#   '강동원 잘생긴거 말고는 딱히....부산행에 비해 재미가 음슴',
#   '6',
#   '32',
#   '7',
#   datetime.datetime(2020, 7, 21, 18, 7),
#   '관람객'],
#  ['이성욱(dkss****)',
#   '좀비는 뒷전이고 그냥 분노의 질주 찍고 싶으셨던게 아닐까',
#   '6',
#   '38',
#   '13',
#   datetime.datetime(2020, 7, 15, 11, 37),
#   0],
#  ['유니폼(isl9****)',
#   '전체적으로 전작에 비해 아쉬움이 남는 영화.마지막 부분은 정말..',
#   '6',
#   '27',
#   '3',
#   datetime.datetime(2020, 7, 19, 20, 35),
#   '관람객'],
#  ['차소영(peac****)',
#   '그냥 무조건 좋음 강동원 개좋음',
#   '10',
#   '30',
#   '6',
#   datetime.datetime(2020, 7, 31, 22, 17),
#   '관람객'],
#  ['tn4372(tn25****)',
#   '어 괜춘한데 왜망했지??~~하다가 중후반이 되시면 댓글들의 이해가되는 영화',
#   '6',
#   '30',
#   '6',
#   datetime.datetime(2020, 7, 26, 11, 42),
#   '관람객'],
#  ['척(kaka****)',
#   '이거 별주는사람 실화냐?',
#   '1',
#   '32',
#   '8',
#   datetime.datetime(2020, 7, 15, 20, 0),
#   0],
#  ['jkke****',
#   '스토리가 머지 중간에 잣어요',
#   '6',
#   '33',
#   '9',
#   datetime.datetime(2020, 7, 20, 15, 45),
#   '관람객'],
#  ['닝닝이(llxx****)',
#   '마지막이 조금 억지스러운 부분이 있지 않나 하지만 전체적으로 재미있게 봤습니다.',
#   '8',
#   '34',
#   '10',
#   datetime.datetime(2020, 7, 26, 15, 59),
#   '관람객'],
#  ['코로나 조심(winm****)',
#   '살아있다보다 100배는 재미있게 봤습니다.',
#   '6',
#   '41',
#   '17',
#   datetime.datetime(2020, 10, 24, 20, 20),
#   '관람객'],
#  ['lhj9****',
#   '정말 답답해 왜 이런건지 그땐 그땐 그땐 좋았었는데',
#   '6',
#   '24',
#   '1',
#   datetime.datetime(2020, 7, 19, 22, 1),
#   '관람객'],
#  ['아메리카노(moon****)',
#   '평들이 나빠서 기대 안하고 보긴 했는데의외로 그냥그냥 볼만함큰 의미 부여하지 말고 오락영화로 보길',
#   '8',
#   '27',
#   '4',
#   datetime.datetime(2020, 8, 2, 15, 23),
#   '관람객'],
#  ['아모(rici****)',
#   '부산행 후속작 타이틀 아니었으면 볼 이유가 없었을거고... 실제로도 왜봤나 싶음...',
#   '3',
#   '29',
#   '6',
#   datetime.datetime(2020, 7, 30, 13, 3),
#   '관람객'],
#  ['baessi(ralp****)',
#   '[당신들의 시간과 돈을 지켜주겠다]영화 반도-1. 올해 개봉한 영화도 몇 없지만후에 개봉할 작품까지 합쳐 최악의 영화2. 빨리 차에 타라면 좀 타라!!!하..그외 평 조차 아깝다.-한줄평:영화 ‘반’ 도 보기 전에 ...',
#   '2',
#   '29',
#   '6',
#   datetime.datetime(2020, 7, 15, 20, 35),
#   0],
#  ['십벌지목(seyu****)',
#   '아~~~~!그멋진 배우들을 가지고 멀한건지...속상합니다.최악',
#   '2',
#   '30',
#   '7',
#   datetime.datetime(2020, 7, 22, 9, 18),
#   '관람객'],
#  ['뽈뽀(hhl1****)',
#   '좀비 영화를 보러 갔는데 자동차 추격씬이랑 구교현만 기억남. 인물들간 감정선에 하나도 이입이 안 돼서 후반 신파랑 반전 장면에는 헛웃음이 나옴.',
#   '5',
#   '31',
#   '8',
#   datetime.datetime(2020, 8, 29, 11, 32),
#   '관람객'],
#  ['이연주(kiju****)',
#   '반도 못보고 뛰쳐나가고싶었어요.',
#   '3',
#   '31',
#   '8',
#   datetime.datetime(2020, 7, 27, 23, 52),
#   '관람객'],
#  ['뽀뽀(kyws****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '31',
#   '8',
#   datetime.datetime(2020, 7, 18, 1, 27),
#   '관람객'],
#  ['수우(beny****)',
#   '부산행만큼은 아니지만 볼만한 영화였고 자동차 액션씬 기억에 남았습니다. 구교환 배우도 매력적이었습니다.',
#   '8',
#   '34',
#   '11',
#   datetime.datetime(2020, 7, 24, 21, 19),
#   '관람객'],
#  ['플레기(azz2****)',
#   '영상미 기대하고 봤는데 신파 덕분에 기분 짜치게 함',
#   '5',
#   '39',
#   '16',
#   datetime.datetime(2020, 7, 15, 11, 14),
#   0],
#  ['비밀이얌(seoj****)',
#   '그놈에 신파...PPL 자동차는 좀비도 쓸어버릴정도로 힘이 좋다는 광고 잘 봤습니다..모하비는 최고 였습니다..좀비판국에 영어는 항상 필수 입니다..전부다 영어를 기가 막히게 잘함',
#   '6',
#   '26',
#   '4',
#   datetime.datetime(2020, 7, 19, 19, 36),
#   '관람객'],
#  ['SKINFO(kill****)',
#   '영 재미가없군 이것저것 붙인 짜집기 영화임 우리나라는 결국망하고 우릴살리는건 미국뿐미국만이 살길임',
#   '2',
#   '30',
#   '8',
#   datetime.datetime(2020, 7, 24, 12, 1),
#   '관람객'],
#  ['us02****',
#   '그냥 그래요 시간은 잘가네요',
#   '6',
#   '30',
#   '8',
#   datetime.datetime(2020, 7, 18, 2, 38),
#   '관람객'],
#  ['없음(kera****)',
#   '알바 득실거리네 긴말안한다 감독전작이 염력이다.',
#   '2',
#   '30',
#   '8',
#   datetime.datetime(2020, 7, 15, 16, 33),
#   0],
#  ['김동걸(teve****)',
#   '진짜 유치해서 못보겠네',
#   '1',
#   '31',
#   '9',
#   datetime.datetime(2020, 7, 15, 17, 5),
#   0],
#  ['랭공(elit****)',
#   '영화볼돈으로 넷플릭스 한 달 가입해서보세요 ㅜㅜ코로나이후로 처음 갔다 실망만하고 옵니다....',
#   '1',
#   '32',
#   '10',
#   datetime.datetime(2020, 7, 22, 23, 20),
#   '관람객'],
#  ['한울6유주(jjin****)',
#   '영상은 많이 발전하고 결말이 급작스럽지만 내용도 흥미진진했습니다. 다음날 #살아있다는 현실좀비내용이라면 반도는 영상과 재미를 다 추구했다고 생각합니다. (역시 강동원만 화면에 비추면 느와르가되는 ㅋㅋ) 비쥬얼 역시 ...',
#   '8',
#   '36',
#   '14',
#   datetime.datetime(2020, 7, 22, 16, 0),
#   '관람객'],
#  ['tjda****',
#   '시사회로 보고왓는데 전 갠적으로 재미있었어요. 액션 좋아하면 완전 찰떡임 캬',
#   '10',
#   '129',
#   '107',
#   datetime.datetime(2020, 7, 15, 9, 50),
#   0],
#  ['그레이스제이(xjrr****)',
#   '',
#   '2',
#   '22',
#   '1',
#   datetime.datetime(2020, 7, 21, 12, 50),
#   '관람객'],
#  ['용이맘(yomg****)',
#   '영화보고 기억에 남는 건 자동차액션씩밖에 없다!!',
#   '6',
#   '23',
#   '2',
#   datetime.datetime(2020, 7, 20, 18, 44),
#   '관람객'],
#  ['sjc5****',
#   '추격씬 액션씬 cg티가 너무 많이나서 몰입이 힘드네요.전체적인 스토리는 평이합니다. 이정현씨 연기는 볼때마다 가수의 모습은 전혀 떠오르지가 않아서 보기 좋았어요.',
#   '6',
#   '26',
#   '5',
#   datetime.datetime(2020, 7, 18, 18, 36),
#   '관람객'],
#  ['영재(ehdd****)',
#   '클리세란 클리세는 다 쳐부어놔서 인물이 어떻게 될지 뻔한영화 좀비영화에서 베이비 드라이버 찍어버리는 미친영화 대단하다 한국영화',
#   '2',
#   '27',
#   '6',
#   datetime.datetime(2020, 7, 15, 19, 28),
#   0],
#  ['연어샐러드(dusx****)',
#   '좀비물인데 감동씬 나오고 코미디씬 나오고 혼종입니다 그리고 내용 개연성이 없습니다 돈이 아깝네요',
#   '2',
#   '28',
#   '7',
#   datetime.datetime(2020, 7, 15, 19, 41),
#   0],
#  ['iceb****',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '1',
#   '28',
#   '7',
#   datetime.datetime(2020, 7, 15, 16, 28),
#   0],
#  ['제이유(feel****)',
#   '캐릭터 서사 개연성 좀비 아무것도 안보이는 영화 예고편 강동원에 너무 크게 낚였다 대실망 기대를 내려놓고 킬링타임으로 추천',
#   '4',
#   '28',
#   '7',
#   datetime.datetime(2020, 7, 15, 15, 32),
#   0],
#  ['yeji****',
#   '진짜 개재없어요기억에 남는건 쀼슝 하나뿐이네요 ㅋ보지마세요 제발..살아있다보다 별로인 영화는 처음이네요',
#   '1',
#   '29',
#   '8',
#   datetime.datetime(2020, 7, 15, 19, 36),
#   0],
#  ['웰쓰(ace_****)',
#   '부산행2 라고요?직관 영화중 젤 실망~',
#   '2',
#   '30',
#   '9',
#   datetime.datetime(2020, 7, 19, 12, 32),
#   '관람객'],
#  ['jyjy****',
#   '부산행을 보고 기대를 너무 했었나봐요~~감동팔이느낌이..',
#   '6',
#   '34',
#   '13',
#   datetime.datetime(2020, 7, 16, 9, 18),
#   '관람객'],
#  ['박동선(spdh****)',
#   '좀비영화가아니라 매드맥스를본거같음',
#   '6',
#   '36',
#   '15',
#   datetime.datetime(2020, 7, 15, 10, 38),
#   0],
#  ['테리(skyi****)',
#   '오랜만에본 영화.정말 정말 재미없는 영화!',
#   '2',
#   '45',
#   '24',
#   datetime.datetime(2020, 7, 18, 22, 34),
#   '관람객'],
#  ['참피(wise****)',
#   '애 두명때문에 평점 깎는다',
#   '2',
#   '68',
#   '47',
#   datetime.datetime(2020, 7, 16, 19, 22),
#   '관람객'],
#  ['최현정(hey8****)',
#   '영화 시작전 현대차 광고가 더 감동적..운전만 하다 끝난 영화',
#   '1',
#   '22',
#   '2',
#   datetime.datetime(2020, 7, 27, 16, 5),
#   0],
#  ['왕뚠(qkfk****)',
#   '장갑차보다 강한 모하비',
#   '4',
#   '26',
#   '6',
#   datetime.datetime(2020, 8, 23, 16, 41),
#   '관람객'],
#  ['OZ(wls7****)',
#   '정.말.재.미.없.었.다.',
#   '1',
#   '26',
#   '6',
#   datetime.datetime(2020, 7, 29, 23, 47),
#   '관람객'],
#  ['레이나니(popo****)',
#   '그냥 내 취향이 아니라고 생각함',
#   '2',
#   '29',
#   '9',
#   datetime.datetime(2020, 7, 18, 15, 24),
#   '관람객'],
#  ['그뉴기(l_he****)',
#   '진짜 처음 남겨봄 평점을',
#   '2',
#   '31',
#   '11',
#   datetime.datetime(2020, 7, 19, 13, 19),
#   '관람객'],
#  ['아돌(cdj1****)',
#   '쓸데없는 신파만 좀 뺏으면 더 깔끔했을듯... 액션은 나쁘지 않음',
#   '7',
#   '31',
#   '11',
#   datetime.datetime(2020, 7, 18, 13, 36),
#   '관람객'],
#  ['La Decimotercera 13(ekrc****)',
#   '이게 좀비영화인지 액션영화인지.... 내용이나 개연성도 부족하고 엔딩은 역시나 되도않는 신파.... 너무 아쉽네요',
#   '5',
#   '32',
#   '12',
#   datetime.datetime(2020, 7, 18, 0, 38),
#   '관람객'],
#  ['assa****',
#   '볼만한대요? ㅋ 재밌게봤어요',
#   '8',
#   '39',
#   '19',
#   datetime.datetime(2020, 7, 23, 15, 38),
#   '관람객'],
#  ['리버풀코인(rise****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '19',
#   '0',
#   datetime.datetime(2020, 7, 18, 17, 31),
#   '관람객'],
#  ['허허허(herm****)',
#   '영화 초반에만 기대감 충족중,후반은 흔한 식상한 스토리부산행에선  좀비가 주연이였다면반도는  양념정도.',
#   '6',
#   '20',
#   '1',
#   datetime.datetime(2020, 7, 18, 18, 42),
#   '관람객'],
#  ['블랙범(sy74****)',
#   '연상호 이 양반 부산행 얻어 걸린거였네.영화 개판이네',
#   '2',
#   '21',
#   '2',
#   datetime.datetime(2020, 7, 16, 17, 39),
#   0],
#  ['Kkkk(tlst****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '23',
#   '4',
#   datetime.datetime(2020, 7, 19, 23, 42),
#   '관람객'],
#  ['이형준(xgud****)',
#   '진짜 이게 왠 부산행2인지ㅋㅋ만들거면 부산행과 이어지게 한국이 부산에서 좀비막고 살아가는 그림이어야되는데 폐허되고 중국가고 무슨 군인갖지도않은 것들 나와서 해적질하고 진짜 스토리. 씹노잼 외국d급영화보다 재미없음',
#   '1',
#   '25',
#   '6',
#   datetime.datetime(2020, 8, 18, 13, 23),
#   '관람객'],
#  ['재뱀교포3세(s1as****)',
#   '부산행 반도 안되는 수준의 영화',
#   '5',
#   '25',
#   '6',
#   datetime.datetime(2020, 7, 22, 8, 53),
#   '관람객'],
#  ['니이모를 찾아서(jiny****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '3',
#   '25',
#   '6',
#   datetime.datetime(2020, 7, 15, 13, 32),
#   0],
#  ['행배야(pmh2****)',
#   '하....이게영화냐????',
#   '4',
#   '26',
#   '7',
#   datetime.datetime(2020, 7, 15, 19, 42),
#   0],
#  ['맹구는 못말려(qkra****)',
#   '전형적인 한국영화 클리셰 억지눈물 억지감동 ㅈ노잼 대사 중2병',
#   '2',
#   '27',
#   '8',
#   datetime.datetime(2020, 7, 15, 17, 6),
#   0],
#  ['피파100단(ogn1****)',
#   '초등학생이 쓴 줄거리 수준이네요..',
#   '1',
#   '28',
#   '9',
#   datetime.datetime(2020, 7, 15, 16, 34),
#   0],
#  ['산티아고 뮤네즈(blue****)',
#   '아.. 이래서 한국영화지..',
#   '1',
#   '29',
#   '10',
#   datetime.datetime(2020, 7, 15, 16, 39),
#   0],
#  ['goqh****',
#   'ㅋㅋ 진짜 영화이름 잘 지었네요 영화의 “반도” 못 보고 나올뻔 그래서 평점도 반으로 드립니다~',
#   '5',
#   '20',
#   '2',
#   datetime.datetime(2020, 7, 16, 2, 51),
#   0],
#  ['caparison(lvle****)',
#   'vod로 볼걸....',
#   '6',
#   '21',
#   '3',
#   datetime.datetime(2020, 7, 20, 6, 36),
#   '관람객'],
#  ['혼이아빠(ldk2****)',
#   '결국 영화는 감독 선택의 결과지만 스토리와 개연성 그리고 액션이라는 부분들의 부족함과 부산행과 연결되지 않으려 했다면 적어도 기존 좀비 영화와는 다른 부분들이 있어야 했다면 욕심일까?',
#   '6',
#   '22',
#   '4',
#   datetime.datetime(2020, 7, 16, 15, 56),
#   '관람객'],
#  ['stu12(dlag****)',
#   '대사하나하나가 너무 오글거리고 억지눈물짜내기',
#   '2',
#   '22',
#   '4',
#   datetime.datetime(2020, 7, 16, 1, 6),
#   0],
#  ['hsm9****',
#   '처음으로 감상평이란걸 써본다.. 와씨 태어나서 이렇게 잼없는 영화 처음봄내 돈 만원... 알바댓글 작작써라',
#   '1',
#   '24',
#   '6',
#   datetime.datetime(2020, 7, 15, 19, 40),
#   0],
#  ['hotttttttt(rlat****)',
#   '진짜 기대이하 요즘 한국영화 너무 막 만든다는 느낌  돈이랑 시간 아깝다',
#   '4',
#   '24',
#   '6',
#   datetime.datetime(2020, 7, 15, 19, 39),
#   0],
#  ['char****',
#   '매드맥스×0.1 + 살아있다x0.5 = 반도....보는 내내 감정을 강요당하는 고문을 당한 느낌.',
#   '1',
#   '25',
#   '7',
#   datetime.datetime(2020, 7, 15, 19, 39),
#   0],
#  ['또리애미(daja****)',
#   '강동원 얼굴이 개연성이다',
#   '6',
#   '27',
#   '9',
#   datetime.datetime(2020, 7, 26, 15, 8),
#   '관람객'],
#  ['강유리(com9****)',
#   '스토리에 개연성이 없더라도 긴박하거나 스릴 넘치는 장면이 많다보면 집중이 되긴 마련인데 .. 영화 내내 지루한 내용이 대부분이어서 소재는 좀 신박한 편이었지만 배우들의 연기를 보여주기도 좀 아쉬운 스토리지 않았나 싶...',
#   '2',
#   '28',
#   '10',
#   datetime.datetime(2020, 8, 22, 15, 37),
#   '관람객'],
#  ['김갱(kalv****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '5',
#   '28',
#   '10',
#   datetime.datetime(2020, 7, 17, 23, 45),
#   '관람객'],
#  ['한세빈(tpql****)',
#   '좀비영화 중 제일 재밌게 본 것 같아요 운전하는 거 멋있네요',
#   '10',
#   '29',
#   '11',
#   datetime.datetime(2020, 7, 31, 17, 29),
#   '관람객'],
#  ['웅(asw4****)',
#   '시간남아도 안보는것을 추천',
#   '5',
#   '39',
#   '21',
#   datetime.datetime(2020, 8, 29, 16, 26),
#   '관람객'],
#  ['피피걸(qvhb****)',
#   '부산행에 마동석이 있다면 반도에는 이레가 있다는 말이 무슨말인지 백번 실감함ㅡㅡ! 나보다 멋지면 다 언니!! 이레 언니 멋있어요ㅋㅋㅋㅋ',
#   '10',
#   '589',
#   '571',
#   datetime.datetime(2020, 7, 15, 12, 32),
#   '관람객'],
#  ['트래블러(fbi5****)',
#   '너무 큰 기대 안 가지고 보면 재미있습니다.',
#   '8',
#   '20',
#   '3',
#   datetime.datetime(2020, 8, 1, 9, 58),
#   '관람객'],
#  ['샤인라잇(kang****)',
#   '부산행은 ㄹㅇ레전드였는데 너무 기대를 한 탓을까요 스토리 구성 흐름 연결성 모두 아쉬워요ㅠㅠ 기대에 전혀 못미쳐요ㅠ',
#   '4',
#   '20',
#   '3',
#   datetime.datetime(2020, 7, 16, 2, 50),
#   0],
#  ['네메(ojo1****)',
#   '제목은 거창하게 반도로 해놓고 인천항도 안되는 얘기에 신기할정도로 배우들이 연기를 못해서 보기 힘든. 이제 연상호감독껀 거르는걸로, 밑천드러났음.',
#   '4',
#   '20',
#   '3',
#   datetime.datetime(2020, 7, 16, 0, 32),
#   0],
#  ['하늘은색(no2b****)',
#   "K좀비. 아메리카 좀비의 반에 '반도'",
#   '1',
#   '20',
#   '3',
#   datetime.datetime(2020, 7, 15, 22, 8),
#   0],
#  ['choh****',
#   '끝날때까지 감동을 주는 명작 ㅡㅡ',
#   '2',
#   '20',
#   '3',
#   datetime.datetime(2020, 7, 15, 20, 29),
#   0],
#  ['강냉이(khj_****)',
#   '강동원나언데서 포스터조차안보고 본내잘못..강동원얼굴만좋고 뻔한좀비물',
#   '1',
#   '24',
#   '7',
#   datetime.datetime(2020, 7, 20, 2, 44),
#   '관람객'],
#  ['안일하면안돼(honn****)',
#   '안보는게 제일 낫겠지만 굳이 보겠다면 밤에 보지않는걸 추천한다 보다가 잠온다 세부 평점하품 7번 -7클리셰 연출 -10강동원 얼굴+10지긋지긋한 한국영화식 신파 -2강동원 잘생겼긴 하더라 진짜 인정한다',
#   '1',
#   '25',
#   '8',
#   datetime.datetime(2020, 7, 30, 8, 37),
#   '관람객'],
#  ['바람의 검(pung****)',
#   '폐허가 된 서울의 모습, 자동차 액션 등 여러가지 면에서 나름 볼만 했습니다만 부산행만큼의 아기자기한 재미는 없네요, 특히 마지막 10분은 말도 안되고, 이해도 안되는 이야기로 이어지며 영화가 끝나 아쉬움이 큽니다....',
#   '6',
#   '28',
#   '11',
#   datetime.datetime(2020, 7, 18, 21, 42),
#   '관람객'],
#  ['베짱이(kate****)',
#   '그냥 분노의 질주를 본 기분이다. 스토리가 집중이 안되고 부산행의 기대에 못 미치는 것 같다. 감동도 억지스럽다. 기대하지 않았지만 실망스럽다ㅠ그래도 액션은 볼 만 했다.',
#   '4',
#   '28',
#   '11',
#   datetime.datetime(2020, 7, 15, 15, 21),
#   0],
#  ['박찌(sung****)',
#   '재밌었음매드맥스 보는거 같았음강동원 잘생김',
#   '10',
#   '30',
#   '13',
#   datetime.datetime(2020, 7, 23, 23, 1),
#   '관람객'],
#  ['썬이(sjs3****)',
#   '한국영화치고는 액션이며 연출 나름 퀼리티높던데 왜이리 꼬투리잡아서 혹평하는지 ㅠㅋㅋ저 액션영화매니아인데  매드맥스은 신급인데 비교하는건 ㅋㅋ 반도도 잘만들었어요  시간이 짧게느낄만큼 재밌음',
#   '10',
#   '33',
#   '16',
#   datetime.datetime(2020, 8, 1, 22, 7),
#   '관람객'],
#  ['푸드드(cheo****)',
#   '좀비 카트라이더 + 억즙 감성팔이 + 페미의 완성작입니다. 예고편에서 봤던 역겨운 대사와 잔다르크의 활약상 가득하구요.  특히 배우들의 연기가 아역보다 못합니다. 1점도 아까워요  액션이라는게 GTA마냥 영화의 절반...',
#   '1',
#   '34',
#   '17',
#   datetime.datetime(2020, 7, 15, 13, 4),
#   0],
#  ['아우으(dkre****)',
#   '재밋던데나는.. 평점들왜이래ㄱㅋ',
#   '10',
#   '37',
#   '20',
#   datetime.datetime(2020, 7, 23, 7, 26),
#   '관람객'],
#  ['덴마크(aejj****)',
#   '별로지만 #살아있다 보다 훨씬 나음',
#   '6',
#   '41',
#   '24',
#   datetime.datetime(2020, 7, 18, 21, 48),
#   '관람객'],
#  ['윤오(ensk****)',
#   '이레 배우님 멋있었습니다.',
#   '6',
#   '47',
#   '30',
#   datetime.datetime(2020, 7, 15, 23, 44),
#   '관람객'],
#  ['인정(dlsw****)',
#   '나는 너무 재밋게 봤는데.. ㅋ ㅠㅋ',
#   '8',
#   '72',
#   '55',
#   datetime.datetime(2020, 7, 16, 17, 7),
#   '관람객'],
#  ['원츄(7763****)',
#   '부산행 반도 안된다..그래서 반도 였나보다',
#   '6',
#   '17',
#   '1',
#   datetime.datetime(2020, 7, 15, 20, 36),
#   0],
#  ['이상형(qnfr****)',
#   "재미없다.차라리 '살아있다'가 낫다.객관적으로 역대급 노잼",
#   '1',
#   '18',
#   '2',
#   datetime.datetime(2020, 7, 21, 14, 29),
#   0],
#  ['ILX1337(ggnb****)',
#   '다시는 한국에서 좀비 영화 후속편 만들면 안될 것 같다는 생각을 심어준 영화 딱 부산행까지가 한국 좀비 영화의 끝인거같다.',
#   '1',
#   '18',
#   '2',
#   datetime.datetime(2020, 7, 16, 2, 24),
#   0],
#  ['FWDo(hyun****)',
#   '그저 부산행이라는 한국 좀비물의 최고봉을 망쳐냈다. 개연성과 현실성은 영화적 허용을 넘어섰다.',
#   '1',
#   '18',
#   '2',
#   datetime.datetime(2020, 7, 16, 2, 4),
#   0],
#  ['내친구 현대자동차(dken****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '4',
#   '19',
#   '3',
#   datetime.datetime(2020, 7, 16, 2, 48),
#   0],
#  ['weqteyertyertwertert(tktm****)',
#   '그냥 볼만한영화가  이거밖에없어서 봤는데 재밋게봤습니다 나쁘지않았',
#   '8',
#   '20',
#   '4',
#   datetime.datetime(2020, 7, 25, 19, 52),
#   '관람객'],
#  ['코니(shin****)',
#   '억지감동 쥐어짜는 느낌이라 좀 그랬는데 전반적으로 ㄱㅊ',
#   '6',
#   '20',
#   '4',
#   datetime.datetime(2020, 7, 23, 0, 48),
#   '관람객'],
#  ['울금(main****)',
#   '한국 영화의 위대한 후퇴. 그저 자본으로 밀어붙인 규모의 영상미. 카메라는 성의없이 흔들리고, 모든 캐릭터는 동떨어져 입만 열면 위화감을 조성한다. 기대하고 갔다 허탈한 웃음만',
#   '1',
#   '20',
#   '4',
#   datetime.datetime(2020, 7, 16, 2, 56),
#   0],
#  ['김건희(pock****)',
#   '핵노잼 진짜 진부하다 구리고 노래도 그렇고 모든게 오글거림',
#   '2',
#   '20',
#   '4',
#   datetime.datetime(2020, 7, 16, 2, 45),
#   0],
#  ['죽은곰(hyun****)',
#   '제발 이런 구닥다리 해피엔딩 클리셰 좀 빼면 안되나.     할 말 많지만 일일이 쓰는 것도 시간아까움. 개인적으로 7광구를 잇는 최악의 영화임',
#   '2',
#   '20',
#   '4',
#   datetime.datetime(2020, 7, 16, 1, 20),
#   0],
#  ['yugn****',
#   '가지말라는데 가고 하지말라는 거 하고, 빨리 가야되는데 멍 때리고, 거리 벌어지고 난 다음에야 총 쏘고, 질질 끄는 진짜 재미 없는 영화',
#   '2',
#   '20',
#   '4',
#   datetime.datetime(2020, 7, 15, 22, 0),
#   0],
#  ['아이리스(dumo****)',
#   '살아있다가 더 나을정도입니다.',
#   '1',
#   '21',
#   '5',
#   datetime.datetime(2020, 7, 16, 3, 2),
#   0],
#  ['허블링(gjgk****)',
#   '어거지감동 넣으려고 쳐 싸우다 즙짜고 적당히 해라 진짜 OOO싫으면 한국영화인걸 감안해도 진짜 즙을 너무 오래짠다 매년 양상되는 코리안 흥행영화',
#   '2',
#   '21',
#   '5',
#   datetime.datetime(2020, 7, 16, 1, 36),
#   0],
#  ['대경서부오리지날장군(bban****)',
#   '저는 너무 재밌었던 것 같아욤!액션 신도 너무 스릴 넘쳤구 좋았어용',
#   '9',
#   '22',
#   '6',
#   datetime.datetime(2020, 7, 31, 22, 29),
#   '관람객'],
#  ['CLYDE(tmdt****)',
#   '역겨운 한국 영화 평점알바',
#   '1',
#   '22',
#   '6',
#   datetime.datetime(2020, 7, 15, 17, 23),
#   0],
#  ['kate(dsky****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '4',
#   '25',
#   '9',
#   datetime.datetime(2020, 7, 19, 14, 2),
#   '관람객'],
#  ['김현우(vz00****)',
#   '음 뭔가 감정이입이 안됨.. 그리고 부산행과 달리 너무 비현실적이야..원래 좀비물이란게 좀비가 쫓아오고 주인공이 달리기만 해도 절반은 가는게 맞는데 이건 너무 오바가 많아',
#   '1',
#   '17',
#   '2',
#   datetime.datetime(2020, 7, 16, 2, 9),
#   0],
#  ['하브하브(2587****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '4',
#   '18',
#   '3',
#   datetime.datetime(2020, 7, 26, 20, 0),
#   '관람객'],
#  ['LeMoNaid(doli****)',
#   '나영석 PD의 신서유기 좀비게임이 더 재밌습니다.혹시 이 영화를 볼까 고민하시는 분이 계시다면 그 돈으로 치킨을 드시길바랍니다. "어?? 평점이 꽤 높은데?", "그래도 나는 재밌게 볼 수 있지...',
#   '1',
#   '18',
#   '3',
#   datetime.datetime(2020, 7, 16, 11, 19),
#   0],
#  ['츄배(wisd****)',
#   '스토리 개연성 너무 억지야...난 솔직히 살아있다가 더재밋었어',
#   '4',
#   '18',
#   '3',
#   datetime.datetime(2020, 7, 16, 2, 40),
#   0],
#  ['minimalism(mini****)',
#   'CG는 정말 발전했는데 스토리와 연출이 정말 너무 아쉬움. (특히 한국식 대사와 무게감 없는 캐릭터)',
#   '3',
#   '18',
#   '3',
#   datetime.datetime(2020, 7, 16, 2, 39),
#   0],
#  ['ever****',
#   '강동원때문에그나마끝까지보구나옴',
#   '2',
#   '19',
#   '4',
#   datetime.datetime(2020, 7, 27, 14, 43),
#   '관람객'],
#  ['로켓맨(caac****)',
#   '진심 눈 썩어가는 줄..카체이싱이 또봇 퀄리티. 뭐하러 넣었냐.좀비 영화 극혐 설정. 인간들 대립구도..하아.좀비영화에 뭐 저런 부류가 다 집중하는건28일후 하나로 족한데 개나 소나 따라하고.개연성은 말할 것도 없고...',
#   '2',
#   '19',
#   '4',
#   datetime.datetime(2020, 7, 15, 23, 22),
#   0],
#  ['원시인(nice****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '1',
#   '19',
#   '4',
#   datetime.datetime(2020, 7, 15, 14, 55),
#   0],
#  ['clzl****',
#   '뻔한 한국식 갬성 짜집어넣기',
#   '5',
#   '21',
#   '6',
#   datetime.datetime(2020, 7, 24, 0, 26),
#   '관람객'],
#  ['ehdd****',
#   '생각보다는 그냥 그랬습니다',
#   '4',
#   '21',
#   '6',
#   datetime.datetime(2020, 7, 18, 15, 36),
#   '관람객'],
#  ['msl8****',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '2',
#   '22',
#   '7',
#   datetime.datetime(2020, 7, 16, 1, 15),
#   0],
#  ['rain****',
#   '짜맞춘 스토리 입니다 재미없다',
#   '2',
#   '24',
#   '9',
#   datetime.datetime(2020, 8, 21, 22, 19),
#   '관람객'],
#  ['rla(rlaw****)',
#   '솔직히 두번볼 영화는아님',
#   '6',
#   '24',
#   '9',
#   datetime.datetime(2020, 7, 15, 12, 6),
#   0],
#  ['나는진보다(jame****)',
#   '씨발 주변에 이 영화 보고 재밌다고 하는 인간은 21세기 문화생활 영유하는데 하자 있는 인간으로 사료됨. 연기,연출,시나리오 다 분노의 질주행',
#   '1',
#   '26',
#   '11',
#   datetime.datetime(2020, 7, 15, 17, 59),
#   0],
#  ['Shvwh(js91****)',
#   '평점테러불쌍해서10점 줍니다,정말 재미있어요, 강동원넘 멋있고 이정현연기넘잘해요 ㅠㅜ 조연들도 잘해요 ㅜㅜ 한번더보려고요',
#   '10',
#   '28',
#   '13',
#   datetime.datetime(2020, 7, 31, 17, 28),
#   '관람객'],
#  ['손발(hjgs****)',
#   '진짜 노잼',
#   '3',
#   '29',
#   '14',
#   datetime.datetime(2020, 7, 25, 14, 29),
#   '관람객'],
#  ['아희(akar****)',
#   '아... 이걸 돈 주고 보다니....부산행 보다 작품성 오락성 모두 떨어지고남편은 옆에서 졸다가 나왔음보자구 보챈 내가 너무 미워졌음',
#   '5',
#   '31',
#   '16',
#   datetime.datetime(2020, 8, 28, 11, 46),
#   '관람객'],
#  ['미밈미(hhyy****)',
#   '',
#   '5',
#   '14',
#   '0',
#   datetime.datetime(2020, 7, 19, 19, 49),
#   '관람객'],
#  ['김은희(toki****)',
#   '가볍게 보기 좋지만 스토리는 사실 그닥...그냥 게임방에서 총게임하는 걸 보는 느낌이었음 인간의 잔혹함을 잘 나타낸 것 같다고 생각함!!!',
#   '7',
#   '15',
#   '1',
#   datetime.datetime(2020, 8, 30, 19, 56),
#   '관람객'],
#  ['삼단버럭(wngu****)',
#   '기대에 못미치네요스토리가 영',
#   '5',
#   '15',
#   '1',
#   datetime.datetime(2020, 7, 21, 12, 53),
#   '관람객'],
#  ['조마시(jooj****)',
#   '좀비물 차량 액션 영화',
#   '6',
#   '15',
#   '1',
#   datetime.datetime(2020, 7, 20, 21, 59),
#   '관람객'],
#  ['남궁캐리(leca****)',
#   '0점이 있다면 주고싶네요...',
#   '1',
#   '15',
#   '1',
#   datetime.datetime(2020, 7, 19, 14, 27),
#   0],
#  ['캡틴(cool****)',
#   '아.. 할말이 없다. 연출 정말 올드하다. 억지 감동 짜내는 슬로우는 보기 힘들었다. 초반은 좋지만 중반부터 말아먹기 시작한다.',
#   '4',
#   '15',
#   '1',
#   datetime.datetime(2020, 7, 16, 11, 10),
#   0],
#  ['타란티노(jjda****)',
#   '한국영화의 시간은 거꾸로 간다. 처참해서 눈을 질끈 감았던 순간이 셀 수 없이 많았다.',
#   '1',
#   '15',
#   '1',
#   datetime.datetime(2020, 7, 16, 11, 5),
#   0],
#  ['이유진(yll4****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '8',
#   '16',
#   '2',
#   datetime.datetime(2020, 7, 21, 14, 50),
#   '관람객'],
#  ['짭짭이(maeb****)',
#   '좀비 위주라기보다 인간 위주의 영화',
#   '6',
#   '17',
#   '3',
#   datetime.datetime(2020, 7, 22, 19, 13),
#   '관람객'],
#  ['꼼앵(rudf****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '2',
#   '17',
#   '3',
#   datetime.datetime(2020, 7, 16, 3, 27),
#   0],
#  ['choi****',
#   '실망이구만. 폐허인데 차가 가운데는 고속도로야ㅋㅋ 더럽게 재미없네',
#   '2',
#   '17',
#   '3',
#   datetime.datetime(2020, 7, 16, 2, 24),
#   0],
#  ['제발요(jch5****)',
#   '뭘표현한건지도 모르겠고 보다가 어이가없어서 웃음나오긴 또 오랜만이네',
#   '4',
#   '17',
#   '3',
#   datetime.datetime(2020, 7, 16, 2, 15),
#   0],
#  ['유후(qhep****)',
#   '적당히 좀 해 알바들아',
#   '1',
#   '17',
#   '3',
#   datetime.datetime(2020, 7, 16, 1, 24),
#   0],
#  ['ㅓㅏㅘㅣㅕㅛ(good****)',
#   '@여러분 이거 2점 이상부터 전부 댓글알바임@지금 보고나오자마자 빡쳐서 앉아서 리뷰 작성 중임. 영화 시작하자마자 배우들 연기가 웹드라마 배우들보다 훨씬 못하는 수준이여서 깜짝놀람. 와 진짜 영화보는내내 우리뿐만아니...',
#   '1',
#   '17',
#   '3',
#   datetime.datetime(2020, 7, 16, 0, 27),
#   0],
#  ['웅(ehdt****)',
#   '부산행을 안봐도 스토리이해가쉬움연출도 화려하고 배우들연기도 좋음재미잇다기보다 그냥 시간떼우기용.기억에남는것도 전혀없음',
#   '4',
#   '18',
#   '4',
# ...
#   '5',
#   datetime.datetime(2020, 8, 7, 1, 29),
#   '관람객'],
#  ['안냐옹(wlsw****)',
#   '또 저만 재밌게 봤나요 ..^^ ㅎㅎ저는 액션도 다양해서 재밌고 살짝 분노의 질주 같기는 했지만 그래도 스릴 넘치고 재밌었습니다.하지만 후반부에서 조금 스토리 연계가 억지의 느낌이 있었지만 전체적으로 평하자면 재밌어...',
#   '9',
#   '10',
#   '5',
#   datetime.datetime(2020, 8, 5, 17, 7),
#   '관람객'],
#  ['똘강이(kyyk****)',
#   '억지감동을 주려고 하니 지루했고 예측가능한 전개,, 좀비 영환데 긴장감 없음',
#   '6',
#   '10',
#   '5',
#   datetime.datetime(2020, 8, 2, 15, 43),
#   '관람객'],
#  ['지니공주(xotn****)',
#   '딸이랑같이 보러갔는데 무섭다고 난리난리여름영화로 강추 .',
#   '8',
#   '10',
#   '5',
#   datetime.datetime(2020, 8, 1, 10, 55),
#   '관람객'],
#  ['라디의 행복(fkel****)',
#   '그럭저럭',
#   '6',
#   '10',
#   '5',
#   datetime.datetime(2020, 7, 31, 20, 21),
#   '관람객'],
#  ['예빈(kimy****)',
#   '분노의 질주?',
#   '7',
#   '10',
#   '5',
#   datetime.datetime(2020, 7, 25, 15, 13),
#   '관람객'],
#  ['rhss****',
#   '재밌게봤어요운전씬도 좋았고근데 너무 첨부터끝날때까지 슬픔을 강조해서 조금 아쉬움',
#   '8',
#   '11',
#   '6',
#   datetime.datetime(2020, 7, 24, 14, 56),
#   '관람객'],
#  ['qodb****',
#   '좀비영화가 아니라 자동차 영화인가 싶었고 부산행이랑 연관된 내용은 1도 없지만 재미있음',
#   '8',
#   '12',
#   '7',
#   datetime.datetime(2020, 8, 20, 8, 24),
#   '관람객'],
#  ['namu(dwfo****)',
#   '매드맥스를 보는 듯한 느낌의 추격씬이 가장 인상적이었습니다.재미있었어요~',
#   '8',
#   '12',
#   '7',
#   datetime.datetime(2020, 7, 31, 21, 10),
#   '관람객'],
#  ['min9160(min3****)',
#   '재미있게 잘 봤습니다. 배우들의 연기는 최고였고, 다만 조금 질질 끄는 게 아쉬웠어요. 전형적인 약간의 억지 감동은 빼주셨으면 더 좋지 않았을까',
#   '7',
#   '12',
#   '7',
#   datetime.datetime(2020, 7, 19, 15, 37),
#   '관람객'],
#  ['쓰랄랄라(naor****)',
#   '저렇게 훌륭한 배우들 데려다가 이딴 스토리밖에 못 만들어낸 감독도 재주다. 갑작스런 신파에서 실소가 터져나온다.아역들도 연기 잘하던데 감독 창피한 줄 알아야한다.',
#   '4',
#   '12',
#   '7',
#   datetime.datetime(2020, 7, 15, 16, 28),
#   0],
#  ['최혜원(fkd4****)',
#   '남친이랑 보다가 조용히 얼굴보고도리도리함',
#   '6',
#   '13',
#   '8',
#   datetime.datetime(2020, 9, 14, 5, 35),
#   '관람객'],
#  ['qkfk****',
#   '가볍게 보기에는 볼만함.냉정하게 6~6.5점이 가장 어울림',
#   '6',
#   '13',
#   '8',
#   datetime.datetime(2020, 7, 22, 15, 26),
#   '관람객'],
#  ['김향단(hiki****)',
#   '호불호가 많이 갈리던데 저는 괜찮았습니다.일단 강동원이 잘생겼고 액션도 나쁘지 않았어요.개인적으로 부산행보다 좀비보단 사람들이 더 무섭네요.',
#   '10',
#   '14',
#   '9',
#   datetime.datetime(2020, 8, 6, 23, 11),
#   '관람객'],
#  ['신림완장(pley****)',
#   '똥영화....그이하 그이상도 아님',
#   '2',
#   '15',
#   '10',
#   datetime.datetime(2020, 7, 29, 19, 21),
#   '관람객'],
#  ['애쉬(hoho****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '1',
#   '15',
#   '10',
#   datetime.datetime(2020, 7, 26, 2, 6),
#   '관람객'],
#  ['rhw(rhwo****)',
#   '재밌게 봐썽요 액션 좋아요',
#   '10',
#   '18',
#   '13',
#   datetime.datetime(2020, 7, 29, 12, 8),
#   '관람객'],
#  ['권혜영(pjs1****)',
#   '잘봤습니다강동원 넘나 멋져요',
#   '8',
#   '19',
#   '14',
#   datetime.datetime(2020, 7, 22, 18, 39),
#   '관람객'],
#  ['냐냐ㅑ(anim****)',
#   '이레랑 강동원 넘 멋있으',
#   '10',
#   '20',
#   '15',
#   datetime.datetime(2020, 7, 23, 0, 4),
#   '관람객'],
#  ['chpa****',
#   '1편보다는 못하지만 평점보다는 재밌음.',
#   '8',
#   '20',
#   '15',
#   datetime.datetime(2020, 7, 22, 15, 38),
#   '관람객'],
#  ['닥흐석흘(garo****)',
#   '좀비10%  레이싱 85% 기타 클리셰 5%.좀비가 등장하는 분노의 질주.',
#   '8',
#   '20',
#   '15',
#   datetime.datetime(2020, 7, 15, 10, 22),
#   0],
#  ['최나영(vnbm****)',
#   '저는 진짜 재밌게 봤어요. 특히 평소 봽지 못했던 배우분들이 많이 나오셨는데 그분들의 연기력이 너무 소름돋았어요. 이번 영화를 통해 그분들의 행보를 기대합니다. 정말 멋있었습니다.',
#   '10',
#   '22',
#   '17',
#   datetime.datetime(2020, 7, 23, 3, 9),
#   '관람객'],
#  ['je(29wl****)',
#   '평점낮고 별로라해서 기대안했는데 너무 재밌게 봤음 그리고 그 첫째딸이 이영화에서 제일 멋있게나옴 bb',
#   '10',
#   '30',
#   '25',
#   datetime.datetime(2020, 7, 22, 13, 33),
#   '관람객'],
#  ['팔각모싸나이(tmdr****)',
#   '모하비사야겠습니다.',
#   '10',
#   '36',
#   '31',
#   datetime.datetime(2020, 7, 15, 20, 50),
#   '관람객'],
#  ['사랑과우정삽입(dpat****)',
#   '그렇게 나쁘진 않은데? 다들 ㅈㄹ해서 10점줌..개인평은 8점정돈됨.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 11, 8, 17, 3),
#   0],
#  ['장언영(mylc****)',
#   '감동은 없으나 매우 재밌게 봄ㅎㅎ저는 재밌고 연기도 너무 좋고 드리프트할때마다 쾌감을 느꼈습니다.',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2020, 11, 5, 21, 6),
#   0],
#  ['skybook(skyb****)',
#   '보는내내 왜이리짜증이..강동원배우 연기가 아까워요..',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 10, 1, 0, 12),
#   0],
#  ['Kameleon(neoj****)',
#   '평점이 뭐가 이렇게 낮아? 나름 긴장감있게 연출 되었음. 마지막부분에 감동호흡이 좀 깁니다. 감독님. 그 부분만 빼고 재미있게 봤습니다.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 30, 0, 57),
#   0],
#  ['아다마스(adam****)',
#   '바이오 하자드  1편인줄.. 물론 영화말고 게임... 자동차 씬.... 요즘 비디오 게임도 그정도 영상은 안나옴 코로나라서 특수효과예산 줄인거임?',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 16, 23, 20),
#   0],
#  ['deew(dgal****)',
#   '살고 싶으면 타릍 포함한 클리셰의 극치. 이게 나라면 감독은 더 이상 영화를 찍으면 안 된다. 그냥 수준에, 능력에 맞게 국산 에니메이션만 찍길 죽을 때까지. 염력이랑 반도로 투자자들이 많이 속아줬다.',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 16, 1, 38),
#   0],
#  ['hyoi****',
#   '난 재밌게 봤음',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 14, 13, 37),
#   0],
#  ['꼬미(defr****)',
#   '리뷰가 별로 라서 망설이다 보게 된 영화 영상미도 좋고 배우님들 연기도 좋고 아역 연기도 좋았어요. 국내 영화도 헐리웃 못지 않게 발전 했단 생각이 들었네요^^한국 영화 화이팅~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 13, 23, 5),
#   0],
#  ['강동원 발닦개(goca****)',
#   '강동원 얼굴이 개연성이었다',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 13, 20, 48),
#   0],
#  ['다니하니(eunj****)',
#   '난 정말 재미있게봤는데.. 그냥재밌어서 집중해서봤음!',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 13, 1, 39),
#   0],
#  ['예림(kyr2****)',
#   '사실 강동원 얼굴보러 간거라 만족',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 10, 14, 8),
#   0],
#  ['하나(aq18****)',
#   '평이 이렇게 낮을 정도로 못 볼만 하진 않아요! 전 나름 재밌게 봤습니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 6, 19, 56),
#   0],
#  ['nbvc****',
#   '부산행은 우리일상에서 일어날수도있는 현실감이라도 있는데 반도는 레이싱경주 보는줄..,.싹다 cg 도배해서 현실감 아예없고 영화니깐 그러려니하는데 너무했다',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 4, 2, 27),
#   0],
#  ['고양이버스(snoo****)',
#   '좀비를 세트로 쓴 신파극.  마지막 진짜 짜증나네 .이게 무슨 7점인지',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 9, 4, 2, 16),
#   0],
#  ['오들희(algo****)',
#   '코로나로 인해 맘고생하셨을텐데, 저는 쫄깃쫄깃하게 잘 보았습니다!!  아역 이예원 님과 구교환 님 연기가 너무 인상깊었어요!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 25, 8, 40),
#   0],
#  ['오들희(algo****)',
#   '코로나로 인해 맘고생하셨을텐데, 저는 쫄깃쫄깃하게 잘 보았습니다!!  아역 이예원 님과 구교환 님 연기가 너무 인상깊었어요!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 25, 8, 40),
#   0],
#  ['한남후장호로록따먹긔(gray****)',
#   '알바들 열심히 1점으로 깎아내리노ㅋㅋ 그리고 강동원 잘생겼다는 글에 유달리 비공쳐박는거보니 한남들 열폭 한번 오지게 하나보네??ㅋ 느그 빻은 면상 거울로 확인이나 해라ㅉㅉ 그리고 여기에 또 한남들 ㅂㄷㅂㄷ거리면서 비...',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 25, 8, 1),
#   0],
#  ['white4141(wiu3****)',
#   '분노의질주+매드맥스 느낌처음에 외국인 아저씨 허접한연기시작으로 지루할것예상했는데 후반갈수록 괜찮았음.. 이정현 모성애연기에 감동받았음이정도 좀비영화면 색다르게 잘봤다',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 25, 7, 19),
#   0],
#  ['siwl(dlaw****)',
#   '생존자들끼리 싸우네;; 내용은 별로지만 잘만듬',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 25, 6, 41),
#   0],
#  ['유잼시티(skdm****)',
#   '부산행 보지 않고 기대도 안하고 봐서 그런지 모르겠는데 재미있었고 무엇보다 다만악에 비해 훨씬 재미있고 스토리 개연성이 있음',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 25, 5, 8),
#   0],
#  ['mami****',
#   '강동원 얼굴 보다..감동 먹음. 마음 따땃하네. 다른 배우가 했음..감동이 없었을 듯.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 25, 4, 0),
#   0],
#  ['김태평 과몰입녀(ipee****)',
#   '참치오피피에이 보러 간 건데 역시 참치형 ㅠㅠ',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 21, 12, 56),
#   0],
#  ['dwjdw(eoni****)',
#   '심각하다 한국 문화산업 근 몇년동안 계속 죽어간다',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 19, 19, 58),
#   0],
#  ['HUG ME(byeb****)',
#   '돈주고 봤어요.. 위로좀 해주세용..',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 19, 8, 21),
#   0],
#  ['jock****',
#   '감독에 뇌구조가 의심스럽다  신파만 없었어도 올해 최고에 영화인데 구지 신파를 고집한 이유를 정신이 나간건지 ㅠㅠ',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 18, 20, 28),
#   0],
#  ['우유커플(kiss****)',
#   '부산행의 좀비를 기대하지마세요. 여기선 그냥 신파의 들러리일 뿐.',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 18, 18, 35),
#   0],
#  ['구윰(9999****)',
#   '부산행이랑 같은 감독이라는게 믿기지가 않아요',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 17, 17, 7),
#   0],
#  ['tjeixin(psks****)',
#   '한국영화의 클리셰란 클리셰는 죄다 넣은 영화',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 17, 14, 11),
#   0],
#  ['한화 evils(pdh1****)',
#   '스토리가 그저 그렇네요',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 16, 21, 21),
#   '관람객'],
#  ['김달봉(jun5****)',
#   '그런데 부산행1에선 마지막장면에선 살아남은배우분들이 2에선 변경됨 뭔상황임?  정말 제작비아깜',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 16, 13, 1),
#   0],
#  ['막내(2002****)',
#   '에바임 보지마셈 진짜젤재미없음제블ㅈ보짐ㅏ',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 16, 4, 32),
#   0],
#  ['wows****',
#   '이게무슨....내돈',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 16, 1, 36),
#   0],
#  ['저격수손흥민(qkrw****)',
#   '이게 영화냐 시이디디디이발',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 16, 0, 37),
#   0],
#  ['포로리냐(tlst****)',
#   '0점없음? 네이버에 처음 평점 남겨봄.. 확실히 강동원은 다작하다 대작하나 얻어걸리는거지 작품 고르는눈 1도없네.. 차라리 부산행 후편이 살아있다여서 최후 저항선 부산에서부터 연합군꾸려서 서울에 생존해있는 애들 구하...',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 15, 23, 50),
#   0],
#  ['무겸K(lgic****)',
#   '평이 좋지 않지만, 와이프가 강동원 때문에 보고 싶다고 해서 봤는데, 역시 걸러야 되는 영화라고 생각했다. 만화같은 비현실적이고 비논리적인 상황이 많아서 몰입하기 좋지않은 영화였다.',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 15, 17, 44),
#   0],
#  ['dcgn****',
#   '관람평이 제일 재미나요~',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 15, 17, 40),
#   0],
#  ['이찬희(shad****)',
#   '너네도 뒷광고하냐 ㅋ모하비 뭔데',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 15, 15, 57),
#   0],
#  ['성민준(smin****)',
#   '반정도 도로가 나와 반도인가요?',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 15, 14, 1),
#   0],
#  ['미선나무(chkh****)',
#   '역시 강동원이다. 강동원의 모습은 변함이 없다.강동원 엑션 연기와 비주얼이 최고임~',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 14, 15, 8),
#   0],
#  ['alswjd0523(1011****)',
#   '강동원 얼굴로 충분함',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 11, 4, 56),
#   0],
#  ['루이(loui****)',
#   '여자애들 첫등장때부터 뛰쳐나가고 싶었지만 꾹 참고 봤다 근데 rc카 장면은 진짜 못보겠어서 화장실 다녀왔는데 아직도 모하비타고 추격전하고 있더라 2시간동안 좀비랑 몇분이나 싸웠냐? 그냥 매드맥스:더 코리아 만들지 왠...',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 8, 2, 36),
#   0],
#  ['Mercury(moon****)',
#   '우선 강동원 잘생겼고 강동원 잘생김. 그리고 막 재미없다고하는데 난 재미있었는데..? 그냥 B급? C급 영화로 편하게 보기 좋음 난 재밌었음',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 7, 20, 25),
#   0],
#  ['몽룡이(qpqp****)',
#   '그냥 볼만해요??갠적으로 부산행이 더 재미있었던것 같아요',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 5, 9, 10),
#   '관람객'],
#  ['Cyrus(kank****)',
#   '감독의 한계가 바로 나와버리죠',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 4, 20, 30),
#   0],
#  ['프로이트(tpkj****)',
#   '암걸린다 보지마라인생 최악의 영화',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 4, 20, 10),
#   0],
#  ['김미정(nine****)',
#   '강동원 때문에 기대했으나 ... 조연들과의 조화가 잘 어우러진건지  크게 주연의 느낌은 못받음..와중 이정현 연기 넘 오랫만에 했나???자동차 액션씬이 가장 기억에 남는다는 리뷰~~~~',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 4, 19, 0),
#   '관람객'],
#  ['꿈틀이(dasn****)',
#   '강동원 만 믿고 보는 영화     추석  명절  때 단골 영화',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 3, 16, 23),
#   '관람객'],
#  ['cjsc****',
#   '모하비광고보고나온느낌.,,',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 3, 1, 5),
#   '관람객'],
#  ['13212(knsk****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2020, 8, 1, 21, 47),
#   0],
#  ['청도깨비(thgu****)',
#   '다른 건 안 봤지만 상영하는 것 중에서 제일 볼 만할 듯 하다. 좀비영화만의 끔찍한 묘사도 많이 없으니 아포칼립스 컨셉 못 보는 분들도 같이 사이좋게 강동원 얼굴 보면 꿀잼일거 같다.',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 31, 22, 15),
#   0],
#  ['동원참치(tpwl****)',
#   '기대안하고보면 재밌습니다ㅎㅎ',
#   '8',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 31, 2, 31),
#   '관람객'],
#  ['여지현(duwl****)',
#   '강동원의 자서전 잘봤습니다',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 30, 22, 41),
#   '관람객'],
#  ['uncas(unca****)',
#   '엔딩 볼 때 공포가 밀려왔다. 설마 후속편 만들려는 건가 싶어서.',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 30, 15, 8),
#   0],
#  ['여행(myon****)',
#   '이 정도로 재미없는건 또 처음',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 30, 14, 30),
#   0],
#  ['블루베리(gold****)',
#   '억지감동이 반전에 반전을 거듭함. 이렇게까지 했어야했나싶어요.',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 30, 13, 0),
#   0],
#  ['이무비(seun****)',
#   '연상호 감독, 애니메이션을 할 때가 좋았다.이제 그는... 자본주의에 찌든 사람인가?',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 30, 12, 17),
#   0],
#  ['kims****',
#   '크흡...!!!!도망쳐',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 30, 8, 2),
#   0],
#  ['찐찐(sses****)', '', '1', '4', '0', datetime.datetime(2020, 7, 30, 7, 23), 0],
#  ['애슐리(lieb****)',
#   '제발 3탄은 만들지마세요~~~~ 스토리 진부해요',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 30, 6, 57),
#   0],
#  ['메이슨(msk0****)',
#   '분노의 질주 보는게 나아요',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 30, 4, 6),
#   0],
#  ['애용(yeji****)', '', '1', '4', '0', datetime.datetime(2020, 7, 30, 0, 40), 0],
#  ['wmbz****', '', '1', '4', '0', datetime.datetime(2020, 7, 29, 22, 16), 0],
#  ['nono****',
#   '',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 29, 21, 16),
#   '관람객'],
#  ['믐믐(mew9****)',
#   '그냥 일반 영화관에서 봐서 밋밋했던것같아서 곧 4dx로 보려 합니다 나름 괜찮았던것같아요',
#   '7',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 29, 20, 16),
#   '관람객'],
#  ['노가은(shrk****)',
#   '대사 분장 연출 줄거리 연기 캐릭터 다 너무 오그라들어서 애니메이션인줄 알았어요... 이렇게 고통받은 영화는 또 처음ㅠ',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 29, 17, 0),
#   0],
#  ['kktw****',
#   '좀비 영화 치고는 그렇게 무섭지는 않네요',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 29, 16, 40),
#   '관람객'],
#  ['0408(1027****)',
#   '',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 29, 3, 29),
#   0],
#  ['Joon C(knig****)',
#   '한국에서 앞으로 마블영화 할리우드 영화 찾지 마라.블록버스터 안 찍어본 데서는 이렇게 나온다 ㅋㅋㅋ부산행 좀 성공 했다고 안 그래도 영화 시장 좀만한 데서돈만 쳐발라놓고선 갈피도 못잡고 액션은 만화가 따로 없음모하비...',
#   '5',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 29, 0, 3),
#   0],
#  ['Arl(papa****)',
#   '좀비들 헬기 프로펠러 소리는 못 듣나ㅋㅋㅋ마지막 10분은 삭제 했어야했다.억지 감동 따위는 이제 그마안ㅡ',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 28, 17, 26),
#   0],
#  ['의료팀장(dkql****)',
#   '부산행 후속 이라고 홍보했지만 세계관만 후속.. 분노의질주 한국좀비판을 보는느낌이랄까나',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 28, 17, 21),
#   0],
#  ['바다거북(mani****)',
#   '평식이... 5점을 주다니~~~영화관 망할 거 같은 상황에 반도가 유일한 희망이었긴 하지만 @@@너마저 ###(중요★)감상 포인트 없는데%%선택해야 등록이 되서 맨 앞에 있는 거 선택함;;',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 28, 9, 18),
#   0],
#  ['이진영(dlwl****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '3',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 27, 18, 52),
#   0],
#  ['o서울o오리(nich****)',
#   '엔딩크레딧 올라갈때 빵 터짐. 집에 에어컨없고 더우면 가보시던가. 스토리, ost모하나 적당한 게 없다. 정말 해외 수출까지는 하지말자.',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 27, 10, 0),
#   0],
#  ['가나다라마바(kong****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 26, 11, 27),
#   0],
#  ['박하케(llaw****)',
#   '',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 26, 10, 55),
#   0],
#  ['JOEU(dksy****)',
#   '도대체 여주인공분은 영화에....왜 계속나오나요....모든 씬에서 몰입 와장창....되네요',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 26, 7, 24),
#   0],
#  ['김주희(gaha****)',
#   '최악의 영화, 강동원을 데려다가 이런 영화를 만들다니.. 보다가 잤다.',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 26, 6, 58),
#   0],
#  ['백두대간(youp****)',
#   '시간 버리고, 돈 버리고,  성격 버리는 영화   보고 난 후 이렇게까지 자괴감 든 영화는 정말 오랜만임',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 25, 2, 41),
#   0],
#  ['듀스포에(pure****)',
#   '흠.,.,.,.,.,',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 25, 2, 28),
#   0],
#  ['도니조아(qkrd****)',
#   '',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 25, 2, 22),
#   0],
#  ['애디(adji****)',
#   '차량추격전은 멜깁슨영화 매드맥스 판박이..CG는 컴퓨터게임 인트로 수준..스토리는 핵전쟁이후 헐리우드 비급 스토리..실사 영화를 보러간건지..애니메이션을 보러간건지...돈주고 봤으면  잠 못잤음..',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 24, 11, 59),
#   0],
#  ['짱(gugj****)',
#   '좀비영화를 가장한 레이싱영화그냥 지루함(재미없음)',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 23, 16, 20),
#   0],
#  ['end(ende****)',
#   '수고많으셨습니다 엄청 기다렸는데 ㅠ',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 23, 9, 17),
#   0],
#  ['어린이(park****)',
#   '카레이싱 장면과 배우분들의 연기는 정말 만족스러웠습니다. 그러나 극도로 낮은 현실감과 억지신파 그리고 좀비들의 멍청함이 몰입감을 바닥으로 떨어뜨리는 아쉬움이 있었습니다. 좀비가 아닌 다른 장르로 나왔으면 좋겠다는 생...',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 23, 8, 14),
#   0],
#  ['정현85(jjh8****)',
#   '근데 진짜 애매하다...좀비를 제3자로 뭉텅이로 몰아버리고 인간끼리 싸우는건 뭔지...갑자기 개인서사도 없이 갑툭튀 가족애 뮝미 ㅋㅋ별점을 세개준건 강동원이 잘생기고 멋있고 자동차액션이 괜찮아서이다. 강동원이 아니였...',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 23, 0, 12),
#   0],
#  ['MULGURI(sing****)',
#   '기대하고 봤는데 드럽게 재미없었음.',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 22, 22, 15),
#   0],
#  ['yggo****',
#   '그냥... 싸구려 중국 영화...',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 22, 22, 13),
#   0],
#  ['정석준(a010****)',
#   '정말 재밋다~^^ㅎㅎ',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 22, 21, 25),
#   0],
#  ['양갱(bebe****)',
#   '억지신파에 주인공은 부각되지도 않고 설정붕괴에 ....그래놓고 관람객들 탓으로 돌리는 감독 웩 염력과 반도가 감독의 한계임',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 22, 19, 38),
#   0],
#  ['BIG J(alex****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '4',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 22, 17, 17),
#   0],
#  ['ThePhantom(bara****)',
#   '부산행 후속편이라고 하지마라OOO 진짜',
#   '2',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 22, 17, 9),
#   0],
#  ['이세영(seye****)',
#   '뭐라 할 말도 딱히 없네요',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 22, 17, 2),
#   0],
#  ['jiho****',
#   '재미없음 개연성 x 말도 안되는 장면 다분 액션신은 볼만함',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 22, 16, 41),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                          0  ...    6
# 0                 thsz****  ...  관람객
# 1      slow life(ssk8****)  ...  관람객
# 2            로야르(vulc****)  ...  관람객
# 3             윤등(feel****)  ...  관람객
# 4                 dlad****  ...  관람객
# ...                    ...  ...  ...
# 29835      Menaw(kcyl****)  ...  관람객
# 29836        강맥스(khkg****)  ...  관람객
# 29837     이라지마이소(chlg****)  ...  관람객
# 29838      리얼리스트(wkdd****)  ...  관람객
# 29839        윤튼튼(may3****)  ...  관람객
#
# [29840 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                   nickname  ... watch_movie
# 0                 thsz****  ...         관람객
# 1      slow life(ssk8****)  ...         관람객
# 2            로야르(vulc****)  ...         관람객
# 3             윤등(feel****)  ...         관람객
# 4                 dlad****  ...         관람객
# ...                    ...  ...         ...
# 29835      Menaw(kcyl****)  ...         관람객
# 29836        강맥스(khkg****)  ...         관람객
# 29837     이라지마이소(chlg****)  ...         관람객
# 29838      리얼리스트(wkdd****)  ...         관람객
# 29839        윤튼튼(may3****)  ...         관람객
#
# [29840 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
