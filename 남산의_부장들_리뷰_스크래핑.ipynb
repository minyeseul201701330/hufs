# %% [markdown]
# <a href="https://colab.research.google.com/github/minyeseul201701330/hufs/blob/main/%EB%82%A8%EC%82%B0%EC%9D%98_%EB%B6%80%EC%9E%A5%EB%93%A4_%EB%A6%AC%EB%B7%B0_%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 176306 ## 남산의 부장들
total_count = 17834  ## 전체 크기=17,834

# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1702
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1703
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1704
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1705
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1706
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1707
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1708
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1709
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1710
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1711
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1712
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1713
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1714
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1715
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1716
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1717
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1718
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1719
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1720
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1721
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1722
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1723
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1724
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1725
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1726
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1727
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1728
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1729
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1730
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1731
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1732
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1733
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1734
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1735
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1736
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1737
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1738
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1739
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1740
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1741
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1742
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1743
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1744
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1745
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1746
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1747
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1748
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1749
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1750
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1751
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1752
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1753
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1754
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1755
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1756
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1757
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1758
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1759
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1760
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1761
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1762
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1763
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1764
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1765
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1766
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1767
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1768
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1769
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1770
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1771
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1772
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1773
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1774
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1775
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1776
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1777
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1778
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1779
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1780
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1781
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1782
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1783

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20201109160108" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20201109160108" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20201109160108" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20201109160108" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="176306"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>17,834</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																김재규를 미화하지않고객관적이며 인간적으로 묘사했던게 좋았고무엇보다 머머리를 좀도둑놈 시키로 그려줬던게 최고의 연출이었다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16632350, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>erlo****</span>
# </a>
# </em>
# <em>2020.01.23 14:55</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','erlo****', 'kCCUSGjJoOxo9w174r5ul2f9W+/LXvctVbcgZL/TqOQ=', '김재규를 미화하지않고객관적이며 인간적으로 묘사했던게 좋았고무엇보다 머머리를 좀도둑놈 시키로 그려줬던게 최고의 연출이었다. ', '16632350', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16632350">5989</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16632350">1987</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																연기 잘 하는 배우가 모여있습니다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16626817, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>빛그림(namj****)</span>
# </a>
# </em>
# <em>2020.01.22 15:55</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','namj****', 'PvtRyA0ScdkcqiF9jlcYKwwFjG3rTUPctp0vLVK1qwI=', '연기 잘 하는 배우가 모여있습니다 ', '16626817', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16626817">4918</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16626817">1417</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																이 영화는 이병헌 연기의 최정점을 볼 수 있다ㄷㄷ 한 장면 한 장면 긴장감을 놓을 수 없고 진짜 잘 만든 영화라는 생각밖에는,,, 오랜만에 잘 만든 한국영화 bb
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16625409, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>쩡(jeon****)</span>
# </a>
# </em>
# <em>2020.01.22 10:10</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','jeon****', 'QsZ8x+41qvnbZdBM+UGr7LSwpjnFT+g6ThwXRSh4y2g=', '이 영화는 이병헌 연기의 최정점을 볼 수 있다ㄷㄷ 한 장면 한 장면 긴장감을 놓을 수 없고 진짜 잘 만든 영화라는 생각밖에는,,, 오랜만에 잘 만든 한국영화 bb ', '16625409', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16625409">4385</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16625409">1678</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																오랜만에 볼만한 한국영화!이성민 배우님 박통 연기 소름돋았습니다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16628105, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>Joonseosa(myeo****)</span>
# </a>
# </em>
# <em>2020.01.22 20:29</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','myeo****', '9hnfhpAaJ2zeR80HabGE4JGrjMpnO7pEYD9NuYVznfc=', '오랜만에 볼만한 한국영화!이성민 배우님 박통 연기 소름돋았습니다 ', '16628105', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16628105">3625</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16628105">1227</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																다 좋은데 마지막에 뭐냐; 전두환이 돈 챙겨가는거ㅋㅋㅋ개찐빠네 마지막이
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16625681, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>ㅎㅎㅎ(eorm****)</span>
# </a>
# </em>
# <em>2020.01.22 11:19</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','eorm****', 'njtFQ5LpdGaxhQQ6LmN19Hs7ZzduqPUBjsBAZeEWtDo=', '다 좋은데 마지막에 뭐냐; 전두환이 돈 챙겨가는거ㅋㅋㅋ개찐빠네 마지막이 ', '16625681', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16625681">3231</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16625681">952</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																이병헌 연기력 폭발함. 후반부까지 긴장감 대박임...
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16625417, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>minmin(ssg8****)</span>
# </a>
# </em>
# <em>2020.01.22 10:12</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ssg8****', 'Alb54bvR5/doHHX27qjYtGzqUYrmyT4wVwPl0OROaWQ=', '이병헌 연기력 폭발함. 후반부까지 긴장감 대박임... ', '16625417', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16625417">3163</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16625417">1216</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																 오랜만에 잘봤습니다. 연기  대박
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16627963, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>PurityDEK(drea****)</span>
# </a>
# </em>
# <em>2020.01.22 20:02</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','drea****', '1/Eu3cBZCFa7gRZCIb9qTQJOSs2h0ZeHbSOoZTADBb4=', ' 오랜만에 잘봤습니다. 연기  대박 ', '16627963', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16627963">2921</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16627963">1025</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																남산으로 향했으면 김재규가 정권을 잡았다고 모든 전문가들이 판단했는데~왜 육본으로 가서   죄를 받았는지~거기에 전두환은 쥐새끼같이 기횔 물고  생쑈를~~
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16635636, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>묘갈(nged****)</span>
# </a>
# </em>
# <em>2020.01.24 02:00</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','nged****', 'V0sqJ7YAQ2P2igM++H1c6/XGgD3qDrgd9GLDwgBqMMo=', '남산으로 향했으면 김재규가 정권을 잡았다고 모든 전문가들이 판단했는데~왜 육본으로 가서   죄를 받았는지~거기에 전두환은 쥐새끼같이 기횔 물고  생쑈를~~ ', '16635636', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16635636">2203</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16635636">590</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																진짜 이병헌 크라쓰가 다르다 긴장감있는 연출도 좋았음
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16625415, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>jjom(more****)</span>
# </a>
# </em>
# <em>2020.01.22 10:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','more****', 'n2WvMH4fysWgclb4+ZteXRSKaGOHdMazGGy50e9VEow=', '진짜 이병헌 크라쓰가 다르다 긴장감있는 연출도 좋았음 ', '16625415', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16625415">2603</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16625415">1068</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																일베들 평점테러보소ㄷㄷ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16626618, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>hun1****</span>
# </a>
# </em>
# <em>2020.01.22 15:03</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','hun1****', 'x/Ov8hOl8zb2aW3cSHTsR4im9HnurlovzfPOQqUSmvU=', '일베들 평점테러보소ㄷㄷ ', '16626618', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16626618">3974</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16626618">2596</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=176306&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "176306",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=176306#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=176306&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=176306#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("176306", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																김재규를 미화하지않고객관적이며 인간적으로 묘사했던게 좋았고무엇보다 머머리를 좀도둑놈 시키로 그려줬던게 최고의 연출이었다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16632350, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>erlo****</span>
# </a>
# </em>
# <em>2020.01.23 14:55</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','erlo****', 'kCCUSGjJoOxo9w174r5ul2f9W+/LXvctVbcgZL/TqOQ=', '김재규를 미화하지않고객관적이며 인간적으로 묘사했던게 좋았고무엇보다 머머리를 좀도둑놈 시키로 그려줬던게 최고의 연출이었다. ', '16632350', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16632350">5989</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16632350">1987</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																연기 잘 하는 배우가 모여있습니다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(16626817, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>빛그림(namj****)</span>
# </a>
# </em>
# <em>2020.01.22 15:55</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','namj****', 'PvtRyA0ScdkcqiF9jlcYKwwFjG3rTUPctp0vLVK1qwI=', '연기 잘 하는 배우가 모여있습니다 ', '16626817', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_16626817">4918</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_16626817">1417</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '관람객'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '관람객'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 점수
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('5989', '1987')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# 'erlo****'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2020, 1, 23, 14, 55)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 176306
total_count = 17834  ## 전체 크기=17834

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....
# 259 번째 페이지 parsing....
# 260 번째 페이지 parsing....
# 261 번째 페이지 parsing....
# 262 번째 페이지 parsing....
# 263 번째 페이지 parsing....
# 264 번째 페이지 parsing....
# 265 번째 페이지 parsing....
# 266 번째 페이지 parsing....
# 267 번째 페이지 parsing....
# 268 번째 페이지 parsing....
# 269 번째 페이지 parsing....
# 270 번째 페이지 parsing....
# 271 번째 페이지 parsing....
# 272 번째 페이지 parsing....
# 273 번째 페이지 parsing....
# 274 번째 페이지 parsing....
# 275 번째 페이지 parsing....
# 276 번째 페이지 parsing....
# 277 번째 페이지 parsing....
# 278 번째 페이지 parsing....
# 279 번째 페이지 parsing....
# 280 번째 페이지 parsing....
# 281 번째 페이지 parsing....
# 282 번째 페이지 parsing....
# 283 번째 페이지 parsing....
# 284 번째 페이지 parsing....
# 285 번째 페이지 parsing....
# 286 번째 페이지 parsing....
# 287 번째 페이지 parsing....
# 288 번째 페이지 parsing....
# 289 번째 페이지 parsing....
# 290 번째 페이지 parsing....
# 291 번째 페이지 parsing....
# 292 번째 페이지 parsing....
# 293 번째 페이지 parsing....
# 294 번째 페이지 parsing....
# 295 번째 페이지 parsing....
# 296 번째 페이지 parsing....
# 297 번째 페이지 parsing....
# 298 번째 페이지 parsing....
# 299 번째 페이지 parsing....
# 300 번째 페이지 parsing....
# 301 번째 페이지 parsing....
# 302 번째 페이지 parsing....
# 303 번째 페이지 parsing....
# 304 번째 페이지 parsing....
# 305 번째 페이지 parsing....
# 306 번째 페이지 parsing....
# 307 번째 페이지 parsing....
# 308 번째 페이지 parsing....
# 309 번째 페이지 parsing....
# 310 번째 페이지 parsing....
# 311 번째 페이지 parsing....
# 312 번째 페이지 parsing....
# 313 번째 페이지 parsing....
# 314 번째 페이지 parsing....
# 315 번째 페이지 parsing....
# 316 번째 페이지 parsing....
# 317 번째 페이지 parsing....
# 318 번째 페이지 parsing....
# 319 번째 페이지 parsing....
# 320 번째 페이지 parsing....
# 321 번째 페이지 parsing....
# 322 번째 페이지 parsing....
# 323 번째 페이지 parsing....
# 324 번째 페이지 parsing....
# 325 번째 페이지 parsing....
# 326 번째 페이지 parsing....
# 327 번째 페이지 parsing....
# 328 번째 페이지 parsing....
# 329 번째 페이지 parsing....
# 330 번째 페이지 parsing....
# 331 번째 페이지 parsing....
# 332 번째 페이지 parsing....
# 333 번째 페이지 parsing....
# 334 번째 페이지 parsing....
# 335 번째 페이지 parsing....
# 336 번째 페이지 parsing....
# 337 번째 페이지 parsing....
# 338 번째 페이지 parsing....
# 339 번째 페이지 parsing....
# 340 번째 페이지 parsing....
# 341 번째 페이지 parsing....
# 342 번째 페이지 parsing....
# 343 번째 페이지 parsing....
# 344 번째 페이지 parsing....
# 345 번째 페이지 parsing....
# 346 번째 페이지 parsing....
# 347 번째 페이지 parsing....
# 348 번째 페이지 parsing....
# 349 번째 페이지 parsing....
# 350 번째 페이지 parsing....
# 351 번째 페이지 parsing....
# 352 번째 페이지 parsing....
# 353 번째 페이지 parsing....
# 354 번째 페이지 parsing....
# 355 번째 페이지 parsing....
# 356 번째 페이지 parsing....
# 357 번째 페이지 parsing....
# 358 번째 페이지 parsing....
# 359 번째 페이지 parsing....
# 360 번째 페이지 parsing....
# 361 번째 페이지 parsing....
# 362 번째 페이지 parsing....
# 363 번째 페이지 parsing....
# 364 번째 페이지 parsing....
# 365 번째 페이지 parsing....
# 366 번째 페이지 parsing....
# 367 번째 페이지 parsing....
# 368 번째 페이지 parsing....
# 369 번째 페이지 parsing....
# 370 번째 페이지 parsing....
# 371 번째 페이지 parsing....
# 372 번째 페이지 parsing....
# 373 번째 페이지 parsing....
# 374 번째 페이지 parsing....
# 375 번째 페이지 parsing....
# 376 번째 페이지 parsing....
# 377 번째 페이지 parsing....
# 378 번째 페이지 parsing....
# 379 번째 페이지 parsing....
# 380 번째 페이지 parsing....
# 381 번째 페이지 parsing....
# 382 번째 페이지 parsing....
# 383 번째 페이지 parsing....
# 384 번째 페이지 parsing....
# 385 번째 페이지 parsing....
# 386 번째 페이지 parsing....
# 387 번째 페이지 parsing....
# 388 번째 페이지 parsing....
# 389 번째 페이지 parsing....
# 390 번째 페이지 parsing....
# 391 번째 페이지 parsing....
# 392 번째 페이지 parsing....
# 393 번째 페이지 parsing....
# 394 번째 페이지 parsing....
# 395 번째 페이지 parsing....
# 396 번째 페이지 parsing....
# 397 번째 페이지 parsing....
# 398 번째 페이지 parsing....
# 399 번째 페이지 parsing....
# 400 번째 페이지 parsing....
# 401 번째 페이지 parsing....
# 402 번째 페이지 parsing....
# 403 번째 페이지 parsing....
# 404 번째 페이지 parsing....
# 405 번째 페이지 parsing....
# 406 번째 페이지 parsing....
# 407 번째 페이지 parsing....
# 408 번째 페이지 parsing....
# 409 번째 페이지 parsing....
# 410 번째 페이지 parsing....
# 411 번째 페이지 parsing....
# 412 번째 페이지 parsing....
# 413 번째 페이지 parsing....
# 414 번째 페이지 parsing....
# 415 번째 페이지 parsing....
# 416 번째 페이지 parsing....
# 417 번째 페이지 parsing....
# 418 번째 페이지 parsing....
# 419 번째 페이지 parsing....
# 420 번째 페이지 parsing....
# 421 번째 페이지 parsing....
# 422 번째 페이지 parsing....
# 423 번째 페이지 parsing....
# 424 번째 페이지 parsing....
# 425 번째 페이지 parsing....
# 426 번째 페이지 parsing....
# 427 번째 페이지 parsing....
# 428 번째 페이지 parsing....
# 429 번째 페이지 parsing....
# 430 번째 페이지 parsing....
# 431 번째 페이지 parsing....
# 432 번째 페이지 parsing....
# 433 번째 페이지 parsing....
# 434 번째 페이지 parsing....
# 435 번째 페이지 parsing....
# 436 번째 페이지 parsing....
# 437 번째 페이지 parsing....
# 438 번째 페이지 parsing....
# 439 번째 페이지 parsing....
# 440 번째 페이지 parsing....
# 441 번째 페이지 parsing....
# 442 번째 페이지 parsing....
# 443 번째 페이지 parsing....
# 444 번째 페이지 parsing....
# 445 번째 페이지 parsing....
# 446 번째 페이지 parsing....
# 447 번째 페이지 parsing....
# 448 번째 페이지 parsing....
# 449 번째 페이지 parsing....
# 450 번째 페이지 parsing....
# 451 번째 페이지 parsing....
# 452 번째 페이지 parsing....
# 453 번째 페이지 parsing....
# 454 번째 페이지 parsing....
# 455 번째 페이지 parsing....
# 456 번째 페이지 parsing....
# 457 번째 페이지 parsing....
# 458 번째 페이지 parsing....
# 459 번째 페이지 parsing....
# 460 번째 페이지 parsing....
# 461 번째 페이지 parsing....
# 462 번째 페이지 parsing....
# 463 번째 페이지 parsing....
# 464 번째 페이지 parsing....
# 465 번째 페이지 parsing....
# 466 번째 페이지 parsing....
# 467 번째 페이지 parsing....
# 468 번째 페이지 parsing....
# 469 번째 페이지 parsing....
# 470 번째 페이지 parsing....
# 471 번째 페이지 parsing....
# 472 번째 페이지 parsing....
# 473 번째 페이지 parsing....
# 474 번째 페이지 parsing....
# 475 번째 페이지 parsing....
# 476 번째 페이지 parsing....
# 477 번째 페이지 parsing....
# 478 번째 페이지 parsing....
# 479 번째 페이지 parsing....
# 480 번째 페이지 parsing....
# 481 번째 페이지 parsing....
# 482 번째 페이지 parsing....
# 483 번째 페이지 parsing....
# 484 번째 페이지 parsing....
# 485 번째 페이지 parsing....
# 486 번째 페이지 parsing....
# 487 번째 페이지 parsing....
# 488 번째 페이지 parsing....
# 489 번째 페이지 parsing....
# 490 번째 페이지 parsing....
# 491 번째 페이지 parsing....
# 492 번째 페이지 parsing....
# 493 번째 페이지 parsing....
# 494 번째 페이지 parsing....
# 495 번째 페이지 parsing....
# 496 번째 페이지 parsing....
# 497 번째 페이지 parsing....
# 498 번째 페이지 parsing....
# 499 번째 페이지 parsing....
# 500 번째 페이지 parsing....
# 501 번째 페이지 parsing....
# 502 번째 페이지 parsing....
# 503 번째 페이지 parsing....
# 504 번째 페이지 parsing....
# 505 번째 페이지 parsing....
# 506 번째 페이지 parsing....
# 507 번째 페이지 parsing....
# 508 번째 페이지 parsing....
# 509 번째 페이지 parsing....
# 510 번째 페이지 parsing....
# 511 번째 페이지 parsing....
# 512 번째 페이지 parsing....
# 513 번째 페이지 parsing....
# 514 번째 페이지 parsing....
# 515 번째 페이지 parsing....
# 516 번째 페이지 parsing....
# 517 번째 페이지 parsing....
# 518 번째 페이지 parsing....
# 519 번째 페이지 parsing....
# 520 번째 페이지 parsing....
# 521 번째 페이지 parsing....
# 522 번째 페이지 parsing....
# 523 번째 페이지 parsing....
# 524 번째 페이지 parsing....
# 525 번째 페이지 parsing....
# 526 번째 페이지 parsing....
# 527 번째 페이지 parsing....
# 528 번째 페이지 parsing....
# 529 번째 페이지 parsing....
# 530 번째 페이지 parsing....
# 531 번째 페이지 parsing....
# 532 번째 페이지 parsing....
# 533 번째 페이지 parsing....
# 534 번째 페이지 parsing....
# 535 번째 페이지 parsing....
# 536 번째 페이지 parsing....
# 537 번째 페이지 parsing....
# 538 번째 페이지 parsing....
# 539 번째 페이지 parsing....
# 540 번째 페이지 parsing....
# 541 번째 페이지 parsing....
# 542 번째 페이지 parsing....
# 543 번째 페이지 parsing....
# 544 번째 페이지 parsing....
# 545 번째 페이지 parsing....
# 546 번째 페이지 parsing....
# 547 번째 페이지 parsing....
# 548 번째 페이지 parsing....
# 549 번째 페이지 parsing....
# 550 번째 페이지 parsing....
# 551 번째 페이지 parsing....
# 552 번째 페이지 parsing....
# 553 번째 페이지 parsing....
# 554 번째 페이지 parsing....
# 555 번째 페이지 parsing....
# 556 번째 페이지 parsing....
# 557 번째 페이지 parsing....
# 558 번째 페이지 parsing....
# 559 번째 페이지 parsing....
# 560 번째 페이지 parsing....
# 561 번째 페이지 parsing....
# 562 번째 페이지 parsing....
# 563 번째 페이지 parsing....
# 564 번째 페이지 parsing....
# 565 번째 페이지 parsing....
# 566 번째 페이지 parsing....
# 567 번째 페이지 parsing....
# 568 번째 페이지 parsing....
# 569 번째 페이지 parsing....
# 570 번째 페이지 parsing....
# 571 번째 페이지 parsing....
# 572 번째 페이지 parsing....
# 573 번째 페이지 parsing....
# 574 번째 페이지 parsing....
# 575 번째 페이지 parsing....
# 576 번째 페이지 parsing....
# 577 번째 페이지 parsing....
# 578 번째 페이지 parsing....
# 579 번째 페이지 parsing....
# 580 번째 페이지 parsing....
# 581 번째 페이지 parsing....
# 582 번째 페이지 parsing....
# 583 번째 페이지 parsing....
# 584 번째 페이지 parsing....
# 585 번째 페이지 parsing....
# 586 번째 페이지 parsing....
# 587 번째 페이지 parsing....
# 588 번째 페이지 parsing....
# 589 번째 페이지 parsing....
# 590 번째 페이지 parsing....
# 591 번째 페이지 parsing....
# 592 번째 페이지 parsing....
# 593 번째 페이지 parsing....
# 594 번째 페이지 parsing....
# 595 번째 페이지 parsing....
# 596 번째 페이지 parsing....
# 597 번째 페이지 parsing....
# 598 번째 페이지 parsing....
# 599 번째 페이지 parsing....
# 600 번째 페이지 parsing....
# 601 번째 페이지 parsing....
# 602 번째 페이지 parsing....
# 603 번째 페이지 parsing....
# 604 번째 페이지 parsing....
# 605 번째 페이지 parsing....
# 606 번째 페이지 parsing....
# 607 번째 페이지 parsing....
# 608 번째 페이지 parsing....
# 609 번째 페이지 parsing....
# 610 번째 페이지 parsing....
# 611 번째 페이지 parsing....
# 612 번째 페이지 parsing....
# 613 번째 페이지 parsing....
# 614 번째 페이지 parsing....
# 615 번째 페이지 parsing....
# 616 번째 페이지 parsing....
# 617 번째 페이지 parsing....
# 618 번째 페이지 parsing....
# 619 번째 페이지 parsing....
# 620 번째 페이지 parsing....
# 621 번째 페이지 parsing....
# 622 번째 페이지 parsing....
# 623 번째 페이지 parsing....
# 624 번째 페이지 parsing....
# 625 번째 페이지 parsing....
# 626 번째 페이지 parsing....
# 627 번째 페이지 parsing....
# 628 번째 페이지 parsing....
# 629 번째 페이지 parsing....
# 630 번째 페이지 parsing....
# 631 번째 페이지 parsing....
# 632 번째 페이지 parsing....
# 633 번째 페이지 parsing....
# 634 번째 페이지 parsing....
# 635 번째 페이지 parsing....
# 636 번째 페이지 parsing....
# 637 번째 페이지 parsing....
# 638 번째 페이지 parsing....
# 639 번째 페이지 parsing....
# 640 번째 페이지 parsing....
# 641 번째 페이지 parsing....
# 642 번째 페이지 parsing....
# 643 번째 페이지 parsing....
# 644 번째 페이지 parsing....
# 645 번째 페이지 parsing....
# 646 번째 페이지 parsing....
# 647 번째 페이지 parsing....
# 648 번째 페이지 parsing....
# 649 번째 페이지 parsing....
# 650 번째 페이지 parsing....
# 651 번째 페이지 parsing....
# 652 번째 페이지 parsing....
# 653 번째 페이지 parsing....
# 654 번째 페이지 parsing....
# 655 번째 페이지 parsing....
# 656 번째 페이지 parsing....
# 657 번째 페이지 parsing....
# 658 번째 페이지 parsing....
# 659 번째 페이지 parsing....
# 660 번째 페이지 parsing....
# 661 번째 페이지 parsing....
# 662 번째 페이지 parsing....
# 663 번째 페이지 parsing....
# 664 번째 페이지 parsing....
# 665 번째 페이지 parsing....
# 666 번째 페이지 parsing....
# 667 번째 페이지 parsing....
# 668 번째 페이지 parsing....
# 669 번째 페이지 parsing....
# 670 번째 페이지 parsing....
# 671 번째 페이지 parsing....
# 672 번째 페이지 parsing....
# 673 번째 페이지 parsing....
# 674 번째 페이지 parsing....
# 675 번째 페이지 parsing....
# 676 번째 페이지 parsing....
# 677 번째 페이지 parsing....
# 678 번째 페이지 parsing....
# 679 번째 페이지 parsing....
# 680 번째 페이지 parsing....
# 681 번째 페이지 parsing....
# 682 번째 페이지 parsing....
# 683 번째 페이지 parsing....
# 684 번째 페이지 parsing....
# 685 번째 페이지 parsing....
# 686 번째 페이지 parsing....
# 687 번째 페이지 parsing....
# 688 번째 페이지 parsing....
# 689 번째 페이지 parsing....
# 690 번째 페이지 parsing....
# 691 번째 페이지 parsing....
# 692 번째 페이지 parsing....
# 693 번째 페이지 parsing....
# 694 번째 페이지 parsing....
# 695 번째 페이지 parsing....
# 696 번째 페이지 parsing....
# 697 번째 페이지 parsing....
# 698 번째 페이지 parsing....
# 699 번째 페이지 parsing....
# 700 번째 페이지 parsing....
# 701 번째 페이지 parsing....
# 702 번째 페이지 parsing....
# 703 번째 페이지 parsing....
# 704 번째 페이지 parsing....
# 705 번째 페이지 parsing....
# 706 번째 페이지 parsing....
# 707 번째 페이지 parsing....
# 708 번째 페이지 parsing....
# 709 번째 페이지 parsing....
# 710 번째 페이지 parsing....
# 711 번째 페이지 parsing....
# 712 번째 페이지 parsing....
# 713 번째 페이지 parsing....
# 714 번째 페이지 parsing....
# 715 번째 페이지 parsing....
# 716 번째 페이지 parsing....
# 717 번째 페이지 parsing....
# 718 번째 페이지 parsing....
# 719 번째 페이지 parsing....
# 720 번째 페이지 parsing....
# 721 번째 페이지 parsing....
# 722 번째 페이지 parsing....
# 723 번째 페이지 parsing....
# 724 번째 페이지 parsing....
# 725 번째 페이지 parsing....
# 726 번째 페이지 parsing....
# 727 번째 페이지 parsing....
# 728 번째 페이지 parsing....
# 729 번째 페이지 parsing....
# 730 번째 페이지 parsing....
# 731 번째 페이지 parsing....
# 732 번째 페이지 parsing....
# 733 번째 페이지 parsing....
# 734 번째 페이지 parsing....
# 735 번째 페이지 parsing....
# 736 번째 페이지 parsing....
# 737 번째 페이지 parsing....
# 738 번째 페이지 parsing....
# 739 번째 페이지 parsing....
# 740 번째 페이지 parsing....
# 741 번째 페이지 parsing....
# 742 번째 페이지 parsing....
# 743 번째 페이지 parsing....
# 744 번째 페이지 parsing....
# 745 번째 페이지 parsing....
# 746 번째 페이지 parsing....
# 747 번째 페이지 parsing....
# 748 번째 페이지 parsing....
# 749 번째 페이지 parsing....
# 750 번째 페이지 parsing....
# 751 번째 페이지 parsing....
# 752 번째 페이지 parsing....
# 753 번째 페이지 parsing....
# 754 번째 페이지 parsing....
# 755 번째 페이지 parsing....
# 756 번째 페이지 parsing....
# 757 번째 페이지 parsing....
# 758 번째 페이지 parsing....
# 759 번째 페이지 parsing....
# 760 번째 페이지 parsing....
# 761 번째 페이지 parsing....
# 762 번째 페이지 parsing....
# 763 번째 페이지 parsing....
# 764 번째 페이지 parsing....
# 765 번째 페이지 parsing....
# 766 번째 페이지 parsing....
# 767 번째 페이지 parsing....
# 768 번째 페이지 parsing....
# 769 번째 페이지 parsing....
# 770 번째 페이지 parsing....
# 771 번째 페이지 parsing....
# 772 번째 페이지 parsing....
# 773 번째 페이지 parsing....
# 774 번째 페이지 parsing....
# 775 번째 페이지 parsing....
# 776 번째 페이지 parsing....
# 777 번째 페이지 parsing....
# 778 번째 페이지 parsing....
# 779 번째 페이지 parsing....
# 780 번째 페이지 parsing....
# 781 번째 페이지 parsing....
# 782 번째 페이지 parsing....
# 783 번째 페이지 parsing....
# 784 번째 페이지 parsing....
# 785 번째 페이지 parsing....
# 786 번째 페이지 parsing....
# 787 번째 페이지 parsing....
# 788 번째 페이지 parsing....
# 789 번째 페이지 parsing....
# 790 번째 페이지 parsing....
# 791 번째 페이지 parsing....
# 792 번째 페이지 parsing....
# 793 번째 페이지 parsing....
# 794 번째 페이지 parsing....
# 795 번째 페이지 parsing....
# 796 번째 페이지 parsing....
# 797 번째 페이지 parsing....
# 798 번째 페이지 parsing....
# 799 번째 페이지 parsing....
# 800 번째 페이지 parsing....
# 801 번째 페이지 parsing....
# 802 번째 페이지 parsing....
# 803 번째 페이지 parsing....
# 804 번째 페이지 parsing....
# 805 번째 페이지 parsing....
# 806 번째 페이지 parsing....
# 807 번째 페이지 parsing....
# 808 번째 페이지 parsing....
# 809 번째 페이지 parsing....
# 810 번째 페이지 parsing....
# 811 번째 페이지 parsing....
# 812 번째 페이지 parsing....
# 813 번째 페이지 parsing....
# 814 번째 페이지 parsing....
# 815 번째 페이지 parsing....
# 816 번째 페이지 parsing....
# 817 번째 페이지 parsing....
# 818 번째 페이지 parsing....
# 819 번째 페이지 parsing....
# 820 번째 페이지 parsing....
# 821 번째 페이지 parsing....
# 822 번째 페이지 parsing....
# 823 번째 페이지 parsing....
# 824 번째 페이지 parsing....
# 825 번째 페이지 parsing....
# 826 번째 페이지 parsing....
# 827 번째 페이지 parsing....
# 828 번째 페이지 parsing....
# 829 번째 페이지 parsing....
# 830 번째 페이지 parsing....
# 831 번째 페이지 parsing....
# 832 번째 페이지 parsing....
# 833 번째 페이지 parsing....
# 834 번째 페이지 parsing....
# 835 번째 페이지 parsing....
# 836 번째 페이지 parsing....
# 837 번째 페이지 parsing....
# 838 번째 페이지 parsing....
# 839 번째 페이지 parsing....
# 840 번째 페이지 parsing....
# 841 번째 페이지 parsing....
# 842 번째 페이지 parsing....
# 843 번째 페이지 parsing....
# 844 번째 페이지 parsing....
# 845 번째 페이지 parsing....
# 846 번째 페이지 parsing....
# 847 번째 페이지 parsing....
# 848 번째 페이지 parsing....
# 849 번째 페이지 parsing....
# 850 번째 페이지 parsing....
# 851 번째 페이지 parsing....
# 852 번째 페이지 parsing....
# 853 번째 페이지 parsing....
# 854 번째 페이지 parsing....
# 855 번째 페이지 parsing....
# 856 번째 페이지 parsing....
# 857 번째 페이지 parsing....
# 858 번째 페이지 parsing....
# 859 번째 페이지 parsing....
# 860 번째 페이지 parsing....
# 861 번째 페이지 parsing....
# 862 번째 페이지 parsing....
# 863 번째 페이지 parsing....
# 864 번째 페이지 parsing....
# 865 번째 페이지 parsing....
# 866 번째 페이지 parsing....
# 867 번째 페이지 parsing....
# 868 번째 페이지 parsing....
# 869 번째 페이지 parsing....
# 870 번째 페이지 parsing....
# 871 번째 페이지 parsing....
# 872 번째 페이지 parsing....
# 873 번째 페이지 parsing....
# 874 번째 페이지 parsing....
# 875 번째 페이지 parsing....
# 876 번째 페이지 parsing....
# 877 번째 페이지 parsing....
# 878 번째 페이지 parsing....
# 879 번째 페이지 parsing....
# 880 번째 페이지 parsing....
# 881 번째 페이지 parsing....
# 882 번째 페이지 parsing....
# 883 번째 페이지 parsing....
# 884 번째 페이지 parsing....
# 885 번째 페이지 parsing....
# 886 번째 페이지 parsing....
# 887 번째 페이지 parsing....
# 888 번째 페이지 parsing....
# 889 번째 페이지 parsing....
# 890 번째 페이지 parsing....
# 891 번째 페이지 parsing....
# 892 번째 페이지 parsing....
# 893 번째 페이지 parsing....
# 894 번째 페이지 parsing....
# 895 번째 페이지 parsing....
# 896 번째 페이지 parsing....
# 897 번째 페이지 parsing....
# 898 번째 페이지 parsing....
# 899 번째 페이지 parsing....
# 900 번째 페이지 parsing....
# 901 번째 페이지 parsing....
# 902 번째 페이지 parsing....
# 903 번째 페이지 parsing....
# 904 번째 페이지 parsing....
# 905 번째 페이지 parsing....
# 906 번째 페이지 parsing....
# 907 번째 페이지 parsing....
# 908 번째 페이지 parsing....
# 909 번째 페이지 parsing....
# 910 번째 페이지 parsing....
# 911 번째 페이지 parsing....
# 912 번째 페이지 parsing....
# 913 번째 페이지 parsing....
# 914 번째 페이지 parsing....
# 915 번째 페이지 parsing....
# 916 번째 페이지 parsing....
# 917 번째 페이지 parsing....
# 918 번째 페이지 parsing....
# 919 번째 페이지 parsing....
# 920 번째 페이지 parsing....
# 921 번째 페이지 parsing....
# 922 번째 페이지 parsing....
# 923 번째 페이지 parsing....
# 924 번째 페이지 parsing....
# 925 번째 페이지 parsing....
# 926 번째 페이지 parsing....
# 927 번째 페이지 parsing....
# 928 번째 페이지 parsing....
# 929 번째 페이지 parsing....
# 930 번째 페이지 parsing....
# 931 번째 페이지 parsing....
# 932 번째 페이지 parsing....
# 933 번째 페이지 parsing....
# 934 번째 페이지 parsing....
# 935 번째 페이지 parsing....
# 936 번째 페이지 parsing....
# 937 번째 페이지 parsing....
# 938 번째 페이지 parsing....
# 939 번째 페이지 parsing....
# 940 번째 페이지 parsing....
# 941 번째 페이지 parsing....
# 942 번째 페이지 parsing....
# 943 번째 페이지 parsing....
# 944 번째 페이지 parsing....
# 945 번째 페이지 parsing....
# 946 번째 페이지 parsing....
# 947 번째 페이지 parsing....
# 948 번째 페이지 parsing....
# 949 번째 페이지 parsing....
# 950 번째 페이지 parsing....
# 951 번째 페이지 parsing....
# 952 번째 페이지 parsing....
# 953 번째 페이지 parsing....
# 954 번째 페이지 parsing....
# 955 번째 페이지 parsing....
# 956 번째 페이지 parsing....
# 957 번째 페이지 parsing....
# 958 번째 페이지 parsing....
# 959 번째 페이지 parsing....
# 960 번째 페이지 parsing....
# 961 번째 페이지 parsing....
# 962 번째 페이지 parsing....
# 963 번째 페이지 parsing....
# 964 번째 페이지 parsing....
# 965 번째 페이지 parsing....
# 966 번째 페이지 parsing....
# 967 번째 페이지 parsing....
# 968 번째 페이지 parsing....
# 969 번째 페이지 parsing....
# 970 번째 페이지 parsing....
# 971 번째 페이지 parsing....
# 972 번째 페이지 parsing....
# 973 번째 페이지 parsing....
# 974 번째 페이지 parsing....
# 975 번째 페이지 parsing....
# 976 번째 페이지 parsing....
# 977 번째 페이지 parsing....
# 978 번째 페이지 parsing....
# 979 번째 페이지 parsing....
# 980 번째 페이지 parsing....
# 981 번째 페이지 parsing....
# 982 번째 페이지 parsing....
# 983 번째 페이지 parsing....
# 984 번째 페이지 parsing....
# 985 번째 페이지 parsing....
# 986 번째 페이지 parsing....
# 987 번째 페이지 parsing....
# 988 번째 페이지 parsing....
# 989 번째 페이지 parsing....
# 990 번째 페이지 parsing....
# 991 번째 페이지 parsing....
# 992 번째 페이지 parsing....
# 993 번째 페이지 parsing....
# 994 번째 페이지 parsing....
# 995 번째 페이지 parsing....
# 996 번째 페이지 parsing....
# 997 번째 페이지 parsing....
# 998 번째 페이지 parsing....
# 999 번째 페이지 parsing....
# 1000 번째 페이지 parsing....
# 1001 번째 페이지 parsing....
# 1002 번째 페이지 parsing....
# 1003 번째 페이지 parsing....
# 1004 번째 페이지 parsing....
# 1005 번째 페이지 parsing....
# 1006 번째 페이지 parsing....
# 1007 번째 페이지 parsing....
# 1008 번째 페이지 parsing....
# 1009 번째 페이지 parsing....
# 1010 번째 페이지 parsing....
# 1011 번째 페이지 parsing....
# 1012 번째 페이지 parsing....
# 1013 번째 페이지 parsing....
# 1014 번째 페이지 parsing....
# 1015 번째 페이지 parsing....
# 1016 번째 페이지 parsing....
# 1017 번째 페이지 parsing....
# 1018 번째 페이지 parsing....
# 1019 번째 페이지 parsing....
# 1020 번째 페이지 parsing....
# 1021 번째 페이지 parsing....
# 1022 번째 페이지 parsing....
# 1023 번째 페이지 parsing....
# 1024 번째 페이지 parsing....
# 1025 번째 페이지 parsing....
# 1026 번째 페이지 parsing....
# 1027 번째 페이지 parsing....
# 1028 번째 페이지 parsing....
# 1029 번째 페이지 parsing....
# 1030 번째 페이지 parsing....
# 1031 번째 페이지 parsing....
# 1032 번째 페이지 parsing....
# 1033 번째 페이지 parsing....
# 1034 번째 페이지 parsing....
# 1035 번째 페이지 parsing....
# 1036 번째 페이지 parsing....
# 1037 번째 페이지 parsing....
# 1038 번째 페이지 parsing....
# 1039 번째 페이지 parsing....
# 1040 번째 페이지 parsing....
# 1041 번째 페이지 parsing....
# 1042 번째 페이지 parsing....
# 1043 번째 페이지 parsing....
# 1044 번째 페이지 parsing....
# 1045 번째 페이지 parsing....
# 1046 번째 페이지 parsing....
# 1047 번째 페이지 parsing....
# 1048 번째 페이지 parsing....
# 1049 번째 페이지 parsing....
# 1050 번째 페이지 parsing....
# 1051 번째 페이지 parsing....
# 1052 번째 페이지 parsing....
# 1053 번째 페이지 parsing....
# 1054 번째 페이지 parsing....
# 1055 번째 페이지 parsing....
# 1056 번째 페이지 parsing....
# 1057 번째 페이지 parsing....
# 1058 번째 페이지 parsing....
# 1059 번째 페이지 parsing....
# 1060 번째 페이지 parsing....
# 1061 번째 페이지 parsing....
# 1062 번째 페이지 parsing....
# 1063 번째 페이지 parsing....
# 1064 번째 페이지 parsing....
# 1065 번째 페이지 parsing....
# 1066 번째 페이지 parsing....
# 1067 번째 페이지 parsing....
# 1068 번째 페이지 parsing....
# 1069 번째 페이지 parsing....
# 1070 번째 페이지 parsing....
# 1071 번째 페이지 parsing....
# 1072 번째 페이지 parsing....
# 1073 번째 페이지 parsing....
# 1074 번째 페이지 parsing....
# 1075 번째 페이지 parsing....
# 1076 번째 페이지 parsing....
# 1077 번째 페이지 parsing....
# 1078 번째 페이지 parsing....
# 1079 번째 페이지 parsing....
# 1080 번째 페이지 parsing....
# 1081 번째 페이지 parsing....
# 1082 번째 페이지 parsing....
# 1083 번째 페이지 parsing....
# 1084 번째 페이지 parsing....
# 1085 번째 페이지 parsing....
# 1086 번째 페이지 parsing....
# 1087 번째 페이지 parsing....
# 1088 번째 페이지 parsing....
# 1089 번째 페이지 parsing....
# 1090 번째 페이지 parsing....
# 1091 번째 페이지 parsing....
# 1092 번째 페이지 parsing....
# 1093 번째 페이지 parsing....
# 1094 번째 페이지 parsing....
# 1095 번째 페이지 parsing....
# 1096 번째 페이지 parsing....
# 1097 번째 페이지 parsing....
# 1098 번째 페이지 parsing....
# 1099 번째 페이지 parsing....
# 1100 번째 페이지 parsing....
# 1101 번째 페이지 parsing....
# 1102 번째 페이지 parsing....
# 1103 번째 페이지 parsing....
# 1104 번째 페이지 parsing....
# 1105 번째 페이지 parsing....
# 1106 번째 페이지 parsing....
# 1107 번째 페이지 parsing....
# 1108 번째 페이지 parsing....
# 1109 번째 페이지 parsing....
# 1110 번째 페이지 parsing....
# 1111 번째 페이지 parsing....
# 1112 번째 페이지 parsing....
# 1113 번째 페이지 parsing....
# 1114 번째 페이지 parsing....
# 1115 번째 페이지 parsing....
# 1116 번째 페이지 parsing....
# 1117 번째 페이지 parsing....
# 1118 번째 페이지 parsing....
# 1119 번째 페이지 parsing....
# 1120 번째 페이지 parsing....
# 1121 번째 페이지 parsing....
# 1122 번째 페이지 parsing....
# 1123 번째 페이지 parsing....
# 1124 번째 페이지 parsing....
# 1125 번째 페이지 parsing....
# 1126 번째 페이지 parsing....
# 1127 번째 페이지 parsing....
# 1128 번째 페이지 parsing....
# 1129 번째 페이지 parsing....
# 1130 번째 페이지 parsing....
# 1131 번째 페이지 parsing....
# 1132 번째 페이지 parsing....
# 1133 번째 페이지 parsing....
# 1134 번째 페이지 parsing....
# 1135 번째 페이지 parsing....
# 1136 번째 페이지 parsing....
# 1137 번째 페이지 parsing....
# 1138 번째 페이지 parsing....
# 1139 번째 페이지 parsing....
# 1140 번째 페이지 parsing....
# 1141 번째 페이지 parsing....
# 1142 번째 페이지 parsing....
# 1143 번째 페이지 parsing....
# 1144 번째 페이지 parsing....
# 1145 번째 페이지 parsing....
# 1146 번째 페이지 parsing....
# 1147 번째 페이지 parsing....
# 1148 번째 페이지 parsing....
# 1149 번째 페이지 parsing....
# 1150 번째 페이지 parsing....
# 1151 번째 페이지 parsing....
# 1152 번째 페이지 parsing....
# 1153 번째 페이지 parsing....
# 1154 번째 페이지 parsing....
# 1155 번째 페이지 parsing....
# 1156 번째 페이지 parsing....
# 1157 번째 페이지 parsing....
# 1158 번째 페이지 parsing....
# 1159 번째 페이지 parsing....
# 1160 번째 페이지 parsing....
# 1161 번째 페이지 parsing....
# 1162 번째 페이지 parsing....
# 1163 번째 페이지 parsing....
# 1164 번째 페이지 parsing....
# 1165 번째 페이지 parsing....
# 1166 번째 페이지 parsing....
# 1167 번째 페이지 parsing....
# 1168 번째 페이지 parsing....
# 1169 번째 페이지 parsing....
# 1170 번째 페이지 parsing....
# 1171 번째 페이지 parsing....
# 1172 번째 페이지 parsing....
# 1173 번째 페이지 parsing....
# 1174 번째 페이지 parsing....
# 1175 번째 페이지 parsing....
# 1176 번째 페이지 parsing....
# 1177 번째 페이지 parsing....
# 1178 번째 페이지 parsing....
# 1179 번째 페이지 parsing....
# 1180 번째 페이지 parsing....
# 1181 번째 페이지 parsing....
# 1182 번째 페이지 parsing....
# 1183 번째 페이지 parsing....
# 1184 번째 페이지 parsing....
# 1185 번째 페이지 parsing....
# 1186 번째 페이지 parsing....
# 1187 번째 페이지 parsing....
# 1188 번째 페이지 parsing....
# 1189 번째 페이지 parsing....
# 1190 번째 페이지 parsing....
# 1191 번째 페이지 parsing....
# 1192 번째 페이지 parsing....
# 1193 번째 페이지 parsing....
# 1194 번째 페이지 parsing....
# 1195 번째 페이지 parsing....
# 1196 번째 페이지 parsing....
# 1197 번째 페이지 parsing....
# 1198 번째 페이지 parsing....
# 1199 번째 페이지 parsing....
# 1200 번째 페이지 parsing....
# 1201 번째 페이지 parsing....
# 1202 번째 페이지 parsing....
# 1203 번째 페이지 parsing....
# 1204 번째 페이지 parsing....
# 1205 번째 페이지 parsing....
# 1206 번째 페이지 parsing....
# 1207 번째 페이지 parsing....
# 1208 번째 페이지 parsing....
# 1209 번째 페이지 parsing....
# 1210 번째 페이지 parsing....
# 1211 번째 페이지 parsing....
# 1212 번째 페이지 parsing....
# 1213 번째 페이지 parsing....
# 1214 번째 페이지 parsing....
# 1215 번째 페이지 parsing....
# 1216 번째 페이지 parsing....
# 1217 번째 페이지 parsing....
# 1218 번째 페이지 parsing....
# 1219 번째 페이지 parsing....
# 1220 번째 페이지 parsing....
# 1221 번째 페이지 parsing....
# 1222 번째 페이지 parsing....
# 1223 번째 페이지 parsing....
# 1224 번째 페이지 parsing....
# 1225 번째 페이지 parsing....
# 1226 번째 페이지 parsing....
# 1227 번째 페이지 parsing....
# 1228 번째 페이지 parsing....
# 1229 번째 페이지 parsing....
# 1230 번째 페이지 parsing....
# 1231 번째 페이지 parsing....
# 1232 번째 페이지 parsing....
# 1233 번째 페이지 parsing....
# 1234 번째 페이지 parsing....
# 1235 번째 페이지 parsing....
# 1236 번째 페이지 parsing....
# 1237 번째 페이지 parsing....
# 1238 번째 페이지 parsing....
# 1239 번째 페이지 parsing....
# 1240 번째 페이지 parsing....
# 1241 번째 페이지 parsing....
# 1242 번째 페이지 parsing....
# 1243 번째 페이지 parsing....
# 1244 번째 페이지 parsing....
# 1245 번째 페이지 parsing....
# 1246 번째 페이지 parsing....
# 1247 번째 페이지 parsing....
# 1248 번째 페이지 parsing....
# 1249 번째 페이지 parsing....
# 1250 번째 페이지 parsing....
# 1251 번째 페이지 parsing....
# 1252 번째 페이지 parsing....
# 1253 번째 페이지 parsing....
# 1254 번째 페이지 parsing....
# 1255 번째 페이지 parsing....
# 1256 번째 페이지 parsing....
# 1257 번째 페이지 parsing....
# 1258 번째 페이지 parsing....
# 1259 번째 페이지 parsing....
# 1260 번째 페이지 parsing....
# 1261 번째 페이지 parsing....
# 1262 번째 페이지 parsing....
# 1263 번째 페이지 parsing....
# 1264 번째 페이지 parsing....
# 1265 번째 페이지 parsing....
# 1266 번째 페이지 parsing....
# 1267 번째 페이지 parsing....
# 1268 번째 페이지 parsing....
# 1269 번째 페이지 parsing....
# 1270 번째 페이지 parsing....
# 1271 번째 페이지 parsing....
# 1272 번째 페이지 parsing....
# 1273 번째 페이지 parsing....
# 1274 번째 페이지 parsing....
# 1275 번째 페이지 parsing....
# 1276 번째 페이지 parsing....
# 1277 번째 페이지 parsing....
# 1278 번째 페이지 parsing....
# 1279 번째 페이지 parsing....
# 1280 번째 페이지 parsing....
# 1281 번째 페이지 parsing....
# 1282 번째 페이지 parsing....
# 1283 번째 페이지 parsing....
# 1284 번째 페이지 parsing....
# 1285 번째 페이지 parsing....
# 1286 번째 페이지 parsing....
# 1287 번째 페이지 parsing....
# 1288 번째 페이지 parsing....
# 1289 번째 페이지 parsing....
# 1290 번째 페이지 parsing....
# 1291 번째 페이지 parsing....
# 1292 번째 페이지 parsing....
# 1293 번째 페이지 parsing....
# 1294 번째 페이지 parsing....
# 1295 번째 페이지 parsing....
# 1296 번째 페이지 parsing....
# 1297 번째 페이지 parsing....
# 1298 번째 페이지 parsing....
# 1299 번째 페이지 parsing....
# 1300 번째 페이지 parsing....
# 1301 번째 페이지 parsing....
# 1302 번째 페이지 parsing....
# 1303 번째 페이지 parsing....
# 1304 번째 페이지 parsing....
# 1305 번째 페이지 parsing....
# 1306 번째 페이지 parsing....
# 1307 번째 페이지 parsing....
# 1308 번째 페이지 parsing....
# 1309 번째 페이지 parsing....
# 1310 번째 페이지 parsing....
# 1311 번째 페이지 parsing....
# 1312 번째 페이지 parsing....
# 1313 번째 페이지 parsing....
# 1314 번째 페이지 parsing....
# 1315 번째 페이지 parsing....
# 1316 번째 페이지 parsing....
# 1317 번째 페이지 parsing....
# 1318 번째 페이지 parsing....
# 1319 번째 페이지 parsing....
# 1320 번째 페이지 parsing....
# 1321 번째 페이지 parsing....
# 1322 번째 페이지 parsing....
# 1323 번째 페이지 parsing....
# 1324 번째 페이지 parsing....
# 1325 번째 페이지 parsing....
# 1326 번째 페이지 parsing....
# 1327 번째 페이지 parsing....
# 1328 번째 페이지 parsing....
# 1329 번째 페이지 parsing....
# 1330 번째 페이지 parsing....
# 1331 번째 페이지 parsing....
# 1332 번째 페이지 parsing....
# 1333 번째 페이지 parsing....
# 1334 번째 페이지 parsing....
# 1335 번째 페이지 parsing....
# 1336 번째 페이지 parsing....
# 1337 번째 페이지 parsing....
# 1338 번째 페이지 parsing....
# 1339 번째 페이지 parsing....
# 1340 번째 페이지 parsing....
# 1341 번째 페이지 parsing....
# 1342 번째 페이지 parsing....
# 1343 번째 페이지 parsing....
# 1344 번째 페이지 parsing....
# 1345 번째 페이지 parsing....
# 1346 번째 페이지 parsing....
# 1347 번째 페이지 parsing....
# 1348 번째 페이지 parsing....
# 1349 번째 페이지 parsing....
# 1350 번째 페이지 parsing....
# 1351 번째 페이지 parsing....
# 1352 번째 페이지 parsing....
# 1353 번째 페이지 parsing....
# 1354 번째 페이지 parsing....
# 1355 번째 페이지 parsing....
# 1356 번째 페이지 parsing....
# 1357 번째 페이지 parsing....
# 1358 번째 페이지 parsing....
# 1359 번째 페이지 parsing....
# 1360 번째 페이지 parsing....
# 1361 번째 페이지 parsing....
# 1362 번째 페이지 parsing....
# 1363 번째 페이지 parsing....
# 1364 번째 페이지 parsing....
# 1365 번째 페이지 parsing....
# 1366 번째 페이지 parsing....
# 1367 번째 페이지 parsing....
# 1368 번째 페이지 parsing....
# 1369 번째 페이지 parsing....
# 1370 번째 페이지 parsing....
# 1371 번째 페이지 parsing....
# 1372 번째 페이지 parsing....
# 1373 번째 페이지 parsing....
# 1374 번째 페이지 parsing....
# 1375 번째 페이지 parsing....
# 1376 번째 페이지 parsing....
# 1377 번째 페이지 parsing....
# 1378 번째 페이지 parsing....
# 1379 번째 페이지 parsing....
# 1380 번째 페이지 parsing....
# 1381 번째 페이지 parsing....
# 1382 번째 페이지 parsing....
# 1383 번째 페이지 parsing....
# 1384 번째 페이지 parsing....
# 1385 번째 페이지 parsing....
# 1386 번째 페이지 parsing....
# 1387 번째 페이지 parsing....
# 1388 번째 페이지 parsing....
# 1389 번째 페이지 parsing....
# 1390 번째 페이지 parsing....
# 1391 번째 페이지 parsing....
# 1392 번째 페이지 parsing....
# 1393 번째 페이지 parsing....
# 1394 번째 페이지 parsing....
# 1395 번째 페이지 parsing....
# 1396 번째 페이지 parsing....
# 1397 번째 페이지 parsing....
# 1398 번째 페이지 parsing....
# 1399 번째 페이지 parsing....
# 1400 번째 페이지 parsing....
# 1401 번째 페이지 parsing....
# 1402 번째 페이지 parsing....
# 1403 번째 페이지 parsing....
# 1404 번째 페이지 parsing....
# 1405 번째 페이지 parsing....
# 1406 번째 페이지 parsing....
# 1407 번째 페이지 parsing....
# 1408 번째 페이지 parsing....
# 1409 번째 페이지 parsing....
# 1410 번째 페이지 parsing....
# 1411 번째 페이지 parsing....
# 1412 번째 페이지 parsing....
# 1413 번째 페이지 parsing....
# 1414 번째 페이지 parsing....
# 1415 번째 페이지 parsing....
# 1416 번째 페이지 parsing....
# 1417 번째 페이지 parsing....
# 1418 번째 페이지 parsing....
# 1419 번째 페이지 parsing....
# 1420 번째 페이지 parsing....
# 1421 번째 페이지 parsing....
# 1422 번째 페이지 parsing....
# 1423 번째 페이지 parsing....
# 1424 번째 페이지 parsing....
# 1425 번째 페이지 parsing....
# 1426 번째 페이지 parsing....
# 1427 번째 페이지 parsing....
# 1428 번째 페이지 parsing....
# 1429 번째 페이지 parsing....
# 1430 번째 페이지 parsing....
# 1431 번째 페이지 parsing....
# 1432 번째 페이지 parsing....
# 1433 번째 페이지 parsing....
# 1434 번째 페이지 parsing....
# 1435 번째 페이지 parsing....
# 1436 번째 페이지 parsing....
# 1437 번째 페이지 parsing....
# 1438 번째 페이지 parsing....
# 1439 번째 페이지 parsing....
# 1440 번째 페이지 parsing....
# 1441 번째 페이지 parsing....
# 1442 번째 페이지 parsing....
# 1443 번째 페이지 parsing....
# 1444 번째 페이지 parsing....
# 1445 번째 페이지 parsing....
# 1446 번째 페이지 parsing....
# 1447 번째 페이지 parsing....
# 1448 번째 페이지 parsing....
# 1449 번째 페이지 parsing....
# 1450 번째 페이지 parsing....
# 1451 번째 페이지 parsing....
# 1452 번째 페이지 parsing....
# 1453 번째 페이지 parsing....
# 1454 번째 페이지 parsing....
# 1455 번째 페이지 parsing....
# 1456 번째 페이지 parsing....
# 1457 번째 페이지 parsing....
# 1458 번째 페이지 parsing....
# 1459 번째 페이지 parsing....
# 1460 번째 페이지 parsing....
# 1461 번째 페이지 parsing....
# 1462 번째 페이지 parsing....
# 1463 번째 페이지 parsing....
# 1464 번째 페이지 parsing....
# 1465 번째 페이지 parsing....
# 1466 번째 페이지 parsing....
# 1467 번째 페이지 parsing....
# 1468 번째 페이지 parsing....
# 1469 번째 페이지 parsing....
# 1470 번째 페이지 parsing....
# 1471 번째 페이지 parsing....
# 1472 번째 페이지 parsing....
# 1473 번째 페이지 parsing....
# 1474 번째 페이지 parsing....
# 1475 번째 페이지 parsing....
# 1476 번째 페이지 parsing....
# 1477 번째 페이지 parsing....
# 1478 번째 페이지 parsing....
# 1479 번째 페이지 parsing....
# 1480 번째 페이지 parsing....
# 1481 번째 페이지 parsing....
# 1482 번째 페이지 parsing....
# 1483 번째 페이지 parsing....
# 1484 번째 페이지 parsing....
# 1485 번째 페이지 parsing....
# 1486 번째 페이지 parsing....
# 1487 번째 페이지 parsing....
# 1488 번째 페이지 parsing....
# 1489 번째 페이지 parsing....
# 1490 번째 페이지 parsing....
# 1491 번째 페이지 parsing....
# 1492 번째 페이지 parsing....
# 1493 번째 페이지 parsing....
# 1494 번째 페이지 parsing....
# 1495 번째 페이지 parsing....
# 1496 번째 페이지 parsing....
# 1497 번째 페이지 parsing....
# 1498 번째 페이지 parsing....
# 1499 번째 페이지 parsing....
# 1500 번째 페이지 parsing....
# 1501 번째 페이지 parsing....
# 1502 번째 페이지 parsing....
# 1503 번째 페이지 parsing....
# 1504 번째 페이지 parsing....
# 1505 번째 페이지 parsing....
# 1506 번째 페이지 parsing....
# 1507 번째 페이지 parsing....
# 1508 번째 페이지 parsing....
# 1509 번째 페이지 parsing....
# 1510 번째 페이지 parsing....
# 1511 번째 페이지 parsing....
# 1512 번째 페이지 parsing....
# 1513 번째 페이지 parsing....
# 1514 번째 페이지 parsing....
# 1515 번째 페이지 parsing....
# 1516 번째 페이지 parsing....
# 1517 번째 페이지 parsing....
# 1518 번째 페이지 parsing....
# 1519 번째 페이지 parsing....
# 1520 번째 페이지 parsing....
# 1521 번째 페이지 parsing....
# 1522 번째 페이지 parsing....
# 1523 번째 페이지 parsing....
# 1524 번째 페이지 parsing....
# 1525 번째 페이지 parsing....
# 1526 번째 페이지 parsing....
# 1527 번째 페이지 parsing....
# 1528 번째 페이지 parsing....
# 1529 번째 페이지 parsing....
# 1530 번째 페이지 parsing....
# 1531 번째 페이지 parsing....
# 1532 번째 페이지 parsing....
# 1533 번째 페이지 parsing....
# 1534 번째 페이지 parsing....
# 1535 번째 페이지 parsing....
# 1536 번째 페이지 parsing....
# 1537 번째 페이지 parsing....
# 1538 번째 페이지 parsing....
# 1539 번째 페이지 parsing....
# 1540 번째 페이지 parsing....
# 1541 번째 페이지 parsing....
# 1542 번째 페이지 parsing....
# 1543 번째 페이지 parsing....
# 1544 번째 페이지 parsing....
# 1545 번째 페이지 parsing....
# 1546 번째 페이지 parsing....
# 1547 번째 페이지 parsing....
# 1548 번째 페이지 parsing....
# 1549 번째 페이지 parsing....
# 1550 번째 페이지 parsing....
# 1551 번째 페이지 parsing....
# 1552 번째 페이지 parsing....
# 1553 번째 페이지 parsing....
# 1554 번째 페이지 parsing....
# 1555 번째 페이지 parsing....
# 1556 번째 페이지 parsing....
# 1557 번째 페이지 parsing....
# 1558 번째 페이지 parsing....
# 1559 번째 페이지 parsing....
# 1560 번째 페이지 parsing....
# 1561 번째 페이지 parsing....
# 1562 번째 페이지 parsing....
# 1563 번째 페이지 parsing....
# 1564 번째 페이지 parsing....
# 1565 번째 페이지 parsing....
# 1566 번째 페이지 parsing....
# 1567 번째 페이지 parsing....
# 1568 번째 페이지 parsing....
# 1569 번째 페이지 parsing....
# 1570 번째 페이지 parsing....
# 1571 번째 페이지 parsing....
# 1572 번째 페이지 parsing....
# 1573 번째 페이지 parsing....
# 1574 번째 페이지 parsing....
# 1575 번째 페이지 parsing....
# 1576 번째 페이지 parsing....
# 1577 번째 페이지 parsing....
# 1578 번째 페이지 parsing....
# 1579 번째 페이지 parsing....
# 1580 번째 페이지 parsing....
# 1581 번째 페이지 parsing....
# 1582 번째 페이지 parsing....
# 1583 번째 페이지 parsing....
# 1584 번째 페이지 parsing....
# 1585 번째 페이지 parsing....
# 1586 번째 페이지 parsing....
# 1587 번째 페이지 parsing....
# 1588 번째 페이지 parsing....
# 1589 번째 페이지 parsing....
# 1590 번째 페이지 parsing....
# 1591 번째 페이지 parsing....
# 1592 번째 페이지 parsing....
# 1593 번째 페이지 parsing....
# 1594 번째 페이지 parsing....
# 1595 번째 페이지 parsing....
# 1596 번째 페이지 parsing....
# 1597 번째 페이지 parsing....
# 1598 번째 페이지 parsing....
# 1599 번째 페이지 parsing....
# 1600 번째 페이지 parsing....
# 1601 번째 페이지 parsing....
# 1602 번째 페이지 parsing....
# 1603 번째 페이지 parsing....
# 1604 번째 페이지 parsing....
# 1605 번째 페이지 parsing....
# 1606 번째 페이지 parsing....
# 1607 번째 페이지 parsing....
# 1608 번째 페이지 parsing....
# 1609 번째 페이지 parsing....
# 1610 번째 페이지 parsing....
# 1611 번째 페이지 parsing....
# 1612 번째 페이지 parsing....
# 1613 번째 페이지 parsing....
# 1614 번째 페이지 parsing....
# 1615 번째 페이지 parsing....
# 1616 번째 페이지 parsing....
# 1617 번째 페이지 parsing....
# 1618 번째 페이지 parsing....
# 1619 번째 페이지 parsing....
# 1620 번째 페이지 parsing....
# 1621 번째 페이지 parsing....
# 1622 번째 페이지 parsing....
# 1623 번째 페이지 parsing....
# 1624 번째 페이지 parsing....
# 1625 번째 페이지 parsing....
# 1626 번째 페이지 parsing....
# 1627 번째 페이지 parsing....
# 1628 번째 페이지 parsing....
# 1629 번째 페이지 parsing....
# 1630 번째 페이지 parsing....
# 1631 번째 페이지 parsing....
# 1632 번째 페이지 parsing....
# 1633 번째 페이지 parsing....
# 1634 번째 페이지 parsing....
# 1635 번째 페이지 parsing....
# 1636 번째 페이지 parsing....
# 1637 번째 페이지 parsing....
# 1638 번째 페이지 parsing....
# 1639 번째 페이지 parsing....
# 1640 번째 페이지 parsing....
# 1641 번째 페이지 parsing....
# 1642 번째 페이지 parsing....
# 1643 번째 페이지 parsing....
# 1644 번째 페이지 parsing....
# 1645 번째 페이지 parsing....
# 1646 번째 페이지 parsing....
# 1647 번째 페이지 parsing....
# 1648 번째 페이지 parsing....
# 1649 번째 페이지 parsing....
# 1650 번째 페이지 parsing....
# 1651 번째 페이지 parsing....
# 1652 번째 페이지 parsing....
# 1653 번째 페이지 parsing....
# 1654 번째 페이지 parsing....
# 1655 번째 페이지 parsing....
# 1656 번째 페이지 parsing....
# 1657 번째 페이지 parsing....
# 1658 번째 페이지 parsing....
# 1659 번째 페이지 parsing....
# 1660 번째 페이지 parsing....
# 1661 번째 페이지 parsing....
# 1662 번째 페이지 parsing....
# 1663 번째 페이지 parsing....
# 1664 번째 페이지 parsing....
# 1665 번째 페이지 parsing....
# 1666 번째 페이지 parsing....
# 1667 번째 페이지 parsing....
# 1668 번째 페이지 parsing....
# 1669 번째 페이지 parsing....
# 1670 번째 페이지 parsing....
# 1671 번째 페이지 parsing....
# 1672 번째 페이지 parsing....
# 1673 번째 페이지 parsing....
# 1674 번째 페이지 parsing....
# 1675 번째 페이지 parsing....
# 1676 번째 페이지 parsing....
# 1677 번째 페이지 parsing....
# 1678 번째 페이지 parsing....
# 1679 번째 페이지 parsing....
# 1680 번째 페이지 parsing....
# 1681 번째 페이지 parsing....
# 1682 번째 페이지 parsing....
# 1683 번째 페이지 parsing....
# 1684 번째 페이지 parsing....
# 1685 번째 페이지 parsing....
# 1686 번째 페이지 parsing....
# 1687 번째 페이지 parsing....
# 1688 번째 페이지 parsing....
# 1689 번째 페이지 parsing....
# 1690 번째 페이지 parsing....
# 1691 번째 페이지 parsing....
# 1692 번째 페이지 parsing....
# 1693 번째 페이지 parsing....
# 1694 번째 페이지 parsing....
# 1695 번째 페이지 parsing....
# 1696 번째 페이지 parsing....
# 1697 번째 페이지 parsing....
# 1698 번째 페이지 parsing....
# 1699 번째 페이지 parsing....
# 1700 번째 페이지 parsing....
# 1701 번째 페이지 parsing....
# 1702 번째 페이지 parsing....
# 1703 번째 페이지 parsing....
# 1704 번째 페이지 parsing....
# 1705 번째 페이지 parsing....
# 1706 번째 페이지 parsing....
# 1707 번째 페이지 parsing....
# 1708 번째 페이지 parsing....
# 1709 번째 페이지 parsing....
# 1710 번째 페이지 parsing....
# 1711 번째 페이지 parsing....
# 1712 번째 페이지 parsing....
# 1713 번째 페이지 parsing....
# 1714 번째 페이지 parsing....
# 1715 번째 페이지 parsing....
# 1716 번째 페이지 parsing....
# 1717 번째 페이지 parsing....
# 1718 번째 페이지 parsing....
# 1719 번째 페이지 parsing....
# 1720 번째 페이지 parsing....
# 1721 번째 페이지 parsing....
# 1722 번째 페이지 parsing....
# 1723 번째 페이지 parsing....
# 1724 번째 페이지 parsing....
# 1725 번째 페이지 parsing....
# 1726 번째 페이지 parsing....
# 1727 번째 페이지 parsing....
# 1728 번째 페이지 parsing....
# 1729 번째 페이지 parsing....
# 1730 번째 페이지 parsing....
# 1731 번째 페이지 parsing....
# 1732 번째 페이지 parsing....
# 1733 번째 페이지 parsing....
# 1734 번째 페이지 parsing....
# 1735 번째 페이지 parsing....
# 1736 번째 페이지 parsing....
# 1737 번째 페이지 parsing....
# 1738 번째 페이지 parsing....
# 1739 번째 페이지 parsing....
# 1740 번째 페이지 parsing....
# 1741 번째 페이지 parsing....
# 1742 번째 페이지 parsing....
# 1743 번째 페이지 parsing....
# 1744 번째 페이지 parsing....
# 1745 번째 페이지 parsing....
# 1746 번째 페이지 parsing....
# 1747 번째 페이지 parsing....
# 1748 번째 페이지 parsing....
# 1749 번째 페이지 parsing....
# 1750 번째 페이지 parsing....
# 1751 번째 페이지 parsing....
# 1752 번째 페이지 parsing....
# 1753 번째 페이지 parsing....
# 1754 번째 페이지 parsing....
# 1755 번째 페이지 parsing....
# 1756 번째 페이지 parsing....
# 1757 번째 페이지 parsing....
# 1758 번째 페이지 parsing....
# 1759 번째 페이지 parsing....
# 1760 번째 페이지 parsing....
# 1761 번째 페이지 parsing....
# 1762 번째 페이지 parsing....
# 1763 번째 페이지 parsing....
# 1764 번째 페이지 parsing....
# 1765 번째 페이지 parsing....
# 1766 번째 페이지 parsing....
# 1767 번째 페이지 parsing....
# 1768 번째 페이지 parsing....
# 1769 번째 페이지 parsing....
# 1770 번째 페이지 parsing....
# 1771 번째 페이지 parsing....
# 1772 번째 페이지 parsing....
# 1773 번째 페이지 parsing....
# 1774 번째 페이지 parsing....
# 1775 번째 페이지 parsing....
# 1776 번째 페이지 parsing....
# 1777 번째 페이지 parsing....
# 1778 번째 페이지 parsing....
# 1779 번째 페이지 parsing....
# 1780 번째 페이지 parsing....
# 1781 번째 페이지 parsing....
# 1782 번째 페이지 parsing....
# 1783 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['erlo****',
#   '김재규를 미화하지않고객관적이며 인간적으로 묘사했던게 좋았고무엇보다 머머리를 좀도둑놈 시키로 그려줬던게 최고의 연출이었다.',
#   '10',
#   '5989',
#   '1987',
#   datetime.datetime(2020, 1, 23, 14, 55),
#   '관람객'],
#  ['빛그림(namj****)',
#   '연기 잘 하는 배우가 모여있습니다',
#   '10',
#   '4918',
#   '1417',
#   datetime.datetime(2020, 1, 22, 15, 55),
#   '관람객'],
#  ['쩡(jeon****)',
#   '이 영화는 이병헌 연기의 최정점을 볼 수 있다ㄷㄷ 한 장면 한 장면 긴장감을 놓을 수 없고 진짜 잘 만든 영화라는 생각밖에는,,, 오랜만에 잘 만든 한국영화 bb',
#   '10',
#   '4385',
#   '1678',
#   datetime.datetime(2020, 1, 22, 10, 10),
#   '관람객'],
#  ['Joonseosa(myeo****)',
#   '오랜만에 볼만한 한국영화!이성민 배우님 박통 연기 소름돋았습니다',
#   '10',
#   '3625',
#   '1227',
#   datetime.datetime(2020, 1, 22, 20, 29),
#   '관람객'],
#  ['ㅎㅎㅎ(eorm****)',
#   '다 좋은데 마지막에 뭐냐; 전두환이 돈 챙겨가는거ㅋㅋㅋ개찐빠네 마지막이',
#   '10',
#   '3231',
#   '952',
#   datetime.datetime(2020, 1, 22, 11, 19),
#   '관람객'],
#  ['minmin(ssg8****)',
#   '이병헌 연기력 폭발함. 후반부까지 긴장감 대박임...',
#   '10',
#   '3163',
#   '1216',
#   datetime.datetime(2020, 1, 22, 10, 12),
#   '관람객'],
#  ['PurityDEK(drea****)',
#   '오랜만에 잘봤습니다. 연기  대박',
#   '10',
#   '2921',
#   '1025',
#   datetime.datetime(2020, 1, 22, 20, 2),
#   0],
#  ['묘갈(nged****)',
#   '남산으로 향했으면 김재규가 정권을 잡았다고 모든 전문가들이 판단했는데~왜 육본으로 가서   죄를 받았는지~거기에 전두환은 쥐새끼같이 기횔 물고  생쑈를~~',
#   '10',
#   '2203',
#   '590',
#   datetime.datetime(2020, 1, 24, 2, 0),
#   '관람객'],
#  ['jjom(more****)',
#   '진짜 이병헌 크라쓰가 다르다 긴장감있는 연출도 좋았음',
#   '10',
#   '2603',
#   '1068',
#   datetime.datetime(2020, 1, 22, 10, 11),
#   '관람객'],
#  ['hun1****',
#   '일베들 평점테러보소ㄷㄷ',
#   '10',
#   '3974',
#   '2596',
#   datetime.datetime(2020, 1, 22, 15, 3),
#   0],
#  ['다크호스(afgh****)',
#   '징한놈이 가니 더 한 놈이 오네...',
#   '10',
#   '1788',
#   '423',
#   datetime.datetime(2020, 1, 24, 12, 12),
#   '관람객'],
#  ['정빛나(brig****)',
#   '이 영화는 평가를 할 수가 없다',
#   '10',
#   '2013',
#   '829',
#   datetime.datetime(2020, 1, 22, 21, 19),
#   0],
#  ['파워피로에(jokw****)',
#   '배우들의 연기로 이미 재미 없을수가 없었다..',
#   '10',
#   '1949',
#   '910',
#   datetime.datetime(2020, 1, 22, 11, 58),
#   0],
#  ['피노코(pino****)',
#   '다들 연기 미쳤다 ㅠㅠㅠㅠ 엔딩 진짜 특히 꼭 봐야함',
#   '10',
#   '1899',
#   '890',
#   datetime.datetime(2020, 1, 22, 10, 5),
#   '관람객'],
#  ['chio****',
#   '와 연기력 진짜 미쳤다 굿',
#   '10',
#   '1780',
#   '863',
#   datetime.datetime(2020, 1, 22, 10, 7),
#   '관람객'],
#  ['움치키움챠(llll****)',
#   '완성도와 재미 모두 갖췄지만 연기가 소름 ... 이병헌 안면근육까지 열연',
#   '10',
#   '1519',
#   '622',
#   datetime.datetime(2020, 1, 22, 10, 14),
#   0],
#  ['Ssssss_(sehy****)',
#   '이병헌, 이성민 압도적인 연기에 이희준도 장난이 아니다. 완벽하게 그때 그 사람들 같다.',
#   '10',
#   '1556',
#   '662',
#   datetime.datetime(2020, 1, 22, 10, 15),
#   '관람객'],
#  ['손흥따리바리(lsj2****)',
#   '작품으로 보고 평가좀 합시다 좌우 갈라서 싸우지 말고 좌파들만 원하는 우파들만 원하는 영화가 나오길 바라나요? 둘다 꿈깨쇼',
#   '10',
#   '1882',
#   '1022',
#   datetime.datetime(2020, 1, 22, 10, 2),
#   0],
#  ['계왕권200배(senc****)',
#   '어떻게 이병헌은 눈두덩이 밑 달달 떨리는 연기도 하냐?ㅎㄷㄷ',
#   '10',
#   '1039',
#   '275',
#   datetime.datetime(2020, 1, 23, 0, 18),
#   0],
#  ['노가리(shwo****)',
#   '영화 자체는 묵직하고 포스 있는데 이병헌의 섬세한 고민 번뇌 등등까지 다 잡았음 진짜 멋드러지는 영화',
#   '10',
#   '1337',
#   '577',
#   datetime.datetime(2020, 1, 22, 10, 4),
#   0],
#  ['gkdlgkdl221(boyo****)',
#   '이병헌 연기 미쳤다.. 내 인생 최고의 엔딩 ㅠ',
#   '10',
#   '1283',
#   '771',
#   datetime.datetime(2020, 1, 22, 10, 16),
#   '관람객'],
#  ['shs1****',
#   '예상했던 것 보다 연기가 더 소름돋음 긴장감 있는 연출 음악 다 좋았고 역시 마지막 엔딩.... 연휴에 한 번 더 볼 각',
#   '10',
#   '1142',
#   '650',
#   datetime.datetime(2020, 1, 22, 10, 15),
#   '관람객'],
#  ['kang****',
#   '박정희, 김재규, 차지철, 전두환 ...  권력투쟁을 사실적으로 잘 묘사한 시대극.',
#   '9',
#   '776',
#   '328',
#   datetime.datetime(2020, 1, 25, 9, 27),
#   0],
#  ['쥬니(vlwk****)',
#   '이병헌이 이병헌했고 우민호가 우민호 했다',
#   '10',
#   '1180',
#   '748',
#   datetime.datetime(2020, 1, 22, 10, 18),
#   '관람객'],
#  ['후이종(ht59****)',
#   '연기는 당연히 믿고받는데 연출까지 최고일줄은 몰랐다..진짜 재밌었음',
#   '10',
#   '1100',
#   '686',
#   datetime.datetime(2020, 1, 22, 10, 12),
#   '관람객'],
#  ['정명호(hanj****)',
#   '한국 영화에서 오랜만에 만나보는 웰메이드 정치 스릴러. 배우들의 놀라운 연기력으로 영화의 품격을 한 층 더 높인다. 차곡차곡 쌓아온 감정선을 폭발시키는 엔딩은 가히 압도적.',
#   '10',
#   '982',
#   '572',
#   datetime.datetime(2020, 1, 22, 10, 8),
#   0],
#  ['레이라(layl****)',
#   '이 영화가 개봉되고 유통되고 있는 것이 신기합니다지금은 이런 세상이군요.',
#   '10',
#   '562',
#   '154',
#   datetime.datetime(2020, 1, 27, 3, 57),
#   '관람객'],
#  ['wasa****',
#   '평점을 좀 대국적으로 다십시오.',
#   '8',
#   '684',
#   '303',
#   datetime.datetime(2020, 1, 22, 14, 6),
#   0],
#  ['상큼한레몬(sulk****)',
#   '평점은 임자 맘대로 혀~ 아는 결말이어도 숨죽이고 봤어요~',
#   '10',
#   '630',
#   '280',
#   datetime.datetime(2020, 1, 22, 22, 14),
#   '관람객'],
#  ['ekzp****',
#   '40년이 지나니까 이런 영화도 나오네요.',
#   '8',
#   '454',
#   '127',
#   datetime.datetime(2020, 1, 26, 21, 44),
#   '관람객'],
#  ['사우스포(pana****)',
#   '일베와 박사모들이 죄다 몰려 와 평점 테러하고 자빠졌네.',
#   '10',
#   '1742',
#   '1432',
#   datetime.datetime(2020, 1, 22, 17, 45),
#   0],
#  ['Dtrk(jdu0****)',
#   '김재규가 영웅이 아니라고?? 영화는 김재규를 꽤 중립적으로 묘사했다. 민주화를 위해 혹은 2인자에서 밀려날까하는 점 등에서 사살의 이유는 복합적이었다. 그러나 여기서 그를 영웅으로 여길 수 있는 점은 김재규가 다까기...',
#   '10',
#   '592',
#   '308',
#   datetime.datetime(2020, 1, 27, 19, 27),
#   '관람객'],
#  ['아범(no38****)',
#   '역시 전두혁이는 쥐새퀴',
#   '10',
#   '461',
#   '180',
#   datetime.datetime(2020, 1, 26, 14, 7),
#   '관람객'],
#  ['미셸(jihy****)',
#   '이런 분위기 영화 진짜 오랜만ㄷㄷㄷ 다들 연기도 쩔어서 몰입도 장난 아니었음 2차 찍으러 갑니다',
#   '10',
#   '817',
#   '538',
#   datetime.datetime(2020, 1, 22, 10, 15),
#   '관람객'],
#  ['형(car4****)',
#   '이병헌 안면근육까지 연기합니다. 꼭보세요 추천합니다!',
#   '10',
#   '489',
#   '217',
#   datetime.datetime(2020, 1, 22, 22, 2),
#   '관람객'],
#  ['KH먹방(dmag****)',
#   '이병헌 어떻게 눈두덩이까지 저렇게 디테일하게 연기하지..? 몰입도 최고 간만에 재밌게본 한국영화!',
#   '10',
#   '639',
#   '378',
#   datetime.datetime(2020, 1, 22, 12, 19),
#   '관람객'],
#  ['jord****',
#   '몰입감 대박. 이병헌의 OOO기!! 70년대 그 때 그 현장에 있던 느낌을 받았네요.명절 맞이 부모님과 같이 봤는데 정말 재밌게 잘봤습니다.',
#   '10',
#   '437',
#   '177',
#   datetime.datetime(2020, 1, 25, 20, 47),
#   0],
#  ['하늘그림(blue****)',
#   '개인적으로 내부자들보다 더 깊이도 있고 세련미 넘치고 재미있게 봤다. 이병헌 존멋, 조조로 봤는데도 1도 안졸리고 시간순삭당함',
#   '10',
#   '704',
#   '465',
#   datetime.datetime(2020, 1, 22, 10, 12),
#   0],
#  ['2020(fast****)',
#   '이병헌, 당신의 연기란',
#   '10',
#   '469',
#   '239',
#   datetime.datetime(2020, 1, 24, 11, 33),
#   '관람객'],
#  ['Berserk(wing****)',
#   '많은 사람들이 봤으면 하는 영화. 이병헌은 맡은 역할마다 연기가 아니라 그냥 그 사람이다.',
#   '10',
#   '440',
#   '217',
#   datetime.datetime(2020, 1, 23, 8, 3),
#   '관람객'],
#  ['안녕하소(gjdb****)',
#   '확실히 우민호 감독은 이병헌과 만나야 시너지가 생긴다',
#   '10',
#   '715',
#   '492',
#   datetime.datetime(2020, 1, 22, 9, 3),
#   0],
#  ['원어민(8kjg****)',
#   '잘만들었다 일베들의공격이 예상됨',
#   '10',
#   '432',
#   '255',
#   datetime.datetime(2020, 1, 26, 15, 58),
#   '관람객'],
#  ['니안(skyt****)',
#   '원래 감상평 잘 안 남기는데 이상하게도 계속 여운이 남는 영화에요',
#   '10',
#   '329',
#   '155',
#   datetime.datetime(2020, 1, 26, 0, 19),
#   0],
#  ['photo(only****)',
#   '쫄깃쫄깃합니다. 내부자들보다 재밌습니다.이병헌, 이성민, 곽도원, 이희준.네 명의 연기가 목구멍 아래에 총을 겨눈 것처럼  아주 그냥 팽팽합니다.',
#   '10',
#   '437',
#   '269',
#   datetime.datetime(2020, 1, 23, 14, 12),
#   '관람객'],
#  ['스(zoof****)',
#   '이병헌 이희준 곽도원 다들 연기가 미쳤음 세련된 느와르로 돌아온 우민호!',
#   '10',
#   '566',
#   '399',
#   datetime.datetime(2020, 1, 22, 10, 19),
#   0],
#  ['belovedkatie(kgi8****)',
#   '연기 몰입도짱쳐지는거없이 긴장감 백푸로기대이상 꼭보세요 존잼',
#   '10',
#   '271',
#   '124',
#   datetime.datetime(2020, 1, 25, 20, 45),
#   0],
#  ['June(pkjk****)',
#   '이병헌 연기력도 쩔지만 이성민 배우님 박통 씽크로율 대박임... 이번엔 진짜 얼굴 표정만으로도 연기 할 수 있다는 걸 입증함. 역사적 사실을 각색한 영화임. 박통이 독재자 었던 것도...부산에 탱크 보내서 광주 꼴 ...',
#   '10',
#   '345',
#   '198',
#   datetime.datetime(2020, 1, 22, 23, 0),
#   0],
#  ['마용(ayun****)',
#   '배우들 연기가 진짜 정말 최고였던 영화 재밌어요!!!',
#   '10',
#   '617',
#   '479',
#   datetime.datetime(2020, 1, 22, 10, 12),
#   '관람객'],
#  ['박상구(gugu****)',
#   '다 아는 내용이지만 배우들 연기가 너무실감나게 잘한다',
#   '10',
#   '249',
#   '116',
#   datetime.datetime(2020, 1, 25, 20, 44),
#   0],
#  ['박연수(yuns****)',
#   '영화를 본 사람들은 압니다. 연출, 연기, 스토리, 영상미, OST 전부 다 가져가는 영화',
#   '10',
#   '484',
#   '359',
#   datetime.datetime(2020, 1, 22, 10, 4),
#   0],
#  ['zin(silv****)',
#   '담백합니다. 불순물이 거의 없습니다. 편중된 의견없이 필요한 이야기만 한 것 같은데 완전히 빠져들었습니다. 배우분들 연기 매우 좋았습니다.',
#   '10',
#   '363',
#   '243',
#   datetime.datetime(2020, 1, 24, 16, 45),
#   '관람객'],
#  ['이수진(ghkr****)',
#   '묵묵히 조용히 지켜 본 사람이 승리자였네',
#   '10',
#   '227',
#   '112',
#   datetime.datetime(2020, 1, 25, 20, 47),
#   0],
#  ['taij****',
#   '임자 옆에 내가있잖아 임자 하고 싶은대로해...',
#   '8',
#   '1634',
#   '1521',
#   datetime.datetime(2020, 1, 22, 23, 11),
#   0],
#  ['APPRENTICE(amaz****)',
#   '이병헌 연기를 너무잘함팩트와 픽션을 잘 조합함',
#   '8',
#   '307',
#   '206',
#   datetime.datetime(2020, 1, 23, 17, 11),
#   '관람객'],
#  ['사막비(youi****)',
#   '고민하는 사람들에게..내부자를 재밌게 본 사람이라면 재밌을거야2시간 내내 긴장하고 봤다',
#   '9',
#   '242',
#   '142',
#   datetime.datetime(2020, 1, 25, 1, 0),
#   0],
#  ['그(kyju****)',
#   '완전 초집중 분위기가 다 했어요',
#   '10',
#   '413',
#   '318',
#   datetime.datetime(2020, 1, 23, 13, 55),
#   '관람객'],
#  ['자연(dnjs****)',
#   '이병헌과 이성민의 연기가 좋았던 영화.',
#   '8',
#   '222',
#   '155',
#   datetime.datetime(2020, 1, 23, 9, 41),
#   '관람객'],
#  ['litt****',
#   '평점테러하지마세용?^^',
#   '10',
#   '595',
#   '535',
#   datetime.datetime(2020, 1, 22, 10, 1),
#   0],
#  ['skikiki(seai****)',
#   '정말 오랜만에 보는 배우들의 연기가 꽉찬 영화! 스토리도 영상도 1시간 50분내내 붙들어둠',
#   '10',
#   '380',
#   '323',
#   datetime.datetime(2020, 1, 22, 10, 17),
#   0],
#  ['alte****',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '90',
#   '41',
#   datetime.datetime(2020, 1, 24, 17, 6),
#   0],
#  ['scou****',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '61',
#   '20',
#   datetime.datetime(2020, 1, 27, 21, 25),
#   '관람객'],
#  ['안효정(dksg****)',
#   '다들 연기 잘하시는 배우들만 나와서  연기가 아주 미쳤습니다!!!! 이병헌은 정말 연기천재인듯..',
#   '10',
#   '208',
#   '170',
#   datetime.datetime(2020, 1, 23, 1, 33),
#   '관람객'],
#  ['crer****',
#   '우민호는 사실적인 영화를 잘 다듬는 감독이다',
#   '10',
#   '170',
#   '134',
#   datetime.datetime(2020, 1, 26, 0, 19),
#   0],
#  ['임림(lhj0****)',
#   '정말 기대 많이 하고 봤는데 기대 이상이네요. 역시 이병헌 역시 우민호 소리가 절로 나와요 ㅎㅎ 추천합니다',
#   '10',
#   '393',
#   '360',
#   datetime.datetime(2020, 1, 22, 10, 16),
#   '관람객'],
#  ['쏘쏘(syde****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '82',
#   '50',
#   datetime.datetime(2020, 1, 23, 8, 44),
#   0],
#  ['한솔(hans****)',
#   '마지막을 달려갈때 손 떨면서 봤음',
#   '10',
#   '124',
#   '93',
#   datetime.datetime(2020, 1, 24, 9, 41),
#   '관람객'],
#  ['뿌뿡뿡(king****)',
#   '김재규에 대한 사실에 기반한 평가가 필요하다. 그는 어떤 인물이었을까? 박정희에게 버림받아 앙심을 품은 것일까, 진정으로 민주주의를 부르짖은 것이었을까',
#   '7',
#   '70',
#   '41',
#   datetime.datetime(2020, 1, 28, 23, 41),
#   '관람객'],
#  ['윤진효(sera****)',
#   '머머리 좀도둑 ㅋㅋㅋ',
#   '9',
#   '44',
#   '16',
#   datetime.datetime(2020, 1, 27, 15, 21),
#   '관람객'],
#  ['Scholsey(kim_****)',
#   '개봉 시기가 참.. 너무 속보이는, 그래서 아쉬운',
#   '1',
#   '57',
#   '31',
#   datetime.datetime(2020, 1, 25, 21, 47),
#   0],
#  ['윤우함(pine****)',
#   '이병헌은 천재다. 이병헌을 좋아하지 않을 수 없다',
#   '10',
#   '133',
#   '107',
#   datetime.datetime(2020, 1, 23, 10, 37),
#   '관람객'],
#  ['yons****',
#   '실화를 가장한 가짜 영화',
#   '1',
#   '195',
#   '169',
#   datetime.datetime(2020, 1, 25, 0, 40),
#   0],
#  ['우뛰짱나(goni****)',
#   '마약왕의 허접한 연출로 의아한 생각을 가졌었고 남산의 부장들 로 인하여 우민호 감독의 연출이 많이 부족한것에 대한 확신을 가졌다. 역시 내부자들이 성공한것은 각본,배우들의 연기,캐릭터성이 뛰어났기에 성공했던것. 남산...',
#   '5',
#   '280',
#   '254',
#   datetime.datetime(2020, 1, 23, 13, 4),
#   0],
#  ['ange****',
#   '이런 쓰레기같은걸 영화라고 만들고선 부끄럽지도않더냐?4월 총선용인건 알겠는데 진심 낯뜨겁더라!',
#   '1',
#   '291',
#   '265',
#   datetime.datetime(2020, 1, 23, 18, 44),
#   0],
#  ['김민정(smil****)',
#   '동화책의 마녀처럼 단순하고 한심한 선악구도. 당시 박정희 대통령 이발사 박수웅 씨나 피격 현장에 실제 있었던 심수봉 등의 실제 증언은 전혀 반영되어있지 않은 주관적 상상력과 허구로 가득찬 쓰레기 정치 선동 영화. 내...',
#   '1',
#   '558',
#   '532',
#   datetime.datetime(2020, 1, 23, 14, 23),
#   0],
#  ['은혼(jong****)',
#   '지극히 범죄자의 주장만을 진실인양 영웅화 시키는 선동을 작정한 영화.',
#   '1',
#   '72',
#   '47',
#   datetime.datetime(2020, 1, 25, 12, 5),
#   0],
#  ['죠다쉬(111b****)',
#   '봤는데 좌빨 영화;이병헌 아니였으면 시체인 영화임..',
#   '1',
#   '73',
#   '48',
#   datetime.datetime(2020, 1, 25, 12, 2),
#   0],
#  ['dlgu****',
#   '너무 정치색이 강하다 영화를 만들고 1년뒤에 공개하다니총선 앞두고 한가지더 이야기 하자면선거때 지소미아 이아기 반일 한번더 드립나온다좌파 놈들 이 한마디 듣고 반막해봐 지금 중국 바이러스때문에 북한도 중국이 국경닫고...',
#   '2',
#   '77',
#   '52',
#   datetime.datetime(2020, 1, 24, 22, 9),
#   0],
#  ['건강하기(ferv****)',
#   '연기빼고는 볼게 없음',
#   '1',
#   '68',
#   '44',
#   datetime.datetime(2020, 1, 24, 1, 26),
#   0],
#  ['bema****',
#   '정치색이 아주 짙은, 역겨운 영화',
#   '1',
#   '77',
#   '53',
#   datetime.datetime(2020, 1, 25, 12, 31),
#   0],
#  ['세월(cys0****)',
#   '정치선동  영화   이런영화는  걍 패스',
#   '2',
#   '82',
#   '58',
#   datetime.datetime(2020, 1, 25, 12, 13),
#   0],
#  ['반석 위에(ulbs****)',
#   '돈주고 선거운동 간 기분임.한쪽으로 치우친 편파적인 정치판을 본것같음.아무리 영화라지만...ㅠ',
#   '2',
#   '82',
#   '58',
#   datetime.datetime(2020, 1, 25, 0, 43),
#   0],
#  ['다비즈(hmk5****)',
#   '딱 선거용 정치 선동질 영화. 대사 아주 초보적이고 그정도 상상은 누구나 하겠다. 이게 영화냐?',
#   '1',
#   '82',
#   '58',
#   datetime.datetime(2020, 1, 24, 22, 32),
#   0],
#  ['all about you(vani****)',
#   '딱 선거전 정치영화. 이병헌 연기빼곤 볼거없음',
#   '1',
#   '83',
#   '59',
#   datetime.datetime(2020, 1, 25, 13, 13),
#   0],
#  ['막시무스(asia****)',
#   '거짓 / 날조 / 선동영화는 그만좀 만들어라. 한심하기 짝이없다.',
#   '1',
#   '84',
#   '60',
#   datetime.datetime(2020, 1, 25, 11, 24),
#   0],
#  ['Moon Garden(sunb****)',
#   '쓰레기 좌편향 영화.    근데 그걸떠나서 이게 다큐인지 영화인지 너무재미없다는게 문제.  더웃긴건. 다큐처럼 내용전달하는수준인데 역사는 또 드럽게 왜곡시켜놓았음ㅎㅎㅎㅎ. 한마디로 1점도아깝다',
#   '1',
#   '90',
#   '66',
#   datetime.datetime(2020, 1, 26, 0, 51),
#   0],
#  ['존귀(jong****)',
#   '정부에서 얼마받고 제작했냐??!!!',
#   '1',
#   '101',
#   '77',
#   datetime.datetime(2020, 1, 24, 19, 50),
#   0],
#  ['pgt4****',
#   '돈 좀 들어가는 한국상업영화에서 오랜만에 작품성좋은영화 영화봐서 기분좋다.이병헌의 또 다른 진가를 본 것 같아 기분좋고다른배우들 연기도, 몰입감 좋다.',
#   '8',
#   '106',
#   '82',
#   datetime.datetime(2020, 1, 23, 18, 28),
#   '관람객'],
#  ['버팀목(ntrw****)',
#   '어찌 갈수록 수준 떨어짐. 드라마 5공화국 >>그때그사람들>>남산의부장들',
#   '1',
#   '114',
#   '90',
#   datetime.datetime(2020, 1, 24, 7, 8),
#   0],
#  ['해피프로도(hjk3****)',
#   '재미가 없어요. 지루하고 따분한 시간이었어요',
#   '3',
#   '121',
#   '97',
#   datetime.datetime(2020, 1, 23, 19, 3),
#   0],
#  ['최한솔(han3****)',
#   '1년 전에 영화 만들어놓고 총선을 바로 앞에 둔 이 시국에 개봉하는 이유가 뭔가요? 근래 본 영화중에 가장 기분나쁜 최악의 영화였네요 돈아깝고 시간아까워요',
#   '1',
#   '122',
#   '98',
#   datetime.datetime(2020, 1, 25, 12, 40),
#   0],
#  ['ss(2s_b****)',
#   '배우들 연기는 인정내용은 지루',
#   '1',
#   '125',
#   '101',
#   datetime.datetime(2020, 1, 24, 1, 45),
#   0],
#  ['소녀(aldo****)',
#   '헐 !!~~ 완전 좌파빨영화네~~작정하고 박정희 대통령을깍아내리려 만든영화구만~~돈이 아깝고 시간이 아깝네~~기분더럽고~~',
#   '1',
#   '134',
#   '110',
#   datetime.datetime(2020, 1, 24, 1, 6),
#   0],
#  ['김성현(pete****)',
#   '',
#   '1',
#   '135',
#   '111',
#   datetime.datetime(2020, 1, 22, 22, 49),
#   0],
#  ['오오미(mlb1****)',
#   '쓰레기쓰레기쓰레기쓰레기',
#   '1',
#   '137',
#   '113',
#   datetime.datetime(2020, 1, 24, 3, 12),
#   0],
#  ['happyend(shal****)',
#   '그때 그 사람들... 무슨 사골국 우려 먹나...',
#   '1',
#   '138',
#   '114',
#   datetime.datetime(2020, 1, 24, 9, 56),
#   0],
#  ['dd(hosu****)',
#   '이런영화를 만드는 의도가 뭐냐???',
#   '1',
#   '139',
#   '115',
#   datetime.datetime(2020, 1, 24, 1, 8),
#   0],
#  ['써틴킬(qudt****)',
#   '이 배우들을 데리고 이렇게 찍었어야 했는가.. 총선을 앞두고 좌파에서 수작부린다는 의견들도 있었는데, 막상 영화를 보니 이 영화로 관람객의 마음을 흔들순 없을것 같다. 정치적 성향을 떠나서 그냥 재미없다. 진짜 재미...',
#   '2',
#   '146',
#   '122',
#   datetime.datetime(2020, 1, 26, 2, 47),
#   0],
#  ['dimor(blon****)',
#   '감독 연출능력이 폐급. 긴장감이 넘쳐흐를 소재로 잠오게 만드는것도 능력은 능력. 스파이역할 아줌마는 연기처음하시는지 발연기 지려버리고 먼놈의 쓸데없는 외국장면은 머하러 그렇게 넣은건지도 모르겠음. 외국에 한국인들밖에...',
#   '1',
#   '166',
#   '142',
#   datetime.datetime(2020, 1, 24, 7, 30),
#   0],
#  ['maag****',
#   '연기는 모두 인정.  편향됨이 도가 지나침.',
#   '2',
#   '176',
#   '152',
#   datetime.datetime(2020, 1, 24, 0, 54),
#   0],
#  ['광팔이(sali****)',
#   '국민을 개돼지로 알고 만든 선전선동 영화. 감독의 아구창을 날리고 싶었다.이렇게 돈 벌고 싶었냐?',
#   '1',
#   '188',
#   '164',
#   datetime.datetime(2020, 1, 24, 22, 4),
#   0],
#  ['l달빛l(i4o5****)',
#   '하... 제발좀 언제까지 이럴래? 각설이 마냥 때되면 나오는군',
#   '2',
#   '195',
#   '171',
#   datetime.datetime(2020, 1, 24, 9, 48),
#   0],
#  ['Fedora(opta****)',
#   '굳이 총선 맞춰서 ㅎㅎ 이젠 욕도 안나옴',
#   '1',
#   '196',
#   '172',
#   datetime.datetime(2020, 1, 24, 20, 38),
#   0],
#  ['요가(stab****)',
#   '여기서 영화보고 새로운 역사를 배웠니...교과서에서 보지못한 세세한부분을 배웠니 OO하는 시키들아...역사를 조작된 영화에서 찾으니 니 인생이 그모양 그꼴인거다...감독이 역사가냐?영화는 그냥 영화로만 봐라...멍청...',
#   '1',
#   '198',
#   '174',
#   datetime.datetime(2020, 1, 24, 14, 52),
#   0],
#  ['ange****',
#   '총선 앞두고 만든 암살자 미화 좌빨선동영화임 이런걸로 역사배우는 멍멍이꿀꿀이들이 많아서 문제다',
#   '1',
#   '198',
#   '174',
#   datetime.datetime(2020, 1, 24, 0, 50),
#   0],
#  ['nega****',
#   '좌파  선동 영화임다아는 내용, 배우들 연기로 포장해 총선 3개월전 설영화로 개봉한거 자체가 다분히  정치적',
#   '1',
#   '206',
#   '182',
#   datetime.datetime(2020, 1, 25, 12, 11),
#   0],
#  ['김선진(tsws****)',
#   '아니 뭔 시작부터 박통 끌어 내려야된다고만 함 ㅋㅋㅋ 박통 잘못이 뭔데용 ? 영화 이해 하나도 안감',
#   '1',
#   '227',
#   '203',
#   datetime.datetime(2020, 1, 24, 16, 5),
#   0],
#  ['lee4****',
#   '편향되고 거짓말투성이 쓰레기',
#   '1',
#   '287',
#   '263',
#   datetime.datetime(2020, 1, 24, 14, 51),
#   0],
#  ['빠밤(pscl****)',
#   '개인적 7점짜리 영화.박대통령의 독재를 비판하는 입장이고 김재규 부장이 재평가 될 수 있다고 생각하지만 박대통령을 돈에 환장한 악역으로 묘사한 점은 이해할수없다.+이병헌의 연기 기가막힌다.',
#   '1',
#   '311',
#   '287',
#   datetime.datetime(2020, 1, 24, 6, 47),
#   0],
#  ['Fernando(bych****)',
#   '배우들의 연기빼고는 내용은 그닥....',
#   '1',
#   '371',
#   '347',
#   datetime.datetime(2020, 1, 23, 12, 41),
#   0],
#  ['믿음(yong****)',
#   '역사모르는 사람들은 이런 영화를 역사로 믿는다는게 문제.',
#   '2',
#   '378',
#   '354',
#   datetime.datetime(2020, 1, 23, 17, 31),
#   0],
#  ['노네임(havi****)',
#   '의도가 뻔히 보이는 절제와 균형을 잃은 지루한 그들만의 다큐.',
#   '2',
#   '411',
#   '387',
#   datetime.datetime(2020, 1, 23, 18, 43),
#   0],
#  ['에효효(snya****)',
#   '겁나 지루한 좌파영화. 평점 높은이유 이해불가.',
#   '1',
#   '57',
#   '34',
#   datetime.datetime(2020, 1, 26, 20, 40),
#   0],
#  ['엔더(ende****)',
#   '이런>>>최앆의 영화',
#   '1',
#   '58',
#   '35',
#   datetime.datetime(2020, 1, 26, 11, 32),
#   0],
#  ['떠기떠기(dduk****)',
#   '구라좀 치지마라. 알바야 뭐야 극장에서 영화보다 잔거 처음임. 나만 이런가해서 주변 둘러보니까 다 고개 꺽여있더만. 연출하고 연기보면 졸작은 아닌데 지루함의 끝판임. 픽션 섞어서 만들면서 왜 이렇게 나온건지 이해불가...',
#   '1',
#   '59',
#   '36',
#   datetime.datetime(2020, 1, 26, 21, 20),
#   0],
#  ['Jin(bsw7****)',
#   '좌파쓰레기가 만든 영화',
#   '1',
#   '65',
#   '42',
#   datetime.datetime(2020, 1, 26, 2, 25),
#   0],
#  ['love****',
#   '역사적 얘기 속에 허구와 상상을 버무림',
#   '1',
#   '65',
#   '42',
#   datetime.datetime(2020, 1, 24, 20, 40),
#   0],
#  ['ppp2****',
#   '정치적 역사왜곡의 극치~',
#   '2',
#   '66',
#   '43',
#   datetime.datetime(2020, 1, 25, 12, 29),
#   0],
#  ['TTK(brem****)',
#   '대한민국의 현대사를 조롱 왜곡하고 그 시대에 살지 못한 젊은이들을 좀비로 만드는 영화다. 나머지는 다 소품이다. 김재규는 3일후 중정부장에서 짤릴것을 알고 평소의 불만과 외부의 사주와 판단의 실수로 어처구니없는 일을...',
#   '1',
#   '67',
#   '44',
#   datetime.datetime(2020, 2, 1, 20, 58),
#   0],
#  ['냑키(gino****)',
#   '친북시선으로 이야기하는 전형적인 빨갱이 이야기. 필리핀보다 못살던 대한민국을 경제대국으로 성장시키기 위해 독재 집권을 해서 선진국의 반열에 오르게 한 세계에서 인정받는 위대한 대통령의 이야기를 가지고 사실을 기반으로...',
#   '1',
#   '67',
#   '44',
#   datetime.datetime(2020, 1, 25, 21, 7),
#   0],
#  ['notforself(band****)',
#   '스토리도 별로...   연기도 별로..  솔직히 실망..   평론가들 다 죽었나',
#   '1',
#   '67',
#   '44',
#   datetime.datetime(2020, 1, 24, 20, 37),
#   0],
#  ['dbst****',
#   '평점이 왜이러지..절대 안봐도 되는 영화',
#   '1',
#   '68',
#   '45',
#   datetime.datetime(2020, 1, 25, 11, 23),
#   0],
#  ['파랑블루스카이코발트(wogm****)',
#   '정치성향그딴건 관심없고 진짜 이렇게잼없는영화는 여태껏첨본거같다 반이상시간을 졸다가 봤다가 했음 너무 지루하고 따분하고 살면서 극장가서본영화중 제일최악 과장아니고 졸다시피하다 나옴',
#   '1',
#   '68',
#   '45',
#   datetime.datetime(2020, 1, 25, 1, 15),
#   0],
#  ['masscho430(jjha****)',
#   '한단어로 추려보면...박정희 정권을 부정하는 좌파 선동영화임 박정희 일본어 연기나오고.. 이병헌 벌레드립 나오고..그냥 박정희독재 까는 내용임 총선 앞두고 개봉한거 보면... 정치색이 짙어서 별 한개도 주기싫다',
#   '1',
#   '69',
#   '46',
#   datetime.datetime(2020, 1, 25, 20, 59),
#   0],
#  ['dbsg****',
#   '역사 왜곡 영화 김재규 신격화.역사적 근거없는 판타지 영화',
#   '1',
#   '69',
#   '46',
#   datetime.datetime(2020, 1, 25, 13, 57),
#   0],
#  ['건포도(cach****)',
#   '좌파 정권하 최악의 왜곡 선동 영화 그 자체',
#   '1',
#   '69',
#   '46',
#   datetime.datetime(2020, 1, 25, 2, 31),
#   0],
#  ['부산공임밧데리동래점(vhxp****)',
#   '완전 박정희를 깍아내리는 영화 한국영화상 최악의 영화 사실이 아닌완전 왜곡된 이런 영화를 만든 이유가 궁금하다',
#   '2',
#   '69',
#   '46',
#   datetime.datetime(2020, 1, 25, 1, 5),
#   0],
#  ['David(min9****)',
#   '박정희를 ‘절대악’김재규를 ‘혁명가’로 묘사했는데 학생들이 이 영화를 보면서 그런 편협된 시선을 갖을까 걱정된다. 실제 사건에 의거해서 스토리가 구성되었만 중간중간에 감독의 정치적 색채를 끼워 넣은걸 보니 완전한 정...',
#   '1',
#   '69',
#   '46',
#   datetime.datetime(2020, 1, 24, 22, 32),
#   0],
#  ['내일(exo_****)',
#   '돈이 아깝다. 시간이 아깝다.',
#   '1',
#   '70',
#   '47',
#   datetime.datetime(2020, 1, 24, 21, 19),
#   0],
#  ['히게피요(kora****)',
#   '다큐 좋아하는데 이건 좀.. 이 내용가지고 이렇게 재미없게 만들수도 잇구나 느끼게 해준영화. 옆에 사람 반쯤보다가 걍 자더라. ㅅㄱ.',
#   '1',
#   '71',
#   '48',
#   datetime.datetime(2020, 1, 25, 18, 44),
#   0],
#  ['park****',
#   '김재규 미화',
#   '1',
#   '80',
#   '57',
#   datetime.datetime(2020, 1, 25, 15, 52),
#   0],
#  ['lee9****',
#   '너무 한쪽에 비판한 영화 평등하지 않음',
#   '1',
#   '82',
#   '59',
#   datetime.datetime(2020, 1, 25, 12, 13),
#   0],
#  ['리버풀제라드(poll****)',
#   '개노잼 편향적 영화 안보는거 추천',
#   '1',
#   '83',
#   '60',
#   datetime.datetime(2020, 1, 25, 12, 23),
#   0],
#  ['seho****',
#   '영화는 영화였으면 좋겠다 봤을때 희노애락을 느낄 수 있게 해주는 오락같은 매체라고해야할까? 언제부턴가...  우리나라에서 개봉하는 영화의 반이상이 정치색깔을 띄고있다 적당히 좀 하자 대중들이 즐길수있는 공간을 어지럽...',
#   '1',
#   '83',
#   '60',
#   datetime.datetime(2020, 1, 25, 11, 10),
#   0],
#  ['꿀이가득(avri****)',
#   '역사왜곡.선동영화. 지나치게 정치편향적.',
#   '1',
#   '83',
#   '60',
#   datetime.datetime(2020, 1, 24, 21, 12),
#   0],
#  ['구스타프말러(qhtj****)',
#   '전형적인 개돼지 대중 선동 영화다.',
#   '1',
#   '92',
#   '69',
#   datetime.datetime(2020, 1, 24, 13, 46),
#   0],
#  ['HYXX94(tldh****)',
#   '이병헌 감정선 미쳤다..',
#   '10',
#   '93',
#   '70',
#   datetime.datetime(2020, 1, 25, 21, 35),
#   '관람객'],
#  ['히데토(jjh1****)',
#   '역사왜곡좌파들의선거용선동영화',
#   '1',
#   '95',
#   '72',
#   datetime.datetime(2020, 1, 24, 20, 48),
#   0],
#  ['지혜진(nori****)',
#   '배우에속고 평점에 속은 영화정치에 관심이없었어도 변호인같은 영화는 잘봤는데 이 영화는 지루하기만 했다.',
#   '2',
#   '95',
#   '72',
#   datetime.datetime(2020, 1, 24, 13, 49),
#   0],
#  ['와리가리비벼(let_****)',
#   '살인자 미화하는 어이없는 영화',
#   '2',
#   '97',
#   '74',
#   datetime.datetime(2020, 1, 25, 12, 52),
#   0],
#  ['잉뱅풍(sum7****)',
#   '연기 굿 내용 지루 노잼 히트맨볼껄',
#   '1',
#   '98',
#   '75',
#   datetime.datetime(2020, 1, 24, 7, 8),
#   0],
#  ['KKKKK(mose****)',
#   '다분히 정치적인 프로파간다 영화 국가를 위해 위대한 일을 한 사람보다 그를 죽인자가 위대하다?',
#   '1',
#   '101',
#   '78',
#   datetime.datetime(2020, 1, 24, 15, 2),
#   0],
#  ['버들이(ther****)',
#   '엄청 기대했는데... 너무 다큐찍듯 만들어 몰입감이 떨어집니다. 정말 좋은 소재인데...ㅠ  영화가 끝나고 김재규보다 전두환만 떠오름...',
#   '6',
#   '127',
#   '104',
#   datetime.datetime(2020, 1, 23, 18, 25),
#   0],
#  ['냠냠메추리(rame****)',
#   '노잼에다가 고인가지고 장난치는 영화',
#   '1',
#   '244',
#   '221',
#   datetime.datetime(2020, 1, 23, 17, 37),
#   0],
#  ['우현석(whsr****)',
#   '색안경 벗고 볼려고해도 정치적 색깔이 너무 강하네요..내가 영화를 보는건지 정치선전물을 보고있는건지 헷갈릴 정도입니다.',
#   '2',
#   '255',
#   '232',
#   datetime.datetime(2020, 1, 24, 22, 4),
#   0],
#  ['lss3****',
#   '색다를 것도 없고 솔직히 엄청 지루하다.... 평점 왜 이렇게 높지 희한하네 알바라도 풀었나...',
#   '2',
#   '265',
#   '242',
#   datetime.datetime(2020, 1, 23, 12, 27),
#   0],
#  ['mypq****',
#   '좌익들 평점 주작 보소ㅋㅋ 이병현 연기말곤 볼거없다',
#   '1',
#   '266',
#   '243',
#   datetime.datetime(2020, 1, 23, 12, 17),
#   0],
#  ['토마스(voca****)',
#   '솔직히 이런 영화 나와도 그만 안 나와도 그만인데. 정치적 의도가 보여서 1점 줍니다. 이번 정권 존나 싫어서 반 점 주고 싶은데 선택지가 없네요.',
#   '1',
#   '283',
#   '260',
#   datetime.datetime(2020, 1, 24, 11, 51),
#   0],
#  ['우글리부글리(sunw****)',
#   '역시 이정권은 선동임 ㅋㅋ',
#   '1',
#   '311',
#   '288',
#   datetime.datetime(2020, 1, 24, 1, 15),
#   0],
#  ['재욱(jaeu****)',
#   '개인차가 있을 수 있지만, 평점 10은 알바가 확실함.영화 끝날때 낚였다는 느낌을 지우기 힘듬. 영화보려고 평점 댓글 찾아보는 분들은 이거 보지 마세요.',
#   '2',
#   '312',
#   '289',
#   datetime.datetime(2020, 1, 24, 8, 26),
#   0],
#  ['주사랑48(holy****)',
#   '요즘은 범죄자 이미지 좋게 만드는 것이 유행인가보군요. 뻔뻔한 나라 뻔뻔한 국민 부끄럽네요',
#   '2',
#   '316',
#   '293',
#   datetime.datetime(2020, 1, 23, 17, 30),
#   0],
#  ['slam****',
#   '한마디로 설명한다 돈아까움',
#   '1',
#   '335',
#   '312',
#   datetime.datetime(2020, 1, 24, 2, 11),
#   0],
#  ['데이비드베컴(bosu****)',
#   '영화 별로던데 ?? 뭐이리 높냐',
#   '1',
#   '356',
#   '333',
#   datetime.datetime(2020, 1, 23, 18, 27),
#   0],
#  ['Dahlia(kyod****)',
#   '하다하다 대통령 살해범을 미화하네ㅋㅋ좌파는 답이 없다',
#   '2',
#   '360',
#   '337',
#   datetime.datetime(2020, 1, 24, 14, 52),
#   0],
#  ['다비드(spmt****)',
#   '2020총선 앞두고  대통령암살범 미화  영화가  왜  필요할까요',
#   '1',
#   '392',
#   '369',
#   datetime.datetime(2020, 1, 24, 13, 46),
#   0],
#  ['호반(kyeo****)',
#   '배부르고 등따시게 만들어준 생명의 은인을 천하의 나쁜놈으로 만드는 나라가 있다??',
#   '1',
#   '403',
#   '380',
#   datetime.datetime(2020, 1, 23, 18, 26),
#   0],
#  ['BNXK(rlae****)',
#   '설날에도 정치영화..북한찬양 아니면 정치영화..이런 정권은 진짜 처음이다..',
#   '1',
#   '440',
#   '417',
#   datetime.datetime(2020, 1, 24, 9, 3),
#   0],
#  ['준비하는 여름(dufm****)',
#   '정치영화 편향이 어느새 당연한듯 나오는 이상한 나라가 되어버려따',
#   '1',
#   '497',
#   '474',
#   datetime.datetime(2020, 1, 23, 18, 28),
#   0],
#  ['sain****',
#   '팩트는좋은데 너무 정치색있는거아닌가 역시 좌파는선동에 달인이맞는가봄 연기는좋았는데 보는내내 불편함',
#   '2',
#   '506',
#   '483',
#   datetime.datetime(2020, 1, 23, 2, 40),
#   0],
#  ['harmony(king****)',
#   '과연 이게 팩트일까? 역사를 왜곡하고 빨갱이를 민주투사로 둔갑시키는 역사왜곡영화. 순수한 민주투사도 섞여 있었지만 실제로 빨갱이 사상을 가진 놈들이 드드드했단다. 병헌아 이런 영화 찍지마라. 니 영혼을 파는거다',
#   '1',
#   '577',
#   '554',
#   datetime.datetime(2020, 1, 23, 12, 15),
#   0],
#  ['도레미(djk1****)',
#   '김재규가 영웅이고 박정희는 역적이라고 설파하는 대중선동용 영화로 보이네요. 또 영화 한편보고 역사가나 혁명가라도 된 것 처럼 대한민국 부정하고 욕하고 다니는 사람 많아지겠죠ㅎㅎㅎ 지금 영화와 팝콘 먹으면서 휴식을 즐...',
#   '1',
#   '1055',
#   '1032',
#   datetime.datetime(2020, 1, 24, 7, 12),
#   0],
#  ['사랑의힘(jiho****)',
#   '좌편향적영화 선거다가왔지 좌빨들 전형적인 매스컴 전략',
#   '1',
#   '54',
#   '32',
#   datetime.datetime(2020, 1, 25, 14, 12),
#   0],
#  ['여행의발견(sunn****)',
#   '하다 하다 이젠 김재규 미화까지 하네...',
#   '1',
#   '55',
#   '33',
#   datetime.datetime(2020, 1, 26, 11, 41),
#   0],
#  ['한가로이(love****)',
#   '아무리 영화로만 생각하고 보려고해도 그냥 좌빨 선동영화',
#   '1',
#   '57',
#   '35',
#   datetime.datetime(2020, 1, 25, 14, 22),
#   0],
#  ['아라미스(pors****)',
#   '',
#   '2',
#   '57',
#   '35',
#   datetime.datetime(2020, 1, 24, 2, 44),
#   0],
#  ['파인애플(jk00****)',
#   '개노잼...입니다 돈 아깝',
#   '1',
#   '58',
#   '36',
#   datetime.datetime(2020, 1, 24, 16, 4),
#   0],
#  ['개달리다(kes3****)',
#   '별두개 준 이유는 CGV의자가 편해 별두개줌중간에 개연성이 너무길어서 잠을잤음',
#   '4',
#   '60',
#   '38',
#   datetime.datetime(2020, 1, 24, 0, 53),
#   0],
#  ['옥스(qodn****)',
#   '그때 그사람들은 참 재미있게 봤는데 아.. 이영화는 진짜;; 이렇게 유명한 얘기를 이렇게 지루하게 만들줄은 몰랐네요.. 좌파고 우파고 다 필요 없고 다 아는 얘기 참 재미없게 만들어 놨어요 어째 요즘 영화들은 배우 ...',
#   '1',
#   '61',
#   '39',
#   datetime.datetime(2020, 1, 25, 1, 11),
#   0],
#  ['rodd****',
#   '왜 죄다 이병헌연기얘기밖에없냐',
#   '1',
#   '61',
#   '39',
#   datetime.datetime(2020, 1, 24, 20, 59),
#   0],
#  ['이동훈(forc****)',
#   '아무리 정권이 바꼈다지만... ㅉ  0점이 없어서 이병헌 연기 때문에라도 1점 줍니다..',
#   '1',
#   '62',
#   '40',
#   datetime.datetime(2020, 1, 24, 22, 25),
#   0],
#  ['신정헌 SpaceCanvas(i_ma****)',
#   '감독의 정치성향에 영화가 통째로 매몰된 작품.박통은 철저히 비열한 인물로만 묘사되고전두환씨는 좀도둑으로 표현됨.영화 문맥과 전혀 무관한 현정권에 빌붙으려는 얄팍한 시도들이 영화를 보는 관객의 몰입도를 현저히 떨어뜨림...',
#   '1',
#   '63',
#   '41',
#   datetime.datetime(2020, 1, 26, 13, 14),
#   0],
#  ['LimPossible(alvi****)',
#   'ㅎㅎㅎㅎ총선 선동 영화',
#   '1',
#   '65',
#   '43',
#   datetime.datetime(2020, 1, 25, 12, 47),
#   0],
#  ['으른(wuje****)',
#   '정치영화 선거철 한철영화',
#   '1',
#   '65',
#   '43',
#   datetime.datetime(2020, 1, 25, 3, 41),
#   0],
#  ['LaLA(wesb****)',
#   '좌빨 영화 아웃!! 역사 왜곡 선동 그 이상 이하도 아님',
#   '1',
#   '66',
#   '44',
#   datetime.datetime(2020, 1, 25, 3, 53),
#   0],
#  ['wide****',
#   '댓글 알바들 쩐다...아예 다큐를 찍지?영화보고 허탈해한건 처음이다..영화 끝나고 주위 관객들 다들 이거 뭐니 하던데...이병헌과 설날 아니면 이영화는 그냥 폭폭망...',
#   '1',
#   '69',
#   '47',
#   datetime.datetime(2020, 1, 24, 20, 47),
#   0],
#  ['hkst****',
#   '금일 여의도 cgv 3관 11:05 J열 60대 노부부 공공장소에서 매너 좀 지킵시다.영화보면서 대화하고 특히 박 전대통령 총맞는 장면에서 웃는데 개소름!이병헌 연기보려고 이 영화보시는분들 보지마세요~정치색이 물씬 ...',
#   '2',
#   '70',
#   '48',
#   datetime.datetime(2020, 1, 24, 13, 44),
#   0],
#  ['kjh6****',
#   '내부자들은 색다른 잔인성과 운이 따랐던거같구,좀 지루합니다',
#   '1',
#   '71',
#   '49',
#   datetime.datetime(2020, 1, 24, 9, 6),
#   0],
#  ['새롬(yooj****)',
#   '궁지에 몰린 문재인의 선거철 비장의 무기, 어떻게 영화가 오직 김재규는 영웅, 박정희는 천하의 악당. 볼건 하나도 없고 ㅋㅋㅋㅋ',
#   '1',
#   '72',
#   '50',
#   datetime.datetime(2020, 1, 24, 16, 6),
#   0],
#  ['람보(team****)',
#   '새해부터 이걸 못피했네 돈아깝다',
#   '1',
#   '83',
#   '61',
#   datetime.datetime(2020, 1, 24, 21, 7),
#   0],
#  ['마스터초이(chlw****)',
#   '그저그런 좌파식 선동영화 이런게 필요할때긴 하지',
#   '1',
#   '89',
#   '67',
#   datetime.datetime(2020, 1, 24, 9, 5),
#   0],
#  ['yio5****',
#   '살인자를 미화하디니 한국영화 진짜 미쳤나봐',
#   '1',
#   '104',
#   '82',
#   datetime.datetime(2020, 1, 24, 16, 5),
#   0],
#  ['The CHOI(vary****)',
#   '에휴',
#   '1',
#   '106',
#   '84',
#   datetime.datetime(2020, 1, 24, 11, 50),
#   0],
#  ['달걀동동(gree****)',
#   '역사의 왜곡  ㅋㅋㅋ  김재규우상화',
#   '2',
#   '107',
#   '85',
#   datetime.datetime(2020, 1, 25, 0, 38),
#   0],
#  ['후회없기위해최선을(iove****)',
#   '영화라지만 참... 반대의 입장에서 대통령영화 만들어서 이렇기 해봐라 ..',
#   '1',
#   '108',
#   '86',
#   datetime.datetime(2020, 1, 25, 11, 16),
#   0],
#  ['닭목비틀면새벽안올까(nogi****)',
#   '기대이하 지루함 그자체',
#   '1',
#   '109',
#   '87',
#   datetime.datetime(2020, 1, 23, 18, 31),
#   0],
#  ['Snunewing(snu_****)',
#   '대놓고 정치영화임. 거기에 정치를 본인 시각으로 왜곡까지 해놨음;; 이건 진짜 인생에서 3시간을 날리는거에요. 보지마세요.',
#   '1',
#   '110',
#   '88',
#   datetime.datetime(2020, 1, 24, 22, 3),
#   0],
#  ['베비(mim8****)',
#   '뭐지 나만 지루한가요 ㅋㅋ',
#   '2',
#   '111',
#   '89',
#   datetime.datetime(2020, 1, 23, 20, 44),
#   0],
#  ['nwo(daeg****)',
#   '원작하고도 거리가 멀고팩트하고 전혀 다르고그냥 할리우드 배끼기 수준 영화',
#   '2',
#   '111',
#   '89',
#   datetime.datetime(2020, 1, 23, 7, 53),
#   0],
#  ['달(moon****)',
#   '전라도 달창들이 두번보고 세번볼 영화',
#   '2',
#   '125',
#   '103',
#   datetime.datetime(2020, 1, 24, 15, 8),
#   0],
#  ['귤(wend****)',
#   '그냥 정치색 없는 학생인데 진짜 스토리도 없고 재미없음.. 돈아까움ㅠㅠ',
#   '1',
#   '150',
#   '128',
#   datetime.datetime(2020, 1, 25, 1, 1),
#   0],
#  ['모까(yeon****)',
#   '요즘 한국 영화는 프로파간다 정치용 선전선동 영화만 만드나? 정치용 영화. 조폭. 느와르. 사회문제나 뒤트는 블랙코미디 영화만 판치면 한국 영화판은 편협해지고 곧 망하지 않을까?',
#   '1',
#   '155',
#   '133',
#   datetime.datetime(2020, 1, 24, 21, 14),
#   0],
#  ['youn****',
#   '자기들 수사한다고 검참들 모가지 전부 날려버리는 현정권을 보면서 박정희가 진짜 독재자였을까? 하는 의구심이 드네요',
#   '2',
#   '212',
#   '190',
#   datetime.datetime(2020, 1, 25, 12, 36),
#   0],
#  ['SPIKE(spik****)',
#   '박통을 너무 쓰레기로 묘사함. 일본인도 없는 술자리에 일어 쓰는 장면을 넣은 의도가..? 이성민 이병헌 연기에 별 두개 플러스',
#   '4',
#   '217',
#   '195',
#   datetime.datetime(2020, 1, 23, 18, 10),
#   0],
#  ['우르곳(hss0****)',
#   'ㅋㅋㅋㅋ하다하다 이젠 전대통령 살인범 까지 미화하네 그들은 어디까지인가....',
#   '2',
#   '218',
#   '196',
#   datetime.datetime(2020, 1, 25, 11, 7),
#   0],
#  ['hhs22790(hhs_****)',
#   '철저한 살인범 미화 영화',
#   '1',
#   '222',
#   '200',
#   datetime.datetime(2020, 1, 24, 19, 45),
#   0],
#  ['운똥(dnst****)',
#   '보기 불편할 정도로 영화의 방향성이 한 쪽으로 치우쳐져 있다 . 그렇다고 재미나 감동을 주기에도 무언가 어설픔 , 이럴거면 김소진은 왜 등장시킴 ? 결국 남은건 배우들의 연기 뿐이다',
#   '4',
#   '226',
#   '204',
#   datetime.datetime(2020, 1, 23, 12, 59),
#   0],
#  ['지니신(skj2****)',
#   '조조로보기 미안할정도로 완벽했다. 이병헌의 눈빚하나까지 전부담은 올해 최고의 영화가 될것같다.',
#   '10',
#   '269',
#   '247',
#   datetime.datetime(2020, 1, 22, 10, 24),
#   0],
#  ['고레도미(rlaw****)',
#   '박정희를 무조건 나쁜 이미지로 만듬.. 그냥 편향된 영화',
#   '1',
#   '467',
#   '445',
#   datetime.datetime(2020, 1, 23, 3, 30),
#   0],
#  ['dyddyd(redj****)',
#   '1년전에 다 만들어두고 총선앞두고 뻔한짓 하네ㅋㅋㅋ너무 뻔해서 웃김 병헌 연기만 굿이지',
#   '1',
#   '895',
#   '873',
#   datetime.datetime(2020, 1, 24, 7, 20),
#   0],
#  ['jso74(gdmi****)',
#   '그닥..3번 졸았네..',
#   '1',
#   '39',
#   '18',
#   datetime.datetime(2020, 1, 26, 11, 25),
#   0],
#  ['서인서인(tjdl****)',
#   '아짜증나진짜짜증나이게뭐야이씨',
#   '1',
#   '40',
#   '19',
#   datetime.datetime(2020, 1, 28, 0, 58),
#   0],
#  ['노잼(dpaf****)',
#   '총선용 영화 개봉시점 죽이네',
#   '1',
#   '41',
#   '20',
#   datetime.datetime(2020, 1, 30, 14, 18),
#   0],
#  ['이정진(leej****)',
#   '중간에 잤네요. 김재규를 김재규라고 못하는 현실... 통탄스럽습니다 박정희를 욕하고 김재규 재평가하고 싶으면 그냥 김재규라고 하시지 그랬어요',
#   '1',
#   '41',
#   '20',
#   datetime.datetime(2020, 1, 28, 10, 13),
#   0],
#  ['Jsantos(zoeu****)',
#   '.프.로.파.간.다.',
#   '1',
#   '44',
#   '23',
#   datetime.datetime(2020, 1, 26, 20, 58),
#   0],
#  ['mikelangelo(mike****)',
#   '0점은 없나?감독아 왜사니',
#   '1',
#   '50',
#   '29',
#   datetime.datetime(2020, 1, 26, 1, 2),
#   0],
#  ['HJ(yhj9****)',
#   'ㄹㅇ 노잼 지루하고 전개가 너무 느림',
#   '1',
#   '51',
#   '30',
#   datetime.datetime(2020, 1, 26, 2, 43),
#   0],
#  ['상디(fofo****)',
#   '불면증 심한분들 추천합니다!',
#   '1',
#   '51',
#   '30',
#   datetime.datetime(2020, 1, 25, 21, 2),
#   0],
#  ['2000****',
#   '재미없고 보는내내 지루했다. 이딴 주제로 왜 영화를 만든지가 의문이다. 재미도 없고 교훈도 없다. 돈과 시간을 낭비하며 본기 정말 아까울 정도.',
#   '1',
#   '55',
#   '34',
#   datetime.datetime(2020, 1, 24, 20, 51),
#   0],
#  ['Jiny0925(dugu****)',
#   '보는 내내 졸다가 마지막 장면에 정신차리고 봤네요. 저는 기대하고 봤다가 실망했습니다.',
#   '1',
#   '56',
#   '35',
#   datetime.datetime(2020, 1, 25, 12, 20),
#   0],
#  ['두부(yuj_****)',
#   '이병헌 연기는 최고 그렇지만 정치색이 너무강한영화',
#   '1',
#   '56',
#   '35',
#   datetime.datetime(2020, 1, 24, 22, 32),
#   0],
#  ['정종희(skb2****)',
#   '5공화국 재탕임ㅋㅋㅋㅋ 근데 개노잼ㅋㅋ 내부자들 만든 감독 맞냐? 아닌거같은데.. 원테이크로 이뤄진 이병헌 연기외엔 개1.쓰레기 영화',
#   '1',
#   '58',
#   '37',
#   datetime.datetime(2020, 1, 25, 13, 13),
#   0],
#  ['skf_****',
#   '좌파영화 진짜 역겨워요.',
#   '1',
#   '73',
#   '52',
#   datetime.datetime(2020, 1, 24, 18, 35),
#   0],
#  ['엘리옌(masa****)',
#   '보긴했는데 역사 왜곡이 ㅜ',
#   '2',
#   '78',
#   '57',
#   datetime.datetime(2020, 1, 25, 12, 38),
#   0],
#  ['오늘도 해피(ckru****)',
#   '선거를 앞두고 1년전에 완성된 영화를 지금 타이밍 맞춰 개봉하는 매우 교활한 정치영화',
#   '1',
#   '78',
#   '57',
#   datetime.datetime(2020, 1, 24, 20, 34),
#   0],
#  ['승현(adve****)',
#   '완전 수면제!!수면이 부족한 당신 보라!!연기파 배우들이 모였지만 충부히 잘 수 있는 스토리~쵝오입니다!!',
#   '2',
#   '80',
#   '59',
#   datetime.datetime(2020, 1, 24, 2, 3),
#   0],
#  ['하트비트(bucd****)',
#   '별루 내마음의별로ㅋㅋ벌벼넞',
#   '1',
#   '80',
#   '59',
#   datetime.datetime(2020, 1, 23, 14, 16),
#   0],
#  ['이재준(jaej****)',
#   '편파적인 관점을 가진 영화',
#   '1',
#   '82',
#   '61',
#   datetime.datetime(2020, 1, 24, 22, 16),
#   0],
#  ['John wick(dong****)',
#   '와 ㅋㅋㅋㅋ 이게 정치적이 아니라고? 정치적인 영화란 영화보고 아 이때 저랫구나 라고 생각하는 돌대가리가 조금이라도 있으면 정치적인 영화임 ㅇㅈ?',
#   '1',
#   '82',
#   '61',
#   datetime.datetime(2020, 1, 23, 18, 36),
#   0],
#  ['슬슬(your****)',
#   '총선용 영화일뿐ㅋㅋㅋ',
#   '1',
#   '85',
#   '64',
#   datetime.datetime(2020, 1, 25, 21, 0),
#   0],
#  ['pkho****',
#   '이제 좌파감독의 영화는 그만 보고 싶다... 왜 박근혜 대통령이 블랙 리스트라는 것을 만든지 알겠다... 다시는 한국영화 안본다...게레쓰기 좌빨 감독 퇴출전까진',
#   '1',
#   '87',
#   '66',
#   datetime.datetime(2020, 1, 24, 16, 1),
#   0],
#  ['퍼스트모바일(firs****)',
#   '와진심 개노잼 역대급 졸림  감독은 무엇을 말하고싶은건가',
#   '1',
#   '88',
#   '67',
#   datetime.datetime(2020, 1, 24, 13, 42),
#   0],
#  ['Root(forh****)',
#   '난 재미없던데...알바생 넘 많네',
#   '1',
#   '90',
#   '69',
#   datetime.datetime(2020, 1, 24, 15, 17),
#   0],
#  ['모험가(ligh****)',
#   '좌파 선동 영화. 우리나라 정서엔 딱맞음. 국민들이 개돼지니까 계속 선동당하지.',
#   '1',
#   '125',
#   '104',
#   datetime.datetime(2020, 1, 24, 20, 11),
#   0],
#  ['버그디테일링(dbgo****)',
#   '노잼 그냥 빨갱이영화..',
#   '1',
#   '134',
#   '113',
#   datetime.datetime(2020, 1, 24, 12, 0),
#   0],
#  ['콜드워터(limp****)',
#   '젊은 20대들이 이 영화를 보고 나름 뭐가 뭔지 판단할수 있는 능력이  있다고 분명 생각한다.. 모든게 오픈된 세상.. 충격도 있지만 진실도 그만큼 드러나기에..  개인적으로 박통의 연기는 최악중에 최악이다.',
#   '1',
#   '135',
#   '114',
#   datetime.datetime(2020, 1, 24, 2, 50),
#   0],
#  ['손본좌(pink****)',
#   '9명의 간첩을 잡았지만 1명의 억울한 좌파시민이 피해봄으로 아직도 욕먹고있는 사건',
#   '1',
#   '136',
#   '115',
#   datetime.datetime(2020, 1, 24, 15, 50),
#   0],
#  ['소굼떠(arir****)',
#   '빨갛게빨갛게 물든영화이걸보고 감동을느끼면 정신에 문제가있는거',
#   '1',
#   '141',
#   '120',
#   datetime.datetime(2020, 1, 24, 15, 43),
#   0],
#  ['프리리맘(moli****)',
#   '좌빨영화 공산주의로 가자고 선동하는 영화~무개념으로 보지말자! 판도라보고 탈원전한다는 대통을 둔 우리나라다 ㅉㅉ',
#   '2',
#   '161',
#   '140',
#   datetime.datetime(2020, 1, 24, 1, 44),
#   0],
#  ['오렌지(hski****)',
#   '이병헌연기는 잘하지만 좌파선거용 홍보물 같네요 영화내용과 반대라고 보면 됩니다.현실도 좌파는 비리천국이고 검찰개혁이라고 떠들면서 독재하고 위헌하고 막가파정치하면서 말만 포장하는 좌파들 김정숙지인5천억특혜, 문현동금도...',
#   '2',
#   '164',
#   '143',
#   datetime.datetime(2020, 1, 24, 12, 1),
#   0],
#  ['백조사냥(swan****)',
#   '역대급으로 노잼..진부한 스토리를 지루하게하는데 일급였음..차라리 그냥 드라마를  한편 보길 권함..졔작비 어디에 쓴거임..인생에 남을 영화.',
#   '1',
#   '166',
#   '145',
#   datetime.datetime(2020, 1, 24, 1, 1),
#   0],
#  ['선도부(ksue****)',
#   '님북한 체재 경쟁에서 완패한 김씨북조선에서 아주 좋아할 영화',
#   '1',
#   '167',
#   '146',
#   datetime.datetime(2020, 1, 24, 15, 44),
#   0],
#  ['j275****',
#   '평점보고 보러갔다가 후회하고 나옴.',
#   '4',
#   '167',
#   '146',
#   datetime.datetime(2020, 1, 24, 3, 28),
#   0],
#  ['YY(khen****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '8',
#   '168',
#   '147',
#   datetime.datetime(2020, 1, 23, 21, 1),
#   '관람객'],
#  ['dlak****',
#   '대깨문들 신났네ㅋㅋㅋ그저 웃고갑니다ㅋㅋ대깨문들 힘내세요! 화이팅 ^^',
#   '2',
#   '169',
#   '148',
#   datetime.datetime(2020, 1, 24, 15, 50),
#   0],
#  ['뭉개는개(hoki****)',
#   '남산의 졸음쉼터 자다가 깨어날까 두려웠다',
#   '1',
#   '172',
#   '151',
#   datetime.datetime(2020, 1, 23, 3, 2),
#   0],
#  ['냐옹냐옹(jbc4****)',
#   '개돼지들은 이걸또..',
#   '1',
#   '181',
#   '160',
#   datetime.datetime(2020, 1, 24, 9, 5),
#   0],
#  ['parkh(hy77****)',
#   '너무너무 재미 없네요... 최악...  스토리도 연기력도...',
#   '1',
#   '181',
#   '160',
#   datetime.datetime(2020, 1, 24, 3, 17),
#   0],
#  ['사짜인생슈킹(dukm****)',
#   '정치영화..김재규를 무슨 영웅처럼 묘사.',
#   '1',
#   '204',
#   '183',
#   datetime.datetime(2020, 1, 24, 1, 10),
#   0],
#  ['평론가(mnbv****)',
#   '총선전에 이런 정치색 짙은 영화가 설날에 나온다고?의도가뻔히보이내ㅎㅎㅎ 독재자는 맞을지언정 날조는 하지말자 ㅋㅋㅋㅋ나중에 조국이랑 민주당의 실체도 영화내라 날조하지말고 잇는그대로ㅋㅋㄱ',
#   '1',
#   '205',
#   '184',
#   datetime.datetime(2020, 1, 25, 12, 42),
#   0],
#  ['안녕(base****)',
#   '역사왜곡 끝판대장 영화네요..  살인범미화영화라니..  카악~~퉤',
#   '1',
#   '208',
#   '187',
#   datetime.datetime(2020, 1, 24, 2, 47),
#   0],
#  ['중요한건(ljmn****)',
#   '광고질 그렇게 하고 평점조작 그렇게 해도 이징도면 보지 말라는 얘기',
#   '1',
#   '231',
#   '210',
#   datetime.datetime(2020, 1, 23, 12, 40),
#   0],
#  ['this****',
#   '박정희를 폄하하기 위해 만든 영화 일 뿐.',
#   '2',
#   '251',
#   '230',
#   datetime.datetime(2020, 1, 24, 9, 35),
#   0],
#  ['칼슘왕(calc****)',
#   '음... 너무 정치적이야.',
#   '1',
#   '44',
#   '24',
#   datetime.datetime(2020, 1, 28, 1, 18),
#   0],
#  ['김타크(kth3****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '8',
#   '45',
#   '25',
#   datetime.datetime(2020, 1, 26, 13, 47),
#   0],
#  ['로그(thel****)',
#   '10 26 이라는 실제 있었던 사건을 어찌 풀어 갈까?전에 한번 흥행에 실패한 영화도 있었는데 라고 생각 했었는데..너무 재미있고, 연기를 너무 잘하는 배우들이 극 전체를 탄탄하게이끌어 간다.실제 사건과 인물들을 배...',
#   '10',
#   '85',
#   '65',
#   datetime.datetime(2020, 1, 23, 15, 56),
#   '관람객'],
#  ['꿀꾸리(cgch****)',
#   '오랜만에 스트레스 없이 본 영화',
#   '10',
#   '96',
#   '76',
#   datetime.datetime(2020, 1, 24, 23, 9),
#   0],
#  ['9183****',
#   '배우들 연기는 좋았는데 내용은 지루했어요',
#   '6',
#   '127',
#   '107',
#   datetime.datetime(2020, 1, 27, 21, 30),
#   '관람객'],
#  ['casa****',
#   '역사나 제대로 알고 영화만듭시다..이건 뭐 그냥 재앙이한테 자기좀 봐달라고 만든 영화 ㅋㅋ',
#   '1',
#   '465',
#   '445',
#   datetime.datetime(2020, 1, 23, 12, 52),
#   0],
#  ['Kimnohyun(iwil****)',
#   '정치적의도가 보여 불편',
#   '2',
#   '52',
#   '33',
#   datetime.datetime(2020, 1, 26, 0, 18),
#   0],
#  ['asd4****',
#   '잘한 부분은 하나도 안나오고 돈 권력에 미친놈으로 묘사하네 ㅉㅉ 미친놈은 지금 따로있는데',
#   '1',
#   '56',
#   '37',
#   datetime.datetime(2020, 1, 25, 13, 53),
#   0],
#  ['유(2bec****)',
#   '역사왜곡을 해놓고 역사왜곡을 하지 않았다는 이병헌과 제작진들 ㅋㅋ 얼탱이가 없음',
#   '1',
#   '56',
#   '37',
#   datetime.datetime(2020, 1, 25, 13, 2),
#   0],
#  ['양초롱(as64****)',
#   '박사모들이 다 봤으면..특히 부산 박사모 꼭 보길ㅋㅋ각하가 부산을 탱크로 밀어버리려고했단걸 보길 ㅋ탕탕!!!',
#   '10',
#   '44',
#   '26',
#   datetime.datetime(2020, 1, 31, 8, 54),
#   '관람객'],
#  ['조규순(gold****)',
#   '10점 많길래 봤는데 뭔가요?? 낚였나요.ㅠㅠ',
#   '1',
#   '49',
#   '31',
#   datetime.datetime(2020, 1, 25, 23, 52),
#   0],
#  ['직업이부자(taka****)',
#   '전지적 빨갱이 소설 시점.',
#   '1',
#   '53',
#   '35',
#   datetime.datetime(2020, 1, 25, 19, 3),
#   0],
#  ['nare****',
#   '와.. 30분 자다 나왔네...;; 진짜 재미없고 돈아깝다',
#   '1',
#   '54',
#   '36',
#   datetime.datetime(2020, 1, 24, 20, 0),
#   0],
#  ['asi1****',
#   '진짜 마지막에 순간순간이 소름이였다.',
#   '10',
#   '162',
#   '144',
#   datetime.datetime(2020, 1, 22, 23, 3),
#   '관람객'],
#  ['bin2****',
#   '여당이 좋아하겠네 ㅋㅋ',
#   '6',
#   '523',
#   '505',
#   datetime.datetime(2020, 1, 25, 0, 56),
#   '관람객'],
#  ['행복하기(okan****)',
#   '뭐냐? 이런 영화. 왜? 쯧.',
#   '1',
#   '48',
#   '31',
#   datetime.datetime(2020, 1, 25, 18, 23),
#   0],
#  ['갓블레스(gmhe****)',
#   '이것만은  알아 둬라 박정희 아니었으면 니들은 이런 영화를 하하호호 하면서 보지도 못했음',
#   '1',
#   '49',
#   '32',
#   datetime.datetime(2020, 2, 1, 6, 16),
#   0],
#  ['호크(clwa****)',
#   '별점테러한 일베놈들 ㅋㅋㅋ별소리다하면서 감독까지 욕하는 ㅋㅋㅋㅋ그러면서 내부자들은 다 봤을듯 ㅎㅎㅎㅎ',
#   '10',
#   '74',
#   '57',
#   datetime.datetime(2020, 1, 28, 0, 13),
#   '관람객'],
#  ['흑설(chys****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '33',
#   '17',
#   datetime.datetime(2020, 1, 23, 20, 15),
#   0],
#  ['강아지(shfm****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '37',
#   '21',
#   datetime.datetime(2020, 1, 23, 13, 26),
#   0],
#  ['북마크(lydf****)',
#   '기대하고 봤는데 그때그사람들 보다는 많이 아쉽네요 살해동기를 강조하고싶었던것 같은데 그것도 좀 어설프고',
#   '6',
#   '43',
#   '27',
#   datetime.datetime(2020, 1, 24, 1, 5),
#   0],
#  ['사생아제조기날강도(ebdc****)',
#   '이병헌 연기는 진짜 최고다 근데 연출이 별로인건지 스토리가 별로인건지 노잼이다 영화끝나고 나가는관객들 다 그냥 그러네 이병헌 연기 최고네만 들림',
#   '1',
#   '55',
#   '39',
#   datetime.datetime(2020, 1, 24, 19, 43),
#   0],
#  ['후히후하(hjoo****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '19',
#   '4',
#   datetime.datetime(2020, 1, 26, 21, 24),
#   0],
#  ['illy(prit****)',
#   '이런것도 감독이라 불러줘야되나하... 세상 바뀌면 어쩌려고ㅋ',
#   '1',
#   '31',
#   '16',
#   datetime.datetime(2020, 1, 28, 1, 56),
#   0],
#  ['mote****',
#   '진짜 아까운 인재가 죽었다고 생각했음',
#   '10',
#   '32',
#   '17',
#   datetime.datetime(2020, 2, 2, 0, 12),
#   '관람객'],
#  ['꼼지락(jun2****)',
#   '아는내용인 영화지만 연기자들의 극중연기가 빛난영화네요  마지막 김재규 부장의 육성에 너무 먹먹해지는 영화였어요',
#   '10',
#   '45',
#   '30',
#   datetime.datetime(2020, 1, 27, 14, 2),
#   '관람객'],
#  ['Eva(wjyh****)',
#   '총선을 위한 영화인가ㅋㅋㅋㅋ',
#   '1',
#   '50',
#   '35',
#   datetime.datetime(2020, 1, 25, 14, 22),
#   0],
#  ['완벽(stor****)',
#   '연기력은 좋았으나 중간에 조금 지루한 느낌이 들었네요.',
#   '6',
#   '57',
#   '42',
#   datetime.datetime(2020, 1, 29, 20, 16),
#   '관람객'],
#  ['멋진싸나이(soob****)',
#   '아 진짜 조온나 재미없네요ㅜㅜ연휴 첫날 진짜 실망하고 나옴 ㅜㅜ히트맨이랑 연속으로 두편 봤는데 뭘 볼지 고민한다면 차라리 히트맨 보세요ㅜㅜ남산의부장들 너무 지루합니다',
#   '2',
#   '57',
#   '42',
#   datetime.datetime(2020, 1, 24, 5, 58),
#   0],
#  ['이채영(abc2****)',
#   '이병헌님... 그냥 ..최고예요....',
#   '10',
#   '95',
#   '80',
#   datetime.datetime(2020, 1, 23, 1, 22),
#   '관람객'],
#  ['Toy GaGa(toyg****)',
#   '지나치게 단편적으로 좌편향된 영화를 만들지 맙시다. 연기는 너무 좋음...',
#   '1',
#   '29',
#   '15',
#   datetime.datetime(2020, 2, 15, 0, 59),
#   0],
#  ['1487****',
#   '전형적 좌파 이념 선동영화',
#   '1',
#   '34',
#   '20',
#   datetime.datetime(2020, 1, 27, 21, 39),
#   0],
#  ['크크(surv****)',
#   '정치편향영화. 현 시점에만 나올 수 있는 영화',
#   '1',
#   '40',
#   '26',
#   datetime.datetime(2020, 1, 25, 23, 7),
#   0],
#  ['gotl****',
#   '실화바탕으로 했으면 픽션이라도 어느정도는 역사성이 있어야 하는데 이건뭐 그냥 감독이 소설을 썼네 ㅋㅋㅋ 어느 대통령이나 잘한점도 있고 못한점도 있는 법입니다. 지금 문재인 대통령도 그렇고요 근데 이영화는 너무 박정희...',
#   '1',
#   '41',
#   '27',
#   datetime.datetime(2020, 1, 28, 14, 7),
#   0],
#  ['pitj****',
#   '인물중심의 영화 철저하게 김재규중심으로의 영화초반에 재미없어서 지루하려고했으나스토리전개가  조금은 엉성한듯했다 난 그닥 ..뻔했다',
#   '6',
#   '48',
#   '34',
#   datetime.datetime(2020, 1, 23, 17, 52),
#   0],
#  ['헬멧써(terr****)',
#   '전장군, 일루 와바 ~ 빨리빨리~ 예~ 알겠습니다~~ㅋㅋ',
#   '8',
#   '52',
#   '38',
#   datetime.datetime(2020, 1, 24, 22, 48),
#   0],
#  ['Maniac(bbqz****)',
#   '연기만 좋았습니다. MBC에서 제작한 다큐멘터리 토시하나 다르지않고 그대로 배우들이 연기한거같네요~ 연기만 보기엔 좋았습니다.  내용은 다큐보시는게 더 좋을듯 합니다.',
#   '4',
#   '62',
#   '48',
#   datetime.datetime(2020, 1, 29, 0, 6),
#   '관람객'],
#  ['포비(whit****)',
#   '연기 미쟝센은 훌륭했으나 이 시점에 왜 이런영화가 나온건지..영화자체는 감동은 없었고 끝나자 관객석  조용~',
#   '6',
#   '208',
#   '194',
#   datetime.datetime(2020, 1, 22, 16, 34),
#   '관람객'],
#  ['도방(star****)',
#   '안중근 의사가 침략자 이토 히로부미를 사살한 날 1909년 10월 26일. 김재규 의사가 독재자 박정희를 처단한 날 1979년 10월 26일. 평행이론 소름.',
#   '10',
#   '1304',
#   '1290',
#   datetime.datetime(2020, 1, 22, 14, 37),
#   0],
#  ['포션(song****)',
#   '댓글 보니까 아직 정신 못차린 사람들 많내 ㅋ',
#   '9',
#   '16',
#   '3',
#   datetime.datetime(2020, 4, 24, 16, 20),
#   0],
#  ['이현규(ingk****)',
#   '아니 진짜 박정희 개 씨1발로무 독재자 새1기를 감싸고 도는 틀딱새기들 진짜 존11나 한심스럽네 독재가 아니라고? 유신헌법으로 장기집권하고 OOO이나 해 쳐먹었으면 그게 독재지 아니면 뭐냐? 제발 틀니 딱딱 새1끼들...',
#   '10',
#   '18',
#   '5',
#   datetime.datetime(2020, 4, 24, 22, 53),
#   0],
#  ['에드워즈(ldhl****)',
#   '다까끼 마사오 헤드샷 좋았구요. 전대가리 수준을 잘 보여주었습니다ㅎㅎ 작품도 좋고 이병헌 연기 기가 막힙니다.',
#   '10',
#   '20',
#   '7',
#   datetime.datetime(2020, 2, 21, 17, 9),
#   0],
#  ['조작돌아이즈원해체(jjin****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '21',
#   '8',
#   datetime.datetime(2020, 1, 27, 2, 40),
#   0],
#  ['초록물고기(nwin****)',
#   '영화를 정치에 이용하지 맙시다',
#   '1',
#   '36',
#   '23',
#   datetime.datetime(2020, 1, 27, 16, 45),
#   0],
#  ['콧날(siwo****)',
#   '암살이후 정치인들과 보수언론이 선거에 이기기 위해 철저히 포장하고 미화시킨 인물. 아직도 우리가 잘 살게된게 그사람 하나 때문이라고 믿는사람들이 있다는게 놀랍다.',
#   '9',
#   '55',
#   '42',
#   datetime.datetime(2020, 1, 26, 22, 46),
#   '관람객'],
#  ['뽐윤(yes7****)',
#   '픽션은 있지만  그 누구도 미화시키지 않은 ..정말  ㅈㄷㅎ ㄱ ㅐ  ㅅ  ㅐ',
#   '10',
#   '56',
#   '43',
#   datetime.datetime(2020, 1, 24, 23, 14),
#   0],
#  ['샤샤샷(zozo****)',
#   '영화 끝까지 몰입해서 잘 봤습니다 사실적으로 잘 표현한듯',
#   '10',
#   '83',
#   '70',
#   datetime.datetime(2020, 1, 24, 12, 17),
#   '관람객'],
#  ['맹고스틴(jym5****)',
#   '보다가그냥 나왔어여..',
#   '4',
#   '99',
#   '86',
#   datetime.datetime(2020, 1, 29, 16, 39),
#   '관람객'],
#  ['무명(syeh****)',
#   '김부장 감정이 전달이되면서 ..너무 안타까웠다.',
#   '10',
#   '117',
#   '104',
#   datetime.datetime(2020, 1, 23, 13, 55),
#   0],
#  ['robi****',
#   '보여주려 하는것만 보여주려는 영화',
#   '1',
#   '492',
#   '479',
#   datetime.datetime(2020, 1, 23, 16, 28),
#   '관람객'],
#  ['xodn****',
#   '연기력빼고 그닥재미없는듯함',
#   '2',
#   '673',
#   '660',
#   datetime.datetime(2020, 1, 24, 7, 55),
#   '관람객'],
#  ['jhem****',
#   '정치색이 아주 짙은영화',
#   '6',
#   '851',
#   '838',
#   datetime.datetime(2020, 1, 24, 1, 35),
#   '관람객'],
#  ['몬드걸(qqkr****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '27',
#   '15',
#   datetime.datetime(2020, 1, 27, 12, 45),
#   0],
#  ['이동일(sols****)',
#   '스토리가 물흐르듯 흘러가지 않고, 끊기는 듯하고 대한민국 국민이 다 아는 내용에 작가 혹은 감독의 주관이 개입된 재미를 느끼지 못한 영화입니다.',
#   '1',
#   '19',
#   '8',
#   datetime.datetime(2020, 1, 26, 22, 30),
#   0],
#  ['엘리(lsa1****)',
#   '별 한 개도 아까운 역사 왜곡 망작',
#   '1',
#   '20',
#   '9',
#   datetime.datetime(2020, 2, 7, 8, 7),
#   0],
#  ['news****',
#   '거지 같은 영화, 개념 없는 영화',
#   '1',
#   '26',
#   '15',
#   datetime.datetime(2020, 1, 26, 20, 35),
#   0],
#  ['vinc****',
#   '너무 재미없네요. 너도 나도 쥐침. 영화관이 여관되었어요..~~',
#   '1',
#   '26',
#   '15',
#   datetime.datetime(2020, 1, 24, 22, 31),
#   0],
#  ['hee(heeb****)',
#   'ㅋ 역사왜곡의 종점을 찍어버림이걸 보고 우리가 세뇌당할거같음?하는 꼬라지 개 한심함 진짜 ㅋ',
#   '1',
#   '27',
#   '16',
#   datetime.datetime(2020, 1, 28, 3, 27),
#   0],
#  ['효쿠(gytj****)',
#   '캐스팅 연기는 정말 화려하고 좋다 하지만 국가적 근대화 영웅의 암살을 미화 하는듯 하는 스토리전개는 보기 거북했다',
#   '1',
#   '29',
#   '18',
#   datetime.datetime(2020, 2, 1, 3, 5),
#   0],
#  ['신류정아수림(dduk****)',
#   '죽은대통령이 좌파였으면 반응 분명 정반대',
#   '1',
#   '30',
#   '19',
#   datetime.datetime(2020, 1, 26, 13, 9),
#   0],
#  ['예니(dmsd****)',
#   '정치적 편견을 가지지 않고 있어 정치적 색을 가진 영화를 원래도 좋아하지도 않지만... 박정희 대통령의 잘한 점은 쏙 빼고 이상한 식으로 타도하는 영화같아 참 보기 불편하고 계획성이 다분한 영화네요;; 이 영화 본 ...',
#   '1',
#   '31',
#   '20',
#   datetime.datetime(2020, 2, 1, 2, 13),
#   0],
#  ['겜블러(anto****)',
#   '좌파들이 열광하는 김재규를 열사로 만들어 놨음..김재규는 대통령을 시해한 범죄자이다.',
#   '1',
#   '33',
#   '22',
#   datetime.datetime(2020, 1, 29, 2, 12),
#   0],
#  ['dlgk****',
#   '영화를 보기 전에 영화의 수준을 알고 싶으면 평점말고 관람평을 봐라. 영화의 이야기보단 배우의 연기에 대한 이야기가 많으면 그 영화는 걸러도 무방하다. 겁캅스 관람평도 배우들의 연기력 얘기 밖에 없더라 ㅋ',
#   '1',
#   '33',
#   '22',
#   datetime.datetime(2020, 1, 27, 20, 36),
#   0],
#  ['엠앤디교육(mand****)',
#   '정치를 하면서 예술이라 사기치는 영화',
#   '1',
#   '33',
#   '22',
#   datetime.datetime(2020, 1, 25, 22, 56),
#   0],
#  ['rbbw****',
#   '임자 마음대로 해~ 임자 옆에 내가 있잖아',
#   '10',
#   '33',
#   '22',
#   datetime.datetime(2020, 1, 24, 23, 7),
#   0],
#  ['사학의명문(ktw7****)',
#   '딱 총선철에 나올만한 영화',
#   '1',
#   '34',
#   '23',
#   datetime.datetime(2020, 1, 27, 21, 44),
#   0],
#  ['dbgm****',
#   '제발이런쓰레기영화를만들지않았으면좋겠다..역사를다룬영화에장난치지말고양심에반성해라.',
#   '1',
#   '34',
#   '23',
#   datetime.datetime(2020, 1, 27, 20, 26),
#   0],
#  ['심지원(tlag****)',
#   '배우들의 연기는 너무휼륭하나  너무나 한쪽으로만 치우친 영화같아.   공감이 안가네요',
#   '1',
#   '36',
#   '25',
#   datetime.datetime(2020, 1, 27, 22, 15),
#   0],
#  ['Tong(webs****)',
#   '배충이들이 별점 테러한다는 소식에  좋은 영화라 생각되었는데 정말 재밌고 유익하게 본것 같습니다.',
#   '10',
#   '36',
#   '25',
#   datetime.datetime(2020, 1, 24, 23, 1),
#   0],
#  ['레이븐정(jemi****)',
#   '졸라 재미없네, 지금 보는중인데 다들 하품하고 난리네...SBS 그것이 알고싶다가 더 재미 있는듯',
#   '2',
#   '38',
#   '27',
#   datetime.datetime(2020, 1, 25, 21, 10),
#   0],
#  ['ekek(ahn4****)',
#   '배우들의 연기력덕분에 영화에 푹빠져서 봤습니다. 연출도 긴장감 넘치고 그때의 긴박한 상황을 오롯이 다 느낄 수 있었습니다.',
#   '10',
#   '70',
#   '59',
#   datetime.datetime(2020, 1, 24, 16, 40),
#   '관람객'],
#  ['진광희(jing****)',
#   '이병헌 연기 빼곤 음~~~잘자고 갑니다~~',
#   '2',
#   '100',
#   '89',
#   datetime.datetime(2020, 1, 31, 9, 48),
#   '관람객'],
#  ['공감능력제로(qndb****)',
#   '솔직히 기대했던 것보다 재미는 없어요',
#   '6',
#   '119',
#   '108',
#   datetime.datetime(2020, 1, 29, 16, 30),
#   '관람객'],
#  ['백마국자(kjh9****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '123',
#   '112',
#   datetime.datetime(2020, 1, 25, 21, 0),
#   '관람객'],
#  ['왕별아빠(gabb****)',
#   '이병헌 대체불가 배우.전두한 욕나옴',
#   '10',
#   '128',
#   '117',
#   datetime.datetime(2020, 1, 22, 23, 57),
#   0],
#  ['urieeeeee(kche****)',
#   '연기에 치인다 bbb 안보면 후회할뻔!!!',
#   '10',
#   '259',
#   '248',
#   datetime.datetime(2020, 1, 22, 10, 11),
#   '관람객'],
#  ['아름다운(cool****)',
#   '그렇게 이룬 이나라 지금은 나아졌나? 사업자들 힘들게 하고 공무원 먹여 살리고있는 나라. 투표 잘합시다.',
#   '6',
#   '467',
#   '456',
#   datetime.datetime(2020, 1, 25, 19, 20),
#   '관람객'],
#  ['아베베룸(nost****)',
#   '만일 김재규가 박정희를 죽이지 않았다면 이 나라가 어떻게 됐을까. 부산 사람들은 다 죽었겠네.  생각도 하기 싫다. 근데 부산은 왜 아직도 박근혜 박근혜 하는거지? 여전히 자한당 한나라당 새누리당 미통당을 지지하고?...',
#   '10',
#   '14',
#   '4',
#   datetime.datetime(2020, 4, 24, 22, 48),
#   0],
#  ['brki****',
#   '배우들 연기는 좋지만... 아쉬움이 많음.',
#   '2',
#   '14',
#   '4',
#   datetime.datetime(2020, 1, 25, 23, 4),
#   0],
#  ['신준혁(tlsw****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '15',
#   '5',
#   datetime.datetime(2020, 2, 21, 13, 32),
#   '관람객'],
#  ['yasu****',
#   '백두산과똑같이 노잼영화..',
#   '1',
#   '18',
#   '8',
#   datetime.datetime(2020, 1, 27, 20, 56),
#   0],
#  ['앨리스(xhxm****)',
#   '아니 해도해도 너무 재미없었다. 정치 영화인줄은 알고 있었는데 생각보다 더 정치 영화에다 연기말고는 볼 게 없었던 영화. 왜 이게 평점 이렇게 높은지 모르겠다. 진심 안보고 좋은 댓글 쓰는거 다 알바같음;;;',
#   '1',
#   '18',
#   '8',
#   datetime.datetime(2020, 1, 26, 22, 5),
#   0],
#  ['mdge****',
#   '평가를 보아하니 역시나 사람들은 이 영화를 팩트라고 믿고 있네요. 상상으로 내용을 만들고 영화 앞뒤엔 역사적인 사실을 소개하면 무지한 관객들은 영화의 내용과 분위기가 사실인 것으로 인지해버리죠. 악의적인 영화는 맞습...',
#   '4',
#   '19',
#   '9',
#   datetime.datetime(2020, 2, 1, 8, 53),
#   0],
#  ['우림(wjsd****)',
#   '연기는 솔직히 전부 다 잘하십니다. 하지만 정장입은사람 여럿이 둘러앉아 정치, 사회 얘기하는 거 지루해 하시는 분들은 이 영화 비추천합니다. 상영시간 내내 이런 장면이 95%입니다. 제 케이스를 말씀드리자면 웬만한 ...',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 28, 23, 15),
#   0],
#  ['잠 못드는밤(rlag****)',
#   '이성민과 이병헌의 연기 대단했습니다',
#   '4',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 28, 22, 47),
#   '관람객'],
#  ['아이유(hikk****)',
#   '한국의 미디어에 미러링 밖에 할줄 모리는 개돼지들을 보며 무릎을 탁치고 갑니다',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 28, 0, 57),
#   0],
#  ['이은솔(les9****)',
#   '이병헌의 연기력은 좋다. 그러나 좋은 연출이 있어야 배우가 빛이 날 수 있다는 것을 보여주는 영화. 지루하고 개연성이 없으며 이해가 전혀 가지 않는 스토리.',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 28, 0, 51),
#   0],
#  ['qwfklkd(shin****)',
#   '지루하디 지루하다 좋은 배우들로 재미없게 만듬 알바에 속지마라',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 28, 0, 36),
#   0],
#  ['둥희(eye0****)',
#   '별로.. 지루.합니다.',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 27, 21, 0),
#   0],
#  ['살구복숭아(kwon****)',
#   '시간+돈 다 아까워... 아오ㅡㅡ',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 26, 23, 23),
#   0],
#  ['샥크(dhh8****)',
#   '나만 재미없었나보네..',
#   '2',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 26, 23, 21),
#   0],
#  ['wind(tkwl****)',
#   '별로 기대안하고 봤는데 기대이하 였다보통 한국영화는 돈아까운 경우가 많은데 이번엔 시간도 아까웠다.',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 26, 20, 43),
#   0],
#  ['황금마차(goga****)',
#   '무엇보다도 지루했음. 장소 변경 없이 항상 비슷한 배경 나중에는 졸리더라 ;;',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 26, 11, 8),
#   0],
#  ['진솔(qewr****)',
#   '영화보면서 깊게 잔적이 없었는데 오늘 꿀잠자고 나왔네연 ㅎ',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 26, 2, 24),
#   0],
#  ['리버스(been****)',
#   '음..  반복되는 얘기들 개인적인 해석그냥 그래요',
#   '1',
#   '19',
#   '9',
#   datetime.datetime(2020, 1, 25, 21, 0),
#   0],
#  ['susu****',
#   '문재앙 정권의 개노릇을 위한 선거용 영화. 우한폐렴으로 BEP도 못넘길듯 자업자득!!!',
#   '1',
#   '20',
#   '10',
#   datetime.datetime(2020, 2, 7, 15, 30),
#   0],
#  ['손혁수(tech****)',
#   '박정희의 업적은 무시하고 나쁜것만 그린영화 사람에 대한 영화를 만들때는 단편적인 모습보다 전체를 봐야 하지 않나 생각함. 영화 변호인을 대통령 퇴직 후 시계뇌물받고 이후 자살할때까지 인물들의 심리갈등만으로 영화를 만...',
#   '1',
#   '20',
#   '10',
# ...
#   0],
#  ['psyp****',
#   '20% 의 상상력으로 박 전 대통령을 쓰레기로만들고 김스나이퍼를 정당화시킨 영화. 여당이 밀어줬겠네... 김재규는 핵을 개발하려던 것을 저지하기위해 미국이 사주했다는 의혹은 쏙 빼놓네 ㅋㅋㅋ 박정희가 100만을 죽인...',
#   '1',
#   '15',
#   '10',
#   datetime.datetime(2020, 1, 29, 21, 23),
#   0],
#  ['레오파(davi****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '6',
#   '15',
#   '10',
#   datetime.datetime(2020, 1, 27, 22, 45),
#   0],
#  ['온(hrsn****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '1',
#   '15',
#   '10',
#   datetime.datetime(2020, 1, 26, 6, 5),
#   0],
#  ['빙초산(sunl****)',
#   '제목부터가 좌빨 선동영화 믿고거릅니다',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 2, 18, 1, 33),
#   0],
#  ['sjho****',
#   '연출에 새로운게 보이지않음, 정치색이 이렇고저렇고를떠나 지루함,객관적으로 극도로 한쪽으로 정치편향적임ㅡ내부자들은 원작이좋아  어쩌다걸려듬, 마약왕에서 기본 연출실력뽀록남, 순제작비가 170억 이라는데  돈은 어디에 ...',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 2, 8, 0, 15),
#   0],
#  ['hyk5****',
#   '영화관에서 처음으로 잤다',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 2, 4, 14, 26),
#   0],
#  ['3731****',
#   '덜도말고 더도말고 딱 마약왕 느낌이었음이런 영화는 이제 끝물인듯',
#   '4',
#   '16',
#   '11',
#   datetime.datetime(2020, 2, 3, 15, 57),
#   '관람객'],
#  ['맑은서울(leei****)',
#   '재미없다 핵 노잼 이런 실화영화 그만 만들자 너무 지루함 돈 아까웠음 한 시간 넘게 다 잠',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 28, 14, 38),
#   0],
#  ['쫑아(hajs****)',
#   '그냥 박정희 까는 영화.. 표정 이상하게 무작정 까댐, 그리고 박정희 없었으면 지금 이렇게 잘살고 편안하게 폰도 못하고 있는데..ㅋㅋ  총선 가까워지니까 라는 합리적 의심이 들고 한국 망치고있는 대깨문들이 좋아할 영...',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 28, 10, 12),
#   0],
#  ['킨슬러(yomm****)',
#   '좌파배우 총집합. 믿고 거릅니다^^',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 28, 7, 49),
#   0],
#  ['LKH(star****)',
#   '총선용영화, 더불어공산당이 싫다',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 28, 4, 54),
#   0],
#  ['삼성가을야구가즈아(isab****)',
#   '영화가 주고자 하는 바가 뭔가요 ? 기승전결이 없는 영화에요 ㅋㅋ',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 26, 23, 43),
#   0],
#  ['하나와이어(hiat****)',
#   '마약왕보다  더  지루했네요',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 26, 8, 19),
#   0],
#  ['날도(7885****)',
#   '정치색만 있는 너무 재미없는 영화이 출연진을 가지고 영화를 이렇게 밖에 못만들다니 안타깝네요',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 26, 1, 27),
#   0],
#  ['사막여우(se7e****)',
#   '믿고 거르는 배우 한 명 추가',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 26, 0, 56),
#   0],
#  ['suhy****',
#   '노잼노잼 돈주고 보기 아까웠습니다',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 25, 22, 33),
#   0],
#  ['hsri****',
#   '이건 뭐 정치적으로 총선을 준비해주는 영화인 듯 대단함 이 정권은 정치 경제 사회 문화 외교 안보 다 참담한데 영화도 자신의 쪽 아니면 연예계에서도 활동할 수 없는 참 대단하네 김재규가 민주화의 투사인가? 경제대통령...',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 25, 17, 59),
#   0],
#  ['sung****',
#   '가치도 없음~~~~.',
#   '1',
#   '16',
#   '11',
#   datetime.datetime(2020, 1, 25, 16, 35),
#   0],
#  ['라이더(soon****)',
#   '쓰벅...역대 최악의 영화...내가 극장에서 잔건 이번이 최초다...그리고 이런 정치적 색깔의 영화가 지금 시기에 나왔다? 닝기...국민들은 바보가 아니다..',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 2, 12, 15, 14),
#   0],
#  ['정후우우우(ljh0****)',
#   '배우들의 연기는 상당히 좋으나 편파적인 내용으로 구성된점에서 감독이 대가리가 없단걸 알게해주는 영화',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 2, 4, 22, 51),
#   0],
#  ['CH(jch9****)',
#   '솔직히 요즘 세대들은 박정희 암살 되었다는것만 알고 내용은 잘 모를수 있는데 박정희가 경제를 살린것도 맞고 독재를 한 것도 맞다 근데 영화가 너무 한쪽 성향으로 치우쳐져 있네요 김재규가 박정희를 죽인 이유는 아무도 ...',
#   '4',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 30, 7, 42),
#   0],
#  ['듀랑고(kore****)',
#   '우리나라 연기자는 황정민 마동석 이병헌 밖에 없나요?? 이셋은 맨날 나와서 영화가 다 그영화 같음..',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 29, 9, 1),
#   0],
#  ['좌탈지순(sozz****)',
#   '기본 팩트를 놓고 해석을 달리하는 건 모르겠는데... 이건 ...',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 29, 3, 50),
#   0],
#  ['12345(alwa****)',
#   '허접하고 흔한 역사왜곡영화. 박정희는 위대한 영웅인게 맞음, 전교조 교사들이 학생들을 잘못된 세뇌교육해서 애들이 오해하고 있는것 뿐임.',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 27, 22, 27),
#   0],
#  ['Sna(noah****)',
#   '1점도 아까운 개 빨갱이 영화 김일성 이세끼랑 박정희 대통령이랑 비교하고 현재 대한민국과 북한을 비교해봐라 진보라는 탈을 쓴 거짓 북한 세습 꼴통들이 나라를 깎아 먹으려 안달이겠지만 니들 돈 벌어서 이런 영화도 만들...',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 27, 0, 8),
#   0],
#  ['쫀뜩(juns****)',
#   '영화의 성역화? 평점을 낮게주면 일베가되는 이상한 현실 ㅋㅋ 국내영화의 한계를 여실히 보여줌',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 26, 18, 30),
#   0],
#  ['FCBayernMunich(gmla****)',
#   '문주당 전형적인 선거전 선동영화 그 이상 그 이허도 아님 ㅇㅇ',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 26, 17, 12),
#   0],
#  ['떠올라(qorq****)',
#   '좌파눈치에 편협한연출!! 암살자를 미화한 3류영화라고 보기 역겨워서 그냥 나와버렷다',
#   '2',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 26, 0, 22),
#   0],
#  ['hyunpro(sjdn****)',
#   '진짜 요즘본 영화중최악. 역사왜곡도왜고이지만  드럽게지루하디ㅡ. 코믹요소는단1도없고.  긴장감도 없다. 예전 비슷한영화 그때그사람들에 비해서도 확연히 떨어짐. 돈 진짜개아깝다.위에평점은 좌파것들이 조작한거같다. 실제...',
#   '2',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 26, 0, 19),
#   0],
#  ['exvs****',
#   '박정희가 79년에 죽었어 그럼 박정희를 기억하려면 최소 고등학생은 되야 되는데 그러면 minium 60살은 되야지 ㅋ ㅈ만한것들이 이성민 연기가 박통 판박이네 소름이네 뭐네 하는건 ㅈㄴ 개드립 평점 주작질이지...',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 25, 23, 42),
#   0],
#  ['zzzk****',
#   '최악의 영화ㄹㅇ로 킬타용도 안되는',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 25, 22, 41),
#   0],
#  ['홍발(ghdr****)',
#   '희대의 쓰레기같은 영화',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 25, 21, 37),
#   0],
#  ['현태(jell****)',
#   '이 영화 왼쪽이에요... ㅠㅠ',
#   '1',
#   '17',
#   '12',
#   datetime.datetime(2020, 1, 25, 13, 58),
#   0],
#  ['Valhalla9(valh****)',
#   '좌파들의 역사왜곡. 지금 문재앙 정권에 김재규 같은 사람이 필요하다',
#   '1',
#   '18',
#   '13',
#   datetime.datetime(2020, 2, 13, 22, 23),
#   0],
#  ['저녁이(wjsu****)',
#   '각색이란 창작은 드러나지 않은 진실에 대해서만 이뤄져야한다. 역사적으로 확인된 인물관계마저  왜곡한다면 그건 사실이 아닌 거짓이다.',
#   '1',
#   '18',
#   '13',
#   datetime.datetime(2020, 2, 4, 3, 41),
#   0],
#  ['yooi****',
#   '전형적인 좌빨영화... 한심하다',
#   '1',
#   '18',
#   '13',
#   datetime.datetime(2020, 2, 3, 0, 29),
#   0],
#  ['좋아해너희들을(dudt****)',
#   '토나온다.역사왜곡도 적당히 해라.영화로 왜곡된 역사인식 심는거 언제까지 할래 이 미친것들아.',
#   '1',
#   '18',
#   '13',
#   datetime.datetime(2020, 1, 25, 19, 11),
#   0],
#  ['호돌이(assh****)',
#   '좌파쓰레기영화 ㅉㅉ 북한 욕하는 영화는 절대 안만들죠?',
#   '1',
#   '18',
#   '13',
#   datetime.datetime(2020, 1, 25, 18, 27),
#   0],
#  ['파피용(gunf****)',
#   '야 이제 영화평점도 바이럴마케팅을 하네. 내 인생 최고의 한국영화라굽쑈? 워 너무 지루해서 중간에 잤네요. 이거 곧 풀릴꺼 같습니다. 조금만 참고 기다리셨다 집에서 킬링타임용으로 보는건 자유~지만. 그 시간에 다른 ...',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 28, 23, 47),
#   0],
#  ['호이(kayb****)',
#   '근대사왜곡영화. 드라마와 영화로 역사를 배우는 개돼지들을 위한 선동예술',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 28, 15, 44),
#   0],
#  ['룰루랄라(jskw****)',
#   '영화로선 좋았지만 박통 까고 김재규 치켜세우는 좌측 시각에서 만든 영화를 그대로 믿어버릴까 싶어서 걱정임',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 27, 23, 17),
#   0],
#  ['다람쥐똥꼬털(jsxl****)',
#   '김재규 미화하고 박정희대통령 흠집내는 그지같은영화',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 27, 21, 24),
#   0],
#  ['천사옐(1oo4****)',
#   '내 인생 최악의 영화 . . .',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 26, 19, 7),
#   0],
#  ['루란루란(ranr****)',
#   '평점에 연기력 얘기만 있는것=댓글알바들도 내용이 쓰레기인건 알아서 양심껏 주작중',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 25, 19, 28),
#   0],
#  ['bobod(ryus****)',
#   '아무리 픽션이라도 역사왜곡은 아니지',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 25, 19, 14),
#   0],
#  ['from(from****)',
#   '김재규 미화하는 영화가 다 나오네 ㅉ 아무리 영화라도 지켜야 할 선은 있는 것',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 25, 18, 23),
#   0],
#  ['도연아빠(jjan****)',
#   '재밌다고 봤는데 완전 쓰레기 영화네요.. 와이프도 대 실맘!! 정치색이 너무강하네요..선거전인데.. 왜 우리나라는 대통령의 잘한점을 부각시키고 국민을 통합하지 못하고 분열시키는 영화를 만드는지 이해 못하겠음..',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 25, 16, 30),
#   0],
#  ['루피(lhw3****)',
#   '이병헌 연기는 좋았는데 좀 과장이 들어간듯,,, 김재규가 실제로는 욱하는 성격이 강하고 돈과 권력욕이 많아서 유신때도 앞잡이였는데 영웅으로 나오네',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 25, 14, 58),
#   0],
#  ['신태용 스피치학원(jino****)',
#   'OOO기 좌빨 영화 진짜 신물난다',
#   '1',
#   '19',
#   '14',
#   datetime.datetime(2020, 1, 25, 12, 55),
#   0],
#  ['ㅇㅇㅇ(djsd****)',
#   '정치색이 너무 짙은 영화. 예매율 왜 1윈 줄 모르겠고 돈 아까움엄청난 좌파 영화임 그냥 박정희 까는 영화ㅇㅇ총선 앞두고 이 시기에 푸는 이유가 뭘까.자유 민주주의를 외친다며 결국 자기들은 공산당과 다름 없다는거. ...',
#   '1',
#   '20',
#   '15',
#   datetime.datetime(2020, 1, 26, 3, 40),
#   0],
#  ['강주혁(airk****)',
#   '그냥그냥 그렇네요 태큭기 휘날리며 1번 더 보는게 재밌음',
#   '4',
#   '21',
#   '16',
#   datetime.datetime(2020, 2, 1, 6, 32),
#   '관람객'],
#  ['재미와감동(limt****)',
#   '연기는 다들좋았지만, 솔직히 지루했음... 다 아는 내용이라그런가? 김재규를 미화한듯한 느낌도 거부감이 드는것도 사실이고;',
#   '5',
#   '21',
#   '16',
#   datetime.datetime(2020, 1, 27, 14, 24),
#   '관람객'],
#  ['날아봐용(minj****)',
#   '????지루함....',
#   '1',
#   '21',
#   '16',
#   datetime.datetime(2020, 1, 24, 12, 37),
#   0],
#  ['김정현(jg_1****)',
#   "걍 총선용 영화.. 지금 정부는 '자유민주주의국가'에서 '자유'를 없애려 하고있음. 검찰 팔다리 자르고 공무원들 자기들 하수인 만들고 국민을 바보로 만들려고한다. 국민들을 좌우로 나누고 ...",
#   '1',
#   '22',
#   '17',
#   datetime.datetime(2020, 1, 25, 11, 45),
#   0],
#  ['posi****',
#   '아무리 그래도 역대 대통령중에는 박정희대통령이 가장 업적이 많다',
#   '1',
#   '23',
#   '18',
#   datetime.datetime(2020, 1, 31, 12, 50),
#   0],
#  ['다둥맘(beti****)',
#   '지루함',
#   '4',
#   '25',
#   '20',
#   datetime.datetime(2020, 2, 2, 15, 13),
#   '관람객'],
#  ['세돌맘(eunj****)',
#   '이병헌 이성민 연기가 정말 좋았어요',
#   '8',
#   '26',
#   '21',
#   datetime.datetime(2020, 1, 25, 22, 11),
#   '관람객'],
#  ['사띠팬(mkus****)',
#   '좌파영화는 날조가 꼭 들어간다. 변호인의 고문장면은 날조된건데 고문장면 없었으면 무맛 영화였을거임, 택시운전사였는지 화려한 외출이었는지에선 시민군이 애국가부르는데 시민을 조준사격한걸로 나오는데 이거도 날조임. 시민군...',
#   '1',
#   '35',
#   '30',
#   datetime.datetime(2020, 1, 23, 20, 47),
#   0],
#  ['YSlover(lhk9****)',
#   '이병헌 연기는 믿고본다 하더라도..감정연출이 정말 소름끼칠정도로 감명깊게 시청했습니다!',
#   '10',
#   '37',
#   '32',
#   datetime.datetime(2020, 1, 26, 18, 22),
#   '관람객'],
#  ['하은(clev****)',
#   '그냥 이병헌이 이병헌 했다배우들 연기력만으로도 눈이 호강 했던 시간이었다다시 한번 더 보러 갈 예정',
#   '10',
#   '41',
#   '36',
#   datetime.datetime(2020, 1, 23, 1, 45),
#   0],
#  ['임마누엘 헤어샵(kyj2****)',
#   '긴장감도없고 스릴도없고 색다른 시각으로 바라봤음 좋았을걸 뻔한내용에 지루했음ㅠㅠ',
#   '4',
#   '46',
#   '41',
#   datetime.datetime(2020, 1, 28, 13, 30),
#   '관람객'],
#  ['ILDH(eogk****)',
#   '연기만잘함 나머진 모르겠음',
#   '4',
#   '57',
#   '52',
#   datetime.datetime(2020, 1, 26, 10, 30),
#   '관람객'],
#  ['홍길동(lore****)',
#   '연출자의 정치 편향을 대놓고 노출하고 있는 영화.',
#   '4',
#   '87',
#   '82',
#   datetime.datetime(2020, 1, 31, 23, 31),
#   '관람객'],
#  ['이재근(ssfi****)',
#   '배우가 연기는 좋은데 총선 앞두고 저런 영화를 내는것이 과연옳을까?      어린학생들이 저런 정치적색깔이 있는 영화보면 무슨 생각을 할까요?',
#   '1',
#   '183',
#   '178',
#   datetime.datetime(2020, 1, 23, 22, 29),
#   '관람객'],
#  ['Whity(yjbg****)',
#   '이병헌 연기의 또다른 정점.',
#   '9',
#   '4',
#   '0',
#   datetime.datetime(2020, 7, 24, 12, 30),
#   0],
#  ['IDEALE(yile****)',
#   '누구나 아는 역사적인 사건을 왜 굳이 가명을 쓴건지 모르겠습니다 물론 이 영화에서 나온 이야기들이100% 사실로  확인된것들은 아니지만 그게 가명을 써야할 이유까진 못되지 않나요?',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 6, 15, 2, 59),
#   0],
#  ['안달루시아(reda****)',
#   '정의의 혁명가인가 탐욕의 살인자인가, 판단은 후대 역사의 몫.',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 2, 22, 23, 35),
#   0],
#  ['허은경(coco****)',
#   '연기는 뭐 말할수없이 좋은데너무재미없어요진짜좋아하는 시대극이고 이사건에대해 관심도많아서 일부러 찾아서 본건데이전영화들이 밀정은 너무재밌었고 천문은 너무 재미없어서 고민했는데 이건 천문만큼 재미없어요이병헌 연기때문에 ...',
#   '6',
#   '4',
#   '0',
#   datetime.datetime(2020, 1, 28, 11, 7),
#   0],
#  ['광일(xcao****)',
#   '아!!! 빡빡이~ 죽쒀서 빡빡이줬어~~ ㅠㅠㅠ',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 5, 20, 18, 50),
#   0],
#  ['yuni****',
#   '사실적인 표현력과 스토리.하나하나 그냥봐서는 안될거같은 영화',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 5, 15, 15, 9),
#   0],
#  ['랄라스(lsh8****)',
#   '역사에 만약이라는 것은 존재할수 없지만  김재규가 마지막 남산으로 갔으면 전두환은 없었을텐데',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 5, 3, 15, 37),
#   0],
#  ['꽝우(lknm****)',
#   '정치성향 싹 걷어내고 연기파배우들의 향연으로 무게감있는 영화였습니다',
#   '8',
#   '5',
#   '1',
#   datetime.datetime(2020, 5, 3, 3, 16),
#   0],
#  ['Alice(obel****)',
#   '흔들리는 눈 빛의 연기... 실존인물에 대한 해석 추천합니다.',
#   '9',
#   '5',
#   '1',
#   datetime.datetime(2020, 5, 2, 18, 58),
#   0],
#  ['유한결(hky0****)',
#   '이런 영화가 많이 나와야합니다 감사합니다',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 30, 21, 47),
#   0],
#  ['ljk8****',
#   '뻥안치고 열번정도봄 심심할때마다연기들 배우 구멍이 없다',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 27, 23, 51),
#   0],
#  ['김나영(kore****)',
#   '이런 영화가 요즘 세상에 나올 수 있다는 것만으로도...@.@...',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 26, 1, 0),
#   0],
#  ['설팩(next****)',
#   '시대를 어느정도 겪어본 한국남자로서는  기생충보다 더  나은 작품이라  말할수 있다',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 26, 0, 39),
#   0],
#  ['그리피스(fate****)',
#   '배우들의 연기력 긴장감으로 몰입해서봤네요역사적 팩트는 한사람의 유신 장기집권을 끝낸것, 부마사태로 인해 수많은사람들이 희생될것을 막아준것은 명백한사실 그래서 지금의 민주주의 상황이 더빨리오지 않았나 싶네요',
#   '8',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 25, 19, 40),
#   0],
#  ['멍뭉(auth****)',
#   '연기, 연출 모두 감동적이었지만 음악이 정말.. 정말 최고예요. 청문회 신부터, 이 영화 극장에서 보길 잘했다는 생각이 들었습니다.',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 25, 16, 19),
#   0],
#  ['HOBIJ(dnwl****)',
#   '정말 잘만든 역사를 다시 조명한 영화입니다진실이 무엇인지 그 당시의 상황과 함께 잘 만들어진 영화입니다강추 입니다. 이병헌 외에도 많은 분들의 연기력에 시간 가는줄 모르고 보게되었어요',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 25, 15, 32),
#   0],
#  ['위대한돼지(lee5****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 25, 6, 25),
#   0],
#  ['주한아빠(binn****)',
#   '',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 23, 15, 52),
#   0],
#  ['icandoit(k2ma****)',
#   '이병헌이 김재규가 빙의한 듯한 떨림의 전율 최고다',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 22, 0, 57),
#   0],
#  ['method(leem****)',
#   '긴장감 대박. 연기 정말 잘함.',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 22, 0, 53),
#   0],
#  ['먹보담(habi****)',
#   '넷플릭스에 떠서 이제 봤는데 기대 이상..',
#   '9',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 21, 14, 36),
#   0],
#  ['yebb****',
#   '처음부터 끝까지 몰입해서 보게되는 영화',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 19, 23, 56),
#   0],
#  ['새우(taew****)',
#   '연기, 연출 미쳤다.. 진짜 같아서 몰입된다',
#   '8',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 15, 17, 8),
#   0],
#  ['내일이면(yg13****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '5',
#   '1',
#   datetime.datetime(2020, 4, 11, 0, 18),
#   0],
#  ['케빈(cs06****)',
#   '이병헌은 항상 영화 초이스를 잘 하는 것 같다...연기도 좋았음',
#   '8',
#   '5',
#   '1',
#   datetime.datetime(2020, 2, 23, 16, 11),
#   0],
#  ['리스트(nakk****)',
#   '연기보는 맛에 봤음 ㅋ 영화로서 내용은 그닥 .. 다큐로 나왔으면 오히려 나았을지도',
#   '4',
#   '5',
#   '1',
#   datetime.datetime(2020, 1, 26, 21, 30),
#   0],
#  ['zpfp****',
#   '연기는 잘하는데 음... 졸ㄹ려요',
#   '6',
#   '5',
#   '1',
#   datetime.datetime(2020, 1, 26, 20, 30),
#   0],
#  ['잘하자아(ydh3****)',
#   '끝까기 지혼자 다 해 처먹을라 카는 늙은이들.. 송장냄새 풍기지 말고 이제 그만 내려놔라. 밥숫갈 곱게 놓고싶으면...',
#   '8',
#   '6',
#   '2',
#   datetime.datetime(2020, 5, 23, 18, 17),
#   0],
#  ['Arise(tmdd****)',
#   '와 진짜..  실제 그 사건을 배경으로 하니까 저는 한국 현대사에 관심이 많아서 재밌게 봤습니다. 무엇보다 김재규 미화하나 싶었는데 그렇지 않았고 그냥 김재규의 모습을 다룬 느낌 이병헌 씨의 연기력 그중에 표정 연기...',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 5, 17, 22, 14),
#   0],
#  ['dnvkd92(dnvk****)',
#   '연기야 당연히 좋았고, 장면 장면 분위기를 더욱 살리는 음악이 너무 훌륭했음. 압도적인 영화.',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 5, 6, 5, 37),
#   0],
#  ['홍시폭죽(tw_7****)',
#   '사실여부를 떠나 스토리가 흥미진진하여 시선을떼기가 힘들었습니다.  사람들이 이병헌 이병헌 하는 이유가 있네요. 연기에 무척 감탄했습니다.',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 5, 5, 20, 48),
#   0],
#  ['Jerry(munj****)',
#   '긴장감 넘치는 연출과 배우들 연기력 덕분에 재미있게 봤습니다.  잘 알지 못했던 역사적 지식도 얻어갑니다. 역사인물 김재규를 다시 평가하게 되네요.',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 5, 3, 21, 13),
#   0],
#  ['asd(jugo****)',
#   '이병헌의 연기는 진짜 최고다... 인간이 느낄 수 있는 모든 감정선을 보여준게 아닌가 생각한다.. 1,2점 애새끼들은 영화 절대 안본거거나 골빈 일베들이다 ㅋㅋ 지금이라도 봐서 다행이다',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 5, 2, 2, 5),
#   0],
#  ['페리오힐튼(zkzk****)',
#   '그는 이병헌인 동시에 김재규였다.',
#   '9',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 30, 8, 12),
#   0],
#  ['형욱(kevi****)',
#   '연기력 대박 + 남초 사이트 일베한테 일침 세게 날리는 영화 ㅋㅋㅋ 개인적으로 1987이랑 같이 좋아하는 영화임',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 29, 22, 37),
#   0],
#  ['자룡(gojc****)',
#   '영화는 이병현의 연기만으로도 재미나다 허나 6.25전쟁후 가난과 굶주림에 죽어가는 국가와 국민을 지금의 나라로 만든 위인이다.  역사를 바꾸려고 하지 말라.',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 26, 18, 18),
#   0],
#  ['펑키타트렁크(orcs****)',
#   '역사에 들어간 느낌! 연기를 다들 너무 잘합니다.',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 24, 16, 13),
#   0],
#  ['진단서(aege****)',
#   '누군가에게는 깊은 공감과 감동을.누군가에게는 깊은 슬픔과 분노를.',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 22, 22, 44),
#   0],
#  ['동현준(pand****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 22, 19, 51),
#   0],
#  ['루돌프(arro****)',
#   '보통 실화를 바탕으로한 역사 영화는 "의미"만 내세울 뿐 영화적인 재미가 많이 부족해서 별로였는데, 이번에 남산의 부장들은 정말 의미도 있고, 재미도 있는 최고의 영화인 것 같다. 이정도로 잔잔한 영화...',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 22, 11, 24),
#   0],
#  ['다신고합니노(hodi****)',
#   '이건 정치색 떠나서 꼭 끝까지 다 보셈 ㄹㅇ 내가 말한대로 끝까지 봐야 이 영화는 진짜 개재밌음 ㅋㅋ',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 22, 6, 54),
#   0],
#  ['자니뎁뎁(nama****)',
#   '먹먹하다.너무 잘봤습니다.',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 4, 22, 3, 37),
#   0],
#  ['jhkj****',
#   '연기력도 뛰어나고 몰입감 짱이에요',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2020, 3, 1, 11, 44),
#   0],
#  ['jack****',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '3',
#   '6',
#   '2',
#   datetime.datetime(2020, 2, 28, 11, 37),
#   0],
#  ['송완주(nowa****)',
#   '권력자들의 복합적인 내면을 잘 표현한 영화. 배우들의 연기가 압도적!',
#   '9',
#   '6',
#   '2',
#   datetime.datetime(2020, 2, 23, 15, 47),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                          0  ...    6
# 0                 erlo****  ...  관람객
# 1            빛그림(namj****)  ...  관람객
# 2              쩡(jeon****)  ...  관람객
# 3      Joonseosa(myeo****)  ...  관람객
# 4            ㅎㅎㅎ(eorm****)  ...  관람객
# ...                    ...  ...  ...
# 17825         부자(hook****)  ...    0
# 17826      하남매둔둔(stan****)  ...    0
# 17827       니벨륭겐(sykm****)  ...    0
# 17828     달콤한시련이(agri****)  ...    0
# 17829     헤드브레이커(yytt****)  ...    0
#
# [17830 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                   nickname  ... watch_movie
# 0                 erlo****  ...         관람객
# 1            빛그림(namj****)  ...         관람객
# 2              쩡(jeon****)  ...         관람객
# 3      Joonseosa(myeo****)  ...         관람객
# 4            ㅎㅎㅎ(eorm****)  ...         관람객
# ...                    ...  ...         ...
# 17825         부자(hook****)  ...           0
# 17826      하남매둔둔(stan****)  ...           0
# 17827       니벨륭겐(sykm****)  ...           0
# 17828     달콤한시련이(agri****)  ...           0
# 17829     헤드브레이커(yytt****)  ...           0
#
# [17830 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
